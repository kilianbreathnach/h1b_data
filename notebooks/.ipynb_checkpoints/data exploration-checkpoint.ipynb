# %%
import string
import numpy as np
import pandas as pd
# import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# grab the h1b data
h1b = pd.read_csv("../dat/db246968-e567-442f-8108-b86a280107d3_H-1BVisaApplications-2014.csv")

# %%
# let's see all the columns
h1b.columns
# Out:
# Index(['lca_case_number', 'status', 'lca_case_submit', 'decision_date',
#        'visa_class', 'lca_case_employment_start_date',
#        'lca_case_employment_end_date', 'lca_case_employer_name',
#        'lca_case_employer_address', 'lca_case_employer_city',
#        'lca_case_employer_state', 'lca_case_employer_postal_code',
#        'lca_case_soc_code', 'lca_case_soc_name', 'lca_case_job_title',
#        'lca_case_wage_rate_from', 'lca_case_wage_rate_to',
#        'lca_case_wage_rate_unit', 'full_time_pos', 'total_workers',
#        'lca_case_workloc1_city', 'lca_case_workloc1_state', 'pw_1',
#        'pw_unit_1', 'pw_source_1', 'other_wage_source_1', 'yr_source_pub_1',
#        'lca_case_workloc2_city', 'lca_case_workloc2_state', 'pw_2',
#        'pw_unit_2', 'pw_source_2', 'other_wage_source_2', 'yr_source_pub_2',
#        'lca_case_naics_code'],
#       dtype='object')

# %%
corr = h1b.corr()
sns.heatmap(corr, cmap=plt.get_cmap("viridis"),
            xticklabels=corr.columns,
            yticklabels=corr.columns)

# Not many numeric values so far

# %%
# case numbers are unique
print(h1b.lca_case_number.nunique())
print(h1b.shape)
# Out:
# 519504
# (519504, 35)

# %%
h1b.full_time_pos.unique()
h1b.fillna(0).groupby("full_time_pos").size()
# Out:
# full_time_pos
# 0         5
# N     14213
# Y    505286
# dtype: int64

# %%
# How many industries are there?
h1b.lca_case_naics_code.nunique()
# Out:
# 2792

# %%
# let's see the top employers
employergroup = h1b.groupby("lca_case_employer_name").size().reset_index(name= "employer_count")
employergroup[employergroup["employer_count"] > 5].sort_values("employer_count", ascending=False)
# Out:
#                                   lca_case_employer_name  employer_count
# 29258                                    INFOSYS LIMITED           23759
# 58511                  TATA CONSULTANCY SERVICES LIMITED           14098
# 66842                                      WIPRO LIMITED            8365
# 16455                            DELOITTE CONSULTING LLP            7017
# 943                                        ACCENTURE LLP            5498
# 28200                          IBM INDIA PRIVATE LIMITED            5029
# 26474                                  HCL AMERICA, INC.            4749
# 20098                             ERNST & YOUNG U.S. LLP            3961
# 34368                   LARSEN & TOUBRO INFOTECH LIMITED            3939
# 38949                              MICROSOFT CORPORATION            3750
# 28466                            IGATE TECHNOLOGIES INC.            3124
# 24828                                        GOOGLE INC.            2951
# 29858                                  INTEL CORPORATION            2506
# 28195                                    IBM CORPORATION            2457
# 13169    COGNIZANT TECHNOLOGY SOLUTIONS U.S. CORPORATION            2358
# 58694                     TECH MAHINDRA (AMERICAS), INC.            1932
# 16450                              DELOITTE & TOUCHE LLP            1628
# 3261                                AMAZON CORPORATE LLC            1596
# 4607                                          APPLE INC.            1458
# 32185                               JPMORGAN CHASE & CO.            1444
# 48542                        QUALCOMM TECHNOLOGIES, INC.            1417
# 63986                                     UST GLOBAL INC            1360
# 43042                                     NTT DATA, INC.            1238
# 10424               CAPGEMINI FINANCIAL SERVICES USA INC            1187
# 58692                     TECH MAHINDRA ( AMERICAS), INC            1104
# 44284                               ORACLE AMERICA, INC.            1072
# 15304                                       CUMMINS INC.            1005
# 37433    MASTECH, INC., A MASTECH HOLDINGS, INC. COMPANY             966
# 40231                                MPHASIS CORPORATION             946
# 39281                                   MINDTREE LIMITED             933
# ...                                                  ...             ...
# 60941                              THERAPY EXPERTS, INC.               6
# 50587                         RK TECHNICAL SERVICES, INC               6
# 60928  THERADYNAMICS PHYSICAL THERAPY REHABILITATION ...               6
# 60916                                     THEMESOFT INC.               6
# 50615                                    RMM GLOBAL, INC               6
# 50621                  RN EXPRESS STAFFING REGISTRY, LLC               6
# 50224                                  RGM ADVISORS, LLC               6
# 4524            APOGEE MEDICAL GROUP, SOUTH CAROLINA, PC               6
# 32743                               KBR TECHNOLOGIES,INC               6
# 50220                            RGA REINSURANCE COMPANY               6
# 50014                            RESONATE NETWORKS, INC.               6
# 20889                       F+P ARCHITECTS NEW YORK INC.               6
# 61305                         TIPPING POINT CREATIVE LLC               6
# 4500                           APOGEE MEDICAL GROUP, INC               6
# 20911                                     FABERGENT INC.               6
# 32821                                   KELLWOOD COMPANY               6
# 50054        RESPIRONICS, INC. (A PHILIPS OWNED COMPANY)               6
# 32795                           KEIO ACADEMY OF NEW YORK               6
# 61226                                     TIGERSPIKE INC               6
# 50069                          RESTORATION HARDWARE INC.               6
# 50084                                 RETAIL CONSULT LLC               6
# 12408                 CITCO FUND SERVICES (MALVERN) INC.               6
# 4511                APOGEE MEDICAL GROUP, NEW JERSEY, PA               6
# 24393                        GLOBAL TEL*LINK CORPORATION               6
# 20949             FACULTY PHYSICIANS & SURGEONS OF LLUSM               6
# 61163                 TI GROUP AUTOMOTIVE SYSTEMS L.L.C.               6
# 50153                               REVENUE ANLYTICS INC               6
# 61113                          THREE SIGMA SOFTWARE INC.               6
# 12389                            CIRRUS HOLDINGS USA LLC               6
# 9631                           BUNGE NORTH AMERICA, INC.               6
#
# [9705 rows x 2 columns]

# %%
# got a few extra states...
h1b.lca_case_employer_state.unique()
# Out:
# array(['TX', 'IN', 'MN', 'GA', 'VA', 'NJ', 'KS', 'KY', 'CA', 'IL', 'FL',
#        'MA', 'NY', 'MI', 'NE', 'AL', 'TN', 'WA', 'PA', 'IA', nan, 'MD',
#        'OR', 'CT', 'WI', 'CO', 'DC', 'OK', 'MO', 'OH', 'NC', 'DE', 'RI',
#        'AK', 'LA', 'AZ', 'NH', 'AR', 'HI', 'WY', 'SC', 'UT', 'WV', 'NM',
#        'ME', 'ID', 'MT', 'MS', 'NV', 'SD', 'ND', 'MP', 'VI', 'VT', 'GU',
#        'PR'], dtype=object)

# %%
h1b[h1b["lca_case_employer_state"] == "NY"].lca_case_employer_city.unique()

# Check it out, one of these is listed as San Francisco! Didn't know there was one in NY...
# Out:
# array(['NEW YORK', 'COLD SPRING HARBOR', 'ROCHESTER', 'STONY BROOK', 'RYE',
#        'CORNING', 'SYOSSET', 'BRONX', 'ORCHARD PARK', 'NEW YORK CITY',
#        'BUFFALO', 'ISLANDIA', 'HAUPPAUGE', 'MELVILLE', 'SHELTER ISLAND',
#        'VALHALLA', 'PAWLING', 'EAST HAMPTON', 'AMSTERDAM',
#        'LONG ISLAND CITY', 'SKANEATELSE FALLS', 'BROOKLYN', 'PURCHASE',
#        'SYRACUSE', 'NEW PALTZ', 'BINGHAMTON', 'FLUSHING', 'PEARL RIVER',
#        'FAIRPORT', 'ALBANY', 'MACEDON', 'SARATOGA SPRINGS', 'TROY',
#        'MILLBROOK', '39TH FLOOR', 'ORANGEBURG', 'WHITE PLAINS', 'EDGEWOOD',
#        'ROCK HILL', 'VICTOR', 'NORTH SALEM', 'GARDEN CITY', 'LATHAM',
#        'SCHENECTADY', 'CARMEL', 'UPTON', 'CLINTON', 'EAST AURORA',
#        'VOORHEESVILLE', 'BABYLON', 'CLARENCE', 'THORNWOOD', 'CENTEREACH',
#        'MINEOLA', 'MARGARETVILLE,', 'BREWSTER', 'MALTA', 'CAZENOVIA',
#        'SUITE 223', 'YONKERS', 'UNIONDALE', 'MANHASSET', 'BRONX, NEW YORK',
#        'FOREST HILLS', 'WATERTOWN', 'BRONXVILLE', 'BAYSIDE', 'NORWICH',
#        'AMHERST', 'LAWRENCE', 'NISKAYUNA', 'GRAND ISLAND', 'SENECA FALLS',
#        'JERICHO', 'BLAUVELT', 'EAST MEADOW', 'GENEVA', 'YAPHANK',
#        'TARRYTOWN', 'AIRMONT', 'GREAT NECK', 'HARRISON', 'LIVERPOOL',
#        'DOBBS FERRY', 'ELMIRA', 'ITHACA', 'RIVERDALE', 'WATERFORD',
#        'ARMONK', 'LIMA', 'PULASKI', 'ORISKANY', 'PORT CHESTER',
#        'RENSSELAER', 'NEW HAMPTON', 'GENESEO', 'BRIARWOOD', 'IRVINGTON',
#        'WILLIAMSVILLE', 'AURORA', 'HICKSVILLE', 'SILVER CREEK',
#        'VALLEY STREAM', 'NEW HYDE PARK', 'FUSHING', 'PALINVIEW', 'ASTORIA',
#        'POUGHKEEPSIE', 'EAST SYRACUSE', 'NEW ROCHELLE', 'ISELIN', 'NYACK',
#        'WESTBURY', 'LONG BEACH', 'SCARSDALE', 'HYDE PARK', 'WOODHAVEN',
#        'NEW YORK, NEW YORK', 'WOODSIDE', 'SOUTHOLD', 'BELLEROSE',
#        'EAST NORTHPORT', 'QUEENSBURY', 'AMITYVILLE', 'ALTAMONT', 'POTSDAM',
#        'OSSINING', 'LAKE SUCCESS', 'BOHEMIA', 'PLEASANTVILLE',
#        'EAST SETAUKET', 'FISHKILL', 'MENANDS', 'STATEN ISLAND', 'UTICA',
#        'PLAINVIEW', 'MASPETH', 'WOODMERE', 'OAKLAND GARDENS',
#        'ANNANDALE-ON-HUDSON', 'SUNNYSIDE', 'HORNELL', 'MAHOPAC', 'CONGERS',
#        'WOODBURY', 'JAMACIA', 'WEST BABYLON', 'RONKONKOMA', 'BROOKVILLE',
#        'BERGEN', 'GREAT RIVER', 'JAMAICA', 'MAMARONECK',
#        'YORKTOWN HEIGHTS', 'COMMACK', 'SEAFORD', 'LYNBROOK', 'DELHI',
#        'REGO PARK', 'HUNTINGTON', 'MT.KISCO', 'GLEN COVE', 'FORESTHILLS',
#        'MOUNT KISCO', 'GARDEN CITY PARK', 'ROCKVILLE CENTRE', 'MASSAPEQUA',
#        'CAMPBELL HALL', 'MT. VERNON', 'CORTLAND', 'RIDGEWOOD',
#        'COOPERSTOWN', 'TONAWANDA', 'ELMSFORD', 'ONEONTA', 'PITTSFORD',
#        'EASTCHESTER', 'NIAGARA FALLS', 'MOUNT VERNON', 'PORT WASHINGTON',
#        'CENTRAL ISLIP', 'HAWTHORNE', 'BETHPAGE', 'SUITE 350',
#        'COLLEGE POINT', 'OSWEGO', 'LITTLE NECK', 'HEMPSTEAD',
#        'SKANEATELES FALLS', 'CORTLANDT MANOR', 'MONTECILLO',
#        'ROCHDALE VILLAGE', 'CARLE PLACE', 'SELDEN', 'ROSLYN HEIGHTS',
#        'SPRINGFIELD GARDENS', 'NANUET', 'PELHAM', 'SAINT JAMES', 'CANTON',
#        'VALHALL', 'QUEENS', 'NORTH SYRACUSE', 'ELMHURST', 'DUNKIRK',
#        'BRIARCLIFF MANOR', 'BAY SHORE', 'PLATTSBURGH',
#        'HUNTINGTON STATION', 'ENDWELL', 'JOHNSON CITY', 'SHIRLEY',
#        'MEDIACOM PARK', 'NEW YORK, NY', 'LOUDONVILLE', 'CUBA',
#        'HASTINGS ON HUDSON', 'MONSEY', 'BAITING HOLLOW', 'HAMILTON',
#        'OAKDALE', 'LYNBROOK,', 'FREEPORT', 'VALLEY COTTAGE', 'MIDDLETOWN',
#        'FARMINGDALE', 'CHESTNUT RIDGE', 'SALT POINT', 'KEW GARDENS',
#        'EDISON', 'JACKSON HEIGHTS', 'QUEENS VILLAGE', 'ALFRED',
#        'CENTER MORICHES', 'FAR ROCKAWAY', 'GLOVERSVILLE', 'BATAVIA',
#        'DIX HILLS', 'SOUTH RICHMOND HILL', 'ALBERTSON', 'NY',
#        'EAST GREENBUSH', 'OLD WESTBURY', 'ROCKAWAY PARK', 'ELMA', 'ROSLYN',
#        'FOREST FILLS', 'GETZVILLE', 'GARNERVILLE', 'NEWARK',
#        'MIDDLE VILLAGE', 'KATONAH', 'BELLPORT', 'HOUGHTON',
#        'RICHMOND HILL', 'GREECE', 'ARVERNE', 'KINGSTON', 'YONKER',
#        'LANCASTER', 'HORSEHEADS', 'SUFFERN', 'SAUGERTIES', 'OGDENSBURG',
#        'FULTON', 'FLORAL PARK', 'FRESH MEADOWS', 'MOUNTAINVILLE',
#        'PALISADES', 'HENRIETTA', 'NEW YORK, NEW YORK 10003', 'WHITESTONE',
#        'RYE BROOK', 'LAURELTON', 'OLEAN', 'L.I.C.', 'WEBSTER', 'GLENDALE',
#        'NEWBURGH', 'NIAGARA UNIVERSITY', 'BALDWIN', 'MALONE', 'DEER PARK',
#        'BALLSTON LAKE', 'BELLMORE', 'HOWARD BEACH', 'FALCONER',
#        'WEST ISLIP', 'TARRY TOWN', 'RIVERHEAD', 'OZONE PARK',
#        'GLENS FALLS', 'BLOOMFIELD', '12TH FLOOR', 'HAMBURG', 'PHOENIX',
#        'LAGRANGEVILLE', '601 W. 26TH ST., SUITE 325-57',
#        'CITY OF NEW YORK', 'POMONA', 'LOCUST VALLEY', 'NEW CITY', 'WARSAW',
#        'HIGH FALLS', 'GLEN HEAD', 'HIGHLAND', 'CALVERTON',
#        'NEW YORK,NEW YORK', 'ROCKY POINT', 'BEDFORD HILLS', 'CHESTER',
#        'LAKE PLACID', 'UNION', 'SUITE 1100', 'CORONA', 'WEST HEMPSTEAD',
#        'BROCKPORT', 'INWOOD', 'SAG HARBOR', 'NEWYORK', 'LONGISLAND CITY',
#        'CLINTONDALE', 'OAKLAND GARDEN', 'CEDARHURST', 'ARDSLEY',
#        'LARCHMONT', 'RICHMONDVILLE', '20 AUGUSTA PL', 'BALTIMORE',
#        'KINGS PARK', 'YORK', 'CHAAPAQUA', 'CORONA, NY', 'GOSHEN',
#        'ISLIP TERRACE', 'WEST NYACK', 'WEST HENRIETTA', 'ROSEDALE',
#        'SMITHTOWN', 'TAPPAN', 'OYSTER BAY', 'JERSEY CITY', 'PLATTSBURG',
#        'TUCKAHOE', 'WEST HAMPTON BEACH', 'LAKEWOOD', 'COLD SPRING',
#        'WADING RIVER', 'CORFU', 'BRENTWOOD', 'MOUNT SINAI', 'WESBURY',
#        'ROME', 'BRIDGEHAMPTON', 'GREENVALE', 'SPENCERTOWN', 'ST. ALBANS',
#        'ISLIP', 'GLENMONT', 'MANHATTAN', 'CATSKILL', 'CLIFTON PARK',
#        'WACCABUC', 'MASSENA', 'CHAMPLAIN', 'CHEEKTOWAGA', 'GROTON',
#        'HOLBROOK', 'STAATSBURG', 'WILLIAMSBURGH', 'DEWITT', 'HURLEYVILLE',
#        'EAST BRUNSWICK', 'LIC', 'HARTSDALE', 'HOPEWELL JUNCTION',
#        'EAST ELMHURST', 'NORTH TONAWANDA', 'TUXEDO PARK', 'PEEKSKILL',
#        'HAMPTON BAYS', 'NEW WINDSOR', 'NEW YORK,', 'FORREST HILLS',
#        'OLD BETHPAGE', 'MONROE', 'ELMHIURST', 'SPRING VALLEY', 'ANGOLA',
#        'WEST SENECA', 'SOUTH HEMPSTEAD', 'FREDONIA', 'MIDDLEBURGH',
#        'ROOSEVELT', 'STATEN ISLAND,', 'EAST ISLIP', 'GREEN ISLAND',
#        'COHOES', 'HOLLIS', 'SALISBURY MILLS', 'NORTHVILLE', 'STONY POINT',
#        'ARDSLEY ON HUDSON', 'WILLISTON PARK', 'WESTCHESTER',
#        '65 VESTRY STREET', 'NEW YORKI', 'ELMONT', 'PLAIN VIEW',
#        'SKANEATELES', 'NEW YOK', 'MONTICELLO', 'LEWISTON', 'HARRIMAN',
#        'LANSING', 'FLORIDA', 'WATERVLIET', 'LITTLE NECK, NY', 'SOMERS',
#        'SANBORN', 'HAUPPAGE', 'PLAINVEIW', 'WAINSCOTT', 'HOLMES', 'TUXEDO',
#        'SLEEPY HOLLOW', 'FRANKLIN SQ', 'GREAT NECK,', 'LACKAWANNA',
#        'JAMESTOWN', 'CORNING TOWER, ROOM 2217', 'LINDENHURST',
#        'EAST MORICHES', 'CANANDAIGUA', 'PATCHOGUE', 'NORWALK',
#        'SAN FRANCISCO', 'MEDFORD', 'NEW HARTFORD', 'EAST MIDDLETOWN',
#        'GHENT', 'MALVERNE', 'RYE BROOKE', 'AUBURN', 'MT. KISCO',
#        'SOUTHAMPTON', 'COPIAGUE', 'NEW YROK', 'FREMONT', 'LOCKPORT',
#        'HEWLETT', 'BARDONIA', 'EAST AMHERST', 'FRANKLIN SQUARE', 'VESTAL',
#        'PALMYRA', 'BETHLEHEM', 'DUNDEE', 'LONG ISLAND CITY,',
#        'PETERSBURGH', 'SARANAC LAKE', 'CARTHAGE', 'MOUNT HERMON',
#        'GLEN COVER', 'CHAPPAQUA', 'EAST ROCKAWAY', 'MATTITUCK',
#        'OCEANSIDE', 'GUILDERLAND CENTER', 'SUGAR LOAF', 'FRAMINGDALE',
#        'SOUTH OZONE PARK', 'TICONDEROGA', 'ISELIP TERRACE',
#        'MASSAPEQUA PARK', 'FORT LEE', 'ORANGEBURGH', 'ELMURST',
#        '29TH FLOOR', 'SOUTH PLAINFIELD', 'CROTON-ON-HUDSON', 'RHINEBECK',
#        'HONEOYE FALLS', 'WHITE PLAINES', 'BRIGHTSWATERS', 'BAYSHORE',
#        'GREATNECK', 'PRINCETON', 'PIERMONT', 'FLUSHING, NY', 'LIBERTY',
#        'SCOTTSVILLE', 'ROCHESTER, NY 14618', 'EAST PATCHOGUE',
#        '31ST FLOOR', 'SHELTER ISLAND HEIGHTS', 'SPENCER', 'POUGHKEEPISE',
#        'HAUPPAGUE', 'OLD BROOKVILLE', 'SOUTH BRUNSWICK', 'LEVEL 9',
#        'WILLIAMSBURG, BROOKLYN', 'GARDINER', 'BEACON', 'NYC', 'MONTAUK',
#        'NEW YORK CIY', 'SALEM', 'BROOKLYM'], dtype=object)

# %%
# add an nyc column to include all companies within the boroughs
valid_nyc = ['NEW YORK', 'BRONX', 'NEW YORK CITY', 'LONG ISLAND CITY', 'BROOKLYN', 'FLUSHING',
             'BRONX, NEW YORK', 'FOREST HILLS', 'BAYSIDE',
             'FUSHING', 'ASTORIA', 'NEW YORK, NEW YORK', 'WOODSIDE', 'STATEN ISLAND', 'SUNNYSIDE', 'JAMACIA',
             'JAMAICA', 'FORESTHILLS', 'RIDGEWOOD', 'QUEENS', 'ELMHURST', 'NEW YORK, NY',
             'JACKSON HEIGHTS', 'QUEENS VILLAGE', 'FAR ROCKAWAY', 'ROCKAWAY PARK', 'FOREST FILLS',
             'FRESH MEADOWS', 'NEW YORK, NEW YORK 10003', 'WHITESTONE', 'L.I.C.', 'OZONE PARK',
             'CITY OF NEW YORK', 'NEW YORK,NEW YORK', 'NEWYORK', 'LONGISLAND CITY', 'MANHATTAN',
             'WILLIAMSBURGH', 'LIC', 'EAST ELMHURST', 'NEW YORK,', 'FORREST HILLS', 'STATEN ISLAND,',
             'NEW YORKI', 'NEW YOK', 'NEW YROK', 'LONG ISLAND CITY,', 'SOUTH OZONE PARK', 'ELMURST', 
             'FLUSHING, NY', 'WILLIAMSBURG, BROOKLYN', 'NYC', 'NEW YORK CIY', 'BROOKLYM']
h1b["nyc"] = np.zeros((h1b.shape[0]))
h1b.loc[h1b["lca_case_employer_city"].isin(valid_nyc), "nyc"] = 1

# %%
h1b[(h1b["lca_case_employer_city"] == "39TH FLOOR") | (h1b["lca_case_employer_city"] == 'SUITE 223') |
    (h1b["lca_case_employer_city"] == "LEVEL 9") | (h1b["lca_case_employer_city"] == "31ST FLOOR") | 
    (h1b["lca_case_employer_city"] == "29TH FLOOR") | (h1b["lca_case_employer_city"] == "65 VESTRY STREET") |
    (h1b["lca_case_employer_city"] == '20 AUGUSTA PL') | (h1b["lca_case_employer_city"] == '601 W. 26TH ST., SUITE 325-57') | 
    (h1b["lca_case_employer_city"] == '12TH FLOOR') | (h1b["lca_case_employer_city"] == 'SUITE 350')]
# Out:
#            lca_case_number               status lca_case_submit decision_date  \
# 7406    I-200-12073-027230            WITHDRAWN      2012-03-13    2014-09-12
# 14072   I-200-12348-605365  CERTIFIED-WITHDRAWN      2012-12-13    2014-04-09
# 55122   I-200-13306-238680            CERTIFIED      2013-11-02    2013-11-12
# 159569  I-200-14045-296644            CERTIFIED      2014-02-14    2014-02-21
# 160254  I-200-14045-564233            CERTIFIED      2014-02-14    2014-02-21
# 164272  I-200-14048-714901               DENIED      2014-02-17    2014-02-24
# 199407  I-200-14060-910446            CERTIFIED      2014-03-03    2014-03-07
# 301041  I-200-14079-534809            CERTIFIED      2014-03-21    2014-03-27
# 446532  I-200-14203-217797            CERTIFIED      2014-07-22    2014-07-28
# 493618  I-200-14252-193281            CERTIFIED      2014-09-09    2014-09-15
# 512072  I-203-13337-255466            CERTIFIED      2013-12-05    2013-12-11
# 512082  I-203-13337-428080            CERTIFIED      2013-12-05    2013-12-11
# 514727  I-203-14084-483473            CERTIFIED      2014-03-25    2014-03-31
#
#             visa_class lca_case_employment_start_date  \
# 7406              H-1B                     2012-04-01
# 14072             H-1B                     2013-01-07
# 55122             H-1B                     2013-11-02
# 159569            H-1B                     2014-08-14
# 160254            H-1B                     2014-08-14
# 164272            H-1B                     2014-06-16
# 199407            H-1B                     2014-03-24
# 301041            H-1B                     2014-09-01
# 446532            H-1B                     2014-08-11
# 493618            H-1B                     2014-09-22
# 512072  E-3 Australian                     2013-12-15
# 512082  E-3 Australian                     2013-12-15
# 514727  E-3 Australian                     2014-04-15
#
#        lca_case_employment_end_date  \
# 7406                     2015-04-01
# 14072                    2016-01-06
# 55122                    2016-09-30
# 159569                   2017-08-14
# 160254                   2017-08-14
# 164272                   2017-06-15
# 199407                   2017-03-23
# 301041                   2017-08-31
# 446532                   2017-08-10
# 493618                   2017-08-28
# 512072                   2015-12-14
# 512082                   2015-12-14
# 514727                   2016-04-15
#
#                            lca_case_employer_name  \
# 7406    ONE WILLIAM STREET CAPITAL MANAGEMENT, LP
# 14072       THE VERITAS HEALTHCARE SOLUTIONS, LLC
# 55122                    NOVISYNC SOLUTIONS, INC.
# 159569                             BIRCHBOX, INC.
# 160254                             BIRCHBOX, INC.
# 164272                        OPEN ASSEMBLY, INC.
# 199407                               ACCORD POWER
# 301041                       AVO CONSTRUCTION LLC
# 446532                      TRICADIA HOLDINGS, LP
# 493618                             GT NEXUS, INC.
# 512072                           READING ROOM INC
# 512082                           READING ROOM INC
# 514727                             BIRCHBOX, INC.
#
#                 lca_case_employer_address         lca_case_employer_city  \
# 7406          1271 AVENUE OF THE AMERICAS                     39TH FLOOR
# 14072             469, 7TH AVE, 3RD FLOOR                      SUITE 223
# 55122   300 WESTAGE BUSINESS CENTER DRIVE                      SUITE 350
# 159569                28 EAST 28TH STREET                     12TH FLOOR
# 160254                28 EAST 28TH STREET                     12TH FLOOR
# 164272      @CENTRE FOR SOCIAL INNOVATION  601 W. 26TH ST., SUITE 325-57
# 199407       135-27 38TH AVENUE,SUITE 119                  20 AUGUSTA PL
# 301041                                NaN               65 VESTRY STREET
# 446532                   780 THIRD AVENUE                     29TH FLOOR
# 493618                    55 WATER STREET                     31ST FLOOR
# 512072                  205 HUDSON STREET                        LEVEL 9
# 512082                  205 HUDSON STREET                        LEVEL 9
# 514727                28 EAST 28TH STREET                     12TH FLOOR
#
#                ...           \
# 7406           ...
# 14072          ...
# 55122          ...
# 159569         ...
# 160254         ...
# 164272         ...
# 199407         ...
# 301041         ...
# 446532         ...
# 493618         ...
# 512072         ...
# 512082         ...
# 514727         ...
#
#                                       other_wage_source_1 yr_source_pub_1  \
# 7406                              OFLC ONLINE DATA CENTER          2011.0
# 14072                             OFLC ONLINE DATA CENTER          2012.0
# 55122                             OFLC ONLINE DATA CENTER          2013.0
# 159569                            OFLC ONLINE DATA CENTER          2014.0
# 160254                            OFLC ONLINE DATA CENTER          2014.0
# 164272  FLC DATA CENTER, ONLINE WAGE LIBRARY: HTTP://W...          2014.0
# 199407                            OFLC ONLINE DATA CENTER          2014.0
# 301041                            OFLC ONLINE DATA CENTER          2013.0
# 446532                            OFLC ONLINE DATA CENTER          2014.0
# 493618                            OFLC ONLINE DATA CENTER          2014.0
# 512072                            OFLC ONLINE DATA CENTER          2013.0
# 512082                            OFLC ONLINE DATA CENTER          2013.0
# 514727                            OFLC ONLINE DATA CENTER          2014.0
#
#        lca_case_workloc2_city lca_case_workloc2_state pw_2  pw_unit_2  \
# 7406                      NaN                     NaN  NaN        NaN
# 14072                     NaN                     NaN  NaN        NaN
# 55122                     NaN                     NaN  NaN        NaN
# 159569                    NaN                     NaN  NaN        NaN
# 160254                    NaN                     NaN  NaN        NaN
# 164272                    NaN                     NaN  NaN        NaN
# 199407                    NaN                     NaN  NaN        NaN
# 301041                    NaN                     NaN  NaN        NaN
# 446532                    NaN                     NaN  NaN        NaN
# 493618                    NaN                     NaN  NaN        NaN
# 512072                    NaN                     NaN  NaN        NaN
# 512082                    NaN                     NaN  NaN        NaN
# 514727                    NaN                     NaN  NaN        NaN
#
#         pw_source_2 other_wage_source_2 yr_source_pub_2  lca_case_naics_code
# 7406            NaN                 NaN             NaN             523900.0
# 14072           NaN                 NaN             NaN             541720.0
# 55122           NaN                 NaN             NaN             541513.0
# 159569          NaN                 NaN             NaN               4539.0
# 160254          NaN                 NaN             NaN               4539.0
# 164272          NaN                 NaN             NaN               5112.0
# 199407          NaN                 NaN             NaN             238220.0
# 301041          NaN                 NaN             NaN             236220.0
# 446532          NaN                 NaN             NaN             523930.0
# 493618          NaN                 NaN             NaN             518210.0
# 512072          NaN                 NaN             NaN             519130.0
# 512082          NaN                 NaN             NaN             519130.0
# 514727          NaN                 NaN             NaN               4539.0
#
# [13 rows x 35 columns]

# %%
# definitely some issues with the zipcode data here - we've gotta find the unique zipcodes (5 digit)
# One of them just says "NEW YORK"...
h1b[h1b["lca_case_employer_state"] == "NY"].lca_case_employer_postal_code.unique()
# Some are only 4 digits long and some definitely are not new york zip codes...
# Out:
# array(['10004', '10019', '10022', '11724', '10017', '10024', '14623',
#        '10016', '10036', '11794-4433', '10580', '10282', '10012', '10005',
#        '10020', '10007', '14831', '10010-3629', '10001', '11794', '10166',
#        '10006', '11791', '10018', '10467', '14127', '14627', '10014',
#        '10121', '10032', '11794-8705', '10105', '11794-3393', '10003',
#        '14644', '14201', '10010', '10152', '11749', '11788', '10036-6796',
#        '14202', '10281-1198', '10011', '11747', '10153', '10013', '10112',
#        '10023', '10027', '10154', '11964', '10595', '10038', '12564',
#        '11937', '10158', '10122', '12010', '10281', '10173', '14604',
#        '11101', '13152', '11201-3949', '10285', '14605', '10104', '10577',
#        '14692-2970', '10178', '13202', '12561', '13904', '14608', '11201',
#        '10041', '11367', '10965', '10065', '14063', '14450', '11365',
#        '12204', '14502', '12866-4391', '14209', '12180', '10005-1081',
#        '12545', '10962', '10604', '11717', '12775', '14564', '13224',
#        '10560-3001', '10172', '11439', '13244', '11530', '10577-2126',
#        '12110', '10167', '10271', '12304', '10512', '10281-1010', '10119',
#        '11973', '12211', '14650', '13323', '14620', '10455', '14052',
#        '12186', '10028', '11702', '10174', '11354', '14031', '10594',
#        '10055', '10150', '10106', '11720', '11501', '11249', '12455',
#        '14222', '10509', '10036-5797', '12020', '13035', '12208-3479',
#        '10029', '10701', '11556', '11030', '10461', '11221', '11375',
#        '14624', '11215', '13601', '10708', '10022-7402', '12866', '11361',
#        '14625', '13815', '11205', '10165', '10075', '14226', '11559',
#        '14606', '12309', '14072', '14618', '13148', '11753', '10913',
#        '11554', '14456', '11980', '12206', '10069', '11238', '10591', nan,
#        '14603-0844', '10952', '11219', '11021', '10025', '10021', '10528',
#        '11213', '10281-1021', '11237', '11355', '10453', '10601', '13090',
#        '10522', '14905', '14850', '10471', '12188', '14614', '10504',
#        '14485', '13142', '13424', '12205', '10573', '10169', '10123',
#        '12144', '14203', '10958', '10606', '12208', '14220', '10033',
#        '14454', '11435', '14260', '10533', '10170', '14221', '11220',
#        '11226', '13026', '11801', '14136', '10115', '14202-2657', '11580',
#        '11385', '11040', '11358', '11803', '12203', '11106', '11204',
#        '12222', '11102', '12601', '14609', '13057', '10801', '10120',
#        '10128', '8830', '11218', '10040', '13210', '10960', '11590',
#        '11561', '10176', '10583', '12538', '10103', '11222', '14626',
#        '11421', '11377', '11971', '11231', '13902', '11426', '14213',
#        '10019-6708', '11731', '12804', '12210', '11701', '10281-1023',
#        '12009', '136756', '11581', '10562', '10171', '11042',
#        '10017- 1021', '13903', '11716', '10570', '11733', '12524', '12308',
#        '10314', '11212', '11234', '14830', '10118', '13501', '10168',
#        '11378', '10468', '10105-4300', '10451', '11598', '10605', '10459',
#        '14228', '11020', '10020-1104', '14263', '10018-7101', '12504',
#        '11104', '14843', '10541', '12207', '10473', '10920', '10279',
#        '11797', '10281-1003', '10002', '11434', '13502', '13699', '11210',
#        '11704', '10022-8541', '11779', '11548', '14416', '11739', '11418',
#        '10543', '10598', '11725', '11783', '11563', '13753', '100017',
#        '11357', '10458', '10463', '10004-1359', '11553', '10456',
#        '13502-1311', '11374', '11743', '10549', '14853', '11542', '11570',
#        '10018-1120', '11758', '10474', '10916', '11211', '10550', '10704',
#        'NEW YORK', '13045', '11023', '10603-2863', '13326', '11233',
#        '14210', '10017-2422', '14217', '11203', '10523', '13820', '14534',
#        '10804', '14304', '10010-2012', '11050', '11722', '13905',
#        '10591-4625', '11214', '10532', '11714', '10607', '11356', '10553',
#        '13204', '13126', '11362', '10177', '11207', '11550', '13153',
#        '10155', '10567', '12701', '11514', '11235', '11784', '11577',
#        '11432', '11413', '12305', '10954', '10803', '11804', '11230',
#        '11780', '13617', '10027-7566', '11372', '10037', '10004-1609',
#        '13212', '11373', '14048', '10510', '11706', '12901', '11229',
#        '14302', '11746', '13760', '11364', '13790', '10457', '11967',
#        '10918', '10452', '10285-3506', '10007-2146', '13361', '10591-4330',
#        '14727', '10706-1412', '10036-1600', '10603', '1018', '14617',
#        '10959', '95050', '11208', '11933', '13346', '11769', '13210-2778',
#        '10003-6827', '11520', '10989', '10941', '11105', '10027-5634',
#        '11735', '10977', '12578', '11415', '8820', '11429', '11549',
#        '10012-1185', '14802', '12212', '11934', '11691', '10111', '12078',
#        '14021', '10472', '11419', '13902-6000', '11232', '11507', '12061',
#        '10705', '11568-8000', '11694', '14059', '11576', '14068', '11206',
#        '10173-1922', '10031', '11216', '10923', '14513', '11379', '14214',
#        '10536', '11713', '14224', '14744', '11692', '12401', '10305',
#        '14621-3095', '14086', '10045', '14845', '10901', '12477', '10035',
#        '14225-0209', '12603', '13669', '14607', '10004-2595', '13069',
#        '11001', '10475', '14215', '12303', '13208', '14150', '10175',
#        '10953', '10964', '14467', '11973-5000', '1055', '11360', '13088',
#        '14760', '11368', '11103', '10019-3310', '14580', '10469', '13214',
#        '12550', '10552', '14109-1911', '11510', '10307', '12953', '100001',
#        '11729', '12019', '11710', '13676', 'NY', '11790', '11414', '14733',
#        '11795', '11217', '10454', '14020', '11901', '12211-1462', '11417',
#        '12801', '14469', '11433', '11778', '14075', '13135', '12540',
#        '10013-1578', '10306', '10020-1079', '10970', '11560', '10956',
#        '10003-2332', '10227', '14569', '10312', '12440', '10009', '11545',
#        '11209', '12528', '10507', '12946', '10017-4503', '10022-4614',
#        '7083', '10285-4506', '100119', '1022', '11552', '14420-2929',
#        '11096', '11963', '10309', '100013', '10003-1225', '12515', '11516',
#        '112016', '13057-0278', '10003-4605', '10502', '10003-4700',
#        '10538', '12149', '8816', '11228', '21224', '11754', '14592',
#        '11416', '11430', '10514', '10924', '10470', '10940', '11752',
#        '10994', '11359', '14586', '11422', '11787', '10983', '11771',
#        '10116', '7302', '12903', '10030', '12345', '10707', '11978',
#        '14750', '14222-1095', '11236', '10107', '14223', '10516', '10303',
#        '11223', '11792', '10302', '11363', '10012-3209', '10301',
#        '14851-6435', '14036', '11201-8301', '10110', '14303', '104608',
#        '12604', '11766', '10281-1050', '13440-1934', '10310', '10002-4358',
#        '11932', '12165', '11366', '14227', '11412', '11751', '12077',
#        '94105', '12414', '10015', '12065', '13440', '10466', '11023-1147',
#        '10034', '14454-1450', '13441', '13045-0900', '10597', '13662',
#        '10005-1304', '12919', '11224', '14225', '11347', '10170-N/A',
#        '13073', '11741', '12580', '10805', '12747', '10530', '100136',
#        '14208', '10008', '10026', '12533', '11369', '11418-344', '14120',
#        '10987', '10566', '10019-6064', '11946', '10013-', '12553', '10950',
#        '10036-6977', '10006-1625', '10022-', '14219', '14614-1046',
#        '11361-1859', '14006', '14615', '10016-3019', '10462', '10280',
#        '11522', '10022-7519', '12122', '1003', '11575', '10543-2232',
#        '13205', '1006', '14625-2776', '11794-3209', '10168-2503', '10151',
#        '11730', '12183', '10016-5990', '12047', '11423', '111377', '10044',
#        '12207-2950', '146534', '12202', '10017-5724', '12577', '12134',
#        '10980', '10503', '10018646', '11596', '13211', '11413-1918',
#        '11003', '11225', '11109', '10022-8009', '10013-4143', '11568',
#        '14092', '10926', '14871', '10004-2306', '14882', '10921', '12189',
#        '10304', '10117', '10589', '12307', '10706', '14132', '12237',
#        '10001-6708', '11975', '10121-2898', '12531', '10994-1945',
#        '1092111235', '14621', '11010', '08520-1450', '11581-2133',
#        '10111-2000', '12551', '10004-1482', '14420', '11370', '114354311',
#        '14218', '14702', '11239', '11757', '10703', '11940', '54189',
#        '14424', '11772', '10524', '11372-6222', '10465', '6851', '14204',
#        '94103', 'HAUPPAUGE', '11763', '13413', '14206', '12203-1490',
#        '12075', '10005-3538', '11565', '13021', '10013-3018', '13203',
#        '13617-1096', '11571-5002', '11968', '11726', '10460', '14701',
#        '94539', '14094', '11557', '10571', '14051', '12211-2362', '13850',
#        '14522', '14207', '18017', '14837', '12138', '12983', '13619',
#        '14611', '1354', '14027', '11518', '11952', '11572', '10017-3206',
#        '12085', '10651', '10981', '10036-2787', '10039', '11420', '12883',
#        '11762', '7024', '13206', '10550-5010', '70013', '7080',
#        '10112-4498', '10520', '12572', '14472', '12117', '11718', '11810',
#        '14216', '13209', '8540', '10968', '14867', '10024-5192',
#        '10020-1401', '12754', '14546', '14613', '1007', '33701', '11965',
#        '11201-8311', '101536', '6901', '11903', '14883', '12602', '8852',
#        '10118-3299', '10016-0201', '10012-2608', '12525', '12508',
#        '11050-4617', '11954', '10994-1739', '10110-0002', '12865-2138',
#        '100036', '94041', '10022-2606', '10017-1021', '10007-2195',
#        '100227', '11042-1034'], dtype=object)

# %%
# Some of these NEW YORK zip code entries were certified so they have other meaningful data :/
h1b[h1b["lca_case_employer_state"] == "NY"][h1b["lca_case_employer_postal_code"] == "NEW YORK"]
# Out:
# /home/kilian/.envs/bittrex/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#            lca_case_number     status lca_case_submit decision_date  \
# 48381   I-200-13302-081305  CERTIFIED      2013-10-29    2013-11-04
# 153661  I-200-14043-511703     DENIED      2014-02-21    2014-02-27
# 180713  I-200-14055-619321  CERTIFIED      2014-02-28    2014-03-06
# 207875  I-200-14063-477360  CERTIFIED      2014-03-12    2014-03-18
# 315250  I-200-14083-836176  CERTIFIED      2014-04-03    2014-04-09
# 347397  I-200-14106-745636  CERTIFIED      2014-04-16    2014-04-25
# 368787  I-200-14126-907101  CERTIFIED      2014-05-08    2014-05-14
# 380216  I-200-14136-574893  WITHDRAWN      2014-05-16    2014-05-16
# 464972  I-200-14220-273157  CERTIFIED      2014-09-12    2014-09-18
# 517193  I-203-14177-778566  CERTIFIED      2014-06-27    2014-07-03
#
#             visa_class lca_case_employment_start_date  \
# 48381             H-1B                     2013-11-21
# 153661            H-1B                     2014-03-03
# 180713            H-1B                     2014-08-27
# 207875            H-1B                     2014-09-06
# 315250            H-1B                     2014-10-01
# 347397            H-1B                     2014-04-28
# 368787            H-1B                     2014-07-22
# 380216            H-1B                     2014-06-19
# 464972            H-1B                     2014-09-12
# 517193  E-3 Australian                     2014-10-22
#
#        lca_case_employment_end_date                  lca_case_employer_name  \
# 48381                    2016-11-21                       MIO PARTNERS INC.
# 153661                   2017-03-02               DOLCE & GABBANA USA, INC.
# 180713                   2017-08-26                  AADOBE ANIMAL HOSPITAL
# 207875                   2017-09-05              JOYSTICK INTERACTIVE CORP.
# 315250                   2017-09-30              VITECH SYSTEMS GROUP, INC.
# 347397                   2017-04-28                         SOTHEBY'S, INC.
# 368787                   2017-07-21                   NEW YORK BLOOD CENTER
# 380216                   2017-06-18  UNITED CEREBRAL PALSY OF NEW YORK CITY
# 464972                   2017-09-11      LF DISTRIBUTION INTERNATIONAL INC.
# 517193                   2016-10-21                      QBE AMERICAS, INC.
#
#          lca_case_employer_address lca_case_employer_city ...   \
# 48381            PARK AVENUE PLAZA               NEW YORK ...
# 153661        148 LAFAYETTE STREET               NEW YORK ...
# 180713             1294 FOREST AVE          STATEN ISLAND ...
# 207875  37 W 17TH STREET, SUITE 6E               NEW YORK ...
# 315250       401 PARK AVENUE SOUTH               NEW YORK ...
# 347397            1334 YORK AVENUE               NEW YORK ...
# 368787      45-01 VERNON BOULEVARD       LONG ISLAND CITY ...
# 380216  80 MAIDEN LANE - 8TH FLOOR               NEW YORK ...
# 464972               1359 BROADWAY               NEW YORK ...
# 517193           WALL STREET PLAZA               NEW YORK ...
#
#        yr_source_pub_1 lca_case_workloc2_city lca_case_workloc2_state pw_2  \
# 48381           2013.0                    NaN                     NaN  NaN
# 153661          2013.0                    NaN                     NaN  NaN
# 180713          2013.0                    NaN                     NaN  NaN
# 207875          2014.0                    NaN                     NaN  NaN
# 315250          2013.0                    NaN                     NaN  NaN
# 347397          2013.0                    NaN                     NaN  NaN
# 368787          2013.0                    NaN                     NaN  NaN
# 380216          2014.0                    NaN                     NaN  NaN
# 464972          2014.0                    NaN                     NaN  NaN
# 517193          2013.0                    NaN                     NaN  NaN
#
#        pw_unit_2  pw_source_2  other_wage_source_2 yr_source_pub_2  \
# 48381        NaN          NaN                  NaN             NaN
# 153661       NaN          NaN                  NaN             NaN
# 180713       NaN          NaN                  NaN             NaN
# 207875       NaN          NaN                  NaN             NaN
# 315250       NaN          NaN                  NaN             NaN
# 347397       NaN          NaN                  NaN             NaN
# 368787       NaN          NaN                  NaN             NaN
# 380216       NaN          NaN                  NaN             NaN
# 464972       NaN          NaN                  NaN             NaN
# 517193       NaN          NaN                  NaN             NaN
#
#        lca_case_naics_code  nyc
# 48381             541610.0  1.0
# 153661              4481.0  1.0
# 180713            541940.0  1.0
# 207875              5418.0  1.0
# 315250            514512.0  1.0
# 347397            453920.0  1.0
# 368787            621991.0  1.0
# 380216            624120.0  1.0
# 464972            423990.0  1.0
# 517193            524126.0  1.0
#
# [10 rows x 36 columns]

# %%
# How many zipcodes in the full dataset have non-numeric values?
[zipcode for zipcode in h1b["lca_case_employer_postal_code"].fillna("00000").unique() if np.array([z in string.ascii_letters for z in zipcode]).any()]
# some of these values are Canadian zip codes it seems??? Even an Australian one

# if we feel like we need it later, we can fix these by making queries of the address
# to the google maps api and grabbing the zipcodes from there
# Out:
# ['92708-N/A',
#  'HUDSON',
#  'NEW YORK',
#  'V6J-1C7',
#  'SAN DIEGO',
#  'M3C 2K8',
#  'OAKLAND',
#  'L5R 0B7',
#  '85034-N/A',
#  'NY',
#  'ILLINOIS',
#  'SOMERSET',
#  'SUITE 506',
#  'ALAMEDA',
#  'CA 92705',
#  'LOS ANGELES',
#  'NSW 2000',
#  '10170-N/A',
#  'G74 5PA',
#  'GWINNETT',
#  'BROWARD',
#  'RIVERSIDE',
#  'WP5PB',
#  'M5J 1R7',
#  '554O2',
#  'FULTON',
#  'COOK',
#  'HAUPPAUGE',
#  'DOUGLAS',
#  'MIDDLESEX',
#  '0T6520/8224',
#  'MA',
#  'MI',
#  'V6J 1C7',
#  'V6C 1C7',
#  'V7X1G4',
#  'HOUSTON',
#  'M5V 1E',
#  'M5V 1E3']

# %%
# this number has a letter in it...
print('O' in string.ascii_letters)
int('554O2')
# Out:
# True
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-cd4cdd668ffa> in <module>()
#       1 # this number has a letter in it...
#       2 print('O' in string.ascii_letters)
# ----> 3 int('554O2')
#
# ValueError: invalid literal for int() with base 10: '554O2'

# %%
h1b.loc[h1b["lca_case_employer_postal_code"] == '554O2', "lca_case_employer_postal_code"] = '55402'

# %%
# So let's get the New York City visas by zipcode (zipcode file taken from nyc open data)
nyzipdf = pd.read_csv("New_York_State_ZIP_Codes-County_FIPS_Cross-Reference.csv")
nyzipdf
# Out:
#       County Name  State FIPS  County Code  County FIPS  ZIP Code   File Date
# 0          Albany          36            1        36001     12046  07/25/2007
# 1          Albany          36            1        36001     12083  07/25/2007
# 2          Albany          36            1        36001     12085  07/25/2007
# 3          Albany          36            1        36001     12201  07/25/2007
# 4          Albany          36            1        36001     12203  07/25/2007
# 5          Albany          36            1        36001     12055  07/25/2007
# 6          Albany          36            1        36001     12204  07/25/2007
# 7          Albany          36            1        36001     12023  07/25/2007
# 8          Albany          36            1        36001     12087  07/25/2007
# 9          Albany          36            1        36001     12205  07/25/2007
# 10         Albany          36            1        36001     12110  07/25/2007
# 11         Albany          36            1        36001     12009  07/25/2007
# 12         Albany          36            1        36001     12202  07/25/2007
# 13         Albany          36            1        36001     12189  07/25/2007
# 14         Albany          36            1        36001     12053  07/25/2007
# 15         Albany          36            1        36001     12159  07/25/2007
# 16         Albany          36            1        36001     12054  07/25/2007
# 17         Albany          36            1        36001     12084  07/25/2007
# 18         Albany          36            1        36001     12045  07/25/2007
# 19         Albany          36            1        36001     12229  07/25/2007
# 20         Albany          36            1        36001     12230  07/25/2007
# 21         Albany          36            1        36001     12243  07/25/2007
# 22         Albany          36            1        36001     12248  07/25/2007
# 23         Albany          36            1        36001     12239  07/25/2007
# 24         Albany          36            1        36001     12227  07/25/2007
# 25         Albany          36            1        36001     12238  07/25/2007
# 26         Albany          36            1        36001     12208  07/25/2007
# 27         Albany          36            1        36001     12222  07/25/2007
# 28         Albany          36            1        36001     12245  07/25/2007
# 29         Albany          36            1        36001     12246  07/25/2007
# ...           ...         ...          ...          ...       ...         ...
# 2513       Orange          36           71        36071     10985  07/25/2007
# 2514       Oswego          36           75        36075     13028  07/25/2007
# 2515         Erie          36           29        36029     14025  07/25/2007
# 2516  Westchester          36          119        36119     10580  07/25/2007
# 2517     Delaware          36           25        36025     13774  07/25/2007
# 2518       Queens          36           81        36081     11451  07/25/2007
# 2519     New York          36           61        36061     10101  07/25/2007
# 2520       Oneida          36           65        36065     13455  07/25/2007
# 2521      Steuben          36          101        36101     14885  07/25/2007
# 2522       Nassau          36           59        36059     11530  07/25/2007
# 2523        Kings          36           47        36047     11242  07/25/2007
# 2524       Greene          36           39        36039     12192  07/25/2007
# 2525      Ontario          36           69        36069     14466  07/25/2007
# 2526       Orange          36           71        36071     10997  07/25/2007
# 2527     Franklin          36           33        36033     12966  07/25/2007
# 2528       Cayuga          36           11        36011     13117  07/25/2007
# 2529         Erie          36           29        36029     14270  07/25/2007
# 2530        Wayne          36          117        36117     14589  07/25/2007
# 2531     Herkimer          36           43        36043     13475  07/25/2007
# 2532      Wyoming          36          121        36121     14427  07/25/2007
# 2533       Broome          36            7        36007     13737  07/25/2007
# 2534     New York          36           61        36061     10162  07/25/2007
# 2535     New York          36           61        36061     10117  07/25/2007
# 2536     Delaware          36           25        36025     13847  07/25/2007
# 2537     New York          36           61        36061     10131  07/25/2007
# 2538     Dutchess          36           27        36027     12514  07/25/2007
# 2539     New York          36           61        36061     10159  07/25/2007
# 2540       Ulster          36          111        36111     12528  07/25/2007
# 2541     New York          36           61        36061     10120  07/25/2007
# 2542     Hamilton          36           41        36041     12032  07/25/2007
#
# [2543 rows x 6 columns]

# %%
nyzips = nyzipdf["ZIP Code"][nyzipdf["County Name"].isin(["New York", "Kings", "Queens", "Bronx", "Richmond"])]
nyzips
# Out:
# 59      10472
# 60      10463
# 61      10468
# 62      10457
# 64      10467
# 68      10462
# 69      10456
# 70      10469
# 71      10453
# 72      10454
# 73      10464
# 78      10474
# 82      10803
# 83      10704
# 85      10499
# 436     11221
# 437     11220
# 438     11224
# 440     11202
# 441     11212
# 442     11218
# 443     11225
# 444     11207
# 446     11216
# 447     11217
# 448     11208
# 449     11230
# 450     11223
# 451     11215
# 452     11203
#         ...
# 2275    10115
# 2290    10173
# 2304    10002
# 2321    11001
# 2322    11229
# 2356    10285
# 2360    11435
# 2372    11423
# 2377    10111
# 2383    10113
# 2399    10103
# 2400    10107
# 2418    10550
# 2430    11256
# 2445    11420
# 2450    10037
# 2465    11247
# 2477    10292
# 2483    11357
# 2485    11365
# 2490    10075
# 2491    11428
# 2518    11451
# 2519    10101
# 2523    11242
# 2534    10162
# 2535    10117
# 2537    10131
# 2539    10159
# 2541    10120
# Name: ZIP Code, Length: 324, dtype: int64

# %%
# Let's get a column of integer, 5-digit zipcodes in the dataframe
first5zips = [zipcode[:5] for zipcode in h1b["lca_case_employer_postal_code"].fillna("00000")]
first5zips = [int(zipcode) if np.array([z in string.digits for z in zipcode]).all() else 0 for zipcode in first5zips ]
h1b["intzip"] = np.array(first5zips)
h1b["intzip"]
# Out:
# 0         78666
# 1         46202
# 2         55802
# 3         30045
# 4         20147
# 5          8540
# 6          8540
# 7         66219
# 8         40243
# 9         78229
# 10         8816
# 11        95110
# 12        60173
# 13        30022
# 14        22031
# 15        75039
# 16        33133
# 17        75039
# 18         8854
# 19        60015
# 20        78229
# 21        92126
# 22        22182
# 23        60015
# 24        77042
# 25        60015
# 26        60563
# 27        94403
# 28        60015
# 29        33178
#           ...
# 519474    11101
# 519475    90067
# 519476    60077
# 519477    20705
# 519478    94303
# 519479    92821
# 519480    98101
# 519481    85250
# 519482    10005
# 519483     7068
# 519484    10018
# 519485    10003
# 519486    90291
# 519487    49419
# 519488    92562
# 519489    77099
# 519490    22102
# 519491    92831
# 519492    37203
# 519493    10001
# 519494    94402
# 519495    94965
# 519496    80503
# 519497    84105
# 519498    27560
# 519499    80401
# 519500    94402
# 519501    96813
# 519502    85714
# 519503    10005
# Name: intzip, Length: 519504, dtype: int64

# %%
##### Just realised that the lca_case_employer_* fields are for the employer's address,
# but we should really be concerned with lca_case_workloc* values since they tell you where
# the person getting the visa is located...

h1b[h1b["lca_case_workloc1_state"] == "NY"].lca_case_workloc1_city.unique()
# about as bad as last time...

# %%
# let's see what California looks like
h1b[h1b["lca_case_workloc1_state"] == "CA"].lca_case_workloc1_city.nunique()
# Out:
# 1066

# %%
# As a first order of magnitude test, let's assume that NYC and SF are responsible for the majority of visas
# in their respective states.
cacnt = h1b[h1b["lca_case_workloc1_state"] == "CA"].groupby("lca_case_workloc1_city").size().reset_index(name="CA_count")
cacnt.sort_values("CA_count", ascending=False)
# Out:
#      lca_case_workloc1_city  CA_count
# 783           SAN FRANCISCO     11360
# 803                SAN JOSE      9268
# 939               SUNNYVALE      6555
# 553           MOUNTAIN VIEW      5328
# 844             SANTA CLARA      5129
# 772               SAN DIEGO      4924
# 454             LOS ANGELES      4079
# 386                  IRVINE      3256
# 628               PALO ALTO      3088
# 315                 FREMONT      2469
# 216               CUPERTINO      2304
# 519                MILPITAS      1973
# 670              PLEASANTON      1658
# 505              MENLO PARK      1305
# 716            REDWOOD CITY      1217
# 823               SAN RAMON      1209
# 267              EL SEGUNDO      1188
# 304             FOSTER CITY      1107
# 972                TORRANCE      1072
# 816               SAN MATEO      1005
# 753              SACRAMENTO       914
# 854            SANTA MONICA       834
# 296                  FOLSOM       787
# 1051         WOODLAND HILLS       719
# 641                PASADENA       711
# 122                 BURBANK       609
# 901     SOUTH SAN FRANCISCO       580
# 600                 OAKLAND       548
# 840               SANTA ANA       500
# 406                LA JOLLA       495
# ...                     ...       ...
# 524             MINNEAPOLIS         1
# 527           MISSION HILLS         1
# 474                 LYNWOOD         1
# 529          MISSION VIEJO,         1
# 1       # 31100 ANAHEIM MSA         1
# 534            MONTAIN VIEW         1
# 536            MONTE SERENO         1
# 542                MONTVALE         1
# 548           MOUNATIN VIEW         1
# 549                MOUNTAIN         1
# 510                MERIDIAN         1
# 507               MENLOPARK         1
# 506             MENLO PARK,         1
# 504                 MENIFEE         1
# 476                 MAGALIA         1
# 477               MALAPITAS         1
# 482                 MANTELA         1
# 484                   MARIN         1
# 486          MARINA DEL RAY         1
# 488             MARLBOROUGH         1
# 489                MARTHER,         1
# 491              MARYSVILLE         1
# 493                 MAYNARD         1
# 496               MCFARLAND         1
# 499                 MEDESTO         1
# 500                 MEDFORD         1
# 501               MELO PARK         1
# 502                MELVILLE         1
# 503                 MEMPHIS         1
# 1065                 ZAMORA         1
#
# [1066 rows x 2 columns]

# %%
nycnt = h1b[h1b["lca_case_workloc1_state"] == "NY"].groupby("lca_case_workloc1_city").size().reset_index(name="NY_count")
nycnt.sort_values("NY_count", ascending=False)

# So to first order, New York (not counting Brooklyn, LIC, Bronx, Flshing, etc.) has 3 times as
# many visa applications than SF (not counting places in South Bay, East Bay, etc.)

# But what about population? NYC has 8m, Manhattan has ~2m. SF has 1m, but people outside of SF work in SF...
# Out:
#     lca_case_workloc1_city  NY_count
# 437               NEW YORK     32170
# 99                BROOKLYN      1890
# 26                  ALBANY       904
# 361       LONG ISLAND CITY       850
# 90                   BRONX       755
# 104                BUFFALO       686
# 539              ROCHESTER       636
# 390               MELVILLE       469
# 216               FLUSHING       435
# 622               SYRACUSE       398
# 688           WHITE PLAINS       370
# 438          NEW YORK CITY       367
# 373                  MALTA       322
# 568            SCHENECTADY       223
# 71                BETHPAGE       179
# 669                WEBSTER       178
# 312                 ITHACA       174
# 644                  UPTON       171
# 277              HAUPPAUGE       170
# 521               PURCHASE       160
# 608            STONY BROOK       158
# 626              TARRYTOWN       151
# 552                    RYE       150
# 636                   TROY       144
# 516        PORT WASHINGTON       132
# 528             RENSSELAER       121
# 591                 SOMERS       118
# 642              UNIONDALE       112
# 489           PAINTED POST       112
# 650               VALHALLA       107
# ..                     ...       ...
# 228                 FULTON         1
# 487             OYSTER BAY         1
# 229            GAINESVILLE         1
# 232            GARNERVILLE         1
# 233               GARRISON         1
# 483               ORISKANY         1
# 482           ORIENT POINT         1
# 237               GETZILLE         1
# 240                 GILBOA         1
# 243             GLEN FALLS         1
# 475           OLD BETHPAGE         1
# 221            FRAMINGDALE         1
# 220            FORT EDWARD         1
# 495             PARSIPPANY         1
# 202               ELMHUSRT         1
# 197            EDGEWOOD NY         1
# 198          ELIZABETHTOWN         1
# 511             PO BOX 299         1
# 199                   ELMA         1
# 200               ELMHRUST         1
# 508             PLATTSBURG         1
# 505               PIERMONT         1
# 219          FORREST HILLS         1
# 504                PHOENIX         1
# 503           PHILADELPHIA         1
# 502            PETERSBURGH         1
# 501           PELHAM MANOR         1
# 206     EMPIRE STATE PLAZA         1
# 212           FAYETTEVILLE         1
# 545            ROCKY POINT         1
#
# [712 rows x 2 columns]

# %%
h1b.groupby("lca_case_wage_rate_unit")["lca_case_number"].count()
# Out:
# lca_case_wage_rate_unit
# Bi-Weekly       136
# Hour          37106
# Month           649
# Week            322
# Year         481255
# Name: lca_case_number, dtype: int64

# %%
print(h1b.visa_class.unique())
print(h1b[h1b["visa_class"] == 'H-1B'].shape[0])
print(h1b[h1b["visa_class"] == 'E-3 Australian'].shape[0])
print(h1b[h1b["visa_class"] == 'H-1B1 Chile'].shape[0])
print(h1b[h1b["visa_class"] == 'H-1B1 Singapore'].shape[0])
# Out:
# ['H-1B' 'E-3 Australian' 'H-1B1 Chile' 'H-1B1 Singapore']
# 508676
# 9446
# 557
# 825

# %%
h1bonly = h1b[h1b["visa_class"] == 'H-1B']
h1bonly.status.unique()
# Out:
# array(['CERTIFIED-WITHDRAWN', 'CERTIFIED', 'DENIED', 'WITHDRAWN',
#        'REJECTED'], dtype=object)

# %%
h1b.status.unique()
# Out:
# array(['CERTIFIED-WITHDRAWN', 'CERTIFIED', 'DENIED', 'WITHDRAWN',
#        'REJECTED', 'INVALIDATED'], dtype=object)

# %%
h1b["lca_case_submit"] = h1b.lca_case_submit.astype("datetime64[ns]")
h1b["decision_date"] = h1b["decision_date"].astype("datetime64[ns]")

# %%
# h1b.groupby(h1b["lca_case_submit"].dt.month).count().plot(kind="bar")
# sns.distplot(h1b["lca_case_submit"].dt.month)
h1b.groupby(pd.Grouper(key="lca_case_submit", freq='1M'))["visa_class"].count().plot(kind='bar')

# %%
# let's see how it looks with every case submission pre- Oct 2013 removed
h1b = h1b[h1b["lca_case_submit"] > "2013-09-01"]
h1b.groupby(pd.Grouper(key="lca_case_submit", freq='1M'))["visa_class"].count().plot(kind='bar')

# %%
h1b.shape
# Out:
# (497796, 35)

# %%
h1b.groupby(pd.Grouper(key="decision_date", freq='1M'))["visa_class"].count().plot(kind='bar')

# %%
h1b["lca_case_employment_start_date"] = pd.to_datetime(h1b["lca_case_employment_start_date"])
h1b["lca_case_employment_end_date"] = pd.to_datetime(h1b["lca_case_employment_end_date"])

# %%
h1b.groupby(pd.Grouper(key="lca_case_employment_start_date", freq='3M'))["visa_class"].count().plot(kind='bar')

# %%
h1b.groupby(pd.Grouper(key="lca_case_employment_end_date", freq='3M'))["visa_class"].count().plot(kind='bar')

# %%
(h1b["lca_case_employment_end_date"] - h1b["lca_case_employment_start_date"]) > pd.Timedelta("{:} days".format(3 * 365))
# Out:
# 1          True
# 2         False
# 3         False
# 4          True
# 5         False
# 6         False
# 7         False
# 10         True
# 13        False
# 14         True
# 15         True
# 17         True
# 18         True
# 19         True
# 21         True
# 23         True
# 24        False
# 25         True
# 26        False
# 27        False
# 28         True
# 29        False
# 31         True
# 33        False
# 34        False
# 35        False
# 36        False
# 37        False
# 38        False
# 39        False
#           ...
# 519474    False
# 519475    False
# 519476    False
# 519477    False
# 519478    False
# 519479    False
# 519480    False
# 519481    False
# 519482    False
# 519483    False
# 519484    False
# 519485    False
# 519486    False
# 519487    False
# 519488    False
# 519489    False
# 519490    False
# 519491    False
# 519492    False
# 519493    False
# 519494    False
# 519495    False
# 519496    False
# 519497    False
# 519498    False
# 519499    False
# 519500    False
# 519501    False
# 519502    False
# 519503    False
# Length: 497796, dtype: bool

# %%
# see are any of the durations of employment greater than 3 years
h1b[(h1b["lca_case_employment_end_date"] - h1b["lca_case_employment_start_date"]) > pd.Timedelta("{:} days".format(3 * 365 + 1))]
# Out:
#            lca_case_number  status lca_case_submit decision_date visa_class  \
# 46030   I-200-13298-421111  DENIED      2013-10-25    2013-11-06       H-1B
# 71269   I-200-13324-708144  DENIED      2013-11-20    2013-11-25       H-1B
# 71555   I-200-13324-940035  DENIED      2013-11-20    2013-11-25       H-1B
# 273395  I-200-14076-124633  DENIED      2014-03-17    2014-03-26       H-1B
# 442120  I-200-14198-245431  DENIED      2014-07-17    2014-07-23       H-1B
#
#        lca_case_employment_start_date lca_case_employment_end_date  \
# 46030                      2014-01-01                   2017-12-29
# 71269                      2014-01-01                   2019-01-01
# 71555                      2014-01-01                   2017-12-31
# 273395                     2014-09-16                   2017-09-17
# 442120                     2014-07-17                   2017-08-18
#
#                      lca_case_employer_name    lca_case_employer_address  \
# 46030   TUFTS UNIVERSITY SCHOOL OF MEDICINE             136 HARRISON AVE
# 71269              D.K.G NATURE'S CURE INC.         37010 17TH AVE SOUTH
# 71555                        ATP TOUR, INC.           201 ATP TOUR BLVD.
# 273395             CEREBRA CONSULTING, INC.  1950 STREET ROAD, SUITE 315
# 442120            CREATIVE HEALTH SOLUTIONS          1800 N. WABASH AVE.
#
#        lca_case_employer_city         ...               other_wage_source_1  \
# 46030                  BOSTON         ...           OFLC ONLINE DATA CENTER
# 71269             FEDERAL WAY         ...                               NaN
# 71555       PONTE VEDRA BEACH         ...           OFLC ONLINE DATA CENTER
# 273395               BENSALEM         ...           OFLC ONLINE DATA CENTER
# 442120                 MARION         ...           OFLC ONLINE DATA CENTER
#
#        yr_source_pub_1 lca_case_workloc2_city lca_case_workloc2_state pw_2  \
# 46030           2013.0                    NaN                     NaN  NaN
# 71269           2012.0                    NaN                     NaN  NaN
# 71555           2013.0                    NaN                     NaN  NaN
# 273395          2014.0                    NaN                     NaN  NaN
# 442120          2014.0                    NaN                     NaN  NaN
#
#         pw_unit_2  pw_source_2 other_wage_source_2 yr_source_pub_2  \
# 46030         NaN          NaN                 NaN             NaN
# 71269         NaN          NaN                 NaN             NaN
# 71555         NaN          NaN                 NaN             NaN
# 273395        NaN          NaN                 NaN             NaN
# 442120        NaN          NaN                 NaN             NaN
#
#         lca_case_naics_code
# 46030              611310.0
# 71269                5112.0
# 71555              711320.0
# 273395             541511.0
# 442120             621491.0
#
# [5 rows x 35 columns]

# %%
# let's see some scatters
rp = sns.regplot(x="lca_case_wage_rate_from", y="pw_1", data=h1b)
rp.set(xlim=(0,1e9), ylim=(0, 2e7), xscale='log', yscale='log')
# Out:
# /home/kilian/.envs/bittrex/lib/python3.6/site-packages/matplotlib/axes/_base.py:3245: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '
# /home/kilian/.envs/bittrex/lib/python3.6/site-packages/matplotlib/axes/_base.py:2923: UserWarning: Attempted to set non-positive xlimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive xlimits for log-scale axis; '
# [None,
#  (64502.459184888452, 20000000.0),
#  None,
#  (92219.427310347572, 1000000000.0)]

# %%
h1b[pd.notnull(h1b["lca_case_wage_rate_to"])].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f67569a5d9d0> in <module>()
# ----> 1 h1b[pd.notnull(h1b["lca_case_wage_rate_to"])].shape
#
# NameError: name 'h1b' is not defined

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xscale('log')
ax.set_yscale('log')
ax.scatter(h1b["lca_case_wage_rate_from"], h1b["lca_case_wage_rate_to"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c3dd328a17ff> in <module>()
# ----> 1 fig = plt.figure()
#       2 ax = fig.add_subplot(111)
#       3 ax.set_xscale('log')
#       4 ax.set_yscale('log')
#       5 ax.scatter(h1b["lca_case_wage_rate_from"], h1b["lca_case_wage_rate_to"])
#
# NameError: name 'plt' is not defined

# %%
# From Google, 2014 numbers
sfpop = 852537
nypop = 8.472e6

# %%
import re
import string
import json
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from fuzzywuzzy import fuzz, process
from shapely.geometry.multipolygon import MultiPolygon

# %matplotlib inline

# %%
h1b = pd.read_csv("../dat/db246968-e567-442f-8108-b86a280107d3_H-1BVisaApplications-2014.csv")

# %%
h1b = h1b[h1b["status"] == "CERTIFIED"]
h1b = h1b[h1b["full_time_pos"] == "Y"]
h1b = h1b.drop(columns=['status', 'full_time_pos'])

# %%
h1b["lca_case_submit"] = pd.to_datetime(h1b["lca_case_submit"])
h1b["decision_date"] = pd.to_datetime(h1b["decision_date"])
h1b = h1b[h1b["lca_case_submit"] > "2013-06-01"]
h1b["lca_case_employment_start_date"] = pd.to_datetime(h1b["lca_case_employment_start_date"])
h1b["lca_case_employment_end_date"] = pd.to_datetime(h1b["lca_case_employment_end_date"])

# %%
h1b.dropna(subset=["lca_case_workloc2_state"])[pd.isnull(h1b.lca_case_workloc2_city)]
# Out:
# /home/kilian/.envs/elucd/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#            lca_case_number lca_case_submit decision_date visa_class  \
# 53040   I-200-13304-537193      2013-11-02    2013-11-07       H-1B
# 53301   I-200-13304-708661      2013-11-02    2013-11-07       H-1B
# 159313  I-200-14045-211105      2014-02-27    2014-03-05       H-1B
# 162920  I-200-14048-083040      2014-02-20    2014-02-26       H-1B
# 168969  I-200-14050-358804      2014-02-20    2014-02-26       H-1B
# 170890  I-200-14050-978313      2014-02-20    2014-02-26       H-1B
# 183929  I-200-14056-487616      2014-02-26    2014-03-04       H-1B
# 191174  I-200-14058-273024      2014-02-27    2014-03-05       H-1B
# 191502  I-200-14058-357207      2014-02-27    2014-03-05       H-1B
# 192738  I-200-14058-663001      2014-02-27    2014-03-05       H-1B
# 324353  I-200-14086-975517      2014-03-27    2014-04-04       H-1B
# 335415  I-200-14097-421560      2014-04-07    2014-04-11       H-1B
#
#        lca_case_employment_start_date lca_case_employment_end_date  \
# 53040                      2013-11-05                   2016-11-04
# 53301                      2013-11-05                   2016-11-04
# 159313                     2014-08-27                   2017-08-26
# 162920                     2014-06-08                   2017-06-07
# 168969                     2014-08-20                   2017-08-19
# 170890                     2014-06-08                   2017-06-07
# 183929                     2014-06-08                   2017-06-07
# 191174                     2014-08-27                   2017-08-26
# 191502                     2014-08-27                   2017-08-26
# 192738                     2014-08-27                   2017-08-26
# 324353                     2014-09-17                   2017-09-16
# 335415                     2014-06-08                   2017-06-07
#
#                      lca_case_employer_name  lca_case_employer_address  \
# 53040      PINE TREE HOME HEALTH CARE, INC.  1125 JUDSON RD., STE. 193
# 53301      PINE TREE HOME HEALTH CARE, INC.  1125 JUDSON RD., STE. 193
# 159313         LAKSHMI PT CONSULTANTS, P.C.  865 MERRICK RD., STE. 201
# 162920         LAKSHMI PT CONSULTANTS, P.C.  865 MERRICK RD., STE# 201
# 168969         LAKSHMI PT CONSULTANTS, P.C.  865 MERRICK RD., STE# 201
# 170890         LAKSHMI PT CONSULTANTS, P.C.  865 MERRICK RD., STE# 201
# 183929         LAKSHMI PT CONSULTANTS, P.C.  865 MERRICK RD., STE. 201
# 191174         LAKSHMI PT CONSULTANTS, P.C.            865 MERRICK RD.
# 191502         LAKSHMI PT CONSULTANTS, P.C.            865 MERRICK RD.
# 192738         LAKSHMI PT CONSULTANTS, P.C.            865 MERRICK RD.
# 324353  UNIVERSAL SYSTEM TECHNOLOGIES, INC.       30700 TELEGRAPH ROAD
# 335415         LAKSHMI PT CONSULTANTS, P.C.  865 MERRICK RD., STE. 201
#
#        lca_case_employer_city lca_case_employer_state         ...          \
# 53040                LONGVIEW                      TX         ...
# 53301                LONGVIEW                      TX         ...
# 159313                BALDWIN                      NY         ...
# 162920                BALDWIN                      NY         ...
# 168969                BALDWIN                      NY         ...
# 170890                BALDWIN                      NY         ...
# 183929                BALDWIN                      NY         ...
# 191174                BALDWIN                      NY         ...
# 191502                BALDWIN                      NY         ...
# 192738                BALDWIN                      NY         ...
# 324353          BINGHAM FARMS                      MI         ...
# 335415                BALDWIN                      NY         ...
#
#               other_wage_source_1 yr_source_pub_1 lca_case_workloc2_city  \
# 53040     OFLC ONLINE DATA CENTER          2013.0                    NaN
# 53301     OFLC ONLINE DATA CENTER          2013.0                    NaN
# 159313    OFLC ONLINE DATA CENTER          2013.0                    NaN
# 162920    OFLC ONLINE DATA CENTER          2013.0                    NaN
# 168969    OFLC ONLINE DATA CENTER          2013.0                    NaN
# 170890    OFLC ONLINE DATA CENTER          2013.0                    NaN
# 183929    OFLC ONLINE DATA CENTER          2013.0                    NaN
# 191174  'OFLC ONLINE DATA CENTER'          2013.0                    NaN
# 191502  'OFLC ONLINE DATA CENTER'          2013.0                    NaN
# 192738  'OFLC ONLINE DATA CENTER'          2013.0                    NaN
# 324353    OFLC ONLINE DATA CENTER          2014.0                    NaN
# 335415    OFLC ONLINE DATA CENTER          2013.0                    NaN
#
#        lca_case_workloc2_state     pw_2  pw_unit_2 pw_source_2  \
# 53040                       TX  80538.0       Year         OES
# 53301                       TX  80538.0       Year         OES
# 159313                      NY  64792.0       Year         OES
# 162920                      NY  86694.0       Year         OES
# 168969                      NY  84157.0       Year         OES
# 170890                      NY  84157.0       Year         OES
# 183929                      NY  86694.0       Year         OES
# 191174                      NY  64792.0       Year         OES
# 191502                      NY  62525.0       Year         OES
# 192738                      NY  62525.0       Year         OES
# 324353                      MI      NaN        NaN         NaN
# 335415                      NY  84157.0       Year         OES
#
#               other_wage_source_2            yr_source_pub_2  \
# 53040     OFLC ONLINE DATA CENTER    OFLC ONLINE DATA CENTER
# 53301     OFLC ONLINE DATA CENTER    OFLC ONLINE DATA CENTER
# 159313    OFLC ONLINE DATA CENTER    OFLC ONLINE DATA CENTER
# 162920    OFLC ONLINE DATA CENTER    OFLC ONLINE DATA CENTER
# 168969    OFLC ONLINE DATA CENTER    OFLC ONLINE DATA CENTER
# 170890    OFLC ONLINE DATA CENTER    OFLC ONLINE DATA CENTER
# 183929    OFLC ONLINE DATA CENTER    OFLC ONLINE DATA CENTER
# 191174  'OFLC ONLINE DATA CENTER'  'OFLC ONLINE DATA CENTER'
# 191502  'OFLC ONLINE DATA CENTER'  'OFLC ONLINE DATA CENTER'
# 192738    OFLC ONLINE DATA CENTER    OFLC ONLINE DATA CENTER
# 324353                        NaN                        NaN
# 335415    OFLC ONLINE DATA CENTER    OFLC ONLINE DATA CENTER
#
#        lca_case_naics_code
# 53040             621610.0
# 53301             621610.0
# 159313            621340.0
# 162920            621340.0
# 168969            621340.0
# 170890            621340.0
# 183929            621340.0
# 191174            621340.0
# 191502            621340.0
# 192738            621340.0
# 324353            541519.0
# 335415            621340.0
#
# [12 rows x 33 columns]

# %%
# first let's do an NY only dataframe
nyc_nabes = json.loads(open("../dat/ext/nyc_nabe_names.json").read())

# %%
nyc_nabes["features"][0]
# Out:
# {'geometry': {'coordinates': [-73.8472019292043, 40.8947134741554],
#   'type': 'Point'},
#  'id': 1,
#  'properties': {'AnnoAngle': 0,
#   'AnnoLine1': 'Wakefield',
#   'AnnoLine2': ' ',
#   'AnnoLine3': ' ',
#   'Borough': 'Bronx',
#   'FID': 1,
#   'Name': 'Wakefield',
#   'Stacked': 1},
#  'type': 'Feature'}

# %%
nabe_boros = [feat["properties"]["Borough"] for feat in nyc_nabes["features"]]

# %%
nabe_names = [feat["properties"]["Name"] for feat in nyc_nabes["features"]]
nabe_dict = {feat["properties"]["Name"]: feat["properties"]["Borough"] for feat in nyc_nabes["features"]}

# %%
[[nabe_names[i], nabe_boros[i]] for i in range(len(nabe_names))]
# this could be troublesome because some places are ambiguous
# e.g. Eastchester is a neighbourhood in the Bronx but also a town in Westchester county...
# Out:
# [['Wakefield', 'Bronx'],
#  ['Co-op City', 'Bronx'],
#  ['Eastchester', 'Bronx'],
#  ['Fieldston', 'Bronx'],
#  ['Riverdale', 'Bronx'],
#  ['Kingsbridge', 'Bronx'],
#  ['South Beach', 'Staten Island'],
#  ['Marble Hill', 'Manhattan'],
#  ['Port Richmond', 'Staten Island'],
#  ['Woodlawn', 'Bronx'],
#  ["Mariner's Harbor", 'Staten Island'],
#  ['Norwood', 'Bronx'],
#  ['Port Ivory', 'Staten Island'],
#  ['Williamsbridge', 'Bronx'],
#  ['Castleton Corners', 'Staten Island'],
#  ['Baychester', 'Bronx'],
#  ['New Springville', 'Staten Island'],
#  ['Pelham Parkway', 'Bronx'],
#  ['Travis', 'Staten Island'],
#  ['City Island', 'Bronx'],
#  ['New Dorp', 'Staten Island'],
#  ['Bedford Park', 'Bronx'],
#  ['Oakwood', 'Staten Island'],
#  ['University Heights', 'Bronx'],
#  ['Great Kills', 'Staten Island'],
#  ['Morris Heights', 'Bronx'],
#  ['Eltingville', 'Staten Island'],
#  ['Fordham', 'Bronx'],
#  ['Annadale', 'Staten Island'],
#  ['East Tremont', 'Bronx'],
#  ['Woodrow', 'Staten Island'],
#  ['West Farms', 'Bronx'],
#  ['Tottenville', 'Staten Island'],
#  ['High  Bridge', 'Bronx'],
#  ['Tompkinsville', 'Staten Island'],
#  ['Melrose', 'Bronx'],
#  ['Silver Lake', 'Staten Island'],
#  ['Mott Haven', 'Bronx'],
#  ['Sunnyside', 'Staten Island'],
#  ['Port Morris', 'Bronx'],
#  ['Ditmas Park', 'Brooklyn'],
#  ['Longwood', 'Bronx'],
#  ['Wingate', 'Brooklyn'],
#  ['Hunts Point', 'Bronx'],
#  ['Rugby', 'Brooklyn'],
#  ['Morrisania', 'Bronx'],
#  ['Park Hill', 'Staten Island'],
#  ['Soundview', 'Bronx'],
#  ['Westerleigh', 'Staten Island'],
#  ['Clason Point', 'Bronx'],
#  ['Graniteville', 'Staten Island'],
#  ['Throgs Neck', 'Bronx'],
#  ['Arlington', 'Staten Island'],
#  ['Country Club', 'Bronx'],
#  ['Arrochar', 'Staten Island'],
#  ['Parkchester', 'Bronx'],
#  ['Grasmere', 'Staten Island'],
#  ['Westchester Square', 'Bronx'],
#  ['Old Town', 'Staten Island'],
#  ['Van Nest', 'Bronx'],
#  ['Dongan Hills', 'Staten Island'],
#  ['Morris Park', 'Bronx'],
#  ['Midland Beach', 'Staten Island'],
#  ['Belmont', 'Bronx'],
#  ['Spuyten Duyvil', 'Bronx'],
#  ['Grant City', 'Staten Island'],
#  ['North Riverdale', 'Bronx'],
#  ['New Dorp Beach', 'Staten Island'],
#  ['Pelham Bay', 'Bronx'],
#  ['Schuylerville', 'Bronx'],
#  ['Edgewater Park', 'Bronx'],
#  ['Castle Hill', 'Bronx'],
#  ['Olinville', 'Bronx'],
#  ['Pelham Gardens', 'Bronx'],
#  ['Concourse', 'Bronx'],
#  ['Unionport', 'Bronx'],
#  ['Edenwald', 'Bronx'],
#  ['Bay Ridge', 'Brooklyn'],
#  ['Bensonhurst', 'Brooklyn'],
#  ['Sunset Park', 'Brooklyn'],
#  ['Greenpoint', 'Brooklyn'],
#  ['Gravesend', 'Brooklyn'],
#  ['Brighton Beach', 'Brooklyn'],
#  ['Sheepshead Bay', 'Brooklyn'],
#  ['Manhattan Terrace', 'Brooklyn'],
#  ['Flatbush', 'Brooklyn'],
#  ['Bay Terrace', 'Staten Island'],
#  ['Crown Heights', 'Brooklyn'],
#  ['East Flatbush', 'Brooklyn'],
#  ['Huguenot', 'Staten Island'],
#  ['Kensington', 'Brooklyn'],
#  ['Pleasant Plains', 'Staten Island'],
#  ['Windsor Terrace', 'Brooklyn'],
#  ['Butler Manor', 'Staten Island'],
#  ['Prospect Heights', 'Brooklyn'],
#  ['Charleston', 'Staten Island'],
#  ['Brownsville', 'Brooklyn'],
#  ['Rossville', 'Staten Island'],
#  ['Williamsburg', 'Brooklyn'],
#  ['Arden Heights', 'Staten Island'],
#  ['Bushwick', 'Brooklyn'],
#  ['Greenridge', 'Staten Island'],
#  ['Bedford Stuyvesant', 'Brooklyn'],
#  ['Heartland Village', 'Staten Island'],
#  ['Brooklyn Heights', 'Brooklyn'],
#  ['Inwood', 'Manhattan'],
#  ['Chelsea', 'Staten Island'],
#  ['Cobble Hill', 'Brooklyn'],
#  ['Hamilton Heights', 'Manhattan'],
#  ['Bloomfield', 'Staten Island'],
#  ['Carroll Gardens', 'Brooklyn'],
#  ['Manhattanville', 'Manhattan'],
#  ['Bulls Head', 'Staten Island'],
#  ['Red Hook', 'Brooklyn'],
#  ['Central Harlem', 'Manhattan'],
#  ['Carnegie Hill', 'Manhattan'],
#  ['Gowanus', 'Brooklyn'],
#  ['East Harlem', 'Manhattan'],
#  ['Noho', 'Manhattan'],
#  ['Fort Greene', 'Brooklyn'],
#  ['Upper East Side', 'Manhattan'],
#  ['Civic Center', 'Manhattan'],
#  ['Park Slope', 'Brooklyn'],
#  ['Yorkville', 'Manhattan'],
#  ['Midtown South', 'Manhattan'],
#  ['Cypress Hills', 'Brooklyn'],
#  ['Lenox Hill', 'Manhattan'],
#  ['Richmond Town', 'Staten Island'],
#  ['East New York', 'Brooklyn'],
#  ['Roosevelt Island', 'Manhattan'],
#  ['Shore Acres', 'Staten Island'],
#  ['Starrett City', 'Brooklyn'],
#  ['Upper West Side', 'Manhattan'],
#  ['Clifton', 'Staten Island'],
#  ['Canarsie', 'Brooklyn'],
#  ['Lincoln Square', 'Manhattan'],
#  ['Concord', 'Staten Island'],
#  ['Flatlands', 'Brooklyn'],
#  ['Clinton', 'Manhattan'],
#  ['Emerson Hill', 'Staten Island'],
#  ['Mill Island', 'Brooklyn'],
#  ['Midtown', 'Manhattan'],
#  ['Randall Manor', 'Staten Island'],
#  ['Manhattan Beach', 'Brooklyn'],
#  ['Murray Hill', 'Manhattan'],
#  ['Howland Hook', 'Staten Island'],
#  ['Coney Island', 'Brooklyn'],
#  ['Chelsea', 'Manhattan'],
#  ['Elm Park', 'Staten Island'],
#  ['Bath Beach', 'Brooklyn'],
#  ['Greenwich Village', 'Manhattan'],
#  ['Remsen Village', 'Brooklyn'],
#  ['Borough Park', 'Brooklyn'],
#  ['East Village', 'Manhattan'],
#  ['New Lots', 'Brooklyn'],
#  ['Dyker Heights', 'Brooklyn'],
#  ['Lower East Side', 'Manhattan'],
#  ['Paerdegat Basin', 'Brooklyn'],
#  ['Tribeca', 'Manhattan'],
#  ['Gerritsen Beach', 'Brooklyn'],
#  ['Mill Basin', 'Brooklyn'],
#  ['Little Italy', 'Manhattan'],
#  ['Jamaica Hills', 'Queens'],
#  ['Marine Park', 'Brooklyn'],
#  ['Soho', 'Manhattan'],
#  ['Utopia', 'Queens'],
#  ['Clinton Hill', 'Brooklyn'],
#  ['West Village', 'Manhattan'],
#  ['Pomonok', 'Queens'],
#  ['Sea Gate', 'Brooklyn'],
#  ['Manhattan Valley', 'Manhattan'],
#  ['Astoria Heights', 'Queens'],
#  ['Downtown', 'Brooklyn'],
#  ['Morningside Heights', 'Manhattan'],
#  ['Claremont Village', 'Bronx'],
#  ['Boerum Hill', 'Brooklyn'],
#  ['Gramercy', 'Manhattan'],
#  ['Concourse Village', 'Bronx'],
#  ['Prospect Lefferts Gardens', 'Brooklyn'],
#  ['Mount Eden', 'Bronx'],
#  ['Battery Park City', 'Manhattan'],
#  ['Ocean Hill', 'Brooklyn'],
#  ['Mount Hope', 'Bronx'],
#  ['City Line', 'Brooklyn'],
#  ['Financial District', 'Manhattan'],
#  ['Sutton Place', 'Manhattan'],
#  ['Bergen Beach', 'Brooklyn'],
#  ['Astoria', 'Queens'],
#  ['Hunters Point', 'Queens'],
#  ['Midwood', 'Brooklyn'],
#  ['Woodside', 'Queens'],
#  ['Turtle Bay', 'Manhattan'],
#  ['Prospect Park South', 'Brooklyn'],
#  ['Jackson Heights', 'Queens'],
#  ['Tudor City', 'Manhattan'],
#  ['Georgetown', 'Brooklyn'],
#  ['Elmhurst', 'Queens'],
#  ['Stuyvesant Town', 'Manhattan'],
#  ['East Williamsburg', 'Brooklyn'],
#  ['Howard Beach', 'Queens'],
#  ['Flatiron', 'Manhattan'],
#  ['North Side', 'Brooklyn'],
#  ['Corona', 'Queens'],
#  ['Sunnyside Gardens', 'Queens'],
#  ['South Side', 'Brooklyn'],
#  ['Forest Hills', 'Queens'],
#  ['Blissville', 'Queens'],
#  ['Ocean Parkway', 'Brooklyn'],
#  ['Kew Gardens', 'Queens'],
#  ['Fulton Ferry', 'Brooklyn'],
#  ['Fort Hamilton', 'Brooklyn'],
#  ['Richmond Hill', 'Queens'],
#  ['Vinegar Hill', 'Brooklyn'],
#  ['Chinatown', 'Manhattan'],
#  ['Flushing', 'Queens'],
#  ['Weeksville', 'Brooklyn'],
#  ['Washington Heights', 'Manhattan'],
#  ['Long Island City', 'Queens'],
#  ['Broadway Junction', 'Brooklyn'],
#  ['Sunnyside', 'Queens'],
#  ['Dumbo', 'Brooklyn'],
#  ['East Elmhurst', 'Queens'],
#  ['Manor Heights', 'Staten Island'],
#  ['Maspeth', 'Queens'],
#  ['Willowbrook', 'Staten Island'],
#  ['Ridgewood', 'Queens'],
#  ['Sandy Ground', 'Staten Island'],
#  ['Egbertville', 'Staten Island'],
#  ['Glendale', 'Queens'],
#  ['Roxbury', 'Queens'],
#  ['Homecrest', 'Brooklyn'],
#  ['Rego Park', 'Queens'],
#  ['Middle Village', 'Queens'],
#  ['Woodhaven', 'Queens'],
#  ["Prince's Bay", 'Staten Island'],
#  ['Ozone Park', 'Queens'],
#  ['Lighthouse Hill', 'Staten Island'],
#  ['South Ozone Park', 'Queens'],
#  ['Richmond Valley', 'Staten Island'],
#  ['Malba', 'Queens'],
#  ['College Point', 'Queens'],
#  ['Highland Park', 'Brooklyn'],
#  ['Whitestone', 'Queens'],
#  ['Madison', 'Brooklyn'],
#  ['Bronxdale', 'Bronx'],
#  ['Bayside', 'Queens'],
#  ['Allerton', 'Bronx'],
#  ['Auburndale', 'Queens'],
#  ['Kingsbridge Heights', 'Bronx'],
#  ['Little Neck', 'Queens'],
#  ['Erasmus', 'Brooklyn'],
#  ['Douglaston', 'Queens'],
#  ['Hudson Yards', 'Manhattan'],
#  ['Glen Oaks', 'Queens'],
#  ['Hammels', 'Queens'],
#  ['Bellerose', 'Queens'],
#  ['Bayswater', 'Queens'],
#  ['Kew Gardens Hills', 'Queens'],
#  ['Queensbridge', 'Queens'],
#  ['Fresh Meadows', 'Queens'],
#  ['Fox Hills', 'Staten Island'],
#  ['Briarwood', 'Queens'],
#  ['Jamaica Center', 'Queens'],
#  ['Oakland Gardens', 'Queens'],
#  ['Queens Village', 'Queens'],
#  ['Hollis', 'Queens'],
#  ['South Jamaica', 'Queens'],
#  ['St. Albans', 'Queens'],
#  ['Rochdale', 'Queens'],
#  ['Springfield Gardens', 'Queens'],
#  ['Cambria Heights', 'Queens'],
#  ['Rosedale', 'Queens'],
#  ['Far Rockaway', 'Queens'],
#  ['Broad Channel', 'Queens'],
#  ['Breezy Point', 'Queens'],
#  ['Steinway', 'Queens'],
#  ['Beechhurst', 'Queens'],
#  ['Bay Terrace', 'Queens'],
#  ['Edgemere', 'Queens'],
#  ['Arverne', 'Queens'],
#  ['Rockaway Beach', 'Queens'],
#  ['Neponsit', 'Queens'],
#  ['Murray Hill', 'Queens'],
#  ['Floral Park', 'Queens'],
#  ['Holliswood', 'Queens'],
#  ['Jamaica Estates', 'Queens'],
#  ['Queensboro Hill', 'Queens'],
#  ['Hillcrest', 'Queens'],
#  ['Ravenswood', 'Queens'],
#  ['Lindenwood', 'Queens'],
#  ['Laurelton', 'Queens'],
#  ['Lefrak City', 'Queens'],
#  ['Belle Harbor', 'Queens'],
#  ['Rockaway Park', 'Queens'],
#  ['Somerville', 'Queens'],
#  ['Brookville', 'Queens'],
#  ['Bellaire', 'Queens'],
#  ['North Corona', 'Queens'],
#  ['Forest Hills Gardens', 'Queens'],
#  ['St. George', 'Staten Island'],
#  ['New Brighton', 'Staten Island'],
#  ['Stapleton', 'Staten Island'],
#  ['Rosebank', 'Staten Island'],
#  ['West Brighton', 'Staten Island'],
#  ['Grymes Hill', 'Staten Island'],
#  ['Todt Hill', 'Staten Island']]

# %%
# get just NY data
nycdf = h1b.loc[np.logical_or(h1b.lca_case_workloc1_state == "NY", h1b.lca_case_workloc2_state == "NY"), :]
nycdf = nycdf.drop(nycdf[np.logical_and(nycdf.lca_case_workloc2_state == "NY", pd.isnull(nycdf.lca_case_workloc2_city))].index)
nycdf.shape
# Out:
# (42224, 33)

# %%
ny_cities = nycdf[h1b.lca_case_workloc1_state == "NY"].dropna(subset=["lca_case_workloc1_city"])
ny_cities = ny_cities["lca_case_workloc1_city"].unique()
ny_cities
len(ny_cities)
# Out:
# /home/kilian/.envs/elucd/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 641

# %%
ny_cities_2 = nycdf[h1b.lca_case_workloc2_state == "NY"].dropna(subset=["lca_case_workloc2_city"])
ny_cities_2 = ny_cities_2["lca_case_workloc2_city"].unique()
ny_cities_2
# len(ny_cities_2)
# Out:
# /home/kilian/.envs/elucd/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# array(['NEW YORK', 'FLUSHING', 'ALBANY', 'BRONX', 'FARMINGDALE',
#        'LIVERPOOL', 'GLENS FALLS', 'NEW WINDSOR', 'BUFFALO', 'UPTON',
#        'BROOKLYN', '3RD FLOOR', 'HICKSVILLE, NY', 'DUNKIRK', 'HICKSVILLE',
#        'RIDGEWOOD', 'BABYLON', 'COLONIE', 'SCHENECTADY', 'WHITE PLAINS',
#        'GREAT NECK', 'NEW HYDE PARK', 'TROY', 'WARRENSBURG', 'WOODBURY',
#        'MELVILLE', 'CLIFTON PARK', 'PEARL RIVER', 'FOREST HILLS',
#        'HAWTHORNE', 'NEW YORK CITY', 'PISCATAWAY', 'CORNING', 'RYE BROOK',
#        'ELMHURST', 'WILLIAMSVILLE', 'ROCHESTER', 'JACKSON HEIGHTS',
#        'POUGHKEEPSIE', 'S RICHMOND HILL', 'YORKTOWN HEIGHTS', 'SEAFORD',
#        'TARRYTOWN', 'RENSSELAER', 'FRESH MEADOWS', 'DELMAR', 'SYRACUSE',
#        'GREENE', 'RYE', 'NEW HAMPTON', 'LONG ISLAND CITY', 'AMHERST',
#        'FREEPORT', 'SUFFERN', 'SENECA FALLS', 'JAMAICA', 'STONY BROOK',
#        'IRONDEQUOIT', 'HAUPPAUGE', 'MANHATTAN', 'GATES', 'TONAWANDA',
#        'ARMONK', 'UTICA', 'CORTLAND', 'LAKE SUCCESS', 'BETHPAGE',
#        'PURCHASE', 'ITHACA', 'OSSINING', 'WALLKILL', 'SOUTH FALLSBURG',
#        'UNIONDALE', 'SOMERS', 'STATEN ISLAND', 'WEST HARRISON',
#        'NORTH TONAWANDA', 'WEBSTER', 'VALHALL', 'SLEEPY HOLLOW',
#        'ALTAMONT', 'ISLANDIA', 'COLD SPRING HARBOR', 'BOHEMIA', 'MALTA',
#        'ROCHESTER,', 'NORWICH', 'ALBANY,', 'BATAVIA', 'BINGHAMTON',
#        'LYNBROOK', 'JOHNSON STREET', 'JOHNSON CITY', 'REGO PARK', 'NEWARK',
#        'WATERTOWN', 'VESTAL', 'CHEEKTOWAGA', 'CLARENCE', 'GETZVILLE',
#        'MOUNT VERNON', 'NEWYORK', 'WARWICK', 'HARTSDALE', 'VALHALLA',
#        'FAIRPORT', 'MENANDS', 'OGDENSBURG', 'NIAGARA FALLS', 'FISHKILL',
#        'HAMBURG', 'MANHASSET', 'PITTSFORD', 'NEW HARTFORD', 'NISKAYUNA',
#        'BAY SHORE', 'DEER PARK', 'WELLSVILLE', 'OLEAN', 'RONKONKOMA',
#        'AUBURN', 'MALONE', 'EDGEWOOD', 'MIDDLETOWN', 'ROTTERDAM',
#        'PLATTSBURGH', 'HOPEWELL JUNCTION', 'BALDWIN', 'HARRISON',
#        'POTSDAM', 'ORCHARD PARK', 'NEW YORK,', 'MONROE', 'VICTOR',
#        'WAPPINGERS FALLS', 'LATHAM', 'YONKERS', 'PORT JEFFERSON STATION',
#        'LONG BEACH', 'WESTBURY', 'PORT WASHINGTON', 'OLD FIELD', 'BELMONT',
#        'FRESHMEADOWS', 'LYNBROOK,', 'TAPPAN', 'JAMESTOWN',
#        'NEW YORK CITY,', 'SALAMANCA', 'JERSEY CITY', 'SNYDER',
#        'EAST AURORA', 'PEARLE RIVER', 'FALLSBURG', 'WESTFIELD', 'ROME',
#        'IRVING', 'BEDFORD', 'ISELIN', 'ROCK HILL', 'GARDEN CITY',
#        'JERICHO', 'NYC', 'PAINTED POST', 'CORNWALL', 'WOODSIDE', 'SYOSSET',
#        'HEMPSTEAD', 'AMITYVILLE', 'OSWEGO', 'WEST MENANDS', 'HOLLIS',
#        'DALLAS', 'CAZENOVIA', '#35620 OZONE PARK NY MSA', 'BAYSHORE',
#        'MAHOPAC', 'SCARSDALE', 'HAWTHORN', 'MINEOLA',
#        'FOREST HILLS QUEENS', 'MURRAY HILL', 'SARANAC LAKE', 'AMSTERDAM',
#        'COOPERSTOWN', 'ELMSFORD', 'DEPEW', 'MASSENA', 'HORSEHEADS',
#        'PENFIELD', 'ORANGEBURG', 'NEWBURGH', 'OLD WESTBURY', 'BROCKPORT',
#        'FORT EDWARD', 'BATH', 'FAR ROCKAWAY', 'ASTORIA', 'QUEENS',
#        'SPRING VALLEY', 'LOCKPORT', 'EAST JEWETT', 'GLEN FALLS', 'POMONA',
#        'NEW ROCHELLE', 'SOUTH OZONE PARK', 'COBLESKILL', 'SANBORN',
#        'ELMIRA', 'ORISKANY', 'SOUTH HAMPTON', 'NORTH CREEK', 'WOLCOTT',
#        'CARTHAGE', 'NORTH SALEM', 'SUNNYSIDE', 'OCEANSIDE', 'BIG FLATS',
#        'TICONDEROGA', 'EAST AMHERST', 'WHITE PLAIN', 'HOLTSVILLE',
#        'EDISON', 'CARLE PLACE', 'RIVERHEAD', 'PLAINVIEW', 'DOUGLASTON',
#        'PARLIN', 'ONEIDA', 'FULTON', 'TARRY TOWN', 'CHAPPAQUA',
#        'VALLEY STREAM', 'BUILDING 12', 'ALBERTSON', 'LARCHMONT',
#        'SOUTHAMPTON'], dtype=object)

# %%
ny_cities = list(set(ny_cities).union(set(ny_cities_2)))

# %%
nabe_boros = list(set(nabe_boros))
ny_cities
# Out:
# ['MOUNT SINAI',
#  'BATH',
#  'NAPANOCH',
#  'NEW WINDSOR',
#  'GILBOA',
#  'KEW GARDENS',
#  'METRO JERICHO',
#  'WOODBURRY',
#  'DANNEMORA',
#  'SYRACUSE',
#  'MALONE',
#  'WATERVLIET',
#  'ELMONT',
#  'HIGH FALLS',
#  'MENANDAS',
#  'OLD BROOKVILLE',
#  'SENECA FALLS',
#  'DELHI',
#  'GLENDALE',
#  'HURLEYVILLE',
#  'ONEIDA',
#  'ROCHDALE VILLAGE',
#  'GRAND ISLAND',
#  'CORNWALL',
#  'STONY POINT',
#  'LATHAM',
#  '1 COURT SQUARE',
#  'SOMERS',
#  'CORTLAND',
#  'ORANGEBURG',
#  'HAUPPAUGE',
#  'EAST NORTHPORT',
#  'WILLISTON PARK',
#  'BROOKVILLE',
#  'TUXEDO',
#  'PLATTSBURGH',
#  'ALBANY NY 12237',
#  'CENTEREACH',
#  'PAINTED POST',
#  'EAST FISHKILL',
#  'MACEDON',
#  'PORT JEFFERSON STATION',
#  'PORT JEFFERSON',
#  'GATES',
#  'EAST AMHERST',
#  'ST. ALBANS',
#  'ROCHESTER',
#  'WOODBURY,',
#  'TONAWANDA',
#  'ROTTERDAM',
#  'PITTSFORD',
#  'MEDFORD',
#  'NEW YORK,',
#  'WEST HARRISON',
#  'WOODHAVEN',
#  'HAWTHORN',
#  'CHEEKTOWAGA,',
#  'SAN FRANCISCO',
#  'FREDONIA',
#  'RENSSELAR',
#  'ALFRED',
#  'WATERBURY',
#  'VOORHEESVILLE',
#  'KATONAH',
#  'MALVERNE',
#  'STAATSBURG',
#  'HUDSON',
#  'WATEFORD',
#  'YORKTOWN HEIGHTS',
#  'NEW ORK',
#  'SUITE 1802',
#  'MILLERTON',
#  'PELHAM MANOR',
#  'RENSSELAER',
#  'SLEEPY HOLLOW, NEW YORK',
#  'PHILADELPHIA',
#  '6TH FLOOR, ROOM 6027W',
#  'NYC',
#  'GLENMONT',
#  'PALISADES',
#  'HOLBROOK',
#  'BROOKLYN,',
#  'CORNING',
#  '6TH FLOOR',
#  'ALBION',
#  'RICHFIELD SPRINGS',
#  'MT. KISCO',
#  'JAMESVILLE',
#  'ENDWELL',
#  'WAYLAND',
#  'PARSIPPANY',
#  'MURRAY HILL',
#  'LONG ISLAND CITY',
#  'SAYVILLE',
#  'SAUGERTUES',
#  'LYNBROOK,',
#  'SARANAC LAKE',
#  'MANHATTAN',
#  'DOWNTOWN BROOKLYN',
#  'MOUNT VERNON',
#  'MT.KISCO',
#  'HAMILTON',
#  'YAPHANK',
#  'BRONX.NEW YORK',
#  'DEWITT',
#  'SILVER CREEK',
#  'COLD SPRING HARBOR',
#  'JAMESTOWN',
#  'SOUTH BUFFALO',
#  'ROCHESTER,',
#  '#35620 OZONE PARK NY MSA',
#  'BATAVIA',
#  'OLD WESTBURY',
#  'NYACK',
#  'ISELIN',
#  'OLEAN',
#  'WILLIAMSBURG, BROOKLYN',
#  'WHITE PLAINS',
#  'WEST BABYLON',
#  'WEST CALDWELL',
#  'GLENS FALLS',
#  'FRESH MEADOWS',
#  'CANANDAIGUA',
#  'BELLPORT',
#  'BLOOMFIELD',
#  'NEW YORK,NEW YORK',
#  'ELMSFORD',
#  'ALDEN',
#  'PO BOX 299',
#  'FRANKLIN SQUARE',
#  'FLORIDA',
#  'FOREST HILLS',
#  'RIVERDALE',
#  'AUBURN',
#  'DEER PARK',
#  'TEWKSBURY',
#  'CLEARWATER',
#  'RHINEBECK',
#  'DUNDEE',
#  'LOUDONVILLE',
#  'NEW TORK',
#  'WEST MENANDS',
#  'BRONX,NEW YORK',
#  'SYRACUSE,',
#  'MEDINA',
#  'PATCHOGUE',
#  'WHITESTONE',
#  'PORT JERVIS',
#  'SHRILEY',
#  'SAG HARBOR',
#  'TARRY TOWN',
#  'CLIFTON SPRINGS',
#  'WARWICK',
#  'NEW YORK, NEW YORK',
#  'WILLIAMSBURGH',
#  'EAST ISLIP',
#  'WESBURY',
#  'BRONX',
#  'EAST MEADOW',
#  'JAMAICA, NY',
#  'LINDENHURST',
#  'SANBORN',
#  'LAS VEGAS',
#  'SELDEN',
#  'WESTBURY',
#  'WESTFIELD',
#  'SUITE 300',
#  'LIBERTY',
#  'BAYSIDE',
#  'WAPPINGERS FALLS',
#  'MASSENA',
#  'YONKERS',
#  'GREEN ISLAND',
#  'ORISKANY',
#  'GUILDERLAND',
#  'RICHMONDVILLE',
#  'SALT POINT',
#  'VALHALL',
#  'HEMPSTEAD',
#  'HORNELL',
#  '160 CONVENT AVENUE',
#  'GLEN OAKS',
#  'HAVESTRAW',
#  'MEW YORK',
#  'TICONDEROGA',
#  'BUFFALO',
#  'NEW WINDSOW',
#  'OGDENSBURG',
#  'NEW HAMPTON',
#  'MALTA',
#  'LITTLE NECK',
#  'POMONA',
#  'VALHALLA',
#  'BROOKYLN',
#  'SELKIRK',
#  'WARRENSBURG',
#  'FLUSHING',
#  'LAKE KATRINE',
#  'PORT WASHINGTON,',
#  'ALBANY,',
#  'SODUS',
#  'BINGHMTON',
#  'SOUTH FALLSBURG',
#  '348 LAKE ROAD',
#  'SHIRLEY',
#  'MANHATTAN, NEW YORK',
#  'GRANVILLE',
#  'DEPEW',
#  'ARVERNE',
#  'SCHENECTADYæ',
#  'GARDEN CITY',
#  'NEW YORK',
#  'HOLLIS',
#  'GREECE',
#  'LITTLE FALLS',
#  'MONTICELLO',
#  'FOREST HILLS QUEENS',
#  'VICTOR',
#  'NORTHUMBERLAND',
#  'GREENVALE',
#  'HARRIMAN',
#  'FRANKLIN SQ',
#  'CORFU',
#  'DEERPARK',
#  'FLORAL PARK',
#  'HORSE HEADS',
#  'NEWYORK CITY',
#  'FAYETTEVILLE',
#  'CHAPPAQUA',
#  'MERRILL',
#  'KENMORE',
#  'NORTH TONAWANDA,',
#  'EAST HAMPTON',
#  'REGO PARK',
#  'CARLE PLACE,',
#  'MT. VERNON',
#  'BEDFORD HILLS',
#  'BROOKLN',
#  'ENDICOTT',
#  'HOLTSVILLE',
#  'EAST ROCHESTER',
#  'SCOTIA',
#  'DELMAR',
#  'QUEENS',
#  'UNION',
#  'BALITMORE',
#  'FARMINGDALE',
#  'AIRMONT',
#  'NEW YORK, NY',
#  'BELLEROSE',
#  'BROOKLY',
#  'DANSVILLE',
#  'ROSLYN',
#  'LOCUST VALLEY',
#  'WELLSVILLE',
#  'ANNANDALE ON HUDSON',
#  'HICKSVILLE, NY',
#  'ITHICA',
#  'COBLESKILL',
#  'UNIONDALE',
#  'BROOKHAVEN',
#  'NIAGARA UNIVERSITY',
#  'MAHOPAC',
#  'INWOOD',
#  'BRIDGEHAMPTON',
#  'GREENPORT',
#  'PURCHASE',
#  'BOSTON',
#  'COPIAGUE',
#  'ROCKY POINT',
#  'LAKE VIEW',
#  'PHOENIX',
#  '55 WATER STREET',
#  'MEDIACOM PARK',
#  'GREAT NECK,',
#  'MELVILLE',
#  'WARSAW',
#  'QUEENS VILLAGE',
#  'BINGHAMTON',
#  'SPRINGFIELD GARDENS',
#  'GOSHEN',
#  'SEA CLIFF',
#  'NEW YORK, NY -',
#  'EAST GREENBUSH',
#  'BABYLON',
#  'RIVERHEAD',
#  'NISKAYUNA',
#  'SOUTHOLD',
#  'MASPETH',
#  'HOPEWELL JCT',
#  'BEDMINSTER',
#  'JAMIACA',
#  'ISLANDIA',
#  'BROOKYN',
#  'GREATNECK',
#  'WACCABUC',
#  'POUGHKEEPSIE',
#  'FLUSHING, NY',
#  'BUFFALO,',
#  'AUSTIN',
#  'LIC',
#  'EDISON',
#  'CROTON-ON-HUDSON',
#  'ROCK HILL',
#  'SPRING VALLEY',
#  'DEER PATH',
#  'WHITETONE',
#  'SUITE 210',
#  'PULASKI',
#  'WEST ISLIP',
#  'BUILDING 12',
#  'MAMARONECK',
#  '701 WEST 168TH STREET',
#  'RIDGEWOOD',
#  'EDGEWOOD',
#  'GLEN COVE',
#  'FREEPORT',
#  '630 WEST 168TH STREET',
#  'VAHALLA',
#  'RYE',
#  'CEDARHURST',
#  'NASSAU',
#  'BOHEMIA',
#  'FRESHMEADOWS',
#  'GREENPOINT',
#  'NORTH SYRACUSE',
#  'DUNKIRK',
#  'LONG BEACH',
#  'NEW YROK',
#  'NEW CITY',
#  'LIVERPOOL',
#  'FULTON',
#  'OLD FIELD',
#  'SCARSDALE',
#  'AURORA',
#  'CASSADAGA',
#  'FRAMINGDALE',
#  'WILMINGTON',
#  'UNION CITY',
#  'RONKONKOMA',
#  'ANGOLA',
#  'FORREST HILLS',
#  'BIG FLATS',
#  'FAR ROCKAWAY',
#  'EAST SYRACUSE',
#  'OAKLAND GARDENS',
#  'HARRISON',
#  'LAKE PLACID',
#  'VALATIE',
#  'MORRISVILLE',
#  'COLLEGE POINT',
#  'HARRIS',
#  'AUBURNDALE',
#  'HAMPTON BAYS',
#  'S RICHMOND HILL',
#  'LONG ISLAND CITY,',
#  'LAKE SUCCESS',
#  'THORNWOOD',
#  'CHARLOTTE',
#  'HORSEHEADS',
#  'OCEANSIDE',
#  'BELLEVUE',
#  'JERICHO',
#  'NEW YOURK',
#  'WHITESBORO',
#  'SUITE 945',
#  'PORT WASHINGTON',
#  'ROSEDALE',
#  'ROME',
#  'SEAFORD',
#  'ALEXANDRIA BAY',
#  'YORKERS',
#  'FREMONT',
#  'CHITTENANGO',
#  'MATTITUCK',
#  'MONSEY',
#  'LANSING',
#  'GETZILLE',
#  'WEST HAMPTON BEACH',
#  'FALLSBURG',
#  'SUFFEREN',
#  'SYOSSET',
#  'PISCATAWAY',
#  'CLINTONDALE',
#  'NEWBURGH',
#  'BRONX, NEW YORK',
#  'LONG ISLAD CITY',
#  'WILLAMSVILLE',
#  'OSSINING',
#  'HICKSVILLE',
#  'BAYSHORE',
#  'CLIFTON PARK',
#  'ELMHURST',
#  'SMYRNA',
#  'NEW PALTZ',
#  'LEVITTOWN',
#  'BRENTWOOD',
#  'SCOTTSVILLE',
#  'ONEONTA',
#  'PLATTSBURG',
#  '3RD FLOOR',
#  'EAST JEWETT',
#  'PAWLING',
#  'CALVERTON',
#  'THROGGS NECK',
#  'NEW HYDE PARK',
#  'RICHMOND HILL',
#  'HENRIETTA',
#  'LAKEWOOD',
#  'WEBSTER',
#  'PLAINVIEW',
#  'DOBBS FERRY',
#  'HASTINGS ON HUDSON',
#  'FISHKILL',
#  'ARGYLE',
#  '7980 TURIN RD., BLDG. 1',
#  'FORT EDWARD',
#  'PETERSBURGH',
#  'BALLSTON SPA',
#  'ITHACA',
#  'WOODSIDE',
#  'JERSEY CITY',
#  'WHITEPLAINS',
#  'EAST MIDDLETOWN',
#  'LONG IS CITY',
#  'JAMAICA',
#  'WOODMERE',
#  'SKANEATELES',
#  'OAK HILL',
#  'HOUSTON',
#  'ROSLYN HEIGHTS',
#  'ELIZABETHTOWN',
#  'GARDEN CITY PARK',
#  'NIAGARA FALLS',
#  'MENANDS',
#  'ALTAMONT',
#  'SCHENECTADY',
#  'EDEN',
#  'NEW ROCHELLE',
#  'LIVINGSTON',
#  'JOHNSON STREET',
#  'COLONIE',
#  'GREAT NECK',
#  'LYONS',
#  'BRONX,NY',
#  'YORK',
#  'HONEOYE FALLS',
#  'NORTHPORT',
#  'GETZVILLE',
#  'HAUPPAGUE',
#  'LONG ISLAND',
#  'HAWTHORNE',
#  'MIDDLEBURGH',
#  'ROCKAWAY',
#  'SOUTHAMPTON',
#  'EAST DURHAM',
#  'SUFFERN',
#  'MERRICK',
#  'UPTON',
#  'GLEAN HEAD',
#  'FAIRPORT',
#  'LAGRANGEVILLE',
#  'BOWLING GREEN',
#  'ST. JAMES',
#  'VALLEY COTTAGE',
#  'SAINT JAMES',
#  'CANADAIGUA',
#  'ALBERTSON',
#  'ARDSLEY',
#  'KIRKWOOD',
#  'LONGISLAND CITY',
#  'OCEANSIDE,',
#  'BAY SHORE',
#  'KEW GARDEN',
#  'ISLIP TERRACE',
#  'GENESEO',
#  'PORT CHESTER',
#  'BREWSTER',
#  'WEBSTER,',
#  'ELMHRUST',
#  'ORCHARD PARK',
#  'PENFIELD',
#  'ROCHESTER, N.Y.',
#  'RYE BROOK',
#  'OWEGO',
#  'BALLSTON LAKE',
#  'ALBANY',
#  'GOUVERNEUR',
#  'CLARENCE',
#  'HUNTINGTON',
#  'RENSSELAE',
#  'MANHASSET',
#  'NEW HARTFORD',
#  'SALAMANCA',
#  'SLEEPY HOLLOW',
#  'BROADWAY',
#  'CASTLETON-ON-HUDSON',
#  'PEARLE RIVER',
#  'ROCKVILLE CENTRE',
#  'PALMYRA',
#  'AMHERST',
#  'BERGEN',
#  'CHELSEA',
#  'ELMIRA',
#  'AGRYLE',
#  'CANTON',
#  'BRONXVILLE',
#  'EMPIRE STATE PLAZA',
#  'METRO ALBANY',
#  'WHITE PLAIN',
#  'AMSTERDAM',
#  'BRIDGEPORT / NEW YORK',
#  'GLOVERSVILLE',
#  'NEWARK',
#  'ST.ELMIRA',
#  'BROOKLYN',
#  'HOPEWELL JUNCTION,',
#  'HYDE PARK',
#  '13 W.100TH STREET, APT. 4B',
#  'WATERFORD',
#  'BRIARCLIFF MANOR',
#  'LYNBROOK',
#  'CHEEKTOWAGA',
#  'BLAUVELT',
#  'CHESTNUT RIDGE',
#  'MINEOLA',
#  'SCHENACTADY',
#  'PALISADAES',
#  'SLOATSBURG',
#  'MELVILLE,',
#  'OAKDALE',
#  'DIX HILLS',
#  'HOWARD BEACH',
#  '* 6. POSTAL CODE * PREVAIL',
#  'WEST HEMPSTEAD',
#  'MIAMI',
#  'EAST ELMHURST',
#  'MONROE',
#  'MIDDLETOWN',
#  'CHESTER',
#  'NEW YOK',
#  'BETHPAGE',
#  'CONGERS',
#  'QUEENSBURY',
#  'GASPORT',
#  'ADAMS CENTER',
#  'NEW BERLIN',
#  'SUITE 600',
#  'TUCKAHOE',
#  '160 FORT WASHINGTON AVENUE',
#  'CENTER MORICHES',
#  'TUXEDO PARK',
#  'GARRISON',
#  'WILLIAMSVILLE',
#  'WATERTOWN',
#  'MOUNT KISCO',
#  'AMITYVILLE',
#  'COMMACK',
#  'MOUNTAINVILLE',
#  'NORTH SALEM',
#  'CAZENOVIA',
#  'GOWANDA',
#  'NEW YORK CITY',
#  'GLEN FALLS',
#  'BEACON',
#  'TARRYTOWN',
#  'WOLCOTT',
#  'CATSKILL',
#  'ST. JOHNSVILLE',
#  'LANCASTER',
#  'TAPPAN',
#  'WALLKILL',
#  'ASTORIA',
#  'IRVINGTON',
#  'OSWEGO',
#  'BRIARWOOD',
#  'LACKAWANNA',
#  'CARTHAGE',
#  'ROCKAWAY PARK',
#  'GREENE',
#  'CULVER CITY',
#  'WEST ALBANY',
#  'NEWYORK',
#  'BALDWIN',
#  'EDGEWOOD NY',
#  'NORWICH',
#  'GENEVA',
#  'HOLMES',
#  'MARCY',
#  'MASPATH',
#  'SOUTH PLAINFIELD',
#  'HOUGHTON',
#  'LAURELTON',
#  'GREAT RIVER',
#  'L.I.C.',
#  'IRVING',
#  'WEST SENECA',
#  'EAST ROCKAWAY',
#  'NORTH TONAWANDA',
#  'GHENT',
#  'MANHATAN',
#  'DOUGLASTON',
#  'SAUGERTIES',
#  'OAKLAND',
#  'KINGSTON',
#  'WEST HENRIETTA',
#  '5 TIMES SQUARE',
#  'WALTON',
#  'ELMA',
#  'CORONA',
#  'BROCKPORT',
#  'BELMONT',
#  'NORTH CREEK',
#  'HOPEWELL JUNCTION',
#  'CANANDIUAGA',
#  'HARTSDALE',
#  'JOHNSON CITY',
#  'NEW YOUR',
#  'VALLEY STREAM',
#  'CRANFORD',
#  'TONWANDA',
#  'DALLAS',
#  'CLINTON',
#  'ANNANDALE-ON-HUDSON',
#  'CENTRAL ISLIP',
#  'SARATOGA SPRINGS',
#  'SOUTH OZONE PARK',
#  'HIGHLAND',
#  'WEST NYACK',
#  'HOMER',
#  'UTICA',
#  'EAST AURORA',
#  'EAST SETAUKET',
#  'MONTEBELLO',
#  'VALATIE.',
#  'MASSAPEQUA',
#  'JACKSON HEIGHTS',
#  'WARREN',
#  'CHAMPLAIN',
#  'OZONE PARK',
#  'PARLIN',
#  'SOUTH HAMPTON',
#  'PAINTED POST,',
#  'MOUNTAIN VIEW',
#  'PEEKSKILL',
#  'GAINESVILLE',
#  'BRIGHTSWATERS',
#  'CARMEL',
#  'LARCHMONT',
#  'SKANEATELES FALLS',
#  'PALATINE BRIDGE',
#  'IRONDEQUOIT',
#  'THROGS NECK',
#  'EASTCHESTER',
#  'SOUTH RICHMOND HILL',
#  '325 HUDSON STREET, 9TH FLOOR',
#  'HOOSICK FALLS',
#  'WILLAIMSVILLE',
#  'POTSDAM',
#  'NY',
#  'ATLANTA',
#  'METRO NEW YORK',
#  'MIDDLE VILLAGE',
#  'VESTAL',
#  'LEWISTON',
#  'CORTLANDT MANOR',
#  'WAINSCOTT',
#  'BEDFORD',
#  'ARMONK',
#  'CARLE PLACE',
#  'NANUET',
#  'MIDTOWN MANHATTAN',
#  'LOCKPORT',
#  'SUNNYSIDE',
#  'SNYDER',
#  'NEW',
#  'STATEN ISLAND',
#  'COOPERSTOWN',
#  'PLEASANTVILLE',
#  'STONY BROOK',
#  'LATHAMæ',
#  'PEARL RIVER',
#  'TROY',
#  'HAMBURG',
#  'WOODBURY',
#  'BARDONIA',
#  'WURTSBORO',
#  'NEW YORK CITY,',
#  'PELHAM',
#  'RENNSELAER']

# %%
# let's do a borough pass first, should be safe, then do neighbourhoods and see what's left
boro_matches = [process.extractOne(city, nabe_boros) for city in ny_cities]
boro_matches
# Out:
# [('Queens', 45),
#  ('Manhattan', 45),
#  ('Manhattan', 47),
#  ('Staten Island', 42),
#  ('Staten Island', 45),
#  ('Queens', 47),
#  ('Bronx', 36),
#  ('Bronx', 36),
#  ('Manhattan', 33),
#  ('Staten Island', 34),
#  ('Manhattan', 45),
#  ('Staten Island', 35),
#  ('Manhattan', 45),
#  ('Manhattan', 21),
#  ('Staten Island', 48),
#  ('Brooklyn', 68),
#  ('Staten Island', 40),
#  ('Staten Island', 36),
#  ('Staten Island', 43),
#  ('Queens', 35),
#  ('Staten Island', 45),
#  ('Staten Island', 41),
#  ('Staten Island', 72),
#  ('Bronx', 36),
#  ('Staten Island', 50),
#  ('Manhattan', 45),
#  ('Queens', 45),
#  ('Queens', 33),
#  ('Staten Island', 48),
#  ('Bronx', 36),
#  ('Manhattan', 33),
#  ('Manhattan', 35),
#  ('Bronx', 38),
#  ('Brooklyn', 67),
#  ('Queens', 33),
#  ('Bronx', 36),
#  ('Bronx', 36),
#  ('Manhattan', 32),
#  ('Staten Island', 46),
#  ('Staten Island', 46),
#  ('Staten Island', 39),
#  ('Bronx', 54),
#  ('Bronx', 60),
#  ('Staten Island', 54),
#  ('Staten Island', 40),
#  ('Staten Island', 52),
#  ('Bronx', 36),
#  ('Brooklyn', 38),
#  ('Staten Island', 45),
#  ('Staten Island', 36),
#  ('Staten Island', 36),
#  ('Staten Island', 20),
#  ('Brooklyn', 25),
#  ('Bronx', 54),
#  ('Brooklyn', 35),
#  ('Manhattan', 47),
#  ('Manhattan', 30),
#  ('Staten Island', 46),
#  ('Bronx', 46),
#  ('Staten Island', 45),
#  ('Staten Island', 32),
#  ('Bronx', 36),
#  ('Queens', 45),
#  ('Staten Island', 40),
#  ('Bronx', 36),
#  ('Staten Island', 43),
#  ('Bronx', 36),
#  ('Staten Island', 38),
#  ('Bronx', 36),
#  ('Brooklyn', 27),
#  ('Staten Island', 35),
#  ('Bronx', 60),
#  ('Manhattan', 46),
#  ('Staten Island', 43),
#  ('Brooklyn', 34),
#  ('Staten Island', 38),
#  ('Bronx', 36),
#  ('Manhattan', 30),
#  ('Bronx', 36),
#  ('Staten Island', 45),
#  ('Brooklyn', 62),
#  ('Brooklyn', 100),
#  ('Bronx', 33),
#  ('Staten Island', 27),
#  ('Bronx', 55),
#  ('Staten Island', 38),
#  ('Staten Island', 36),
#  ('Staten Island', 35),
#  ('Staten Island', 39),
#  ('Staten Island', 51),
#  ('Staten Island', 35),
#  ('Staten Island', 33),
#  ('Staten Island', 60),
#  ('Staten Island', 38),
#  ('Queens', 50),
#  ('Brooklyn', 62),
#  ('Staten Island', 48),
#  ('Manhattan', 100),
#  ('Brooklyn', 90),
#  ('Bronx', 60),
#  ('Staten Island', 45),
#  ('Manhattan', 47),
#  ('Manhattan', 50),
#  ('Bronx', 90),
#  ('Staten Island', 43),
#  ('Queens', 43),
#  ('Bronx', 36),
#  ('Staten Island', 36),
#  ('Staten Island', 31),
#  ('Bronx', 36),
#  ('Bronx', 36),
#  ('Staten Island', 40),
#  ('Staten Island', 38),
#  ('Manhattan', 36),
#  ('Staten Island', 60),
#  ('Brooklyn', 54),
#  ('Brooklyn', 90),
#  ('Staten Island', 48),
#  ('Bronx', 54),
#  ('Staten Island', 38),
#  ('Queens', 45),
#  ('Queens', 32),
#  ('Staten Island', 42),
#  ('Bronx', 31),
#  ('Brooklyn', 44),
#  ('Bronx', 36),
#  ('Queens', 29),
#  ('Staten Island', 54),
#  ('Bronx', 54),
#  ('Brooklyn', 45),
#  ('Staten Island', 26),
#  ('Staten Island', 40),
#  ('Staten Island', 34),
#  ('Bronx', 55),
#  ('Queens', 30),
#  ('Bronx', 36),
#  ('Staten Island', 41),
#  ('Bronx', 36),
#  ('Queens', 50),
#  ('Bronx', 36),
#  ('Staten Island', 32),
#  ('Staten Island', 56),
#  ('Bronx', 90),
#  ('Staten Island', 34),
#  ('Manhattan', 45),
#  ('Queens', 30),
#  ('Manhattan', 42),
#  ('Staten Island', 33),
#  ('Brooklyn', 40),
#  ('Bronx', 36),
#  ('Bronx', 40),
#  ('Staten Island', 36),
#  ('Brooklyn', 27),
#  ('Brooklyn', 34),
#  ('Bronx', 36),
#  ('Staten Island', 52),
#  ('Brooklyn', 40),
#  ('Bronx', 100),
#  ('Staten Island', 42),
#  ('Manhattan', 40),
#  ('Queens', 45),
#  ('Bronx', 50),
#  ('Staten Island', 34),
#  ('Queens', 50),
#  ('Brooklyn', 38),
#  ('Staten Island', 45),
#  ('Staten Island', 36),
#  ('Brooklyn', 40),
#  ('Staten Island', 30),
#  ('Queens', 30),
#  ('Manhattan', 50),
#  ('Bronx', 33),
#  ('Staten Island', 72),
#  ('Staten Island', 45),
#  ('Staten Island', 42),
#  ('Bronx', 36),
#  ('Staten Island', 52),
#  ('Manhattan', 38),
#  ('Staten Island', 45),
#  ('Bronx', 33),
#  ('Manhattan', 40),
#  ('Queens', 40),
#  ('Manhattan', 44),
#  ('Brooklyn', 25),
#  ('Bronx', 36),
#  ('Bronx', 33),
#  ('Staten Island', 42),
#  ('Queens', 45),
#  ('Manhattan', 50),
#  ('Manhattan', 57),
#  ('Staten Island', 42),
#  ('Manhattan', 45),
#  ('Manhattan', 47),
#  ('Brooklyn', 88),
#  ('Staten Island', 30),
#  ('Queens', 45),
#  ('Queens', 29),
#  ('Staten Island', 40),
#  ('Manhattan', 40),
#  ('Manhattan', 45),
#  ('Queens', 36),
#  ('Manhattan', 44),
#  ('Bronx', 36),
#  ('Staten Island', 38),
#  ('Brooklyn', 40),
#  ('Manhattan', 90),
#  ('Staten Island', 36),
#  ('Queens', 36),
#  ('Staten Island', 39),
#  ('Staten Island', 42),
#  ('Staten Island', 42),
#  ('Brooklyn', 25),
#  ('Staten Island', 30),
#  ('Queens', 33),
#  ('Staten Island', 40),
#  ('Bronx', 36),
#  ('Queens', 90),
#  ('Bronx', 18),
#  ('Brooklyn', 45),
#  ('Queens', 45),
#  ('Manhattan', 47),
#  ('Brooklyn', 42),
#  ('Bronx', 20),
#  ('Queens', 29),
#  ('Staten Island', 31),
#  ('Staten Island', 42),
#  ('Brooklyn', 34),
#  ('Staten Island', 40),
#  ('Manhattan', 33),
#  ('Staten Island', 39),
#  ('Queens', 31),
#  ('Staten Island', 43),
#  ('Manhattan', 48),
#  ('Brooklyn', 35),
#  ('Staten Island', 42),
#  ('Bronx', 60),
#  ('Bronx', 36),
#  ('Brooklyn', 93),
#  ('Staten Island', 43),
#  ('Staten Island', 26),
#  ('Bronx', 36),
#  ('Staten Island', 45),
#  ('Staten Island', 32),
#  ('Queens', 100),
#  ('Bronx', 40),
#  ('Bronx', 29),
#  ('Staten Island', 40),
#  ('Bronx', 50),
#  ('Brooklyn', 34),
#  ('Bronx', 43),
#  ('Brooklyn', 93),
#  ('Staten Island', 36),
#  ('Brooklyn', 71),
#  ('Staten Island', 36),
#  ('Queens', 30),
#  ('Staten Island', 38),
#  ('Staten Island', 36),
#  ('Staten Island', 32),
#  ('Brooklyn', 33),
#  ('Staten Island', 43),
#  ('Brooklyn', 67),
#  ('Manhattan', 40),
#  ('Manhattan', 50),
#  ('Staten Island', 45),
#  ('Bronx', 44),
#  ('Queens', 45),
#  ('Queens', 29),
#  ('Brooklyn', 57),
#  ('Queens', 29),
#  ('Brooklyn', 53),
#  ('Staten Island', 36),
#  ('Bronx', 50),
#  ('Staten Island', 41),
#  ('Staten Island', 29),
#  ('Staten Island', 35),
#  ('Staten Island', 34),
#  ('Staten Island', 32),
#  ('Queens', 90),
#  ('Manhattan', 53),
#  ('Queens', 45),
#  ('Staten Island', 45),
#  ('Staten Island', 36),
#  ('Brooklyn', 34),
#  ('Queens', 60),
#  ('Bronx', 50),
#  ('Queens', 30),
#  ('Staten Island', 45),
#  ('Brooklyn', 38),
#  ('Manhattan', 38),
#  ('Queens', 30),
#  ('Queens', 45),
#  ('Manhattan', 38),
#  ('Staten Island', 68),
#  ('Brooklyn', 93),
#  ('Manhattan', 33),
#  ('Manhattan', 24),
#  ('Queens', 45),
#  ('Staten Island', 32),
#  ('Bronx', 33),
#  ('Manhattan', 45),
#  ('Brooklyn', 30),
#  ('Staten Island', 45),
#  ('Brooklyn', 45),
#  ('Brooklyn', 47),
#  ('Staten Island', 36),
#  ('Staten Island', 34),
#  ('Manhattan', 44),
#  ('Staten Island', 36),
#  ('Queens', 31),
#  ('Staten Island', 52),
#  ('Brooklyn', 32),
#  ('Bronx', 54),
#  ('Queens', 43),
#  ('Brooklyn', 35),
#  ('Queens', 29),
#  ('Queens', 43),
#  ('Bronx', 31),
#  ('Queens', 43),
#  ('Manhattan', 50),
#  ('Brooklyn', 36),
#  ('Manhattan', 32),
#  ('Manhattan', 45),
#  ('Staten Island', 39),
#  ('Queens', 33),
#  ('Queens', 45),
#  ('Staten Island', 35),
#  ('Queens', 31),
#  ('Bronx', 34),
#  ('Bronx', 40),
#  ('Staten Island', 34),
#  ('Brooklyn', 47),
#  ('Bronx', 36),
#  ('Staten Island', 36),
#  ('Staten Island', 43),
#  ('Bronx', 36),
#  ('Staten Island', 36),
#  ('Staten Island', 40),
#  ('Manhattan', 42),
#  ('Bronx', 36),
#  ('Bronx', 54),
#  ('Manhattan', 45),
#  ('Staten Island', 38),
#  ('Staten Island', 34),
#  ('Brooklyn', 45),
#  ('Staten Island', 38),
#  ('Brooklyn', 45),
#  ('Bronx', 54),
#  ('Staten Island', 50),
#  ('Staten Island', 39),
#  ('Staten Island', 31),
#  ('Bronx', 36),
#  ('Staten Island', 32),
#  ('Bronx', 54),
#  ('Manhattan', 46),
#  ('Staten Island', 41),
#  ('Staten Island', 60),
#  ('Queens', 45),
#  ('Bronx', 36),
#  ('Manhattan', 44),
#  ('Queens', 45),
#  ('Queens', 45),
#  ('Queens', 29),
#  ('Bronx', 33),
#  ('Brooklyn', 24),
#  ('Bronx', 54),
#  ('Staten Island', 36),
#  ('Manhattan', 40),
#  ('Brooklyn', 38),
#  ('Brooklyn', 45),
#  ('Staten Island', 40),
#  ('Staten Island', 42),
#  ('Queens', 31),
#  ('Bronx', 50),
#  ('Manhattan', 50),
#  ('Manhattan', 44),
#  ('Bronx', 36),
#  ('Staten Island', 49),
#  ('Staten Island', 34),
#  ('Staten Island', 45),
#  ('Bronx', 36),
#  ('Queens', 57),
#  ('Staten Island', 26),
#  ('Staten Island', 41),
#  ('Staten Island', 40),
#  ('Bronx', 36),
#  ('Bronx', 90),
#  ('Staten Island', 50),
#  ('Staten Island', 38),
#  ('Staten Island', 38),
#  ('Staten Island', 33),
#  ('Bronx', 31),
#  ('Bronx', 36),
#  ('Manhattan', 35),
#  ('Manhattan', 45),
#  ('Staten Island', 34),
#  ('Bronx', 36),
#  ('Bronx', 54),
#  ('Staten Island', 42),
#  ('Brooklyn', 40),
#  ('Bronx', 36),
#  ('Brooklyn', 35),
#  ('Staten Island', 31),
#  ('Staten Island', 30),
#  ('Bronx', 60),
#  ('Bronx', 36),
#  ('Queens', 28),
#  ('Bronx', 36),
#  ('Manhattan', 44),
#  ('Staten Island', 34),
#  ('Staten Island', 37),
#  ('Staten Island', 34),
#  ('Brooklyn', 32),
#  ('Manhattan', 40),
#  ('Staten Island', 34),
#  ('Staten Island', 30),
#  ('Bronx', 36),
#  ('Staten Island', 33),
#  ('Queens', 45),
#  ('Staten Island', 48),
#  ('Manhattan', 45),
#  ('Staten Island', 32),
#  ('Staten Island', 33),
#  ('Staten Island', 42),
#  ('Staten Island', 43),
#  ('Bronx', 36),
#  ('Manhattan', 38),
#  ('Queens', 29),
#  ('Staten Island', 48),
#  ('Brooklyn', 38),
#  ('Brooklyn', 40),
#  ('Brooklyn', 56),
#  ('Manhattan', 36),
#  ('Staten Island', 41),
#  ('Manhattan', 34),
#  ('Manhattan', 50),
#  ('Manhattan', 47),
#  ('Staten Island', 42),
#  ('Queens', 68),
#  ('Bronx', 36),
#  ('Staten Island', 41),
#  ('Staten Island', 42),
#  ('Brooklyn', 40),
#  ('Staten Island', 35),
#  ('Brooklyn', 54),
#  ('Bronx', 90),
#  ('Brooklyn', 45),
#  ('Bronx', 34),
#  ('Manhattan', 33),
#  ('Queens', 27),
#  ('Manhattan', 33),
#  ('Staten Island', 67),
#  ('Manhattan', 44),
#  ('Bronx', 36),
#  ('Brooklyn', 50),
#  ('Staten Island', 42),
#  ('Staten Island', 33),
#  ('Queens', 46),
#  ('Brooklyn', 27),
#  ('Bronx', 40),
#  ('Staten Island', 43),
#  ('Bronx', 36),
#  ('Bronx', 36),
#  ('Queens', 50),
#  ('Staten Island', 45),
#  ('Manhattan', 35),
#  ('Staten Island', 42),
#  ('Manhattan', 42),
#  ('Bronx', 57),
#  ('Brooklyn', 40),
#  ('Brooklyn', 38),
#  ('Staten Island', 50),
#  ('Queens', 45),
#  ('Staten Island', 34),
#  ('Queens', 38),
#  ('Staten Island', 51),
#  ('Queens', 46),
#  ('Bronx', 34),
#  ('Bronx', 36),
#  ('Staten Island', 37),
#  ('Manhattan', 35),
#  ('Staten Island', 30),
#  ('Staten Island', 48),
#  ('Staten Island', 37),
#  ('Brooklyn', 67),
#  ('Brooklyn', 31),
#  ('Staten Island', 46),
#  ('Manhattan', 45),
#  ('Queens', 45),
#  ('Bronx', 36),
#  ('Manhattan', 42),
#  ('Staten Island', 45),
#  ('Manhattan', 67),
#  ('Manhattan', 38),
#  ('Staten Island', 45),
#  ('Staten Island', 31),
#  ('Bronx', 54),
#  ('Staten Island', 44),
#  ('Staten Island', 32),
#  ('Brooklyn', 45),
#  ('Staten Island', 30),
#  ('Staten Island', 39),
#  ('Bronx', 55),
#  ('Staten Island', 39),
#  ('Staten Island', 32),
#  ('Staten Island', 30),
#  ('Manhattan', 53),
#  ('Bronx', 90),
#  ('Staten Island', 55),
#  ('Brooklyn', 45),
#  ('Staten Island', 50),
#  ('Staten Island', 36),
#  ('Bronx', 36),
#  ('Queens', 30),
#  ('Manhattan', 30),
#  ('Staten Island', 45),
#  ('Brooklyn', 100),
#  ('Bronx', 36),
#  ('Staten Island', 27),
#  ('Staten Island', 34),
#  ('Staten Island', 36),
#  ('Bronx', 36),
#  ('Brooklyn', 62),
#  ('Manhattan', 30),
#  ('Staten Island', 32),
#  ('Staten Island', 44),
#  ('Staten Island', 39),
#  ('Staten Island', 42),
#  ('Staten Island', 49),
#  ('Bronx', 36),
#  ('Staten Island', 34),
#  ('Brooklyn', 40),
#  ('Staten Island', 27),
#  ('Manhattan', 29),
#  ('Staten Island', 38),
#  ('Staten Island', 44),
#  ('Manhattan', 36),
#  ('Queens', 32),
#  ('Bronx', 36),
#  ('Bronx', 36),
#  ('Staten Island', 37),
#  ('Brooklyn', 27),
#  ('Staten Island', 32),
#  ('Bronx', 33),
#  ('Queens', 90),
#  ('Staten Island', 37),
#  ('Staten Island', 38),
#  ('Brooklyn', 44),
#  ('Staten Island', 36),
#  ('Staten Island', 34),
#  ('Manhattan', 38),
#  ('Staten Island', 36),
#  ('Staten Island', 33),
#  ('Bronx', 54),
#  ('Staten Island', 36),
#  ('Bronx', 54),
#  ('Bronx', 36),
#  ('Staten Island', 35),
#  ('Brooklyn', 27),
#  ('Manhattan', 45),
#  ('Staten Island', 40),
#  ('Staten Island', 45),
#  ('Staten Island', 49),
#  ('Brooklyn', 34),
#  ('Queens', 38),
#  ('Bronx', 55),
#  ('Bronx', 43),
#  ('Brooklyn', 27),
#  ('Staten Island', 45),
#  ('Staten Island', 37),
#  ('Staten Island', 52),
#  ('Manhattan', 45),
#  ('Staten Island', 34),
#  ('Staten Island', 49),
#  ('Bronx', 43),
#  ('Brooklyn', 29),
#  ('Brooklyn', 47),
#  ('Manhattan', 42),
#  ('Manhattan', 35),
#  ('Brooklyn', 45),
#  ('Queens', 50),
#  ('Queens', 30),
#  ('Staten Island', 50),
#  ('Brooklyn', 27),
#  ('Brooklyn', 40),
#  ('Bronx', 36),
#  ('Staten Island', 26),
#  ('Queens', 33),
#  ('Queens', 33),
#  ('Manhattan', 36),
#  ('Manhattan', 50),
#  ('Staten Island', 48),
#  ('Bronx', 40),
#  ('Bronx', 43),
#  ('Staten Island', 33),
#  ('Staten Island', 36),
#  ('Bronx', 36),
#  ('Staten Island', 42),
#  ('Brooklyn', 45),
#  ('Staten Island', 43),
#  ('Manhattan', 36),
#  ('Manhattan', 94),
#  ('Staten Island', 41),
#  ('Queens', 50),
#  ('Brooklyn', 53),
#  ('Bronx', 40),
#  ('Staten Island', 44),
#  ('Queens', 45),
#  ('Manhattan', 45),
#  ('Staten Island', 45),
#  ('Bronx', 55),
#  ('Bronx', 54),
#  ('Bronx', 50),
#  ('Queens', 43),
#  ('Bronx', 36),
#  ('Staten Island', 42),
#  ('Manhattan', 44),
#  ('Bronx', 36),
#  ('Staten Island', 22),
#  ('Staten Island', 38),
#  ('Bronx', 36),
#  ('Staten Island', 48),
#  ('Staten Island', 32),
#  ('Manhattan', 38),
#  ('Staten Island', 38),
#  ('Staten Island', 46),
#  ('Staten Island', 41),
#  ('Bronx', 36),
#  ('Staten Island', 56),
#  ('Staten Island', 35),
#  ('Bronx', 20),
#  ('Manhattan', 36),
#  ('Bronx', 36),
#  ('Staten Island', 44),
#  ('Bronx', 36),
#  ('Staten Island', 39),
#  ('Manhattan', 42),
#  ('Bronx', 38),
#  ('Staten Island', 45),
#  ('Manhattan', 44),
#  ('Bronx', 36),
#  ('Brooklyn', 43),
#  ('Bronx', 40),
#  ('Staten Island', 46),
#  ('Manhattan', 45),
#  ('Queens', 45),
#  ('Staten Island', 33),
#  ('Staten Island', 38),
#  ('Staten Island', 32),
#  ('Bronx', 43),
#  ('Queens', 43),
#  ('Staten Island', 43),
#  ('Bronx', 54),
#  ('Bronx', 38),
#  ('Staten Island', 40),
#  ('Staten Island', 42),
#  ('Staten Island', 39),
#  ('Brooklyn', 38),
#  ('Staten Island', 36),
#  ('Staten Island', 30),
#  ('Manhattan', 45),
#  ('Manhattan', 50),
#  ('Bronx', 54),
#  ('Staten Island', 37),
#  ('Staten Island', 43),
#  ('Staten Island', 45),
#  ('Manhattan', 50),
#  ('Manhattan', 44),
#  ('Bronx', 33),
#  ('Bronx', 55),
#  ('Staten Island', 42),
#  ('Manhattan', 45),
#  ('Manhattan', 90),
#  ('Brooklyn', 25),
#  ('Queens', 45),
#  ('Staten Island', 45),
#  ('Manhattan', 30),
#  ('Staten Island', 100),
#  ('Bronx', 38),
#  ('Staten Island', 44),
#  ('Brooklyn', 60),
#  ('Manhattan', 45),
#  ('Staten Island', 25),
#  ('Brooklyn', 50),
#  ('Bronx', 33),
#  ('Brooklyn', 38),
#  ('Bronx', 62),
#  ('Bronx', 54),
#  ('Brooklyn', 34),
#  ('Staten Island', 32),
#  ('Queens', 45)]

# %%
[[ny_cities[i], boro_matches[i]] for i in range(len(ny_cities)) if boro_matches[i][1] >= 80]
# Out:
# [['BROOKLYN,', ('Brooklyn', 100)],
#  ['MANHATTAN', ('Manhattan', 100)],
#  ['DOWNTOWN BROOKLYN', ('Brooklyn', 90)],
#  ['BRONX.NEW YORK', ('Bronx', 90)],
#  ['WILLIAMSBURG, BROOKLYN', ('Brooklyn', 90)],
#  ['BRONX,NEW YORK', ('Bronx', 90)],
#  ['BRONX', ('Bronx', 100)],
#  ['BROOKYLN', ('Brooklyn', 88)],
#  ['MANHATTAN, NEW YORK', ('Manhattan', 90)],
#  ['FOREST HILLS QUEENS', ('Queens', 90)],
#  ['BROOKLN', ('Brooklyn', 93)],
#  ['QUEENS', ('Queens', 100)],
#  ['BROOKLY', ('Brooklyn', 93)],
#  ['QUEENS VILLAGE', ('Queens', 90)],
#  ['BROOKYN', ('Brooklyn', 93)],
#  ['BRONX, NEW YORK', ('Bronx', 90)],
#  ['BRONX,NY', ('Bronx', 90)],
#  ['BRONXVILLE', ('Bronx', 90)],
#  ['BROOKLYN', ('Brooklyn', 100)],
#  ['QUEENSBURY', ('Queens', 90)],
#  ['MANHATAN', ('Manhattan', 94)],
#  ['MIDTOWN MANHATTAN', ('Manhattan', 90)],
#  ['STATEN ISLAND', ('Staten Island', 100)]]

# %%
# downtown brooklyn is a neighbourhood, as is midtown
[n for n in nyc_nabes["features"] if n["properties"]["Name"] == "Downtown"]
# Out:
# [{'geometry': {'coordinates': [-73.9834648142757, 40.6908522739855],
#    'type': 'Point'},
#   'id': 173,
#   'properties': {'AnnoAngle': 0,
#    'AnnoLine1': 'Downtown',
#    'AnnoLine2': ' ',
#    'AnnoLine3': ' ',
#    'Borough': 'Brooklyn',
#    'FID': 173,
#    'Name': 'Downtown',
#    'Stacked': 1},
#   'type': 'Feature'}]

# %%
# these are the "cities" with no more specific info than the borough
good_boros = [ny_cities[i] for i in range(len(ny_cities)) if boro_matches[i][1] >= 80]
good_boros.remove("DOWNTOWN BROOKLYN")
good_boros.remove("WILLIAMSBURG, BROOKLYN")
good_boros.remove("FOREST HILLS QUEENS")
good_boros.remove("QUEENS VILLAGE")
good_boros.remove("BRONXVILLE")
good_boros.remove("QUEENSBURY")
good_boros.remove("MIDTOWN MANHATTAN")

# %%
# make a borough column for nycdf
nycdf["borough"] = ["" for i in range(nycdf.shape[0])]
# and dummy city columns to keep track of the ones we're done with
nycdf["dummy_city_1"] = nycdf.loc[:, "lca_case_workloc1_city"]
nycdf["dummy_city_2"] = nycdf.loc[:, "lca_case_workloc2_city"]
for boro in good_boros:
    cityind = ny_cities.index(boro)
    nycdf.loc[nycdf.lca_case_workloc1_city == boro, ["borough"]] = boro_matches[cityind][0]
    nycdf.loc[nycdf.lca_case_workloc1_city == boro, ["dummy_city_1"]] = np.nan
    nycdf.loc[nycdf.lca_case_workloc2_city == boro, ["borough"]] = boro_matches[cityind][0]
    nycdf.loc[nycdf.lca_case_workloc2_city == boro, ["dummy_city_2"]] = np.nan

# %%
nabe_matches = [process.extractOne(city, nabe_names) for city in ny_cities]
nabe_matches
# Out:
# [('Mount Eden', 67),
#  ('Bath Beach', 90),
#  ('Noho', 68),
#  ('New Dorp', 74),
#  ('Long Island City', 60),
#  ('Kew Gardens', 100),
#  ('Richmond Town', 59),
#  ('Woodrow', 62),
#  ('Manhattan Terrace', 50),
#  ('Bay Terrace', 53),
#  ('Melrose', 62),
#  ('Travis', 60),
#  ('Belmont', 92),
#  ('Flushing', 64),
#  ('Fresh Meadows', 56),
#  ('Brookville', 95),
#  ('New Lots', 53),
#  ('Marble Hill', 54),
#  ('Glendale', 100),
#  ('Schuylerville', 75),
#  ('Brighton Beach', 60),
#  ('Rochdale', 90),
#  ('Sandy Ground', 71),
#  ('Corona', 71),
#  ('Clason Point', 78),
#  ('Pelham Parkway', 60),
#  ('Lincoln Square', 64),
#  ('Somerville', 75),
#  ('Heartland Village', 68),
#  ("Mariner's Harbor", 51),
#  ('Huguenot', 47),
#  ('Astoria', 64),
#  ('Park Hill', 86),
#  ('Brookville', 100),
#  ('Tudor City', 60),
#  ('Flatbush', 63),
#  ('Malba', 72),
#  ('Jamaica Center', 64),
#  ('Neponsit', 60),
#  ('Great Kills', 67),
#  ('Madison', 71),
#  ('Port Richmond', 86),
#  ('Port Richmond', 59),
#  ('Sea Gate', 80),
#  ('East Elmhurst', 80),
#  ('St. Albans', 100),
#  ('Parkchester', 80),
#  ('Woodrow', 67),
#  ('Oakwood', 50),
#  ('Fordham', 62),
#  ('Fordham', 50),
#  ('Bedford Park', 77),
#  ('East New York', 90),
#  ('West Farms', 70),
#  ('Woodhaven', 100),
#  ('Chinatown', 59),
#  ('Chelsea', 56),
#  ('Travis', 60),
#  ('Fieldston', 59),
#  ('Pelham Gardens', 57),
#  ('Wakefield', 53),
#  ('Roxbury', 62),
#  ('Weeksville', 70),
#  ('Astoria', 57),
#  ('Arverne', 80),
#  ('East Williamsburg', 59),
#  ('Hudson Yards', 90),
#  ('Wakefield', 59),
#  ('Crown Heights', 83),
#  ('New Springville', 86),
#  ('Sunnyside Gardens', 45),
#  ('Allerton', 82),
#  ('Pelham Bay', 73),
#  ('Remsen Village', 58),
#  ('New Springville', 86),
#  ('Highland Park', 56),
#  ('Floral Park', 50),
#  ('Castleton Corners', 60),
#  ('Claremont Village', 68),
#  ('Flatlands', 56),
#  ('Willowbrook', 63),
#  ('Brooklyn Heights', 90),
#  ('Morningside Heights', 77),
#  ('South Ozone Park', 50),
#  ('Arlington', 67),
#  ('Springfield Gardens', 61),
#  ('Great Kills', 50),
#  ('Weeksville', 70),
#  ('Edenwald', 53),
#  ('Heartland Village', 64),
#  ('Park Slope', 50),
#  ('Murray Hill', 100),
#  ('Long Island City', 100),
#  ('Rossville', 71),
#  ('Sea Gate', 56),
#  ('Willowbrook', 63),
#  ('Silver Lake', 61),
#  ('Manhattan Terrace', 90),
#  ('Downtown', 90),
#  ('Mount Eden', 73),
#  ('Port Richmond', 56),
#  ('Hamilton Heights', 90),
#  ('Pelham Parkway', 51),
#  ('New Dorp', 86),
#  ('Edgewater Park', 60),
#  ('Silver Lake', 70),
#  ('Belle Harbor', 86),
#  ('Charleston', 63),
#  ('South Beach', 67),
#  ('Parkchester', 80),
#  ('Ozone Park', 90),
#  ('Manhattanville', 64),
#  ('Old Town', 86),
#  ('Throgs Neck', 54),
#  ('City Island', 60),
#  ('Howland Hook', 72),
#  ('Williamsburg', 90),
#  ('Pleasant Plains', 64),
#  ('West Brighton', 64),
#  ('East Harlem', 58),
#  ('Glen Oaks', 70),
#  ('Fresh Meadows', 100),
#  ('Annadale', 53),
#  ('Belmont', 67),
#  ('Bloomfield', 100),
#  ('East New York', 95),
#  ('Bedford Park', 56),
#  ('Pelham Gardens', 72),
#  ('Noho', 45),
#  ('Lincoln Square', 69),
#  ('Fordham', 71),
#  ('Forest Hills', 100),
#  ('Riverdale', 100),
#  ('Auburndale', 90),
#  ('Edgewater Park', 86),
#  ('Westchester Square', 50),
#  ('Bayswater', 63),
#  ('Tribeca', 62),
#  ('Sunnyside', 53),
#  ('Olinville', 70),
#  ('New Springville', 86),
#  ('West Farms', 64),
#  ('New Dorp', 86),
#  ('Bay Terrace', 53),
#  ('Madison', 62),
#  ('Eastchester', 50),
#  ('Whitestone', 100),
#  ('Port Morris', 73),
#  ('Schuylerville', 60),
#  ("Mariner's Harbor", 86),
#  ('Stuyvesant Town', 86),
#  ('Clifton', 90),
#  ('Bushwick', 53),
#  ('East New York', 95),
#  ('Williamsburg', 96),
#  ('Upper East Side', 86),
#  ('West Brighton', 64),
#  ('Bronxdale', 90),
#  ('East Williamsburg', 86),
#  ('Jamaica Hills', 78),
#  ('Bensonhurst', 64),
#  ('Manor Heights', 61),
#  ('Vinegar Hill', 54),
#  ('Westerleigh', 60),
#  ('West Brighton', 68),
#  ('Wakefield', 78),
#  ('Spuyten Duyvil', 50),
#  ('Lefrak City', 56),
#  ('Bayside', 100),
#  ('West Farms', 54),
#  ('Maspeth', 57),
#  ('Castleton Corners', 64),
#  ('Roosevelt Island', 71),
#  ('Morrisania', 67),
#  ('Silver Lake', 55),
#  ('Richmond Valley', 86),
#  ('Hunts Point', 67),
#  ('Central Harlem', 64),
#  ('Sheepshead Bay', 70),
#  ('Hollis', 62),
#  ('Arverne', 64),
#  ('Glen Oaks', 100),
#  ('Astoria', 62),
#  ('East New York', 86),
#  ('Corona', 59),
#  ('Auburndale', 47),
#  ('New Dorp', 63),
#  ('Queensbridge', 55),
#  ('New Brighton', 70),
#  ('Malba', 80),
#  ('Little Neck', 100),
#  ('Pomonok', 77),
#  ('Central Harlem', 56),
#  ('Brooklyn Heights', 79),
#  ('Elm Park', 53),
#  ('Williamsburg', 61),
#  ('Flushing', 100),
#  ('Marine Park', 66),
#  ('Port Ivory', 86),
#  ('St. Albans', 75),
#  ('South Beach', 54),
#  ('Brighton Beach', 70),
#  ('South Side', 86),
#  ('Silver Lake', 50),
#  ('Shore Acres', 57),
#  ('New Dorp', 86),
#  ('Graniteville', 86),
#  ('Soundview', 54),
#  ('Arverne', 100),
#  ('Sheepshead Bay', 56),
#  ('Battery Park City', 86),
#  ('East New York', 90),
#  ('Hollis', 100),
#  ('Fort Greene', 75),
#  ('Little Italy', 75),
#  ('Claremont Village', 63),
#  ('Forest Hills', 90),
#  ('Civic Center', 56),
#  ('North Riverdale', 55),
#  ('Glendale', 71),
#  ('Morrisania', 56),
#  ('Flatlands', 50),
#  ('Corona', 55),
#  ('Edgewater Park', 73),
#  ('Floral Park', 100),
#  ('Shore Acres', 64),
#  ('Lefrak City', 70),
#  ('Tottenville', 70),
#  ('Ocean Parkway', 45),
#  ('Somerville', 71),
#  ('Edgemere', 53),
#  ('North Side', 86),
#  ('East Harlem', 70),
#  ('Rego Park', 100),
#  ('Sutton Place', 59),
#  ('Mott Haven', 60),
#  ('Forest Hills Gardens', 86),
#  ('Brooklyn Heights', 77),
#  ('Mott Haven', 53),
#  ('Olinville', 74),
#  ('Eastchester', 88),
#  ('Astoria', 62),
#  ('Elm Park', 71),
#  ('Queensbridge', 90),
#  ('Unionport', 90),
#  ('Bellaire', 59),
#  ('Auburndale', 67),
#  ('Claremont Village', 77),
#  ('New Dorp', 86),
#  ('Bellerose', 100),
#  ('Brooklyn Heights', 90),
#  ('Brownsville', 70),
#  ('Throgs Neck', 60),
#  ('Manhattan Valley', 60),
#  ('Weeksville', 80),
#  ('Hudson Yards', 86),
#  ('Olinville', 60),
#  ('Tribeca', 62),
#  ('Cobble Hill', 76),
#  ('Annadale', 71),
#  ('Woodhaven', 74),
#  ('University Heights', 68),
#  ('Ditmas Park', 51),
#  ('Inwood', 100),
#  ('New Brighton', 64),
#  ('Greenpoint', 84),
#  ('Parkchester', 63),
#  ('Douglaston', 62),
#  ('Utopia', 57),
#  ('Breezy Point', 70),
#  ('Silver Lake', 66),
#  ('Neponsit', 53),
#  ('East Tremont', 52),
#  ('Elm Park', 86),
#  ('Great Kills', 67),
#  ('Somerville', 78),
#  ('West Farms', 57),
#  ('Queens Village', 100),
#  ('New Brighton', 64),
#  ('Springfield Gardens', 100),
#  ('Rosebank', 57),
#  ('Chelsea', 59),
#  ('New Dorp', 86),
#  ('East Flatbush', 67),
#  ('Belmont', 57),
#  ('Riverdale', 67),
#  ('Morrisania', 53),
#  ('South Ozone Park', 68),
#  ('Maspeth', 100),
#  ('Mount Hope', 52),
#  ('Baychester', 60),
#  ('Jamaica Hills', 77),
#  ('Roosevelt Island', 77),
#  ('Brooklyn Heights', 77),
#  ('Great Kills', 60),
#  ('Broadway Junction', 45),
#  ('South Side', 55),
#  ('Flushing', 90),
#  ('Auburndale', 47),
#  ('Astoria', 62),
#  ('Port Richmond', 60),
#  ('Madison', 77),
#  ('Hudson Yards', 64),
#  ('Lighthouse Hill', 86),
#  ('New Springville', 71),
#  ('Edgewater Park', 61),
#  ('Whitestone', 95),
#  ('Spuyten Duyvil', 50),
#  ('Pleasant Plains', 51),
#  ('Upper West Side', 86),
#  ('High  Bridge', 43),
#  ('Throgs Neck', 57),
#  ('West Farms', 86),
#  ('Ridgewood', 100),
#  ('Ridgewood', 82),
#  ('Glen Oaks', 67),
#  ('Greenpoint', 67),
#  ('West Farms', 86),
#  ('Vinegar Hill', 53),
#  ('Country Club', 68),
#  ('Elmhurst', 67),
#  ('Sunnyside Gardens', 57),
#  ('Boerum Hill', 56),
#  ('Fresh Meadows', 96),
#  ('Greenpoint', 100),
#  ('North Side', 67),
#  ('University Heights', 51),
#  ('Manhattan Beach', 86),
#  ('New Springville', 86),
#  ('New Springville', 86),
#  ('Riverdale', 56),
#  ('Fulton Ferry', 90),
#  ('Fieldston', 64),
#  ('Rosedale', 71),
#  ('Belle Harbor', 66),
#  ('Oakland Gardens', 50),
#  ('Wingate', 64),
#  ('Arlington', 74),
#  ('Battery Park City', 86),
#  ('Corona', 50),
#  ('Oakland Gardens', 60),
#  ('Forest Hills', 96),
#  ('Flatbush', 59),
#  ('Far Rockaway', 100),
#  ('East Flatbush', 62),
#  ('Oakland Gardens', 100),
#  ('Charleston', 67),
#  ('Lefrak City', 55),
#  ('Richmond Valley', 56),
#  ('Olinville', 70),
#  ('College Point', 100),
#  ("Mariner's Harbor", 60),
#  ('Auburndale', 100),
#  ('Pelham Bay', 64),
#  ('Richmond Hill', 95),
#  ('Long Island City', 100),
#  ('Silver Lake', 58),
#  ('Norwood', 75),
#  ('Charleston', 63),
#  ('Fresh Meadows', 61),
#  ('Canarsie', 71),
#  ('Bellerose', 71),
#  ('Port Richmond', 64),
#  ('New Springville', 86),
#  ('Whitestone', 70),
#  ('Spuyten Duyvil', 50),
#  ('Port Ivory', 86),
#  ('Rosedale', 100),
#  ('Melrose', 68),
#  ('Bedford Park', 64),
#  ('Bay Ridge', 86),
#  ('Castleton Corners', 64),
#  ('East Tremont', 77),
#  ('Chinatown', 60),
#  ('Manhattan Terrace', 46),
#  ('Melrose', 62),
#  ('Flushing', 67),
#  ('Egbertville', 74),
#  ('South Beach', 86),
#  ('Williamsburg', 67),
#  ('Prospect Lefferts Gardens', 53),
#  ('Sunset Park', 51),
#  ('Steinway', 56),
#  ('Clinton', 90),
#  ('New Brighton', 70),
#  ('New Dorp', 86),
#  ('Long Island City', 97),
#  ('Williamsbridge', 69),
#  ('Morningside Heights', 56),
#  ('Blissville', 70),
#  ('Soho', 68),
#  ('Clifton', 90),
#  ('Elmhurst', 100),
#  ('Morningside Heights', 57),
#  ('New Springville', 86),
#  ('Clifton', 62),
#  ('Inwood', 75),
#  ('Tottenville', 73),
#  ('Neponsit', 67),
#  ('Williamsburg', 64),
#  ('Red Hook', 59),
#  ('East Williamsburg', 86),
#  ('Arlington', 62),
#  ('Allerton', 82),
#  ('Throgs Neck', 96),
#  ('New Dorp', 86),
#  ('Richmond Hill', 100),
#  ('Homecrest', 56),
#  ('Oakwood', 80),
#  ('Westerleigh', 77),
#  ('Olinville', 67),
#  ('Fulton Ferry', 61),
#  ('Hudson Yards', 86),
#  ('Forest Hills', 60),
#  ('Marble Hill', 62),
#  ('Travis', 45),
#  ('Prospect Lefferts Gardens', 58),
#  ('Westchester Square', 58),
#  ('Allerton', 68),
#  ('South Jamaica', 53),
#  ('Woodside', 100),
#  ('Battery Park City', 86),
#  ('Whitestone', 57),
#  ('Midtown', 64),
#  ('Long Island City', 86),
#  ('Jamaica Hills', 90),
#  ('Woodrow', 67),
#  ('Annadale', 53),
#  ('Carnegie Hill', 86),
#  ('Douglaston', 71),
#  ('Brooklyn Heights', 87),
#  ('Chinatown', 55),
#  ('Co-op City', 86),
#  ('Great Kills', 58),
#  ('Fresh Meadows', 64),
#  ('Claremont Village', 68),
#  ('Sheepshead Bay', 56),
#  ('Edenwald', 90),
#  ('New Dorp', 86),
#  ('Arlington', 74),
#  ('Neponsit', 56),
#  ('Olinville', 62),
#  ('Great Kills', 67),
#  ('Fort Hamilton', 60),
#  ('Bronxdale', 59),
#  ('Yorkville', 90),
#  ('Soho', 64),
#  ('Unionport', 67),
#  ('Egbertville', 80),
#  ('Huguenot', 59),
#  ('Long Island City', 95),
#  ('Chinatown', 56),
#  ('Middle Village', 56),
#  ('Far Rockaway', 90),
#  ('Stapleton', 70),
#  ('East Williamsburg', 86),
#  ('Spuyten Duyvil', 51),
#  ('Port Morris', 56),
#  ('Sutton Place', 72),
#  ('Glen Oaks', 63),
#  ('Port Ivory', 64),
#  ('Graniteville', 80),
#  ('Fort Greene', 58),
#  ('West Farms', 64),
#  ('Manhattan Valley', 64),
#  ('West Farms', 57),
#  ('Annadale', 56),
#  ('Allerton', 82),
#  ('Park Slope', 59),
#  ('Inwood', 71),
#  ('Long Island City', 97),
#  ('Canarsie', 71),
#  ('Sheepshead Bay', 86),
#  ('Kew Gardens', 95),
#  ('Bay Terrace', 74),
#  ('Fort Greene', 56),
#  ('Parkchester', 78),
#  ('Baychester', 67),
#  ('Westerleigh', 77),
#  ('Elmhurst', 88),
#  ('Elm Park', 86),
#  ('Wakefield', 71),
#  ('Parkchester', 64),
#  ('Red Hook', 71),
#  ('Longwood', 54),
#  ('Allerton', 68),
#  ('St. Albans', 75),
#  ('Arverne', 59),
#  ('Claremont Village', 68),
#  ('Kensington', 70),
#  ('Remsen Village', 61),
#  ('Maspeth', 62),
#  ('New Dorp', 86),
#  ('Jamaica Estates', 57),
#  ('Hollis', 60),
#  ('Broadway Junction', 90),
#  ('Hudson Yards', 86),
#  ('Silver Lake', 58),
#  ('Brookville', 72),
#  ('Pelham Parkway', 51),
#  ('Elmhurst', 67),
#  ('Bergen Beach', 90),
#  ('Chelsea', 100),
#  ('East Elmhurst', 60),
#  ('Marble Hill', 60),
#  ('Clinton', 77),
#  ('Brownsville', 86),
#  ('Pleasant Plains', 55),
#  ('Malba', 72),
#  ('City Line', 60),
#  ('Astoria', 62),
#  ('New Dorp', 86),
#  ('Somerville', 73),
#  ('Vinegar Hill', 62),
#  ('Elmhurst', 67),
#  ('Brooklyn Heights', 90),
#  ('Broadway Junction', 65),
#  ('Edgewater Park', 86),
#  ('Turtle Bay', 51),
#  ('Edgewater Park', 60),
#  ('Randall Manor', 62),
#  ('Willowbrook', 63),
#  ('Chelsea', 56),
#  ('Laurelton', 71),
#  ('Bay Ridge', 86),
#  ('Marine Park', 56),
#  ('Steinway', 53),
#  ('Annadale', 56),
#  ('Williamsburg', 64),
#  ('Somerville', 78),
#  ('Annadale', 67),
#  ('Kew Gardens Hills', 86),
#  ('Howard Beach', 100),
#  ('Neponsit', 53),
#  ('Eastchester', 64),
#  ("Mariner's Harbor", 54),
#  ('East Elmhurst', 100),
#  ('Melrose', 62),
#  ('Midtown', 82),
#  ('Eastchester', 90),
#  ('New Springville', 86),
#  ('East Harlem', 53),
#  ('Castleton Corners', 77),
#  ('Queensbridge', 73),
#  ('Port Morris', 61),
#  ('Jamaica Center', 69),
#  ('New Springville', 86),
#  ('Spuyten Duyvil', 50),
#  ('Port Richmond', 45),
#  ('Fort Greene', 86),
#  ('Jamaica Center', 66),
#  ('Battery Park City', 86),
#  ('Madison', 67),
#  ('Williamsbridge', 74),
#  ('Allerton', 71),
#  ('Mount Hope', 67),
#  ('Graniteville', 73),
#  ('Rockaway Beach', 49),
#  ('Manhattanville', 74),
#  ('North Side', 76),
#  ('Claremont Village', 54),
#  ('Gowanus', 71),
#  ('New Dorp', 86),
#  ('Glen Oaks', 74),
#  ('South Beach', 66),
#  ('Allerton', 59),
#  ('New Lots', 53),
#  ('Great Kills', 63),
#  ('Olinville', 70),
#  ('Baychester', 63),
#  ('Stapleton', 53),
#  ('Wakefield', 59),
#  ('Astoria', 100),
#  ('Arlington', 78),
#  ('Holliswood', 50),
#  ('Briarwood', 100),
#  ('Far Rockaway', 55),
#  ('Carnegie Hill', 56),
#  ('Rockaway Park', 100),
#  ('Fort Greene', 90),
#  ('Battery Park City', 86),
#  ('St. Albans', 76),
#  ('East New York', 77),
#  ('Madison', 57),
#  ('Ridgewood', 70),
#  ('Greenwich Village', 64),
#  ('Fort Greene', 60),
#  ('Homecrest', 67),
#  ('Gramercy', 72),
#  ('Maspeth', 86),
#  ('South Side', 86),
#  ('Douglaston', 67),
#  ('Laurelton', 100),
#  ('Great Kills', 64),
#  ('Co-op City', 54),
#  ('Arlington', 60),
#  ('Upper West Side', 59),
#  ('Far Rockaway', 80),
#  ('North Side', 86),
#  ('Huguenot', 62),
#  ('Manhattan Terrace', 79),
#  ('Douglaston', 100),
#  ('Egbertville', 57),
#  ('Oakland Gardens', 90),
#  ('Kensington', 78),
#  ('West Brighton', 59),
#  ('Westchester Square', 62),
#  ('Allerton', 71),
#  ('Pelham Parkway', 68),
#  ('Corona', 100),
#  ('Unionport', 56),
#  ('Belmont', 100),
#  ('North Corona', 70),
#  ('Broadway Junction', 65),
#  ('Annadale', 53),
#  ('Rosedale', 71),
#  ('Co-op City', 64),
#  ('New Springville', 86),
#  ('Richmond Valley', 61),
#  ('Concord', 67),
#  ('Howland Hook', 57),
#  ('Williamsbridge', 60),
#  ('Clinton', 100),
#  ('Hudson Yards', 86),
#  ('Central Harlem', 67),
#  ('Pleasant Plains', 52),
#  ('South Ozone Park', 100),
#  ('Highland Park', 90),
#  ('Upper West Side', 86),
#  ('Homecrest', 72),
#  ('Utopia', 73),
#  ('East Williamsburg', 86),
#  ('East Tremont', 64),
#  ('Mount Eden', 60),
#  ('Richmond Valley', 56),
#  ('Maspeth', 59),
#  ('Jackson Heights', 100),
#  ('Arverne', 62),
#  ('Pleasant Plains', 60),
#  ('Ozone Park', 100),
#  ('Arlington', 75),
#  ('Midtown South', 73),
#  ('Neponsit', 60),
#  ('Soundview', 64),
#  ('Weeksville', 74),
#  ('Graniteville', 78),
#  ('West Brighton', 66),
#  ('Hammels', 62),
#  ('Claremont Village', 70),
#  ('Castle Hill', 58),
#  ('High  Bridge', 67),
#  ('Dumbo', 54),
#  ('Throgs Neck', 100),
#  ('Eastchester', 100),
#  ('Richmond Hill', 95),
#  ('Hudson Yards', 86),
#  ('Soho', 64),
#  ('Blissville', 70),
#  ('Fordham', 57),
#  ('Sunnyside', 90),
#  ('Manhattan Terrace', 64),
#  ('New Dorp', 86),
#  ('Middle Village', 100),
#  ('Riverdale', 60),
#  ('Charleston', 67),
#  ('Randall Manor', 71),
#  ('Windsor Terrace', 60),
#  ('Bedford Park', 90),
#  ('Claremont Village', 75),
#  ('Sutton Place', 59),
#  ('Laurelton', 60),
#  ('Midtown', 90),
#  ('Unionport', 59),
#  ('Sunnyside', 100),
#  ('Sunnyside', 67),
#  ('New Springville', 90),
#  ('City Island', 67),
#  ('Corona', 59),
#  ('East Village', 72),
#  ('Willowbrook', 55),
#  ('Pelham Parkway', 60),
#  ('Port Ivory', 57),
#  ('Throgs Neck', 68),
#  ('Williamsburg', 77),
#  ('Woodrow', 67),
#  ('Bronxdale', 59),
#  ('Queensboro Hill', 60),
#  ('New Dorp', 86),
#  ('Pelham Parkway', 90),
#  ('Remsen Village', 58)]

# %%
[[ny_cities[i], nabe_matches[i]] for i in range(len(ny_cities)) if 85 <= nabe_matches[i][1] < 95]
# Out:
# [['BATH', ('Bath Beach', 90)],
#  ['ELMONT', ('Belmont', 92)],
#  ['ROCHDALE VILLAGE', ('Rochdale', 90)],
#  ['WILLISTON PARK', ('Park Hill', 86)],
#  ['PORT JEFFERSON STATION', ('Port Richmond', 86)],
#  ['NEW YORK,', ('East New York', 90)],
#  ['HUDSON', ('Hudson Yards', 90)],
#  ['NEW ORK', ('New Springville', 86)],
#  ['SLEEPY HOLLOW, NEW YORK', ('New Springville', 86)],
#  ['BROOKLYN,', ('Brooklyn Heights', 90)],
#  ['MANHATTAN', ('Manhattan Terrace', 90)],
#  ['DOWNTOWN BROOKLYN', ('Downtown', 90)],
#  ['HAMILTON', ('Hamilton Heights', 90)],
#  ['BRONX.NEW YORK', ('New Dorp', 86)],
#  ['COLD SPRING HARBOR', ('Belle Harbor', 86)],
#  ['#35620 OZONE PARK NY MSA', ('Ozone Park', 90)],
#  ['OLD WESTBURY', ('Old Town', 86)],
#  ['WILLIAMSBURG, BROOKLYN', ('Williamsburg', 90)],
#  ['AUBURN', ('Auburndale', 90)],
#  ['DEER PARK', ('Edgewater Park', 86)],
#  ['NEW TORK', ('New Springville', 86)],
#  ['BRONX,NEW YORK', ('New Dorp', 86)],
#  ['SAG HARBOR', ("Mariner's Harbor", 86)],
#  ['TARRY TOWN', ('Stuyvesant Town', 86)],
#  ['CLIFTON SPRINGS', ('Clifton', 90)],
#  ['EAST ISLIP', ('Upper East Side', 86)],
#  ['BRONX', ('Bronxdale', 90)],
#  ['EAST MEADOW', ('East Williamsburg', 86)],
#  ['RICHMONDVILLE', ('Richmond Valley', 86)],
#  ['MEW YORK', ('East New York', 86)],
#  ['PORT WASHINGTON,', ('Port Ivory', 86)],
#  ['SOUTH FALLSBURG', ('South Side', 86)],
#  ['MANHATTAN, NEW YORK', ('New Dorp', 86)],
#  ['GRANVILLE', ('Graniteville', 86)],
#  ['GARDEN CITY', ('Battery Park City', 86)],
#  ['NEW YORK', ('East New York', 90)],
#  ['FOREST HILLS QUEENS', ('Forest Hills', 90)],
#  ['NORTH TONAWANDA,', ('North Side', 86)],
#  ['BEDFORD HILLS', ('Forest Hills Gardens', 86)],
#  ['EAST ROCHESTER', ('Eastchester', 88)],
#  ['QUEENS', ('Queensbridge', 90)],
#  ['UNION', ('Unionport', 90)],
#  ['NEW YORK, NY', ('New Dorp', 86)],
#  ['BROOKLY', ('Brooklyn Heights', 90)],
#  ['ANNANDALE ON HUDSON', ('Hudson Yards', 86)],
#  ['MEDIACOM PARK', ('Elm Park', 86)],
#  ['NEW YORK, NY -', ('New Dorp', 86)],
#  ['FLUSHING, NY', ('Flushing', 90)],
#  ['ROCK HILL', ('Lighthouse Hill', 86)],
#  ['WEST ISLIP', ('Upper West Side', 86)],
#  ['701 WEST 168TH STREET', ('West Farms', 86)],
#  ['630 WEST 168TH STREET', ('West Farms', 86)],
#  ['LONG BEACH', ('Manhattan Beach', 86)],
#  ['NEW YROK', ('New Springville', 86)],
#  ['NEW CITY', ('New Springville', 86)],
#  ['FULTON', ('Fulton Ferry', 90)],
#  ['UNION CITY', ('Battery Park City', 86)],
#  ['NEW YOURK', ('New Springville', 86)],
#  ['PORT WASHINGTON', ('Port Ivory', 86)],
#  ['ALEXANDRIA BAY', ('Bay Ridge', 86)],
#  ['WEST HAMPTON BEACH', ('South Beach', 86)],
#  ['CLINTONDALE', ('Clinton', 90)],
#  ['BRONX, NEW YORK', ('New Dorp', 86)],
#  ['CLIFTON PARK', ('Clifton', 90)],
#  ['NEW PALTZ', ('New Springville', 86)],
#  ['EAST JEWETT', ('East Williamsburg', 86)],
#  ['NEW HYDE PARK', ('New Dorp', 86)],
#  ['HASTINGS ON HUDSON', ('Hudson Yards', 86)],
#  ['JERSEY CITY', ('Battery Park City', 86)],
#  ['LONG IS CITY', ('Long Island City', 86)],
#  ['JAMAICA', ('Jamaica Hills', 90)],
#  ['OAK HILL', ('Carnegie Hill', 86)],
#  ['ROSLYN HEIGHTS', ('Brooklyn Heights', 87)],
#  ['GARDEN CITY PARK', ('Co-op City', 86)],
#  ['EDEN', ('Edenwald', 90)],
#  ['NEW ROCHELLE', ('New Dorp', 86)],
#  ['YORK', ('Yorkville', 90)],
#  ['ROCKAWAY', ('Far Rockaway', 90)],
#  ['EAST DURHAM', ('East Williamsburg', 86)],
#  ['BAY SHORE', ('Sheepshead Bay', 86)],
#  ['ELMHRUST', ('Elmhurst', 88)],
#  ['ORCHARD PARK', ('Elm Park', 86)],
#  ['NEW HARTFORD', ('New Dorp', 86)],
#  ['BROADWAY', ('Broadway Junction', 90)],
#  ['CASTLETON-ON-HUDSON', ('Hudson Yards', 86)],
#  ['BERGEN', ('Bergen Beach', 90)],
#  ['BRONXVILLE', ('Brownsville', 86)],
#  ['BRIDGEPORT / NEW YORK', ('New Dorp', 86)],
#  ['BROOKLYN', ('Brooklyn Heights', 90)],
#  ['HYDE PARK', ('Edgewater Park', 86)],
#  ['CHESTNUT RIDGE', ('Bay Ridge', 86)],
#  ['DIX HILLS', ('Kew Gardens Hills', 86)],
#  ['CHESTER', ('Eastchester', 90)],
#  ['NEW YOK', ('New Springville', 86)],
#  ['NEW BERLIN', ('New Springville', 86)],
#  ['160 FORT WASHINGTON AVENUE', ('Fort Greene', 86)],
#  ['TUXEDO PARK', ('Battery Park City', 86)],
#  ['NEW YORK CITY', ('New Dorp', 86)],
#  ['GREENE', ('Fort Greene', 90)],
#  ['CULVER CITY', ('Battery Park City', 86)],
#  ['MASPATH', ('Maspeth', 86)],
#  ['SOUTH PLAINFIELD', ('South Side', 86)],
#  ['NORTH TONAWANDA', ('North Side', 86)],
#  ['OAKLAND', ('Oakland Gardens', 90)],
#  ['NEW YOUR', ('New Springville', 86)],
#  ['ANNANDALE-ON-HUDSON', ('Hudson Yards', 86)],
#  ['HIGHLAND', ('Highland Park', 90)],
#  ['WEST NYACK', ('Upper West Side', 86)],
#  ['EAST AURORA', ('East Williamsburg', 86)],
#  ['325 HUDSON STREET, 9TH FLOOR', ('Hudson Yards', 86)],
#  ['NY', ('Sunnyside', 90)],
#  ['METRO NEW YORK', ('New Dorp', 86)],
#  ['BEDFORD', ('Bedford Park', 90)],
#  ['MIDTOWN MANHATTAN', ('Midtown', 90)],
#  ['NEW', ('New Springville', 90)],
#  ['NEW YORK CITY,', ('New Dorp', 86)],
#  ['PELHAM', ('Pelham Parkway', 90)]]

# %%
good_nabes = [ny_cities[i] for i in range(len(ny_cities)) if 95 <= nabe_matches[i][1]]
good_nabes.remove("OLD BROOKVILLE")
good_nabes.remove("NEW YORK, NEW YORK")
good_nabes.remove("NEW YORK,NEW YORK")
good_nabes.append("#35620 OZONE PARK NY MSA")
good_nabes.append("WILLIAMSBURG, BROOKLYN")
good_nabes.append("FOREST HILLS QUEENS")
good_nabes.append("FLUSHING, NY")
good_nabes.append("LONG IS CITY")
good_nabes.append("JAMAICA")
good_nabes.append("ROCKAWAY")
good_nabes.append("ELMHRUST")
good_nabes.append("BROADWAY")
good_nabes.append("MASPATH")

# %%
# need a neighbourhood column now
nycdf["neighbourhood"] = ["" for i in range(nycdf.shape[0])]
for nabe in good_nabes:
    cityind = ny_cities.index(nabe)
    nycdf.loc[nycdf.lca_case_workloc1_city == nabe, ["neighbourhood"]] = nabe_matches[cityind][0]
    nycdf.loc[nycdf.lca_case_workloc1_city == nabe, ["borough"]] = nabe_dict[nabe_matches[cityind][0]]
    nycdf.loc[nycdf.lca_case_workloc1_city == nabe, ["dummy_city_1"]] = np.nan
    nycdf.loc[nycdf.lca_case_workloc2_city == nabe, ["neighbourhood"]] = nabe_matches[cityind][0]
    nycdf.loc[nycdf.lca_case_workloc2_city == nabe, ["borough"]] = nabe_dict[nabe_matches[cityind][0]]
    nycdf.loc[nycdf.lca_case_workloc2_city == nabe, ["dummy_city_2"]] = np.nan

# %%
# and now let's get the remainder
ny_cities = nycdf[h1b.lca_case_workloc1_state == "NY"].dropna(subset=["dummy_city_1"])
ny_cities = ny_cities["lca_case_workloc1_city"].unique()
ny_cities_2 = nycdf[h1b.lca_case_workloc2_state == "NY"].dropna(subset=["dummy_city_2"])
ny_cities_2 = ny_cities_2["lca_case_workloc2_city"].unique()
ny_cities = list(set(ny_cities).union(set(ny_cities_2)))
# Out:
# /home/kilian/.envs/elucd/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /home/kilian/.envs/elucd/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
# the rest were just various bastardisations of "NEW YORK"
ny_matches = [process.extractOne(city, ["NEW YORK"]) for city in ny_cities]

# %%
[city for city in ny_cities if fuzz.ratio(city, "NEW YORK") > 50]
# Out:
# ['NEW WINDSOR',
#  'NEW YORK,',
#  'NEW ORK',
#  'SLEEPY HOLLOW, NEW YORK',
#  'NEW YORK,NEW YORK',
#  'NEW TORK',
#  'NEW YORK, NEW YORK',
#  'MEW YORK',
#  'NEW WINDSOW',
#  'NEW HAMPTON',
#  'NEW YORK',
#  'NEWYORK CITY',
#  'NEW YORK, NY',
#  'NEW YORK, NY -',
#  'NEW YROK',
#  'NEW CITY',
#  'NEW YOURK',
#  'YORKERS',
#  'NEW HYDE PARK',
#  'YORK',
#  'NEW HARTFORD',
#  'BRIDGEPORT / NEW YORK',
#  'NEWARK',
#  'NEW YOK',
#  'NEW BERLIN',
#  'NEW YORK CITY',
#  'NEWYORK',
#  'NEW YOUR',
#  'METRO NEW YORK',
#  'NEW',
#  'NEW YORK CITY,']

# %%
good_ny = [city for city in ny_cities if fuzz.ratio(city, "NEW YORK") > 50]
good_ny.remove("NEW WINDSOR")
good_ny.remove("SLEEPY HOLLOW, NEW YORK")
good_ny.remove("NEW WINDSOW")
good_ny.remove("NEW HAMPTON")
good_ny.remove("YORKERS")
good_ny.remove("NEW HYDE PARK")
good_ny.remove("YORK")
good_ny.remove("NEW HARTFORD")
good_ny.remove("BRIDGEPORT / NEW YORK")
good_ny.remove("NEWARK")
good_ny.remove("NEW BERLIN")

# %%
for ny in good_ny:
    cityind = ny_cities.index(ny)
    nycdf.loc[nycdf.lca_case_workloc1_city == ny, ["borough"]] = 'Manhattan'
    nycdf.loc[nycdf.lca_case_workloc2_city == ny, ["borough"]] = 'Manhattan'

# %%
# Now we can drop all the rest
nycdf = nycdf.loc[nycdf.borough != "", :]

# %%
nycdf
# Out:
#            lca_case_number lca_case_submit decision_date      visa_class  \
# 23      I-200-09259-849209      2014-03-12    2014-03-18            H-1B
# 62      I-200-10022-756568      2013-10-24    2013-11-01            H-1B
# 101     I-200-10117-226427      2014-04-30    2014-05-06            H-1B
# 102     I-200-10117-359404      2014-04-28    2014-05-02            H-1B
# 103     I-200-10119-288408      2013-10-28    2013-11-01            H-1B
# 228     I-200-13304-001040      2013-11-04    2013-11-08            H-1B
# 256     I-200-10286-475427      2014-05-20    2014-05-27            H-1B
# 314     I-200-10306-514283      2014-07-17    2014-07-23            H-1B
# 426     I-200-10333-894969      2013-11-04    2013-11-13            H-1B
# 532     I-200-10354-804120      2013-11-04    2013-11-13            H-1B
# 546     I-200-10357-444811      2013-11-04    2013-11-13            H-1B
# 681     I-200-11014-606365      2014-07-07    2014-07-11            H-1B
# 682     I-200-11014-650147      2014-03-11    2014-03-17            H-1B
# 700     I-200-11019-122743      2013-09-30    2013-10-22            H-1B
# 709     I-200-11019-604127      2013-09-30    2013-10-22            H-1B
# 721     I-200-11020-488817      2014-03-06    2014-03-12            H-1B
# 779     I-200-11028-424470      2013-09-30    2013-10-22            H-1B
# 802     I-200-11032-589322      2014-03-06    2014-03-12            H-1B
# 841     I-200-11039-452203      2014-03-10    2014-03-14            H-1B
# 1147    I-200-11066-881550      2013-10-18    2013-10-26            H-1B
# 1810    I-200-11097-696183      2013-10-30    2013-11-05            H-1B
# 1811    I-200-11097-732874      2014-03-19    2014-03-25            H-1B
# 1894    I-200-11103-685896      2014-04-28    2014-05-02            H-1B
# 1939    I-200-11105-739790      2014-04-25    2014-05-01            H-1B
# 3130    I-200-11180-352579      2014-07-11    2014-07-21            H-1B
# 3192    I-200-11183-511996      2014-04-30    2014-05-06            H-1B
# 3248    I-200-11188-604966      2013-09-20    2013-10-18            H-1B
# 3327    I-200-11194-104014      2014-07-24    2014-07-30            H-1B
# 4428    I-200-11255-476823      2014-05-07    2014-05-13            H-1B
# 4780    I-200-11276-073943      2014-05-20    2014-05-27            H-1B
# ...                    ...             ...           ...             ...
# 519352  I-203-14260-637387      2014-09-23    2014-09-29  E-3 Australian
# 519354  I-203-14260-708488      2014-09-17    2014-09-23  E-3 Australian
# 519355  I-203-14260-859571      2014-09-17    2014-09-23  E-3 Australian
# 519359  I-203-14261-025752      2014-09-18    2014-09-24  E-3 Australian
# 519362  I-203-14261-048787      2014-09-23    2014-09-29  E-3 Australian
# 519368  I-203-14261-186650      2014-09-18    2014-09-24  E-3 Australian
# 519370  I-203-14261-230679      2014-09-18    2014-09-24  E-3 Australian
# 519371  I-203-14261-277853      2014-09-22    2014-09-26  E-3 Australian
# 519375  I-203-14261-459948      2014-09-18    2014-09-24  E-3 Australian
# 519380  I-203-14261-613611      2014-09-23    2014-09-29  E-3 Australian
# 519381  I-203-14261-659019      2014-09-24    2014-09-30  E-3 Australian
# 519387  I-203-14261-790493      2014-09-18    2014-09-24  E-3 Australian
# 519392  I-203-14261-879896      2014-09-18    2014-09-24  E-3 Australian
# 519394  I-203-14261-954673      2014-09-22    2014-09-26  E-3 Australian
# 519401  I-203-14262-215290      2014-09-19    2014-09-25  E-3 Australian
# 519404  I-203-14262-472438      2014-09-19    2014-09-25  E-3 Australian
# 519406  I-203-14262-521108      2014-09-19    2014-09-25  E-3 Australian
# 519408  I-203-14262-581176      2014-09-19    2014-09-25  E-3 Australian
# 519410  I-203-14262-735299      2014-09-19    2014-09-25  E-3 Australian
# 519412  I-203-14262-755541      2014-09-22    2014-09-26  E-3 Australian
# 519414  I-203-14262-839293      2014-09-19    2014-09-25  E-3 Australian
# 519416  I-203-14262-898142      2014-09-19    2014-09-25  E-3 Australian
# 519434  I-203-14265-300669      2014-09-22    2014-09-26  E-3 Australian
# 519440  I-203-14265-656378      2014-09-23    2014-09-29  E-3 Australian
# 519466  I-203-14266-789319      2014-09-23    2014-09-29  E-3 Australian
# 519468  I-203-14266-937399      2014-09-23    2014-09-29  E-3 Australian
# 519470  I-203-14267-050133      2014-09-24    2014-09-30  E-3 Australian
# 519471  I-203-14267-072965      2014-09-24    2014-09-30  E-3 Australian
# 519474  I-203-14267-121234      2014-09-24    2014-09-30  E-3 Australian
# 519485  I-203-14267-645308      2014-09-24    2014-09-30  E-3 Australian
#
#        lca_case_employment_start_date lca_case_employment_end_date  \
# 23                         2014-09-10                   2017-09-10
# 62                         2013-10-24                   2016-10-22
# 101                        2014-05-12                   2017-05-12
# 102                        2014-05-05                   2017-05-05
# 103                        2014-01-06                   2017-01-06
# 228                        2013-11-15                   2016-11-15
# 256                        2014-06-02                   2017-06-02
# 314                        2014-08-10                   2017-08-09
# 426                        2013-11-20                   2016-11-20
# 532                        2013-11-20                   2016-11-20
# 546                        2013-12-16                   2016-12-16
# 681                        2014-07-15                   2016-08-14
# 682                        2014-09-06                   2017-09-06
# 700                        2013-10-07                   2016-10-06
# 709                        2013-10-07                   2016-10-06
# 721                        2014-03-17                   2017-03-17
# 779                        2013-10-07                   2016-10-06
# 802                        2014-03-17                   2017-03-17
# 841                        2014-09-02                   2017-09-02
# 1147                       2013-12-19                   2014-12-18
# 1810                       2013-10-30                   2015-10-30
# 1811                       2014-03-20                   2017-03-20
# 1894                       2014-05-01                   2017-05-01
# 1939                       2014-05-01                   2017-05-01
# 3130                       2014-07-14                   2017-07-14
# 3192                       2014-09-26                   2017-09-25
# 3248                       2013-10-07                   2015-09-30
# 3327                       2014-08-15                   2017-08-15
# 4428                       2014-05-16                   2017-05-16
# 4780                       2014-05-26                   2017-05-26
# ...                               ...                          ...
# 519352                     2014-09-29                   2016-09-29
# 519354                     2014-10-01                   2016-10-01
# 519355                     2014-10-06                   2016-10-05
# 519359                     2014-10-01                   2016-10-01
# 519362                     2014-10-13                   2016-10-13
# 519368                     2015-01-01                   2016-12-31
# 519370                     2014-10-06                   2016-10-05
# 519371                     2014-10-13                   2016-10-13
# 519375                     2014-09-18                   2015-03-10
# 519380                     2014-10-20                   2016-10-20
# 519381                     2014-10-01                   2016-10-01
# 519387                     2014-10-08                   2016-10-08
# 519392                     2014-10-13                   2016-10-13
# 519394                     2014-10-13                   2016-10-12
# 519401                     2014-10-14                   2016-10-13
# 519404                     2014-10-10                   2016-10-09
# 519406                     2014-10-06                   2016-10-06
# 519408                     2014-10-01                   2016-10-01
# 519410                     2014-09-25                   2016-09-24
# 519412                     2014-10-06                   2016-10-06
# 519414                     2014-10-01                   2016-10-01
# 519416                     2014-11-03                   2016-11-02
# 519434                     2014-10-01                   2016-10-01
# 519440                     2014-10-13                   2016-10-12
# 519466                     2014-10-01                   2016-09-30
# 519468                     2014-10-25                   2016-10-25
# 519470                     2014-10-13                   2016-10-12
# 519471                     2014-10-08                   2016-10-08
# 519474                     2014-10-20                   2016-10-20
# 519485                     2014-10-01                   2016-09-30
#
#                                    lca_case_employer_name  \
# 23                                      FRS AMERICA, INC.
# 62                   BLACKROCK INVESTMENT MANAGEMENT, LLC
# 101                                  JPMORGAN CHASE & CO.
# 102                                  JPMORGAN CHASE & CO.
# 103                               HEADSTRONG SERVICES LLC
# 228                                              CUNY, TV
# 256                                  JPMORGAN CHASE & CO.
# 314                                 CT CORPORATION SYSTEM
# 426                               HEADSTRONG SERVICES LLC
# 532                               HEADSTRONG SERVICES LLC
# 546                               HEADSTRONG SERVICES LLC
# 681                                   CAST SOFTWARE, INC.
# 682                                  JPMORGAN CHASE & CO.
# 700                                         JEFFERIES LLC
# 709                                         JEFFERIES LLC
# 721                                  JPMORGAN CHASE & CO.
# 779                                         JEFFERIES LLC
# 802                                  JPMORGAN CHASE & CO.
# 841                                  JPMORGAN CHASE & CO.
# 1147                     ISRAEL DISCOUNT BANK OF NEW YORK
# 1810                              QUESTSOFT SOLUTIONS INC
# 1811                                 JPMORGAN CHASE & CO.
# 1894                             JPMORGAN CHASE &AMP; CO.
# 1939                                 JPMORGAN CHASE & CO.
# 3130              NYL- NEW YORK LEAGUE FOR EARLY LEARNING
# 3192                                SAPHIRE SOLUTIONS INC
# 3248                         DW INVESTMENT MANAGEMENT, LP
# 3327    OVID TECHNOLOGIES, INC. (A SUBSIDIARY OF WOLTE...
# 4428                                 JPMORGAN CHASE & CO.
# 4780                                 JPMORGAN CHASE & CO.
# ...                                                   ...
# 519352  THE FORUM CORPORATION (PROVIDENCE CORPORATE DE...
# 519354                              ELIZABETH ARDEN, INC.
# 519355                                     IBISWORLD INC.
# 519359                                  BETWEEN TAKES LLC
# 519362                                BRAND NETWORKS, LLC
# 519368                CHRISTIAN CITY CHURCH MANHATTAN INC
# 519370                        ATMOSPHERE INTERACTIVE INC.
# 519371                         WEIL, GOTSHAL & MANGES LLP
# 519375           SKADDEN, ARPS, SLATE, MEAGHER & FLOM LLP
# 519380                                   TOMLIN LAW, PLLC
# 519381              FRESHFIELDS BRUCKHAUS DERINGER US LLP
# 519387                                 THE WILD BUNCH LLC
# 519392                               LINKEDIN CORPORATION
# 519394                                 DLA PIPER LLP (US)
# 519401                                         HARARE INC
# 519404                                       ROOM 106 LLC
# 519406                            SFX ENTERTAINMENT, INC.
# 519408                                        YODLE, INC.
# 519410                          MORGAN STANLEY BANK, N.A.
# 519412                                   UBS SERVICES LLC
# 519414                       INFINITY NORTH AMERICA, INC.
# 519416                           VECTOR MEDIA GROUP, INC.
# 519434                                        COACH, INC.
# 519440                                    EMC CORPORATION
# 519466                        PHYSICIANS FOR HUMAN RIGHTS
# 519468                                    CATAPULT DESIGN
# 519470     NATIONAL GAY AND LESBIAN TASK FORCE FOUNDATION
# 519471                   FIRSTBORN MULTIMEDIA CORPORATION
# 519474                     SKILLMAN TENNIS ASSOCIATES LLC
# 519485                                        BITLY, INC.
#
#                    lca_case_employer_address lca_case_employer_city  \
# 23                       2700 LAKE COOK ROAD             RIVERWOODS
# 62                       40 EAST 52ND STREET               NEW YORK
# 101                 10 SOUTH DEARBORN STREET                CHICAGO
# 102                 10 SOUTH DEARBORN STREET                CHICAGO
# 103                      11911 FREEDOM DRIVE                 RESTON
# 228                         365 FIFTH AVENUE               NEW YORK
# 256                 10 SOUTH DEARBORN STREET                CHICAGO
# 314                      2700 LAKE COOK ROAD             RIVERWOODS
# 426                      11911 FREEDOM DRIVE                 RESTON
# 532                      11911 FREEDOM DRIVE                 RESTON
# 546                      11911 FREEDOM DRIVE                 RESTON
# 681              373 PARK AVE SO., 5TH FLOOR               NEW YORK
# 682                 10 SOUTH DEARBORN STREET                CHICAGO
# 700                          520 MADISON AVE               NEW YORK
# 709                          520 MADISON AVE               NEW YORK
# 721                 10 SOUTH DEARBORN STREET                CHICAGO
# 779                          520 MADISON AVE               NEW YORK
# 802                 10 SOUTH DEARBORN STREET                CHICAGO
# 841                 10 SOUTH DEARBORN STREET                CHICAGO
# 1147                        511 FIFTH AVENUE               NEW YORK
# 1810                     432 ROUTE 34,STE#3A                MATAWAN
# 1811                10 SOUTH DEARBORN STREET                CHICAGO
# 1894                10 SOUTH DEARBORN STREET                CHICAGO
# 1939                10 SOUTH DEARBORN STREET                CHICAGO
# 3130                    460 WEST 34TH STREET               NEW YORK
# 3192             523 GREEN STREET, 2ND FLOOR                 ISELIN
# 3248                      590 MADISON AVENUE               NEW YORK
# 3327                     2700 LAKE COOK ROAD             RIVERWOODS
# 4428                10 SOUTH DEARBORN STREET                CHICAGO
# 4780                10 SOUTH DEARBORN STREET                CHICAGO
# ...                                      ...                    ...
# 519352                   265 FRANKLIN STREET                 BOSTON
# 519354                 200 PARK AVENUE SOUTH               NEW YORK
# 519355                            40 WALL ST               NEW YORK
# 519359              1521 CONCORD PIKE NO 303             WILMINGTON
# 519362                      180 CANAL STREET                 BOSTON
# 519368               332 BLEECKER STREET D43               NEW YORK
# 519370           1285 AVENUE OF THE AMERICAS               NEW YORK
# 519371                      767 FIFTH AVENUE               NEW YORK
# 519375                     FOUR TIMES SQUARE               NEW YORK
# 519380                           733 3RD AVE               NEW YORK
# 519381                     601 LEXINGTON AVE               NEW YORK
# 519387             81 DELANCEY STREET APT 16               NEW YORK
# 519392                   2029 STIERLIN COURT          MOUNTAIN VIEW
# 519394                     6225 SMITH AVENUE              BALTIMORE
# 519401                       112 LINCOLN AVE                  BRONX
# 519404  C/O WEALTH MGMT 45 BROADWAY STE 2230               NEW YORK
# 519406                       430 PARK AVENUE               NEW YORK
# 519408                   50 WEST 23RD STREET               NEW YORK
# 519410                         1585 BROADWAY               NEW YORK
# 519412              677 WASHINGTON BOULEVARD               STAMFORD
# 519414                          5 PENN PLAZA               NEW YORK
# 519416                   18 WEST 21ST STREET               NEW YORK
# 519434                  516 WEST 34TH STREET               NEW YORK
# 519440        80 SOUTH STREET, MAILSTOP 1C-5              HOPKINTON
# 519466                  256 WEST 56TH STREET               NEW YORK
# 519468                    972 MISSION STREET          SAN FRANCISCO
# 519470  1325 MASSACHUSETTS AVE. NW SUITE 600             WASHINGTON
# 519471  32 AVENUE OF THE AMERICAS, 5TH FLOOR               NEW YORK
# 519474                      43-34 32ND PLACE       LONG ISLAND CITY
# 519485                  85 5TH AVE 4TH FLOOR               NEW YORK
#
#        lca_case_employer_state        ...             pw_2 pw_unit_2  \
# 23                          IL        ...         129418.0      Year
# 62                          NY        ...              NaN       NaN
# 101                         IL        ...              NaN       NaN
# 102                         IL        ...              NaN       NaN
# 103                         VA        ...          62566.0      Year
# 228                         NY        ...              NaN       NaN
# 256                         IL        ...              NaN       NaN
# 314                         IL        ...              NaN       NaN
# 426                         VA        ...          86403.0      Year
# 532                         VA        ...          86403.0      Year
# 546                         VA        ...          71510.0      Year
# 681                         NY        ...              NaN       NaN
# 682                         IL        ...              NaN       NaN
# 700                         NY        ...          67205.0      Year
# 709                         NY        ...          56597.0      Year
# 721                         IL        ...              NaN       NaN
# 779                         NY        ...          51459.0      Year
# 802                         IL        ...              NaN       NaN
# 841                         IL        ...              NaN       NaN
# 1147                        NY        ...              NaN       NaN
# 1810                        NJ        ...          56597.0      Year
# 1811                        IL        ...              NaN       NaN
# 1894                        IL        ...              NaN       NaN
# 1939                        IL        ...              NaN       NaN
# 3130                        NY        ...              NaN       NaN
# 3192                        NJ        ...          68557.0      Year
# 3248                        NY        ...              NaN       NaN
# 3327                        IL        ...              NaN       NaN
# 4428                        IL        ...              NaN       NaN
# 4780                        IL        ...              NaN       NaN
# ...                        ...        ...              ...       ...
# 519352                      MA        ...              NaN       NaN
# 519354                      NY        ...              NaN       NaN
# 519355                      NY        ...              NaN       NaN
# 519359                      DE        ...              NaN       NaN
# 519362                      MA        ...              NaN       NaN
# 519368                      NY        ...              NaN       NaN
# 519370                      NY        ...              NaN       NaN
# 519371                      NY        ...              NaN       NaN
# 519375                      NY        ...              NaN       NaN
# 519380                      NY        ...              NaN       NaN
# 519381                      NY        ...              NaN       NaN
# 519387                      NY        ...              NaN       NaN
# 519392                      CA        ...              NaN       NaN
# 519394                      MD        ...              NaN       NaN
# 519401                      NY        ...              NaN       NaN
# 519404                      NY        ...              NaN       NaN
# 519406                      NY        ...              NaN       NaN
# 519408                      NY        ...              NaN       NaN
# 519410                      NY        ...              NaN       NaN
# 519412                      CT        ...         182957.0      Year
# 519414                      NY        ...              NaN       NaN
# 519416                      NY        ...              NaN       NaN
# 519434                      NY        ...              NaN       NaN
# 519440                      MA        ...              NaN       NaN
# 519466                      NY        ...              NaN       NaN
# 519468                      CA        ...              NaN       NaN
# 519470                      DC        ...              NaN       NaN
# 519471                      NY        ...              NaN       NaN
# 519474                      NY        ...              NaN       NaN
# 519485                      NY        ...              NaN       NaN
#
#        pw_source_2      other_wage_source_2          yr_source_pub_2  \
# 23             OES  OFLC ONLINE DATA CENTER  OFLC ONLINE DATA CENTER
# 62             NaN                      NaN                      NaN
# 101            NaN                      NaN                      NaN
# 102            NaN                      NaN                      NaN
# 103            OES  OFLC ONLINE DATA CENTER  OFLC ONLINE DATA CENTER
# 228            NaN                      NaN                      NaN
# 256            NaN                      NaN                      NaN
# 314            NaN                      NaN                      NaN
# 426            OES  OFLC ONLINE DATA CENTER  OFLC ONLINE DATA CENTER
# 532            OES  OFLC ONLINE DATA CENTER  OFLC ONLINE DATA CENTER
# 546            OES  OFLC ONLINE DATA CENTER  OFLC ONLINE DATA CENTER
# 681            NaN                      NaN                      NaN
# 682            NaN                      NaN                      NaN
# 700            OES  OFLC ONLINE DATA CENTER  OFLC ONLINE DATA CENTER
# 709            OES  OFLC ONLINE DATA CENTER  OFLC ONLINE DATA CENTER
# 721            NaN                      NaN                      NaN
# 779            OES  OFLC ONLINE DATA CENTER  OFLC ONLINE DATA CENTER
# 802            NaN                      NaN                      NaN
# 841            NaN                      NaN                      NaN
# 1147           NaN                      NaN                      NaN
# 1810         Other  FLC ONLINE WAGE LIBRARY  FLC ONLINE WAGE LIBRARY
# 1811           NaN                      NaN                      NaN
# 1894           NaN                      NaN                      NaN
# 1939           NaN                      NaN                      NaN
# 3130           NaN                      NaN                      NaN
# 3192           OES      ONLINE WAGE LIBRARY      ONLINE WAGE LIBRARY
# 3248           NaN                      NaN                      NaN
# 3327           NaN                      NaN                      NaN
# 4428           NaN                      NaN                      NaN
# 4780           NaN                      NaN                      NaN
# ...            ...                      ...                      ...
# 519352         NaN                      NaN                      NaN
# 519354         NaN                      NaN                      NaN
# 519355         NaN                      NaN                      NaN
# 519359         NaN                      NaN                      NaN
# 519362         NaN                      NaN                      NaN
# 519368         NaN                      NaN                      NaN
# 519370         NaN                      NaN                      NaN
# 519371         NaN                      NaN                      NaN
# 519375         NaN                      NaN                      NaN
# 519380         NaN                      NaN                      NaN
# 519381         NaN                      NaN                      NaN
# 519387         NaN                      NaN                      NaN
# 519392         NaN                      NaN                      NaN
# 519394         NaN                      NaN                      NaN
# 519401         NaN                      NaN                      NaN
# 519404         NaN                      NaN                      NaN
# 519406         NaN                      NaN                      NaN
# 519408         NaN                      NaN                      NaN
# 519410         NaN                      NaN                      NaN
# 519412         OES  OFLC ONLINE DATA CENTER  OFLC ONLINE DATA CENTER
# 519414         NaN                      NaN                      NaN
# 519416         NaN                      NaN                      NaN
# 519434         NaN                      NaN                      NaN
# 519440         NaN                      NaN                      NaN
# 519466         NaN                      NaN                      NaN
# 519468         NaN                      NaN                      NaN
# 519470         NaN                      NaN                      NaN
# 519471         NaN                      NaN                      NaN
# 519474         NaN                      NaN                      NaN
# 519485         NaN                      NaN                      NaN
#
#         lca_case_naics_code    borough  dummy_city_1 dummy_city_2  \
# 23                 511210.0  Manhattan      NEW YORK     NEW YORK
# 62                 523920.0  Manhattan      NEW YORK          NaN
# 101                551112.0  Manhattan      NEW YORK          NaN
# 102                551112.0  Manhattan      NEW YORK          NaN
# 103                541611.0  Manhattan   JERSEY CITY     NEW YORK
# 228                515120.0  Manhattan      NEW YORK          NaN
# 256                551112.0  Manhattan      NEW YORK          NaN
# 314                511210.0  Manhattan      NEW YORK          NaN
# 426                541611.0  Manhattan      NEW YORK     NEW YORK
# 532                541611.0  Manhattan      NEW YORK     NEW YORK
# 546                541611.0  Manhattan      NEW YORK     NEW YORK
# 681                541511.0  Manhattan      NEW YORK          NaN
# 682                551112.0  Manhattan      NEW YORK          NaN
# 700                523110.0  Manhattan      NEW YORK  JERSEY CITY
# 709                523110.0  Manhattan      NEW YORK  JERSEY CITY
# 721                551112.0  Manhattan      NEW YORK          NaN
# 779                523110.0  Manhattan      NEW YORK     STAMFORD
# 802                551112.0  Manhattan      NEW YORK          NaN
# 841                551112.0  Manhattan      NEW YORK          NaN
# 1147               522110.0  Manhattan      NEW YORK          NaN
# 1810               541511.0  Manhattan       MATAWAN     NEW YORK
# 1811               551112.0  Manhattan      NEW YORK          NaN
# 1894               551112.0  Manhattan      NEW YORK          NaN
# 1939               551112.0  Manhattan      NEW YORK          NaN
# 3130               623220.0     Queens           NaN          NaN
# 3192               541511.0  Manhattan      NEW YORK       ISELIN
# 3248               523920.0  Manhattan      NEW YORK          NaN
# 3327               511210.0  Manhattan      NEW YORK          NaN
# 4428               551112.0  Manhattan      NEW YORK          NaN
# 4780               551112.0  Manhattan      NEW YORK          NaN
# ...                     ...        ...           ...          ...
# 519352             611430.0  Manhattan      NEW YORK          NaN
# 519354             424210.0  Manhattan      NEW YORK          NaN
# 519355              54191.0  Manhattan      NEW YORK          NaN
# 519359             512110.0  Manhattan      NEW YORK          NaN
# 519362               5418.0  Manhattan      NEW YORK          NaN
# 519368             813110.0  Manhattan      NEW YORK          NaN
# 519370             541810.0  Manhattan      NEW YORK          NaN
# 519371             541110.0  Manhattan      NEW YORK          NaN
# 519375             541110.0  Manhattan      NEW YORK          NaN
# 519380             541110.0  Manhattan      NEW YORK          NaN
# 519381             541110.0  Manhattan      NEW YORK          NaN
# 519387             541430.0  Manhattan      NEW YORK          NaN
# 519392             518112.0  Manhattan      NEW YORK          NaN
# 519394              54110.0  Manhattan      NEW YORK          NaN
# 519401             541490.0  Manhattan      NEW YORK          NaN
# 519404             711510.0  Manhattan      NEW YORK          NaN
# 519406             711320.0  Manhattan      NEW YORK          NaN
# 519408             541511.0  Manhattan      NEW YORK          NaN
# 519410             523110.0  Manhattan      NEW YORK          NaN
# 519412             523110.0  Manhattan      NEW YORK    WEEHAWKEN
# 519414               9231.0  Manhattan      NEW YORK          NaN
# 519416             541613.0  Manhattan      NEW YORK          NaN
# 519434             448320.0  Manhattan      NEW YORK          NaN
# 519440             541511.0  Manhattan      NEW YORK          NaN
# 519466             813311.0  Manhattan      NEW YORK          NaN
# 519468             541420.0  Manhattan      NEW YORK          NaN
# 519470             813311.0  Manhattan      NEW YORK          NaN
# 519471             541511.0  Manhattan      NEW YORK          NaN
# 519474             711211.0     Queens           NaN          NaN
# 519485             519100.0  Manhattan      NEW YORK          NaN
#
#            neighbourhood
# 23
# 62
# 101
# 102
# 103
# 228
# 256
# 314
# 426
# 532
# 546
# 681
# 682
# 700
# 709
# 721
# 779
# 802
# 841
# 1147
# 1810
# 1811
# 1894
# 1939
# 3130       College Point
# 3192
# 3248
# 3327
# 4428
# 4780
# ...                  ...
# 519352
# 519354
# 519355
# 519359
# 519362
# 519368
# 519370
# 519371
# 519375
# 519380
# 519381
# 519387
# 519392
# 519394
# 519401
# 519404
# 519406
# 519408
# 519410
# 519412
# 519414
# 519416
# 519434
# 519440
# 519466
# 519468
# 519470
# 519471
# 519474  Long Island City
# 519485
#
# [32162 rows x 37 columns]

# %%
# Right....

# %%
# Now for the Bay Area...
bayzips = pd.read_csv("../dat/ext/bayarea_zipcodes.csv")
baycounty = pd.read_csv("../dat/ext/bayarea_county.csv")

# %%
bay_po = bayzips.PO_NAME.values.tolist()
bay_po = list(set(bay_po))
bay_po
# Out:
# ['SAN LEANDRO',
#  'SAN QUENTIN',
#  'STANFORD',
#  'SAN BRUNO',
#  'MENLO PARK',
#  'WALNUT CREEK',
#  'SAN RAMON',
#  'MARTINEZ',
#  'GREENBRAE',
#  'BRENTWOOD',
#  'DALY CITY',
#  'CORTE MADERA',
#  'FAIRFIELD',
#  'STINSON BEACH',
#  'ALBANY',
#  'SAUSALITO',
#  'NAPA',
#  'SAN ANSELMO',
#  'SUNNYVALE',
#  'EMERYVILLE',
#  'SAN CARLOS',
#  'RODEO',
#  'ALAMEDA',
#  'ALAMO',
#  'PINOLE',
#  'EL CERRITO',
#  'MOSS BEACH',
#  'HAYWARD',
#  'SAN GERONIMO',
#  'EL SOBRANTE',
#  'BYRON',
#  'HERCULES',
#  'ANTIOCH',
#  'SAN JOSE',
#  'OAKLEY',
#  'NEWARK',
#  'UNION CITY',
#  'BERKELEY',
#  'CLAYTON',
#  'LAGUNITAS',
#  'NOVATO',
#  'VALLEJO',
#  'ALVISO',
#  'SAN RAFAEL',
#  'RICHMOND',
#  'BENICIA',
#  'PLEASANT HILL',
#  'SONOMA',
#  'ORINDA',
#  'NICASIO',
#  'MOUNTAIN VIEW',
#  'PETALUMA',
#  'MILPITAS',
#  'DUBLIN',
#  'PORTOLA VALLEY',
#  'MILL VALLEY',
#  'MOUNT HAMILTON',
#  'MORAGA',
#  'SUISUN CITY',
#  'PORT COSTA',
#  'PALO ALTO',
#  'MILLBRAE',
#  'BELMONT',
#  'FREMONT',
#  'BRISBANE',
#  'REDWOOD CITY',
#  'PITTSBURG',
#  'SAN MATEO',
#  'CASTRO VALLEY',
#  'HALF MOON BAY',
#  'PACIFICA',
#  'SUNOL',
#  'SAN FRANCISCO',
#  'LARKSPUR',
#  'BELVEDERE TIBURON',
#  'CROCKETT',
#  'OAKLAND',
#  'LIVERMORE',
#  'DANVILLE',
#  'ATHERTON',
#  'TRAVIS AFB',
#  'CONCORD',
#  'WOODACRE',
#  'FAIRFAX',
#  'SAN PABLO',
#  'LOS ALTOS',
#  'LAFAYETTE',
#  'DIABLO',
#  'BIRDS LANDING',
#  'RIO VISTA',
#  'SOUTH SAN FRANCISCO',
#  'DIXON',
#  'PLEASANTON',
#  'AMERICAN CANYON',
#  'FOREST KNOLLS',
#  'SAN LORENZO',
#  'BURLINGAME']

# %%
bay_co = baycounty.COUNTY.values.tolist()
bay_co
# Out:
# ['Alameda',
#  'Contra Costa',
#  'Marin',
#  'Napa',
#  'San Francisco',
#  'San Mateo',
#  'Santa Clara',
#  'Solano',
#  'Sonoma']

# %%
sfdf = h1b.loc[np.logical_or(h1b.lca_case_workloc1_state == "CA", h1b.lca_case_workloc2_state == "CA"), :]
sfdf = sfdf.drop(sfdf[np.logical_and(sfdf.lca_case_workloc1_state == "CA", pd.isnull(sfdf.lca_case_workloc1_city))].index)
sfdf = sfdf.drop(sfdf[np.logical_and(sfdf.lca_case_workloc2_state == "CA", pd.isnull(sfdf.lca_case_workloc2_city))].index)
sfdf.shape
# Out:
# (86282, 33)

# %%
sf_cities = sfdf[h1b.lca_case_workloc1_state == "CA"].dropna(subset=["lca_case_workloc1_city"])
sf_cities = sf_cities["lca_case_workloc1_city"].unique()
sf_cities_2 = sfdf[h1b.lca_case_workloc2_state == "CA"].dropna(subset=["lca_case_workloc2_city"])
sf_cities_2 = sf_cities_2["lca_case_workloc2_city"].unique()
sf_cities = list(set(sf_cities).union(set(sf_cities_2)))
# Out:
# /home/kilian/.envs/elucd/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# /home/kilian/.envs/elucd/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
len(sf_cities)
# Out:
# 1022

# %%
sf_cities
# Out:
# ['VERNON',
#  'SOLVANG',
#  'RESTON',
#  'GARDEN GROVE',
#  'KINGSBURG',
#  'COLUMBUS',
#  'RANCHO CARDOVA',
#  'SAN RAMON',
#  'LINCOLNSHIRE',
#  'NORCO',
#  'TORRENCE',
#  'UNIVERSITY CITY',
#  'ANN ARBOR',
#  'CURERTINO',
#  'MECCA',
#  'REDLANDS',
#  'SANA RAMON',
#  'EL FORADO HILLS',
#  'CA',
#  'NEEDLES',
#  'EL æSEGUNDO',
#  'DALY CITY',
#  'FORT IRWIN',
#  'SUNNYALE',
#  'TEMPE',
#  'HEBER',
#  'CORTE MADERA',
#  'FAIRFIELD',
#  'IMPERIAL',
#  'BRAWLEY',
#  'SOUTH EL MONTE',
#  'MARLBOROUGH',
#  'SOUTH PASADENA',
#  'WEST HILLS',
#  'TERRANCE',
#  'YERMO',
#  'CULVER CITY',
#  'FREEPORT',
#  'HEALDSBURG',
#  'SAUSALITO',
#  'PACIFIC PALISADES',
#  'PLAINSBORO',
#  'YUCCA VALLEY',
#  'PALOS VERDES PENINSULA',
#  'VANCOUVER',
#  'EMERYVILLE',
#  'STUDIO CITY',
#  'SUNNYVALE,',
#  'SAN PETRO',
#  'MARINA DEL RAY',
#  'FOSTER PARK DR.,',
#  'SAN JACINTO',
#  'SCHAUMBURG',
#  'PLEASANT',
#  'NORTH HOLLYWOOD',
#  'WOODLAND',
#  'SANTA CLARA,',
#  'WATSONVILLE,',
#  'LATHROP',
#  'TRUCKEE',
#  'SOLANA BEACH',
#  'HARBOR CITY',
#  'FOOTHILL RANCH, CA 92610',
#  'WESTLAKE VILLIAGE',
#  'DURHAM',
#  'GILROY',
#  'SUUNYVALE',
#  'SOUTH SAN FRANCISO',
#  'LAKESIDE',
#  'TORRANCE,',
#  'ROUND ROCK',
#  'MOJAVE',
#  'TRACY',
#  'BARSTOW',
#  'PERRIS',
#  'CUPERTINO',
#  'VENTURA',
#  'HERCULES',
#  'PALO ALTO,',
#  'SAN FANCISCO',
#  'INGLEWOOD',
#  'FOOTHILL RANCH',
#  'FRANCISCO',
#  'MONTROSE',
#  'COMMERCE',
#  'MONTVALE',
#  'OAK LAND',
#  'BERKELEY',
#  'PORTER RANCH',
#  'ONTARIO',
#  'VALLEJO',
#  'SAN RAFAEL',
#  'TUSTIN,',
#  'PARAMOUNT',
#  'LADERA RANCH',
#  'MELO PARK',
#  'CITY OF INDUTRY',
#  'NOVATO,',
#  'SHASTA LAKE CITY',
#  'HAWTHORNE',
#  'MIDDLETOWN',
#  'SAN DIEGOS',
#  'WILDWOOD',
#  'CITY OF INDUSTRY,',
#  'RANCHO CUCAMONGA',
#  'WILSONVILLE',
#  'SAINT HELENA',
#  'SAN GABRIEL',
#  'ATLANDENA',
#  'MILLBREA',
#  'SAN MARINO',
#  'WARSAW',
#  'VISTA',
#  'STANTON',
#  'SAN FRACISCO',
#  'MILWAUKEE',
#  'KIRKLAND',
#  'MILPITAS',
#  'ORCUTT',
#  'LANCASTER',
#  'EI SEGUNDA',
#  'CYPRESS',
#  'CANOGA PARK',
#  'PORTOLA VALLEY',
#  'MATHER',
#  'MAYWOOD',
#  'WOODLAND HILS',
#  'NORATO',
#  'HUNTINGTON PARK',
#  'RAMCHO CORDOVA',
#  'METRO SUNNYVALE',
#  'CUPERTNO',
#  'SACREMENTO',
#  'TROY',
#  'CALABASAS HILLS',
#  'MOUTAIN VIEW',
#  'BROOMFIELD',
#  'PARLIER',
#  'MIPLITAS',
#  'OREGON HOUSE',
#  'ALHAMBRA',
#  'BUENAS PARK',
#  'WELCOME',
#  'ORANGEVALE',
#  'GLENDALE',
#  'R',
#  'BISHOP',
#  'AGOURS HILLS',
#  'EAST ALHAMBRA',
#  'RANCHO CARDOVO',
#  'SAN LUIS OBISPO',
#  'FRENCH CAMP',
#  'LAKE ALFRED',
#  'HEMET',
#  'RANCHO SANTA MARGARITA',
#  'MANTELA',
#  'SAN DIEGO,',
#  'SANTA FE SPRINGS',
#  'REDLANDS CA 9',
#  'ALAMEDA,',
#  'RANCHO CORDOVA',
#  'LEBEC',
#  'GOLETA',
#  'RANCHO CUCAMONGA,',
#  'HYAMPOM',
#  'PACHECO',
#  'ZAMORA',
#  'SEATTLE',
#  'SUMMYVALE',
#  'VICTORVILLE',
#  'CAPINTERIA',
#  'SANTA JOSE',
#  'EL CENTRO',
#  'FAIR OAKS',
#  'SAN MARTIN',
#  'WESTMINISTER',
#  'LAGUNA BEACH',
#  'REDWOOD CITY',
#  'MEDESTO',
#  'MOUNTAIN VIEW CITY',
#  'ORO GRANDE',
#  'SUNYVALE',
#  'WILMINGTON',
#  'PITTSBURG',
#  'OCEANSIDE',
#  'TUCSON,',
#  'CASTRO VALLEY',
#  'LA CRESCENTA',
#  'CARMEL',
#  'SANTA BARBARA',
#  'E. RANCHO DOMINGUEZ',
#  'GARDEN GROVE CITY',
#  'CAMARILLO,',
#  'ROWLAND HEIGHTS',
#  'FRAMINGHAM',
#  'SAN FRANCISCO',
#  'TUSTUN',
#  'CANYON COUNTRY',
#  'LIVERMORE',
#  'CROCKETT',
#  'CITY OF INDUSTRY',
#  'LA PALMA',
#  'DANVILLE',
#  'ATHERTON',
#  'EASTVALE',
#  'CHEVIOT HILLS',
#  'FELLOWS',
#  'CORTE MADERA,',
#  'LARKSPUR,',
#  'LAFAYETTE',
#  'PACOIMA',
#  'BONSALL',
#  'ELSEGUNDO',
#  '94558',
#  'COALINGA',
#  'BEVERY HILLS',
#  'ARLETA',
#  'MILPITASæ',
#  'REDLANDS CA 92373',
#  'ROSEVILLE,',
#  'CAMRILLO',
#  'HILMAR',
#  'AZUSA',
#  'BAKER',
#  'S SAN FRANCISCO',
#  'CAMPBELL',
#  'EL SEGUNDO',
#  'THOUSAN OAKS',
#  'PLEASONTON',
#  'ELDORADO HILLS',
#  'SANTA CRUZ',
#  'THOUSAND OAKS,',
#  'SAN LORENZO',
#  'CONTRA COSTA',
#  'LOMA LINDIA',
#  'CARTAGO',
#  '94103',
#  'LOMPOC',
#  'N. HOLLYWOOD',
#  'ST. HELENA',
#  'PIRU',
#  'POWAY',
#  'WOODLAND HILLS,',
#  'STANFORD',
#  'SAN MANTEO',
#  'EL CAJON',
#  'NEWPORT COAST',
#  'DUARTE',
#  'SANTAANA',
#  'BOSTON',
#  'SAN RAMON,',
#  'DAYTON',
#  'BAKERSFILED',
#  'FERNDALE',
#  'LOST HILLS',
#  'SIM VALLEY',
#  'RANCHO CODOVA',
#  'LENEXA',
#  'HESPERIA',
#  'HOLLISTER',
#  'PLAM SPRINGS',
#  'NORTHRIDGE',
#  'THOUSANDS OAKS',
#  'GREATER LOS ANGELES',
#  'MISSION VIEJO,',
#  'BROOKLYN PARK',
#  'MOUNTAIN VIEW,',
#  'COSTA MESA',
#  'BRENTWOOD',
#  'TEMPLE CITY',
#  'FOSTER CITY',
#  'UNION SQUARE',
#  'TOLUCA LAKE',
#  'COMPTON',
#  'DOWNEY',
#  'ALTADENA',
#  'SIERRA MADRE',
#  'CHARLOTTE',
#  'GILA BEND',
#  'FRESNO',
#  'HUGHSON',
#  'TURLOK',
#  'NORWALK,',
#  'SAN ANSELMO',
#  'SUNNYVALE',
#  'MENTO PARK',
#  'PASO ROBLES',
#  'SAN CARLOS',
#  'PASADENA',
#  'REEDWOOD CITY',
#  'MONTEREY PARK',
#  'URBANDALE',
#  'PALM DESERT',
#  'WINNETKA',
#  'GALT',
#  'ROCKLIN',
#  '#40140, CA MSA',
#  'LAGUNA NIGUEL',
#  'EAGLE ROCK',
#  'KENTFIELD',
#  'SAN BERNADINO',
#  'LA QUINTA',
#  'ORANGEVILLE',
#  'SANTA MONICA',
#  'MOORPARK',
#  'CARPINTERIA',
#  'LOMITA',
#  'DEL REY',
#  'WEST SACRAMENTO',
#  'NEWHALL',
#  'LOS ALAMITOS',
#  'ST HELENA',
#  'CALEXICO',
#  'TUJUNGA',
#  'LOWER LAKE',
#  'NEVADA CITY',
#  'SANTA CLARA, CA',
#  'CARLSBAD',
#  'FREMONT, CA 94538',
#  'YUBA CITY',
#  'ALISO VIEJO',
#  'MONROVIA',
#  'ANTIOCH',
#  'SAM RAMON',
#  'MURRIETA',
#  'KEENE',
#  'SANTA MONICA,',
#  'RANCHO SANTA FE',
#  'SUITE 280',
#  'SANTA',
#  'FOLSOM',
#  'SHAFTER',
#  'TRAVER',
#  'MOFFETT FIELD',
#  'RANCHO CORDAVA',
#  'HERNDON',
#  'LA MESA',
#  'FOSTER',
#  'MONTAIN VIEW',
#  'REEDLEY',
#  'TIBURON',
#  'RANCHO MIRAGE',
#  'ELK GROVE',
#  'ROSS',
#  'WHITTIER',
#  'NORTH HILLS',
#  'SAN DIMAS, CA',
#  'CHUALAR',
#  'MOUNTIAN VIEW',
#  'MOUNTAIN AVE',
#  'POINT RICHMOND',
#  'LAWNDALE',
#  'WOODLAND HILL',
#  'PACIFIC GROVE',
#  'PHOENIX',
#  'MOUNTAIN VIEW, CA 94043',
#  'GLENDALE,',
#  'ARCATA',
#  'EL SEQUNDO',
#  'ALPHARETTA',
#  'APPLE VALLEY',
#  'REDDING',
#  'CRESCENT CITY',
#  'YUCAIPA',
#  'BORON',
#  'DALE CITY',
#  'SANJOSE',
#  'HERSHEY',
#  'LOS ANGGELES',
#  'CHAMPAIGN',
#  'SYLMAR',
#  'LA CANADA',
#  '# 31100 ANAHEIM MSA',
#  'CUPTERTINO',
#  'BLYTHE',
#  'LEMON GROVE',
#  'HINKLEY',
#  'COSTA MESSA',
#  'EL SENGUNDO',
#  'PLUMAS LAKE',
#  'WEST TOLUCA LAKE',
#  'REDWOOD CITY, CA-94065',
#  'HIGHLAND',
#  'STANTA CLARA',
#  'SUITE 1400',
#  '400 Q STREET',
#  'SAN FRANCOSCI',
#  'SAN RAFAEL,',
#  'SOUTH LAKE FOREST',
#  'PRINCETON',
#  'LAGUNA HILLS',
#  'PLEASANTON,',
#  'MORGAN HILL',
#  'FOSTER CITY,',
#  'AZUSAS',
#  'BAKERFIELD',
#  'SANT ANA',
#  'BAY POINT',
#  '2145 HAMILTON AVE.',
#  'CHANDLER',
#  'PALMDALE',
#  'PALO ALTO',
#  'SAN FRANSCISCO',
#  'GOLD RIVER',
#  'AHAHEIM',
#  '#41740 SAN DIEGO CA MSA',
#  'TEMPLE TERRACE',
#  'EL MONTE',
#  'SACRAMENTO',
#  '# 31100 ANAHEIM CA MSA',
#  'SUITE 130',
#  'CARMEL VALLEY',
#  'BRISBANE',
#  'SOQUEL',
#  'UKIAH',
#  'CITRUS HEIGHTS',
#  'NEW PORT BEACH',
#  'HALF MOON BAY',
#  'DENVER',
#  'SUNNY VALE',
#  'CUPERTINO, CA',
#  'COLTON',
#  'JACKSONVILLE',
#  'ALLENTOWN',
#  'SAN CAROLS',
#  'RANCHO MISSION VIEJO',
#  'RANCHO DOMINGUEZ',
#  'HERMOSH BEACH',
#  'COSTAMESA',
#  'SANAT CLARA',
#  'HERMOSA BEACH',
#  'RANCHO DOMINQUEZ',
#  'FOUNTAIN VALLEY',
#  'CONCORD',
#  'FULLERTON',
#  'ETIWANDA',
#  'DINUBA',
#  'SACRAMENTO,',
#  'INDIO',
#  'WESTLAKE VILLAGE',
#  'LAKE FOREST',
#  'BASKERFIELD',
#  'BREA,',
#  'RED BLUFF',
#  'SA DIEGO',
#  'MONTERY PARK',
#  'SAN DIMAS,',
#  'AUBERRY',
#  'GARDENA',
#  'REDWOOD SHORES',
#  'SANTA CLARITA',
#  'SAN CLEMENTE',
#  'CENTURY CITY,',
#  'LAS VEGAS',
#  'DIAMOND BAR',
#  'LOS NGELES',
#  'WALNUT CREEK,',
#  'RACHO CORDOVA',
#  'REDWOOD VALLEY',
#  'CHICAGO',
#  'DIXON',
#  'MOUNTAINVIEW',
#  'SAN JOAQUIN',
#  'SAN ANDREAS',
#  'LOS ANGELES,',
#  'TULARE',
#  'MORENO VALLEY',
#  'MARINA',
#  'BURLINGAME',
#  'BIRSBANE',
#  'SACRCAMENTO',
#  'PEASANTON',
#  'SAN LEANDRO',
#  'CHULA VISTA',
#  'KENNESAW',
#  'CARLSBAD,',
#  'MONTEREY',
#  'BAKERSFRIELD',
#  'WILLIAMS',
#  'SOUTH SANFRANSCISCO',
#  'HOUSTON',
#  'SHREWSBURY',
#  'RESEDA',
#  'BASKERSFIELD',
#  'HAYWARD,',
#  'SANTA ANA',
#  'CERES',
#  'MENLO PARK',
#  'LONG BEACH',
#  'WALNUT CREEK',
#  'NAPERVILLE',
#  'WOODLANDHILLS',
#  'HOLLYWOOD',
#  'NATIONAL CITY',
#  'ROHNERT PARK',
#  'MARTINEZ',
#  'WASCO',
#  'WEST HILL',
#  'CALISTOGA',
#  'FILMORE',
#  'CLOVIS',
#  'SANTA ANA,',
#  'SOUTH GATE',
#  'TURLOCK',
#  'SANTA CLARA',
#  'IRVINA',
#  'MIAMI',
#  'PORT HUENEME',
#  'COACHELLA',
#  'WALNUT AVENUE',
#  'TAFT',
#  'NIPTON',
#  'MILIPITAS',
#  'BURLINGAME,',
#  'RANCHI MIRAGE',
#  'MANHATTAN BEACH',
#  'ALBANY',
#  'YOUNTVILLE',
#  'THOUSAND OAKS',
#  'CAPITOLA',
#  'NAPA',
#  'TORRANCE',
#  'POMONA',
#  'GANADO',
#  'SUSANVILLE',
#  'SUITE 500',
#  'OJAI',
#  'MOSS LANDING',
#  'CAMARILLO',
#  'SAN FRANSICO',
#  'EL PASO',
#  'SANTA MARIA',
#  'ALAMEDA',
#  'CORONA',
#  'GRANITE BAY',
#  'SANTA CALRA',
#  'CENTURY CITY',
#  'CITY OF COMMERCE',
#  'ALAMO',
#  'SOLEDAD',
#  'IRWINDALE',
#  'TRONA',
#  'LUSK BLVD',
#  'RUNNING SPRINGS',
#  'SAN FRANISCO',
#  'QUINCY',
#  'VAN NUYS',
#  'WILLOWS',
#  'MENLO PARK,',
#  'UNIVERSAL CITY',
#  'SAN FRANCICSO',
#  'LINCOLN',
#  'CHICO',
#  'FONTANA',
#  'SOUTH LAKE TAHOE',
#  'NEW YORK',
#  'WIXOM',
#  'SCOTTSDATE',
#  'HAYWARD',
#  'THERMAL',
#  'TEMPLETON',
#  'HILLSBORO',
#  'SAN GERONIMO',
#  'LOS AGNELES',
#  'SAN BRUNO, CA',
#  'MENLOPARK',
#  'SAN DIEGO',
#  'SANTACLARA',
#  'ATWATER',
#  '19175 3RD STREET',
#  'NORTHWOOD',
#  'BOLINAS',
#  '333 SOUTH BEAUDRY AVE.',
#  'SUITE #310',
#  'FOSTER PARK DR.',
#  'WILDOMAR',
#  'FREMON',
#  'SONORA',
#  'NEWARK',
#  'SIGNAL HILL',
#  'SAN FRANSISCO',
#  'UNION CITY',
#  'DR SUNNYVALE',
#  'WOODSIDE',
#  'LAKEWOOD',
#  'EAST RANCHO DOMINGUEZ',
#  'PLAYA DEL REY',
#  'MCFARLAND',
#  'SUN VALLEY',
#  'NOVATO',
#  'SAND CITY',
#  'ALVISO',
#  'SAN DIMAS',
#  'RICHMOND',
#  'ROSEMEAN',
#  'CARSON',
#  'REDONDO BEACH',
#  'NEWMAN',
#  'CERRITOS',
#  'PLEASANT HILL',
#  'LOMA LINDA',
#  'WALNUT PARK',
#  'PASADENA,',
#  'BLOOMINGTON',
#  'SHERMAN OAKSS',
#  'CHOWCHILLA',
#  'SAINT CLOUD',
#  'MOUNTAIN VIEW',
#  'SAN MARCOS',
#  'LOS ANGELES',
#  'HACIENDA HEIGHTS',
#  'PETALUMA',
#  'BEAVONTON',
#  'MCCLELLAN',
#  'SPRING VALLEY',
#  'CORONA DEL MAR',
#  'DULLES',
#  'CORCORAN',
#  'SANDIEGO',
#  'LUCERNE VALLEY',
#  'EL GRANADA',
#  'DUBLIN',
#  'ROLLING HILLS ESTATE',
#  'EL SEGUNDO,',
#  'CHINA LAKE',
#  'WOODLANDS HILLS',
#  'RANCHO PALOS VERDES',
#  'MILL VALLEY',
#  ', SUNNYVALE',
#  'MARINA DEL REY',
#  'VACVILLE',
#  'LAKE BALBOA',
#  'SN RAMON',
#  'FRERMONT',
#  '#41740 SAN DIEGO, CA MSA',
#  'ANAHEIM',
#  'GRANADA HILLS',
#  'DALLAS',
#  'FREEMONT',
#  'SAN JUAN BAUTISTA',
#  'KING CITY',
#  'COLMA',
#  'SUITE 141',
#  'AUBURN',
#  'GLENVIEW',
#  'DANA POINT',
#  'SANDY',
#  'PITTSBURGH',
#  'MOUNTAINT VIEW',
#  'CALEXIO',
#  'FORT BRAGG',
#  'PLEASANTAN',
#  'ROSEMEAD',
#  'REDWOOD SHORES,',
#  '# 41740 SA DIEGO CA MSA',
#  'BLUE JAY',
#  'RIPON',
#  'NEWBURY PARK',
#  'SOUTH SAN FRANSCISCO',
#  'WEST LAKES VILLAGE',
#  'NEWBURY PARK-NQ',
#  'LYNWOOD',
#  'MORAGA',
#  'SANFRANCISCO',
#  'RICHGROVE',
#  'ENCINITAS',
#  'MONTEBELLO',
#  'SNA JOSE',
#  'LOS ANGELES, CA',
#  'EAST PALO ALTO',
#  'ESCALON',
#  'MARTHER,',
#  'LOST GATOS',
#  'BELLFLOWER',
#  'MILLBRAE',
#  'BELMONT',
#  'FREMONT',
#  'SELMA',
#  'MARYSVILLE',
#  'SUNNYVALLE',
#  'ACAMPO',
#  'WOODVILLE',
#  'SOUTH WOODLAND HILLS',
#  'TUSTIN',
#  'CATHEDRAL CITY',
#  'SUNNVALE',
#  'VENICE',
#  'JOSHUA TREE',
#  '1ST FLOOR',
#  'SAN MATEO',
#  'SAN DEIGO',
#  'TUPMAN',
#  'RUTHERFORD',
#  'HILLSBOROUGH',
#  'BENECIA',
#  'SANFRANSISCO',
#  'LOSANGELES',
#  'SUITE 301',
#  'SANTA FE CITY',
#  'WEST HOLLWOOD',
#  'MILPITAS,',
#  'SAN RAMOM',
#  'CARSON CITY',
#  'PASADENAC',
#  'WINDSOR',
#  'LARKSPUR',
#  'LOS ANGELES (CENTURY CITY)',
#  'SAN FRANCICSCO',
#  'MADERA',
#  'WEST LAKE VILLAGE',
#  'TRAVIS AFB',
#  'SAN JOSE,',
#  'VALLEY VILLAGE',
#  'LA HABRA',
#  'ROSEVILLE',
#  'WESTMINSTER',
#  'SAN PABLO',
#  'FAIRFAX',
#  'CLEARLAKE',
#  'LYNNWOOD',
#  'LOS ALTOS',
#  'BAKERSFIELD',
#  'MOUNTAIN VIE',
#  'FIREBAUGH',
#  'RICHARDSON',
#  'IRVING',
#  'NEWPORT BEACH',
#  'PALO AUTO',
#  'NORWALK',
#  'DESERT HOT SPRINGS',
#  'UPLAND',
#  'LOSA ANGELES',
#  'MARIN',
#  'SAN RAFEAL',
#  'ARROYO GRANDE',
#  'VACAVILLE',
#  'MERCED',
#  'SAN FRANCSICO',
#  'IRVINE',
#  'EDISON',
#  'PLEASANTON',
#  'SAN FRCANCISCO',
#  'PLEASATON',
#  'SANTA ABA',
#  'SANTA ANNA',
#  'AMERICAN CANYON',
#  'MOUNTAIN',
#  'SUNNYVALE CA',
#  'ESCONDIDO',
#  'SEASIDE',
#  'GLENDORA',
#  'BOULDER',
#  'RIVERBANK',
#  'MODESTO',
#  'BUENA PARK',
#  'GLASSELL PARK',
#  'TORANCE',
#  'NOVI',
#  'LA',
#  'SAN FRANCISCO,',
#  'TEMECULA',
#  'MONTCLAIR',
#  'LA VERNE',
#  'SAN FRANCISCO, CA',
#  'SAN ANTONIO',
#  'EL SECUNDO',
#  'MISSION HILLS',
#  'SAN LEANDRO,',
#  'SAN BRUNO',
#  'PICO RIVERA',
#  'SEGUNDO',
#  'WESTAKE VILLAGE',
#  'ANANHEIM',
#  'IRIVINE',
#  'BALDWIN PARK',
#  'SOUTH SAN FRANCISCO ,',
#  'PALTO ALTO',
#  'GREENBRAE',
#  'CULVER',
#  'SIMI VALLEY',
#  'MCKITTRICK',
#  'ALISA VIEJO',
#  'RACNCHO CORDOVA',
#  'LAKEFOREST',
#  'MOUNTAIN HOUSE',
#  'TARZANA',
#  'FREMONT CA',
#  'SALINAS',
#  'VILLA PARK',
#  'CHINO',
#  'PALA',
#  'LA PUETE',
#  'EL MONTE / LOS ANGELES',
#  'PORTERVILLE',
#  'RIVERSIDE',
#  'EMBARCADERO',
#  'IRVINE,',
#  'RALEIGH',
#  'ST. TORRANCE',
#  'NEWPORT',
#  'PARADISE',
#  'ORANGE',
#  'DUNSMUIR',
#  'PALO, ALTO',
#  'RIDGECREST',
#  'ELCENTRO',
#  'SA FRANCISCO',
#  'STEVENSON RANCH',
#  'FOSTERCITY',
#  'OAKDALE',
#  'HAWTHORNE,',
#  'ENGLEWOOD',
#  'BUBANK',
#  'BEVERLY HILLS',
#  'AUSTIN',
#  'SOUTH FRANCISCO',
#  'SANTA ROSA',
#  'PINOLE',
#  'CHARLOTTESVILLE',
#  'LAKE MATHEWS',
#  'EL CERRITO',
#  'SHERMAN OAKS',
#  'LA MIRADA',
#  'MARICOPA',
#  'PATTERSON',
#  'OLD TAPPAN',
#  'WEST HOLLYWOOD',
#  'VISALIA',
#  'GARDENIA',
#  'CORONADO',
#  'SARATOGA',
#  'TOPANGA',
#  'SANTA MONICA BLVD',
#  'KLAMATH',
#  'WALNUT',
#  'LAKE ELSINORE',
#  'PLEASENTON',
#  'BANNING',
#  'WEST SACREMENTO',
#  'ARTESIA',
#  'SUWANNEE',
#  'BERKLEY',
#  'PLACENTIA',
#  'CALABASAS',
#  'BURBANK',
#  'LA JOLLA',
#  'BREA',
#  '10 UNIVERSAL CITY PLZ',
#  'ARCADIA',
#  'VALENCIA',
#  'LOS ANGLES',
#  'SUNLAND',
#  'LOS ALTOS HILLS',
#  'CULVIR CITY',
#  'LOS ANGELS',
#  'MIRA LOMA',
#  'BLOOMINGDALE',
#  'SAN JOSE',
#  'SANRAMON',
#  'WALUNT',
#  'PLAYA VISTA,',
#  'CARMICHAEL',
#  'SAN FRANSCICO',
#  'SAN ROMAN',
#  'MALAPITAS',
#  'CONTRA COSTA COUNTY',
#  'APTOS',
#  'PEBBLE BEACH',
#  'EMERYILLE',
#  'BENICIA',
#  'SAN FERNANDO',
#  '22ND FLOOR',
#  'PAL ALTO',
#  'PATTON',
#  'CASTRO VALLEY BLVD',
#  'CARLBAD',
#  'SONOMA',
#  'ORINDA',
#  'ANGWIN',
#  'SANTEE',
#  'SANTA MONICA, CA',
#  'SANTA YNEZ',
#  'ALISO VEIJO',
#  'SAN JUAN CAPISTRANO',
#  'FREMOUNT',
#  'EUREKA',
#  'REDWOORD CITY',
#  'HANFORD',
#  'MISSION VIEJO',
#  'FALLBROOK',
#  'SUNNYWALE',
#  'SANT CLARA',
#  'CUDAHY',
#  'LONGMONT',
#  'FILLMORE',
#  'LOS ANGELOS',
#  'SUITE 490',
#  '925 HARBOR PLAZA',
#  'GRASS VALLEY',
#  'AVALON',
#  'MANTECA',
#  'REDWOOD',
#  'PLAYA VISTA',
#  'WILLITS',
#  'SAN PEDRO',
#  '17355 DAIMLER ST.,',
#  'SCOTTS VALLEY',
#  'SUNNYVLAE',
#  'GREENFIELD',
#  'SANTA CARLA',
#  'NEWTOWN',
#  'WEST COVINA',
#  'BACKERSFIELD',
#  'LAMONT',
#  'PALM SPRINGS',
#  'SANTA PAULA',
#  'ANAHEIM HILLS',
#  'MENIFEE',
#  'ENCINO',
#  'CSA 103',
#  'MOUNATIN VIEW',
#  'YORBA LINDA',
#  'DEL MAR',
#  'SUNNYVILLE',
#  'EL SEGUNOD',
#  'REDWOODCITY',
#  'CLAREMONT',
#  'PALOS VERDES',
#  'NEW BURY PARK',
#  'BAY POIINT',
#  'LA PUENTE',
#  'INDUSTRY',
#  'WATSONVILLE',
#  'SUNNUVALE',
#  'FOUNTAIN VALLEY,',
#  'PACIFIC',
#  'SAN FRANCSCO',
#  'NEWARK,',
#  'DELANO',
#  'SAN BERNARDINO',
#  'SAN FRANCISCOC',
#  'MEMPHIS',
#  'HONOLULU',
#  'RIALTO',
#  'SANTA CLARLA',
#  'EI DORADO HILLS',
#  'ISELIN',
#  'WOODLAND HILLS',
#  'EI SEGUNDO',
#  'LOS GATOS',
#  'PANORAMA CITY',
#  'GOLDEN VALLEY',
#  'EL DORADO HILLS',
#  'ALISO VIJEO',
#  'ENCINO,',
#  'LOS BANOS',
#  'SEBASTOPOL',
#  'CHATSWORTH',
#  'JACKSON',
#  'PACIFICA',
#  'SANS JOSE',
#  'GONZALES',
#  'SUNNYVALE, CA',
#  'SAN MIGUEL',
#  'FOLSOM,',
#  'OAKVILLE',
#  'HAYWOOD',
#  'MILPTAS',
#  'SUITE 200',
#  'MEDFORD',
#  'LAKE BUENA VISTA',
#  'OAKHURST',
#  'RANCHO CORDOVA,',
#  'OAKLAND',
#  'OXNARD',
#  'TEHACHAPI',
#  'DAVIS',
#  'CULVER CITY,',
#  'SAN FRANCICO',
#  'REDMOND',
#  'BELL',
#  'OROVILLE',
#  'STE.300',
#  'SANT HELENA',
#  'LA HABRA HEIGHTS',
#  'AGOURA HILLS',
#  'SAN FRANCISO',
#  'PASADENA AVENUE',
#  'NEWBURY PARK - NQ',
#  'ST BURBANK',
#  'PLESANTON',
#  'BRIDGEWATER',
#  'MALIBU',
#  'PAS ROBLES',
#  'CHINO HILLS',
#  'BELL GARDENS',
#  'BEAUMONT',
#  'AURORA',
#  'CALIFORNIA',
#  '94105',
#  ...]

# %%
# first let's do counties, like we did boroughs
county_matches = [process.extractOne(city, bay_co) for city in sf_cities]

# %%
[[sf_cities[i], county_matches[i]] for i in range(len(sf_cities)) if county_matches[i][1] >= 88]
# Out:
# [['MARINA DEL RAY', ('Marin', 90)],
#  ['SANTA CLARA,', ('Santa Clara', 100)],
#  ['SAN FANCISCO', ('San Francisco', 96)],
#  ['FRANCISCO', ('San Francisco', 95)],
#  ['SAN MARINO', ('Marin', 90)],
#  ['SAN FRACISCO', ('San Francisco', 96)],
#  ['R', ('Marin', 90)],
#  ['ALAMEDA,', ('Alameda', 100)],
#  ['SAN FRANCISCO', ('San Francisco', 100)],
#  ['S SAN FRANCISCO', ('San Francisco', 95)],
#  ['CONTRA COSTA', ('Contra Costa', 100)],
#  ['SAN MANTEO', ('San Mateo', 95)],
#  ['SANTA CLARA, CA', ('Santa Clara', 95)],
#  ['SANTA', ('Santa Clara', 90)],
#  ['STANTA CLARA', ('Santa Clara', 96)],
#  ['SAN FRANSCISCO', ('San Francisco', 96)],
#  ['SANAT CLARA', ('Santa Clara', 91)],
#  ['SANTA CLARITA', ('Santa Clara', 92)],
#  ['MARINA', ('Marin', 91)],
#  ['SANTA CLARA', ('Santa Clara', 100)],
#  ['NAPA', ('Napa', 100)],
#  ['SAN FRANSICO', ('San Francisco', 88)],
#  ['ALAMEDA', ('Alameda', 100)],
#  ['SANTA CALRA', ('Santa Clara', 91)],
#  ['SAN FRANISCO', ('San Francisco', 96)],
#  ['SAN FRANCICSO', ('San Francisco', 92)],
#  ['SANTACLARA', ('Santa Clara', 95)],
#  ['SAN FRANSISCO', ('San Francisco', 92)],
#  ['MARINA DEL REY', ('Marin', 90)],
#  ['SANFRANCISCO', ('San Francisco', 96)],
#  ['SAN MATEO', ('San Mateo', 100)],
#  ['SANFRANSISCO', ('San Francisco', 88)],
#  ['SAN FRANCICSCO', ('San Francisco', 96)],
#  ['MARIN', ('Marin', 100)],
#  ['SAN FRANCSICO', ('San Francisco', 92)],
#  ['SAN FRCANCISCO', ('San Francisco', 96)],
#  ['LA', ('Alameda', 90)],
#  ['SAN FRANCISCO,', ('San Francisco', 100)],
#  ['SAN FRANCISCO, CA', ('San Francisco', 95)],
#  ['SOUTH SAN FRANCISCO ,', ('San Francisco', 95)],
#  ['SA FRANCISCO', ('San Francisco', 96)],
#  ['SAN FRANSCICO', ('San Francisco', 92)],
#  ['CONTRA COSTA COUNTY', ('Contra Costa', 90)],
#  ['SONOMA', ('Sonoma', 100)],
#  ['SANT CLARA', ('Santa Clara', 95)],
#  ['SANTA CARLA', ('Santa Clara', 91)],
#  ['SAN FRANCSCO', ('San Francisco', 96)],
#  ['SAN FRANCISCOC', ('San Francisco', 96)],
#  ['SANTA CLARLA', ('Santa Clara', 96)],
#  ['SAN FRANCICO', ('San Francisco', 96)],
#  ['SAN FRANCISO', ('San Francisco', 96)],
#  ['S. SAN FRANCISCO', ('San Francisco', 95)],
#  ['SOUTH SAN FRANCISCO', ('San Francisco', 95)],
#  ['SAN FRANACISCO', ('San Francisco', 96)]]

# %%
good_counties = [sf_cities[i] for i in range(len(sf_cities)) if county_matches[i][1] > 85]
good_counties.remove('MARINA')
good_counties.remove('LA')
good_counties.remove('MARINA DEL REY')
good_counties.remove('SANTA CLARITA')
good_counties.remove('R')
good_counties.remove('RANCHO SANTA MARGARITA')
good_counties.remove('SAN BERNARDINO')
good_counties.remove('MARINA DEL RAY')
good_counties.remove('S. SAN FRANCISCO')
good_counties.remove('SANTA')
good_counties.remove('S SAN FRANCISCO')

# %%
# make a place column for bay area placenames
sfdf["bay_city"] = ["" for i in range(sfdf.shape[0])]
# and dummy city columns to keep track of the ones we're done with
sfdf["dummy_city_1"] = sfdf.loc[:, "lca_case_workloc1_city"]
sfdf["dummy_city_2"] = sfdf.loc[:, "lca_case_workloc2_city"]
for co in good_counties:
    cityind = sf_cities.index(co)
    sfdf.loc[sfdf.lca_case_workloc1_city == co, ["bay_city"]] = county_matches[cityind][0]
    sfdf.loc[sfdf.lca_case_workloc1_city == co, ["dummy_city_1"]] = np.nan
    sfdf.loc[sfdf.lca_case_workloc2_city == co, ["bay_city"]] = county_matches[cityind][0]
    sfdf.loc[sfdf.lca_case_workloc2_city == co, ["dummy_city_2"]] = np.nan

# %%
city_matches = [process.extractOne(city, bay_po) for city in sf_cities]

# %%
[[sf_cities[i], city_matches[i]] for i in range(len(sf_cities)) if city_matches[i][1] >= 88]
# Out:
# [['SAN RAMON', ('SAN RAMON', 100)],
#  ['SANA RAMON', ('SAN RAMON', 95)],
#  ['CA', ('SAN CARLOS', 90)],
#  ['DALY CITY', ('DALY CITY', 100)],
#  ['SUNNYALE', ('SUNNYVALE', 94)],
#  ['CORTE MADERA', ('CORTE MADERA', 100)],
#  ['FAIRFIELD', ('FAIRFIELD', 100)],
#  ['SAUSALITO', ('SAUSALITO', 100)],
#  ['EMERYVILLE', ('EMERYVILLE', 100)],
#  ['SUNNYVALE,', ('SUNNYVALE', 100)],
#  ['PLEASANT', ('PLEASANT HILL', 90)],
#  ['SUUNYVALE', ('SUNNYVALE', 89)],
#  ['SOUTH SAN FRANCISO', ('SOUTH SAN FRANCISCO', 97)],
#  ['HERCULES', ('HERCULES', 100)],
#  ['PALO ALTO,', ('PALO ALTO', 100)],
#  ['SAN FANCISCO', ('SAN FRANCISCO', 96)],
#  ['FRANCISCO', ('SAN FRANCISCO', 95)],
#  ['OAK LAND', ('OAKLAND', 93)],
#  ['BERKELEY', ('BERKELEY', 100)],
#  ['VALLEJO', ('VALLEJO', 100)],
#  ['SAN RAFAEL', ('SAN RAFAEL', 100)],
#  ['MELO PARK', ('MENLO PARK', 95)],
#  ['NOVATO,', ('NOVATO', 100)],
#  ['MILLBREA', ('MILLBRAE', 88)],
#  ['VISTA', ('RIO VISTA', 90)],
#  ['SAN FRACISCO', ('SAN FRANCISCO', 96)],
#  ['MILPITAS', ('MILPITAS', 100)],
#  ['PORTOLA VALLEY', ('PORTOLA VALLEY', 100)],
#  ['METRO SUNNYVALE', ('SUNNYVALE', 90)],
#  ['MOUTAIN VIEW', ('MOUNTAIN VIEW', 96)],
#  ['MIPLITAS', ('MILPITAS', 88)],
#  ['R', ('STANFORD', 90)],
#  ['ALAMEDA,', ('ALAMEDA', 100)],
#  ['SANTA JOSE', ('SAN JOSE', 89)],
#  ['REDWOOD CITY', ('REDWOOD CITY', 100)],
#  ['MOUNTAIN VIEW CITY', ('MOUNTAIN VIEW', 95)],
#  ['SUNYVALE', ('SUNNYVALE', 94)],
#  ['PITTSBURG', ('PITTSBURG', 100)],
#  ['CASTRO VALLEY', ('CASTRO VALLEY', 100)],
#  ['SAN FRANCISCO', ('SAN FRANCISCO', 100)],
#  ['LIVERMORE', ('LIVERMORE', 100)],
#  ['CROCKETT', ('CROCKETT', 100)],
#  ['DANVILLE', ('DANVILLE', 100)],
#  ['ATHERTON', ('ATHERTON', 100)],
#  ['CORTE MADERA,', ('CORTE MADERA', 100)],
#  ['LARKSPUR,', ('LARKSPUR', 100)],
#  ['LAFAYETTE', ('LAFAYETTE', 100)],
#  ['MILPITASæ', ('MILPITAS', 100)],
#  ['S SAN FRANCISCO', ('SAN FRANCISCO', 95)],
#  ['PLEASONTON', ('PLEASANTON', 90)],
#  ['SAN LORENZO', ('SAN LORENZO', 100)],
#  ['STANFORD', ('STANFORD', 100)],
#  ['SAN MANTEO', ('SAN MATEO', 95)],
#  ['SAN RAMON,', ('SAN RAMON', 100)],
#  ['MOUNTAIN VIEW,', ('MOUNTAIN VIEW', 100)],
#  ['BRENTWOOD', ('BRENTWOOD', 100)],
#  ['SAN ANSELMO', ('SAN ANSELMO', 100)],
#  ['SUNNYVALE', ('SUNNYVALE', 100)],
#  ['MENTO PARK', ('MENLO PARK', 90)],
#  ['SAN CARLOS', ('SAN CARLOS', 100)],
#  ['REEDWOOD CITY', ('REDWOOD CITY', 96)],
#  ['FREMONT, CA 94538', ('FREMONT', 90)],
#  ['ANTIOCH', ('ANTIOCH', 100)],
#  ['SAM RAMON', ('SAN RAMON', 89)],
#  ['MONTAIN VIEW', ('MOUNTAIN VIEW', 96)],
#  ['TIBURON', ('BELVEDERE TIBURON', 90)],
#  ['MOUNTIAN VIEW', ('MOUNTAIN VIEW', 92)],
#  ['MOUNTAIN AVE', ('MOUNTAIN VIEW', 88)],
#  ['POINT RICHMOND', ('RICHMOND', 90)],
#  ['MOUNTAIN VIEW, CA 94043', ('MOUNTAIN VIEW', 90)],
#  ['DALE CITY', ('DALY CITY', 89)],
#  ['SANJOSE', ('SAN JOSE', 93)],
#  ['REDWOOD CITY, CA-94065', ('REDWOOD CITY', 90)],
#  ['SAN RAFAEL,', ('SAN RAFAEL', 100)],
#  ['PLEASANTON,', ('PLEASANTON', 100)],
#  ['PALO ALTO', ('PALO ALTO', 100)],
#  ['SAN FRANSCISCO', ('SAN FRANCISCO', 96)],
#  ['BRISBANE', ('BRISBANE', 100)],
#  ['HALF MOON BAY', ('HALF MOON BAY', 100)],
#  ['SUNNY VALE', ('SUNNYVALE', 95)],
#  ['SAN CAROLS', ('SAN CARLOS', 90)],
#  ['CONCORD', ('CONCORD', 100)],
#  ['WALNUT CREEK,', ('WALNUT CREEK', 100)],
#  ['DIXON', ('DIXON', 100)],
#  ['MOUNTAINVIEW', ('MOUNTAIN VIEW', 96)],
#  ['BURLINGAME', ('BURLINGAME', 100)],
#  ['BIRSBANE', ('BRISBANE', 88)],
#  ['PEASANTON', ('PLEASANTON', 95)],
#  ['SAN LEANDRO', ('SAN LEANDRO', 100)],
#  ['SOUTH SANFRANSCISCO', ('SOUTH SAN FRANCISCO', 95)],
#  ['HAYWARD,', ('HAYWARD', 100)],
#  ['MENLO PARK', ('MENLO PARK', 100)],
#  ['WALNUT CREEK', ('WALNUT CREEK', 100)],
#  ['MARTINEZ', ('MARTINEZ', 100)],
#  ['MILIPITAS', ('MILPITAS', 94)],
#  ['BURLINGAME,', ('BURLINGAME', 100)],
#  ['ALBANY', ('ALBANY', 100)],
#  ['NAPA', ('NAPA', 100)],
#  ['SAN FRANSICO', ('SAN FRANCISCO', 88)],
#  ['ALAMEDA', ('ALAMEDA', 100)],
#  ['ALAMO', ('ALAMO', 100)],
#  ['SAN FRANISCO', ('SAN FRANCISCO', 96)],
#  ['MENLO PARK,', ('MENLO PARK', 100)],
#  ['SAN FRANCICSO', ('SAN FRANCISCO', 92)],
#  ['HAYWARD', ('HAYWARD', 100)],
#  ['SAN GERONIMO', ('SAN GERONIMO', 100)],
#  ['SAN BRUNO, CA', ('SAN BRUNO', 95)],
#  ['MENLOPARK', ('MENLO PARK', 95)],
#  ['FREMON', ('FREMONT', 92)],
#  ['NEWARK', ('NEWARK', 100)],
#  ['SAN FRANSISCO', ('SAN FRANCISCO', 92)],
#  ['UNION CITY', ('UNION CITY', 100)],
#  ['DR SUNNYVALE', ('SUNNYVALE', 95)],
#  ['NOVATO', ('NOVATO', 100)],
#  ['ALVISO', ('ALVISO', 100)],
#  ['RICHMOND', ('RICHMOND', 100)],
#  ['PLEASANT HILL', ('PLEASANT HILL', 100)],
#  ['MOUNTAIN VIEW', ('MOUNTAIN VIEW', 100)],
#  ['PETALUMA', ('PETALUMA', 100)],
#  ['DUBLIN', ('DUBLIN', 100)],
#  ['MILL VALLEY', ('MILL VALLEY', 100)],
#  [', SUNNYVALE', ('SUNNYVALE', 100)],
#  ['SN RAMON', ('SAN RAMON', 94)],
#  ['FRERMONT', ('FREMONT', 93)],
#  ['FREEMONT', ('FREMONT', 93)],
#  ['PITTSBURGH', ('PITTSBURG', 95)],
#  ['MOUNTAINT VIEW', ('MOUNTAIN VIEW', 96)],
#  ['PLEASANTAN', ('PLEASANTON', 90)],
#  ['SOUTH SAN FRANSCISCO', ('SOUTH SAN FRANCISCO', 97)],
#  ['MORAGA', ('MORAGA', 100)],
#  ['SANFRANCISCO', ('SAN FRANCISCO', 96)],
#  ['SNA JOSE', ('SAN JOSE', 88)],
#  ['EAST PALO ALTO', ('PALO ALTO', 90)],
#  ['MILLBRAE', ('MILLBRAE', 100)],
#  ['BELMONT', ('BELMONT', 100)],
#  ['FREMONT', ('FREMONT', 100)],
#  ['SUNNYVALLE', ('SUNNYVALE', 95)],
#  ['SUNNVALE', ('SUNNYVALE', 94)],
#  ['SAN MATEO', ('SAN MATEO', 100)],
#  ['SANFRANSISCO', ('SAN FRANCISCO', 88)],
#  ['MILPITAS,', ('MILPITAS', 100)],
#  ['SAN RAMOM', ('SAN RAMON', 89)],
#  ['LARKSPUR', ('LARKSPUR', 100)],
#  ['SAN FRANCICSCO', ('SAN FRANCISCO', 96)],
#  ['MADERA', ('CORTE MADERA', 90)],
#  ['TRAVIS AFB', ('TRAVIS AFB', 100)],
#  ['SAN JOSE,', ('SAN JOSE', 100)],
#  ['SAN PABLO', ('SAN PABLO', 100)],
#  ['FAIRFAX', ('FAIRFAX', 100)],
#  ['LOS ALTOS', ('LOS ALTOS', 100)],
#  ['MOUNTAIN VIE', ('MOUNTAIN VIEW', 96)],
#  ['PALO AUTO', ('PALO ALTO', 89)],
#  ['SAN RAFEAL', ('SAN RAFAEL', 90)],
#  ['SAN FRANCSICO', ('SAN FRANCISCO', 92)],
#  ['PLEASANTON', ('PLEASANTON', 100)],
#  ['SAN FRCANCISCO', ('SAN FRANCISCO', 96)],
#  ['PLEASATON', ('PLEASANTON', 95)],
#  ['AMERICAN CANYON', ('AMERICAN CANYON', 100)],
#  ['MOUNTAIN', ('MOUNTAIN VIEW', 90)],
#  ['SUNNYVALE CA', ('SUNNYVALE', 95)],
#  ['LA', ('ALAMEDA', 90)],
#  ['SAN FRANCISCO,', ('SAN FRANCISCO', 100)],
#  ['SAN FRANCISCO, CA', ('SAN FRANCISCO', 95)],
#  ['SAN LEANDRO,', ('SAN LEANDRO', 100)],
#  ['SAN BRUNO', ('SAN BRUNO', 100)],
#  ['SOUTH SAN FRANCISCO ,', ('SOUTH SAN FRANCISCO', 100)],
#  ['PALTO ALTO', ('PALO ALTO', 95)],
#  ['GREENBRAE', ('GREENBRAE', 100)],
#  ['FREMONT CA', ('FREMONT', 95)],
#  ['PALO, ALTO', ('PALO ALTO', 95)],
#  ['SA FRANCISCO', ('SAN FRANCISCO', 96)],
#  ['SOUTH FRANCISCO', ('SOUTH SAN FRANCISCO', 95)],
#  ['PINOLE', ('PINOLE', 100)],
#  ['EL CERRITO', ('EL CERRITO', 100)],
#  ['WALNUT', ('WALNUT CREEK', 90)],
#  ['PLEASENTON', ('PLEASANTON', 90)],
#  ['BERKLEY', ('BERKELEY', 93)],
#  ['LOS ALTOS HILLS', ('LOS ALTOS', 90)],
#  ['SAN JOSE', ('SAN JOSE', 100)],
#  ['SANRAMON', ('SAN RAMON', 94)],
#  ['SAN FRANSCICO', ('SAN FRANCISCO', 92)],
#  ['EMERYILLE', ('EMERYVILLE', 95)],
#  ['BENICIA', ('BENICIA', 100)],
#  ['PAL ALTO', ('PALO ALTO', 94)],
#  ['CASTRO VALLEY BLVD', ('CASTRO VALLEY', 95)],
#  ['SONOMA', ('SONOMA', 100)],
#  ['ORINDA', ('ORINDA', 100)],
#  ['FREMOUNT', ('FREMONT', 93)],
#  ['REDWOORD CITY', ('REDWOOD CITY', 96)],
#  ['SUNNYWALE', ('SUNNYVALE', 89)],
#  ['REDWOOD', ('REDWOOD CITY', 90)],
#  ['SUNNYVLAE', ('SUNNYVALE', 89)],
#  ['MOUNATIN VIEW', ('MOUNTAIN VIEW', 92)],
#  ['REDWOODCITY', ('REDWOOD CITY', 96)],
#  ['SUNNUVALE', ('SUNNYVALE', 89)],
#  ['PACIFIC', ('PACIFICA', 93)],
#  ['SAN FRANCSCO', ('SAN FRANCISCO', 96)],
#  ['NEWARK,', ('NEWARK', 100)],
#  ['SAN FRANCISCOC', ('SAN FRANCISCO', 96)],
#  ['LOS GATOS', ('LOS ALTOS', 89)],
#  ['PACIFICA', ('PACIFICA', 100)],
#  ['SANS JOSE', ('SAN JOSE', 94)],
#  ['SUNNYVALE, CA', ('SUNNYVALE', 95)],
#  ['MILPTAS', ('MILPITAS', 93)],
#  ['OAKLAND', ('OAKLAND', 100)],
#  ['SAN FRANCICO', ('SAN FRANCISCO', 96)],
#  ['SAN FRANCISO', ('SAN FRANCISCO', 96)],
#  ['PLESANTON', ('PLEASANTON', 95)],
#  ['S. SAN FRANCISCO', ('SAN FRANCISCO', 95)],
#  ['PALOALTO', ('PALO ALTO', 94)],
#  ['SOUTH SAN FRANCISCO', ('SOUTH SAN FRANCISCO', 100)],
#  ['SAN FRANACISCO', ('SAN FRANCISCO', 96)],
#  ['MILPITOS', ('MILPITAS', 88)],
#  ['SOUTH SANFRANCISCO', ('SOUTH SAN FRANCISCO', 97)]]

# %%
good_cities = [sf_cities[i] for i in range(len(sf_cities)) if city_matches[i][1] > 88]
good_cities.remove("LOS GATOS")
good_cities.remove("LA")
good_cities.remove("R")
good_cities.remove("CA")
good_cities.remove("S SAN FRANCISCO")  # Only annoying match

# %%
for city in good_cities:
    cityind = sf_cities.index(city)
    sfdf.loc[sfdf.lca_case_workloc1_city == city, ["bay_city"]] = city_matches[cityind][0]
    sfdf.loc[sfdf.lca_case_workloc1_city == city, ["dummy_city_1"]] = np.nan
    sfdf.loc[sfdf.lca_case_workloc2_city == city, ["bay_city"]] = city_matches[cityind][0]
    sfdf.loc[sfdf.lca_case_workloc2_city == city, ["dummy_city_2"]] = np.nan

# %%
sfdf.loc[sfdf.lca_case_workloc1_city == "S SAN FRANCISCO", ["bay_city"]] = 'SOUTH SAN FRANCISCO'
sfdf.loc[sfdf.lca_case_workloc2_city == "S SAN FRANCISCO", ["bay_city"]] = 'SOUTH SAN FRANCISCO'

# %%
# and done
sfdf = sfdf.loc[sfdf.bay_city != "", :]

# %%
sfdf
# Out:
#            lca_case_number lca_case_submit decision_date      visa_class  \
# 27      I-200-09273-187930      2013-10-24    2013-11-01            H-1B
# 34      I-200-09289-217121      2013-10-21    2013-10-26            H-1B
# 75      I-200-10064-055302      2014-09-17    2014-09-23            H-1B
# 79      I-200-10068-750324      2014-09-17    2014-09-23            H-1B
# 85      I-200-10076-219246      2014-09-23    2014-09-29            H-1B
# 215     I-200-10270-759594      2014-03-01    2014-03-06            H-1B
# 226     I-200-10277-495440      2013-11-05    2013-11-13            H-1B
# 233     I-200-10278-819931      2013-11-05    2013-11-13            H-1B
# 405     I-200-10326-048457      2014-03-01    2014-03-06            H-1B
# 427     I-200-10333-946905      2014-03-01    2014-03-06            H-1B
# 732     I-200-11021-297566      2013-11-08    2013-11-15            H-1B
# 734     I-200-11021-482079      2014-09-09    2014-09-16            H-1B
# 736     I-200-11021-804510      2013-11-08    2013-11-15            H-1B
# 4044    I-200-11234-333454      2013-11-05    2013-11-13            H-1B
# 4200    I-200-11242-153021      2014-02-10    2014-02-15            H-1B
# 4436    I-200-11255-757115      2014-07-18    2014-07-24            H-1B
# 4464    I-200-11256-648599      2014-03-01    2014-03-06            H-1B
# 4552    I-200-11262-682205      2014-03-01    2014-03-06            H-1B
# 4783    I-200-11276-178344      2014-01-06    2014-01-10            H-1B
# 5004    I-200-11287-099817      2014-01-16    2014-01-23            H-1B
# 5664    I-200-11320-740900      2014-03-13    2014-03-19            H-1B
# 5731    I-200-11326-047557      2014-03-26    2014-04-01            H-1B
# 5762    I-200-11326-991437      2014-01-09    2014-01-15            H-1B
# 5960    I-200-11347-284002      2014-03-11    2014-03-17            H-1B
# 6176    I-200-12009-175040      2014-01-09    2014-01-15            H-1B
# 6269    I-200-12013-609984      2014-09-09    2014-09-16            H-1B
# 6304    I-200-12018-316559      2014-01-09    2014-01-15            H-1B
# 6467    I-200-12031-835135      2014-09-11    2014-09-18            H-1B
# 6561    I-200-12037-669222      2014-09-15    2014-09-19            H-1B
# 6578    I-200-12038-246319      2014-06-12    2014-06-18            H-1B
# ...                    ...             ...           ...             ...
# 519209  I-203-14255-216189      2014-09-17    2014-09-23  E-3 Australian
# 519210  I-203-14255-227389      2014-09-15    2014-09-19  E-3 Australian
# 519226  I-203-14255-541564      2014-09-12    2014-09-18  E-3 Australian
# 519227  I-203-14255-551490      2014-09-17    2014-09-23  E-3 Australian
# 519229  I-203-14255-568201      2014-09-15    2014-09-19  E-3 Australian
# 519269  I-203-14258-328563      2014-09-15    2014-09-19  E-3 Australian
# 519282  I-203-14258-624648      2014-09-15    2014-09-19  E-3 Australian
# 519296  I-203-14258-980426      2014-09-15    2014-09-19  E-3 Australian
# 519306  I-203-14259-198360      2014-09-18    2014-09-24  E-3 Australian
# 519313  I-203-14259-354296      2014-09-16    2014-09-22  E-3 Australian
# 519326  I-203-14259-713340      2014-09-16    2014-09-22  E-3 Australian
# 519342  I-203-14260-161426      2014-09-18    2014-09-24  E-3 Australian
# 519344  I-203-14260-297691      2014-09-17    2014-09-23  E-3 Australian
# 519347  I-203-14260-469774      2014-09-18    2014-09-24  E-3 Australian
# 519350  I-203-14260-510051      2014-09-18    2014-09-24  E-3 Australian
# 519358  I-203-14260-968244      2014-09-18    2014-09-24  E-3 Australian
# 519365  I-203-14261-168725      2014-09-19    2014-09-25  E-3 Australian
# 519369  I-203-14261-220565      2014-09-19    2014-09-25  E-3 Australian
# 519379  I-203-14261-513796      2014-09-18    2014-09-24  E-3 Australian
# 519383  I-203-14261-696715      2014-09-18    2014-09-24  E-3 Australian
# 519418  I-203-14263-491305      2014-09-22    2014-09-26  E-3 Australian
# 519423  I-203-14264-494901      2014-09-22    2014-09-26  E-3 Australian
# 519425  I-203-14265-006757      2014-09-22    2014-09-26  E-3 Australian
# 519430  I-203-14265-121276      2014-09-22    2014-09-26  E-3 Australian
# 519439  I-203-14265-634991      2014-09-22    2014-09-26  E-3 Australian
# 519443  I-203-14265-758139      2014-09-22    2014-09-26  E-3 Australian
# 519446  I-203-14265-812434      2014-09-22    2014-09-26  E-3 Australian
# 519462  I-203-14266-600774      2014-09-23    2014-09-29  E-3 Australian
# 519465  I-203-14266-751200      2014-09-24    2014-09-30  E-3 Australian
# 519478  I-203-14267-301790      2014-09-24    2014-09-30  E-3 Australian
#
#        lca_case_employment_start_date lca_case_employment_end_date  \
# 27                         2014-04-21                   2017-04-20
# 34                         2013-10-21                   2016-10-20
# 75                         2014-10-06                   2017-10-05
# 79                         2014-10-06                   2017-10-05
# 85                         2014-10-13                   2017-10-12
# 215                        2014-08-30                   2017-08-29
# 226                        2014-03-07                   2017-03-06
# 233                        2014-01-05                   2017-01-04
# 405                        2014-08-30                   2017-08-29
# 427                        2014-08-30                   2017-08-29
# 732                        2013-11-08                   2016-08-21
# 734                        2014-09-22                   2017-09-21
# 736                        2013-11-08                   2015-08-19
# 4044                       2014-01-15                   2017-01-14
# 4200                       2014-08-12                   2017-08-11
# 4436                       2014-07-19                   2017-07-19
# 4464                       2014-08-30                   2017-08-29
# 4552                       2014-08-30                   2017-08-29
# 4783                       2014-01-22                   2017-01-21
# 5004                       2014-05-30                   2017-05-29
# 5664                       2014-09-12                   2017-09-12
# 5731                       2014-09-25                   2017-09-24
# 5762                       2014-07-08                   2017-07-07
# 5960                       2014-09-10                   2017-09-09
# 6176                       2014-03-01                   2017-02-28
# 6269                       2014-09-22                   2017-09-21
# 6304                       2014-01-27                   2017-01-26
# 6467                       2014-09-29                   2017-09-28
# 6561                       2014-10-06                   2017-10-05
# 6578                       2014-06-20                   2017-06-20
# ...                               ...                          ...
# 519209                     2014-09-24                   2016-09-23
# 519210                     2014-10-01                   2016-10-01
# 519226                     2014-09-19                   2016-09-18
# 519227                     2014-10-20                   2016-10-19
# 519229                     2014-09-22                   2016-09-22
# 519269                     2014-09-16                   2016-09-15
# 519282                     2014-10-06                   2016-10-05
# 519296                     2014-12-22                   2016-12-21
# 519306                     2014-10-15                   2016-10-14
# 519313                     2014-10-03                   2016-10-03
# 519326                     2015-01-01                   2016-12-31
# 519342                     2014-09-25                   2016-09-24
# 519344                     2014-10-06                   2016-10-06
# 519347                     2014-10-01                   2016-09-30
# 519350                     2014-12-05                   2016-12-04
# 519358                     2014-10-01                   2016-09-30
# 519365                     2014-09-25                   2016-09-25
# 519369                     2014-10-01                   2016-09-30
# 519379                     2014-10-01                   2016-09-30
# 519383                     2014-09-25                   2016-09-24
# 519418                     2014-11-22                   2016-11-22
# 519423                     2014-10-01                   2016-09-30
# 519425                     2014-10-15                   2016-10-14
# 519430                     2015-02-12                   2017-02-11
# 519439                     2014-10-06                   2016-10-05
# 519443                     2014-09-22                   2016-09-21
# 519446                     2014-09-29                   2016-09-29
# 519462                     2014-10-22                   2016-05-31
# 519465                     2015-03-13                   2017-03-12
# 519478                     2014-10-06                   2016-10-06
#
#                                    lca_case_employer_name  \
# 27                                           NEXTAG, INC.
# 34                          ALREK BUSINESS SOLUTIONS, INC
# 75                                           VMWARE, INC.
# 79                                           VMWARE, INC.
# 85                                           VMWARE, INC.
# 215             SAMSUNG INFORMATION SYSTEMS AMERICA, INC.
# 226                                            ZYNGA INC.
# 233                                            ZYNGA INC.
# 405             SAMSUNG INFORMATION SYSTEMS AMERICA, INC.
# 427             SAMSUNG INFORMATION SYSTEMS AMERICA, INC.
# 732     FRESENIUS USA, INC., A FRESENIUS MEDICAL CARE ...
# 734                                          VMWARE, INC.
# 736     FRESENIUS USA, INC., A FRESENIUS MEDICAL CARE ...
# 4044                                           ZYNGA INC.
# 4200                              APPLIED MATERIALS, INC.
# 4436                                           KIIP, INC.
# 4464            SAMSUNG INFORMATION SYSTEMS AMERICA, INC.
# 4552             SAMSUNG INFORMATION SYSTEMS AMERICA, INC
# 4783                              APPLIED MATERIALS, INC.
# 5004                                           ZYNGA INC.
# 5664                          KNOWLEDGEPATH SOLUTIONS LLC
# 5731                                           NEXMO INC.
# 5762                    CYPRESS SEMICONDUCTOR CORPORATION
# 5960                            BRIGHTSOURCE ENERGY, INC.
# 6176                      GLODOW NEAD COMMUNICATIONS, LLC
# 6269                                         VMWARE, INC.
# 6304                                           ZYNGA INC.
# 6467                                         VMWARE, INC.
# 6561                                         VMWARE, INC.
# 6578                                     BANK OF THE WEST
# ...                                                   ...
# 519209                         A2Z DEVELOPMENT CENTER INC
# 519210                            HEWLETT-PACKARD COMPANY
# 519226                         ETOUCH SYSTEMS CORPORATION
# 519227                                        GOOGLE INC.
# 519229                                NEGOCIANTS USA INC.
# 519269                                        GOOGLE INC.
# 519282                                       BBDO USA LLC
# 519296          LAWRENCE LIVERMORE NATIONAL SECURITY, LLC
# 519306                                   SUTRO HEALTH INC
# 519313                             PROLIFICS TESTING INC.
# 519326                                    MOUNTAIN TRAVEL
# 519342                            APPLIED MATERIALS, INC.
# 519344                                      IT-SCIENT LLC
# 519347                                         APPLE INC.
# 519350                          PACIFIC DATA IMAGES, INC.
# 519358                                         APPLE INC.
# 519365                                      ZENDESK, INC.
# 519369                             OVERLAND ADVISORS, LLC
# 519379                                       SQUARE, INC.
# 519383                        QUALCOMM TECHNOLOGIES, INC.
# 519418                                      ZENDESK, INC.
# 519423                                 BIZNESS APPS, INC.
# 519425                             VIMOC TECHNOLOGIES INC
# 519430                                        GOOGLE INC.
# 519439                                       BBDO USA LLC
# 519443                        ABEAM CONSULTING (USA) LTD.
# 519446                                VIRTUSA CORPORATION
# 519462                                 MUSTANG RUGBY,INC.
# 519465                                        GOOGLE INC.
# 519478                                        PERZO, INC.
#
#                 lca_case_employer_address lca_case_employer_city  \
# 27                      2955 CAMPUS DRIVE              SAN MATEO
# 34                     804 WOODFIELD ROAD             SCHAUMBURG
# 75                      3401 HILLVIEW AVE              PALO ALTO
# 79                      3401 HILLVIEW AVE              PALO ALTO
# 85                      3401 HILLVIEW AVE              PALO ALTO
# 215                75 WEST PLUMERIA DRIVE               SAN JOSE
# 226                        699 8TH STREET          SAN FRANCISCO
# 233                        699 8TH STREET          SAN FRANCISCO
# 405                75 WEST PLUMERIA DRIVE               SAN JOSE
# 427                75 WEST PLUMERIA DRIVE               SAN JOSE
# 732                     920 WINTER STREET                WALTHAM
# 734                     3401 HILLVIEW AVE              PALO ALTO
# 736                     920 WINTER STREET                WALTHAM
# 4044                       699 8TH STREET          SAN FRANCISCO
# 4200           3225 OAKMEAD VILLAGE DRIVE            SANTA CLARA
# 4436                    970 FOLSOM STREET          SAN FRANCISCO
# 4464               75 WEST PLUMERIA DRIVE               SAN JOSE
# 4552               75 WEST PLUMERIA DRIVE               SAN JOSE
# 4783           3225 OAKMEAD VILLAGE DRIVE            SANTA CLARA
# 5004                       699 8TH STREET          SAN FRANCISCO
# 5664               6550 ROCK SPRING DRIVE               BETHESDA
# 5731                    577 HOWARD STREET          SAN FRANCISCO
# 5762                   198 CHAMPION COURT              SAN JOSE,
# 5960                 1999 HARRISON STREET                OAKLAND
# 6176    1700 MONTGOMERY STREET, SUITE 203          SAN FRANCISCO
# 6269                    3401 HILLVIEW AVE              PALO ALTO
# 6304                       699 8TH STREET          SAN FRANCISCO
# 6467                    3401 HILLVIEW AVE              PALO ALTO
# 6561                    3401 HILLVIEW AVE              PALO ALTO
# 6578                    2527 CAMINO RAMON              SAN RAMON
# ...                                   ...                    ...
# 519209                    440 TERRY AVE N                SEATTLE
# 519210                3000 HANOVER STREET              PALO ALTO
# 519226              6627 DUMBARTON CIRCLE                FREMONT
# 519227          1600 AMPHITHEATRE PARKWAY          MOUNTAIN VIEW
# 519229                    477 DEVLIN ROAD                   NAPA
# 519269          1600 AMPHITHEATRE PARKWAY          MOUNTAIN VIEW
# 519282        1285 AVENUE OF THE AMERICAS               NEW YORK
# 519296                P.O. BOX 808, L-646              LIVERMORE
# 519306                     37267 ACORN PL                 NEWARK
# 519313           7041 KOLL CENTER PARKWAY             PLEASANTON
# 519326                   1266 66TH STREET             EMERYVILLE
# 519342         3225 OAKMEAD VILLAGE DRIVE            SANTA CLARA
# 519344               44790 S GRIMMER BLVD                FREMONT
# 519347                  ONE INFINITE LOOP              CUPERTINO
# 519350                 1000 FLOWER STREET               GLENDALE
# 519358                  ONE INFINITE LOOP              CUPERTINO
# 519365                 1019 MARKET STREET          SAN FRANCISCO
# 519369  601 GATEWAY BOULEVARD, SUITE 1050    SOUTH SAN FRANCISCO
# 519379       1455 MARKET STREET SUITE 600          SAN FRANCISCO
# 519383               5775 MOREHOUSE DRIVE              SAN DIEGO
# 519418                 1019 MARKET STREET          SAN FRANCISCO
# 519423                1645 CALIFORNIA ST.          SAN FRANCISCO
# 519425  201 SAN ANTONIO CIRCLE, SUITE 104          MOUNTAIN VIEW
# 519430          1600 AMPHITHEATRE PARKWAY          MOUNTAIN VIEW
# 519439        1285 AVENUE OF THE AMERICAS               NEW YORK
# 519443              8445 FREEPORT PARKWAY                 IRVING
# 519446               2000 WEST PARK DRIVE            WESTBOROUGH
# 519462                           10 DAVIS                 IRVINE
# 519465          1600 AMPHITHEATRE PARKWAY          MOUNTAIN VIEW
# 519478     744 SAN ANTONIO ROAD, SUITE 22              PALO ALTO
#
#        lca_case_employer_state     ...      lca_case_workloc2_state      pw_2  \
# 27                          CA     ...                          NaN       NaN
# 34                          IL     ...                          NaN       NaN
# 75                          CA     ...                          NaN       NaN
# 79                          CA     ...                          NaN       NaN
# 85                          CA     ...                          NaN       NaN
# 215                         CA     ...                          NaN       NaN
# 226                         CA     ...                          NaN       NaN
# 233                         CA     ...                          NaN       NaN
# 405                         CA     ...                          NaN       NaN
# 427                         CA     ...                          NaN       NaN
# 732                         MA     ...                          NaN       NaN
# 734                         CA     ...                          NaN       NaN
# 736                         MA     ...                          NaN       NaN
# 4044                        CA     ...                          NaN       NaN
# 4200                        CA     ...                          NaN       NaN
# 4436                        CA     ...                          NaN       NaN
# 4464                        CA     ...                          NaN       NaN
# 4552                        CA     ...                          NaN       NaN
# 4783                        CA     ...                          NaN       NaN
# 5004                        CA     ...                          NaN       NaN
# 5664                        MD     ...                          NaN       NaN
# 5731                        CA     ...                          NaN       NaN
# 5762                        CA     ...                          NaN       NaN
# 5960                        CA     ...                          NaN       NaN
# 6176                        CA     ...                          NaN       NaN
# 6269                        CA     ...                          NaN       NaN
# 6304                        CA     ...                           CA   76669.0
# 6467                        CA     ...                          NaN       NaN
# 6561                        CA     ...                          NaN       NaN
# 6578                        CA     ...                          NaN       NaN
# ...                        ...     ...                          ...       ...
# 519209                      WA     ...                          NaN       NaN
# 519210                      CA     ...                          NaN       NaN
# 519226                      CA     ...                          NaN       NaN
# 519227                      CA     ...                          NaN       NaN
# 519229                      CA     ...                          NaN       NaN
# 519269                      CA     ...                          NaN       NaN
# 519282                      NY     ...                          NaN       NaN
# 519296                      CA     ...                          NaN       NaN
# 519306                      CA     ...                          NaN       NaN
# 519313                      CA     ...                          NaN       NaN
# 519326                      CA     ...                          NaN       NaN
# 519342                      CA     ...                          NaN       NaN
# 519344                      CA     ...                          NaN       NaN
# 519347                      CA     ...                           CA  131269.0
# 519350                      CA     ...                          NaN       NaN
# 519358                      CA     ...                           CA   88254.0
# 519365                      CA     ...                          NaN       NaN
# 519369                      CA     ...                          NaN       NaN
# 519379                      CA     ...                          NaN       NaN
# 519383                      CA     ...                          NaN       NaN
# 519418                      CA     ...                          NaN       NaN
# 519423                      CA     ...                          NaN       NaN
# 519425                      CA     ...                          NaN       NaN
# 519430                      CA     ...                          NaN       NaN
# 519439                      NY     ...                          NaN       NaN
# 519443                      TX     ...                           TX  105560.0
# 519446                      MA     ...                           MA   81474.0
# 519462                      CA     ...                          NaN       NaN
# 519465                      CA     ...                          NaN       NaN
# 519478                      CA     ...                          NaN       NaN
#
#        pw_unit_2 pw_source_2      other_wage_source_2  \
# 27           NaN         NaN                      NaN
# 34           NaN         NaN                      NaN
# 75           NaN         NaN                      NaN
# 79           NaN         NaN                      NaN
# 85           NaN         NaN                      NaN
# 215          NaN         NaN                      NaN
# 226          NaN         NaN                      NaN
# 233          NaN         NaN                      NaN
# 405          NaN         NaN                      NaN
# 427          NaN         NaN                      NaN
# 732          NaN         NaN                      NaN
# 734          NaN         NaN                      NaN
# 736          NaN         NaN                      NaN
# 4044         NaN         NaN                      NaN
# 4200         NaN         NaN                      NaN
# 4436         NaN         NaN                      NaN
# 4464         NaN         NaN                      NaN
# 4552         NaN         NaN                      NaN
# 4783         NaN         NaN                      NaN
# 5004         NaN         NaN                      NaN
# 5664         NaN         NaN                      NaN
# 5731         NaN         NaN                      NaN
# 5762         NaN         NaN                      NaN
# 5960         NaN         NaN                      NaN
# 6176         NaN         NaN                      NaN
# 6269         NaN         NaN                      NaN
# 6304        Year         OES  OFLC ONLINE DATA CENTER
# 6467         NaN         NaN                      NaN
# 6561         NaN         NaN                      NaN
# 6578         NaN         NaN                      NaN
# ...          ...         ...                      ...
# 519209       NaN         NaN                      NaN
# 519210       NaN         NaN                      NaN
# 519226       NaN         NaN                      NaN
# 519227       NaN         NaN                      NaN
# 519229       NaN         NaN                      NaN
# 519269       NaN         NaN                      NaN
# 519282       NaN         NaN                      NaN
# 519296       NaN         NaN                      NaN
# 519306       NaN         NaN                      NaN
# 519313       NaN         NaN                      NaN
# 519326       NaN         NaN                      NaN
# 519342       NaN         NaN                      NaN
# 519344       NaN         NaN                      NaN
# 519347      Year         OES  OFLC ONLINE DATA CENTER
# 519350       NaN         NaN                      NaN
# 519358      Year         OES  OFLC ONLINE DATA CENTER
# 519365       NaN         NaN                      NaN
# 519369       NaN         NaN                      NaN
# 519379       NaN         NaN                      NaN
# 519383       NaN         NaN                      NaN
# 519418       NaN         NaN                      NaN
# 519423       NaN         NaN                      NaN
# 519425       NaN         NaN                      NaN
# 519430       NaN         NaN                      NaN
# 519439       NaN         NaN                      NaN
# 519443      Year         OES  OFLC ONLINE DATA CENTER
# 519446      Year       Other  OFLC ONLINE DATA CENTER
# 519462       NaN         NaN                      NaN
# 519465       NaN         NaN                      NaN
# 519478       NaN         NaN                      NaN
#
#                 yr_source_pub_2 lca_case_naics_code             bay_city  \
# 27                          NaN            541710.0            SAN MATEO
# 34                          NaN            541511.0           MENLO PARK
# 75                          NaN            541511.0            PALO ALTO
# 79                          NaN            541511.0            PALO ALTO
# 85                          NaN            541511.0            PALO ALTO
# 215                         NaN            541710.0        SAN FRANCISCO
# 226                         NaN            516110.0        SAN FRANCISCO
# 233                         NaN            516110.0        SAN FRANCISCO
# 405                         NaN            541710.0             SAN JOSE
# 427                         NaN            541710.0             SAN JOSE
# 732                         NaN            621399.0              CONCORD
# 734                         NaN            541511.0            PALO ALTO
# 736                         NaN            621399.0              CONCORD
# 4044                        NaN            516110.0        SAN FRANCISCO
# 4200                        NaN             33441.0          Santa Clara
# 4436                        NaN            541519.0        SAN FRANCISCO
# 4464                        NaN            541710.0             SAN JOSE
# 4552                        NaN            541710.0             SAN JOSE
# 4783                        NaN             33441.0          Santa Clara
# 5004                        NaN            516110.0        SAN FRANCISCO
# 5664                        NaN            541519.0        SAN FRANCISCO
# 5731                        NaN            561421.0        SAN FRANCISCO
# 5762                        NaN            334413.0             SAN JOSE
# 5960                        NaN            541710.0              OAKLAND
# 6176                        NaN            541820.0        SAN FRANCISCO
# 6269                        NaN            541511.0            PALO ALTO
# 6304    OFLC ONLINE DATA CENTER            516110.0        SAN FRANCISCO
# 6467                        NaN            541511.0            PALO ALTO
# 6561                        NaN            541511.0            PALO ALTO
# 6578                        NaN            522190.0        SAN FRANCISCO
# ...                         ...                 ...                  ...
# 519209                      NaN            454111.0        SAN FRANCISCO
# 519210                      NaN            334111.0            PALO ALTO
# 519226                      NaN            541511.0        SAN FRANCISCO
# 519227                      NaN            541512.0        MOUNTAIN VIEW
# 519229                      NaN            312130.0                 NAPA
# 519269                      NaN            541512.0        SAN FRANCISCO
# 519282                      NaN            541810.0        SAN FRANCISCO
# 519296                      NaN            541710.0            LIVERMORE
# 519306                      NaN              5112.0        SAN FRANCISCO
# 519313                      NaN            541519.0            PALO ALTO
# 519326                      NaN             56151.0           EMERYVILLE
# 519342                      NaN             33441.0          Santa Clara
# 519344                      NaN            541512.0              FREMONT
# 519347  OFLC ONLINE DATA CENTER            334111.0            SUNNYVALE
# 519350                      NaN            512110.0         REDWOOD CITY
# 519358  OFLC ONLINE DATA CENTER            334111.0            SUNNYVALE
# 519365                      NaN            541511.0        SAN FRANCISCO
# 519369                      NaN             52399.0  SOUTH SAN FRANCISCO
# 519379                      NaN            511210.0        SAN FRANCISCO
# 519383                      NaN            334220.0        SAN FRANCISCO
# 519418                      NaN            541511.0        SAN FRANCISCO
# 519423                      NaN            541511.0        SAN FRANCISCO
# 519425                      NaN            511210.0        MOUNTAIN VIEW
# 519430                      NaN            541512.0        MOUNTAIN VIEW
# 519439                      NaN            541810.0        SAN FRANCISCO
# 519443  OFLC ONLINE DATA CENTER            541512.0             SAN JOSE
# 519446  OFLC ONLINE DATA CENTER            541511.0             SAN JOSE
# 519462                      NaN            813410.0            San Mateo
# 519465                      NaN            541512.0        MOUNTAIN VIEW
# 519478                      NaN            541511.0            PALO ALTO
#
#        dummy_city_1 dummy_city_2
# 27              NaN          NaN
# 34              NaN          NaN
# 75              NaN          NaN
# 79              NaN          NaN
# 85              NaN          NaN
# 215             NaN          NaN
# 226             NaN          NaN
# 233             NaN          NaN
# 405             NaN          NaN
# 427             NaN          NaN
# 732             NaN          NaN
# 734             NaN          NaN
# 736             NaN          NaN
# 4044            NaN          NaN
# 4200            NaN          NaN
# 4436            NaN          NaN
# 4464            NaN          NaN
# 4552            NaN          NaN
# 4783            NaN          NaN
# 5004            NaN          NaN
# 5664            NaN          NaN
# 5731            NaN          NaN
# 5762            NaN          NaN
# 5960            NaN          NaN
# 6176            NaN          NaN
# 6269            NaN          NaN
# 6304            NaN          NaN
# 6467            NaN          NaN
# 6561            NaN          NaN
# 6578            NaN          NaN
# ...             ...          ...
# 519209          NaN          NaN
# 519210          NaN          NaN
# 519226          NaN          NaN
# 519227          NaN          NaN
# 519229          NaN          NaN
# 519269          NaN          NaN
# 519282          NaN          NaN
# 519296          NaN          NaN
# 519306          NaN          NaN
# 519313          NaN          NaN
# 519326          NaN          NaN
# 519342          NaN          NaN
# 519344          NaN          NaN
# 519347    CUPERTINO          NaN
# 519350          NaN          NaN
# 519358    CUPERTINO          NaN
# 519365          NaN          NaN
# 519369          NaN          NaN
# 519379          NaN          NaN
# 519383          NaN          NaN
# 519418          NaN          NaN
# 519423          NaN          NaN
# 519425          NaN          NaN
# 519430          NaN          NaN
# 519439          NaN          NaN
# 519443          NaN       IRVING
# 519446          NaN  WESTBOROUGH
# 519462          NaN          NaN
# 519465          NaN          NaN
# 519478          NaN          NaN
#
# [53948 rows x 36 columns]

# %%
baygeo = gpd.GeoSeries(bayzips.the_geom)

# %%
baygeo.plot()

# %%
bayzips.the_geom
# Out:
# 0      MULTIPOLYGON (((-122.10329200180091 38.5132829...
# 1      MULTIPOLYGON (((-121.947475002335 38.301511000...
# 2      MULTIPOLYGON (((-121.65335500334429 38.3133870...
# 3      MULTIPOLYGON (((-122.406843003057 38.155681999...
# 4      MULTIPOLYGON (((-122.29368500225117 38.1552379...
# 5      MULTIPOLYGON (((-122.45766900253919 38.1168949...
# 6      MULTIPOLYGON (((-121.8624620022998 38.06602999...
# 7      MULTIPOLYGON (((-121.89653900297888 38.2865679...
# 8      MULTIPOLYGON (((-122.20418700285576 38.2096949...
# 9      MULTIPOLYGON (((-122.48655900081091 38.1005269...
# 10     MULTIPOLYGON (((-122.48655900081091 38.1005269...
# 11     MULTIPOLYGON (((-121.8861390034904 38.12559299...
# 12     MULTIPOLYGON (((-122.22853700371564 38.1259699...
# 13     MULTIPOLYGON (((-122.064180002481 38.118817000...
# 14     MULTIPOLYGON (((-122.27408000249419 38.1109719...
# 15     MULTIPOLYGON (((-122.22853700371564 38.1259699...
# 16     MULTIPOLYGON (((-122.5407480037163 38.07354500...
# 17     MULTIPOLYGON (((-122.22853700371564 38.1259699...
# 18     MULTIPOLYGON (((-122.70929400072164 38.0046029...
# 19     MULTIPOLYGON (((-121.6626900026755 37.96880400...
# 20     MULTIPOLYGON (((-122.23531100178164 38.0448190...
# 21     MULTIPOLYGON (((-122.20417900134166 38.0526089...
# 22     MULTIPOLYGON (((-122.17089600301948 38.1404639...
# 23     MULTIPOLYGON (((-122.42640900174993 37.7646739...
# 24     MULTIPOLYGON (((-121.86382800309376 37.9575340...
# 25     MULTIPOLYGON (((-122.49907400116736 38.0478490...
# 26     MULTIPOLYGON (((-122.0280980025857 37.97537300...
# 27     MULTIPOLYGON (((-122.23521200348411 38.0039249...
# 28     MULTIPOLYGON (((-122.164549003297 37.921340000...
# 29     MULTIPOLYGON (((-122.24657000312598 37.9888689...
#                              ...
# 157    MULTIPOLYGON (((-122.30246400226652 37.5603889...
# 158    MULTIPOLYGON (((-121.96232400328215 37.5650469...
# 159    MULTIPOLYGON (((-122.02412500327601 37.4832120...
# 160    MULTIPOLYGON (((-122.2484780025183 37.52149900...
# 161    MULTIPOLYGON (((-122.23051100094648 37.4827339...
# 162    MULTIPOLYGON (((-122.2286450004733 37.42428200...
# 163    MULTIPOLYGON (((-122.33769500070524 37.5062560...
# 164    MULTIPOLYGON (((-122.25620600321284 37.5172039...
# 165    MULTIPOLYGON (((-121.91520000154074 37.3961050...
# 166    MULTIPOLYGON (((-121.96836300285315 37.4188210...
# 167    MULTIPOLYGON (((-122.18966900086005 37.3202479...
# 168    MULTIPOLYGON (((-122.05966700219697 37.4341609...
# 169    MULTIPOLYGON (((-122.15465600174151 37.4325139...
# 170    MULTIPOLYGON (((-122.24078200281765 37.4115679...
# 171    MULTIPOLYGON (((-122.10202500183732 37.4155830...
# 172    MULTIPOLYGON (((-121.91520000154074 37.3961050...
# 173    MULTIPOLYGON (((-121.44776300300138 37.3958489...
# 174    MULTIPOLYGON (((-122.2261990025683 37.44234599...
# 175    MULTIPOLYGON (((-122.04438000129052 37.3942409...
# 176    MULTIPOLYGON (((-122.15696000240852 37.4184569...
# 177    MULTIPOLYGON (((-122.16528400181451 37.4419170...
# 178    MULTIPOLYGON (((-122.03533900299037 37.4007049...
# 179    MULTIPOLYGON (((-122.11693600191806 37.4035500...
# 180    MULTIPOLYGON (((-122.17556700350646 37.3252860...
# 181    MULTIPOLYGON (((-122.05999500035823 37.3752980...
# 182    MULTIPOLYGON (((-122.09598200263689 37.3860539...
# 183    MULTIPOLYGON (((-121.98688800346149 37.3886580...
# 184    MULTIPOLYGON (((-122.05999500035823 37.3752980...
# 185    MULTIPOLYGON (((-122.09598200263689 37.3860539...
# 186    MULTIPOLYGON (((-122.06240400062882 37.3592939...
# Name: the_geom, Length: 187, dtype: object

# %%
gzip = gpd.GeoSeries(bayzips.the_geom)
gzip[0].geometry
gpd.
# for row in bayzips.the_geom.values.tolist().flatten:
#     print(row.geometry)
    
#     indf = gpd.GeoDataFrame.from_file(indata)
#     outdf = gpd.GeoDataFrame(columns=indf.columns)
#     for idx, row in indf.iterrows():
#         if type(row.geometry) == Polygon:
#             outdf = outdf.append(row,ignore_index=True)
#         if type(row.geometry) == MultiPolygon:
#             multdf = gpd.GeoDataFrame(columns=indf.columns)
#             recs = len(row.geometry)
#             multdf = multdf.append([row]*recs,ignore_index=True)
#             for geom in range(recs):
#                 multdf.loc[geom,'geometry'] = row.geometry[geom]
#             outdf = outdf.append(multdf,ignore_index=True)
# return outdf
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-01d300a8c50f> in <module>()
#       1 gzip = gpd.GeoSeries(bayzips.the_geom)
# ----> 2 gzip[0].geometry
#       3
#       4 # for row in bayzips.the_geom.values.tolist().flatten:
#       5 #     print(row.geometry)
#
# AttributeError: 'str' object has no attribute 'geometry'

# %%
import numpy as np
import pandas as pd
import emcee
from sklearn import model_selection
from sklearn.ensemble import RandomForestClassifier as RFC
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import seaborn as sns

# %matplotlib inline

# %%
h1b = pd.read_csv("../dat/clean_jobloc.csv")

# %%
h1b.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0_x', 'lca_case_number', 'lca_case_submit',
#        'decision_date', 'visa_class', 'lca_case_employment_start_date',
#        'lca_case_employment_end_date', 'lca_case_employer_name',
#        'lca_case_employer_address', 'lca_case_employer_city',
#        'lca_case_employer_state', 'lca_case_employer_postal_code',
#        'lca_case_soc_code', 'lca_case_soc_name', 'lca_case_job_title',
#        'lca_case_wage_rate_from', 'lca_case_wage_rate_to', 'total_workers',
#        'lca_case_workloc1_city', 'lca_case_workloc1_state', 'pw_1',
#        'pw_source_1', 'other_wage_source_1', 'yr_source_pub_1',
#        'lca_case_workloc2_city', 'lca_case_workloc2_state', 'pw_2',
#        'pw_source_2', 'other_wage_source_2', 'yr_source_pub_2',
#        'lca_case_naics_code', 'intzips', 'emp_full_addr', 'emp_unique_addrs',
#        'n_unique_addrs', 'soc_fam', 'seniority', 'frac_wage_rate_to',
#        'Unnamed: 0_y', 'Unnamed: 0.1', 'LAT', 'LONG', '12km_clusters',
#        '15km_clusters', '20km_clusters', '10km_clusters', '25km_clusters',
#        'Unnamed: 0.1.1', 'Unnamed: 0.1_2', 'LAT_2', 'LONG_2',
#        '12km_clusters_2', '15km_clusters_2', '20km_clusters_2',
#        '10km_clusters_2', '25km_clusters_2'],
#       dtype='object')

# %%
# first get everything trimmed down to the columns we want and dummy encoded etc.

# lose the Unnamed columns I've annoyingly accumulated and the case numbers
h1b = h1b.drop(columns=["Unnamed: 0", "Unnamed: 0_x", "Unnamed: 0_y", "Unnamed: 0.1", "Unnamed: 0.1.1", "Unnamed: 0.1_2",
                        "lca_case_number"])

# %%
# let's put the non-H1B visa classes as dummy variables to see if they have any predictive power
visadf = pd.get_dummies(h1b.visa_class)
visadf = visadf.drop(columns=["H-1B"])
h1b = pd.concat([h1b, visadf], axis=1)

# %%
# and drop the visa class column
h1b = h1b.drop(columns=["visa_class"])

# %%
# I'll start with the dates, turning them into integer numbers from the earliest date, say 2014-01-01
startdate = pd.to_datetime("2014-01-01")
h1b.lca_case_submit = pd.to_datetime(h1b.lca_case_submit)
h1b.decision_date = pd.to_datetime(h1b.decision_date)
h1b.lca_case_employment_start_date = pd.to_datetime(h1b.lca_case_employment_start_date)
h1b.lca_case_employment_end_date = pd.to_datetime(h1b.lca_case_employment_end_date)
h1b.lca_case_submit = (h1b['lca_case_submit'] - startdate) / np.timedelta64(1,'D')
h1b.decision_date = (h1b['decision_date'] - startdate) / np.timedelta64(1,'D')
h1b.lca_case_employment_start_date = (h1b['lca_case_employment_start_date'] - startdate) / np.timedelta64(1,'D')
h1b.lca_case_employment_end_date = (h1b['lca_case_employment_end_date'] - startdate) / np.timedelta64(1,'D')

# %%
# let's make columns for the top companies that hire H1Bs
empcounts = pd.value_counts(h1b.lca_case_employer_name)
# empcounts.sort_values(ascending=False)[:150]
# try for the companies with more than 250 applications, gives us a bit over 100
empmask = h1b.lca_case_employer_name.isin(empcounts[empcounts > 250].index)
h1b["top_employers"] = h1b.lca_case_employer_name.copy()
h1b.top_employers[~empmask] = '-'
compdf = pd.get_dummies(h1b.top_employers)
h1b = pd.concat([h1b, compdf], axis=1)
# Out:
# /home/kilian/.envs/elucd/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
# now I can drop the employer name columns, the column with a "-" and also the employer address fields
h1b = h1b.drop(columns=["lca_case_employer_name", "top_employers", "-",
                        "lca_case_employer_address", "lca_case_employer_city",
                        "lca_case_employer_state", "lca_case_employer_postal_code",
                        "emp_full_addr", "emp_unique_addrs", "intzips"])
# I'll try keeping number of unique addresses for now, could end up having some predictive power

# %%
# how about industry sector codes
sectordf = pd.get_dummies(h1b.lca_case_naics_code, prefix="sector", drop_first=False)  # dropping one redundant one
h1b = pd.concat([h1b, sectordf], axis=1)
h1b = h1b.drop(columns=["lca_case_naics_code"])

# %%
# for job data, I'll keep the soc code - first two digits - and whether it is a position of seniority
h1b["jobcat"] = [soc[:2] for soc in h1b.lca_case_soc_code.fillna("-")]  # replace nans with "-" to remove once encoded
jobdf = pd.get_dummies(h1b.jobcat, prefix="soc")
h1b = pd.concat([h1b, jobdf], axis=1)

# %%
# and drop columns
h1b = h1b.drop(columns=["lca_case_soc_code", "lca_case_soc_name", "lca_case_job_title",
                        "soc_fam", "jobcat", "soc_-"])

# %%
# now for work location data, I like the 15km clusters best so I'll start by encoding those
work1df = pd.get_dummies(h1b["15km_clusters"], prefix="work1")
h1b = pd.concat([h1b, work1df], axis=1)

# %%
work2df = pd.get_dummies(h1b["15km_clusters_2"], prefix="work2")
h1b = pd.concat([h1b, work2df], axis=1)

# %%
# and drop everything else associated with location, along with the columns for non-assigned work locations (-1)
h1b = h1b.drop(columns=["lca_case_workloc1_city", "lca_case_workloc1_state",
                        "lca_case_workloc2_city", "lca_case_workloc2_state",
                        'LAT', 'LONG', 'LAT_2', 'LONG_2',
                        '12km_clusters', '20km_clusters', '10km_clusters', '25km_clusters',
                        '12km_clusters_2', '20km_clusters_2', '10km_clusters_2', '25km_clusters_2',
                        "work1_-1.0", "work2_-1.0"])

# %%
# and finally to deal with the pay data
h1b.groupby("pw_source_1")["pw_source_1"].count().sort_values()
# Out:
# pw_source_1
# DBA                          7
# OES (All Industries)         8
# SCA                         13
# CBA                       3624
# Other                    85855
# OES                     353403
# Name: pw_source_1, dtype: int64

# %%
# h1b.groupby("pw_source_1")["pw_source_1"].count().sort_values()
h1b.groupby("other_wage_source_1")["other_wage_source_1"].count().sort_values(ascending=False)
# okay looks like I need to wrangle a little more...
# Out:
# other_wage_source_1
# OFLC ONLINE DATA CENTER                                                            373274
# OFLC ONLINE DATACENTER                                                               8002
# ONLINE WAGE LIBRARY                                                                  5553
# RADFORD GLOBAL TECHNOLOGY SURVEY                                                     5057
# FLC DATA CENTER ONLINE WAGE LIBRARY                                                  3850
# OFLC DATA CENTER                                                                     3274
# OFLC ONLINE WAGE LIBRARY                                                             2784
# FLC DATA CENTER                                                                      2783
# FLC ONLINE DATA CENTER                                                               1797
# WWW.FLCDATACENTER.COM                                                                1673
# OFLC ONLINE DATA CENTRE                                                              1350
# 'OFLC ONLINE DATA CENTER'                                                             993
# COLLECTIVE BARGAINING AGREEMENT                                                       797
# FLC ONLINE WAGE LIBRARY                                                               698
# AAMC SURVEY OF RESIDENT/FELLOW STIPENDS AND BENEFITS                                  617
# OFLC - ONLINE DATA CENTER                                                             575
# OFLC ONLINE WAGE DATA CENTER                                                          568
# OWL                                                                                   551
# DOL ONLINE WAGE LIBRARY                                                               489
# TOWERS WATSON: PROFESSIONAL (TECHNICAL AND OPERATIONS) COMPENSATION SURVEY            460
# OFLC ONLINE DATE CENTER                                                               453
# RADFORD GLOBAL TECHNOLOGY SURVEY - US PREVAILING WAGE (H-1B/PERM) CUSTOM REPORT       385
# OLFC ONLINE DATA CENTER                                                               383
# FLC DATACENTER                                                                        353
# OFCL ONLINE DATA CENTER                                                               338
# DIETRICH FALL 2013 ENGINEERING SALARY SURVEY                                          323
# FOREIGN LABOR CERTIFICATION DATA CENTER ONLINE WAGE LIBRARY                           286
# AAMC SURVEY OF RESIDENT/FELLOW STIPENDS & BENEFITS                                    266
# OFLC DATACENTER                                                                       257
# OFLC - ONLINE WAGE LIBRARY                                                            256
#                                                                                     ...
# RADFORD GLOBAL LIFE SCIENCE SURVEY, AON CORPORATION                                     1
# RADFORD GLOBAL LIFE SCIENCE SURVEY - CUSTOM REPORT                                      1
# RADFORD GLOBAL LIFE SCIENCE SURVEY                                                      1
# RADFORD GLOBA TECHNOLOGY SURVEY                                                         1
# RADFORD GLOABL TECHNOLOGY SURVEY                                                        1
# RADFORD GLOBAL TECHNOLOGY SURVEY - 2013 AON CORPORATION                                 1
# RADFORD DATA GLOBAL LIFE SCIENCE, AON CORPORATION                                       1
# RADFORD 2014 GTS COMPENSATION REPORT                                                    1
# RADFOR GLOBAL TECHNOLOGY SURVEY                                                         1
# PUBLISHER: SPONTANEOUS NETWORKS LLC. SURVEY TITLE: EMPLOYER'S SURVEY                    1
# PUBLISHER: BEYOND MANAGEMENT,INC./ SURVEY TITLE: EMPLOYER'S SURVEY                      1
# PTE, LOCAL 17 - INFORMATION TECHNOLOGY                                                  1
# RADFORD GLOBAL LIFE SCIENCES: CUSTOM REPORT                                             1
# RADFORD GLOBAL SALES SURVEY - 5043                                                      1
# RADFORD GLOBAL SALES SURVEY - 5063                                                      1
# RADFORD GLOBAL SALES SURVEY - 5163                                                      1
# RADFORD GLOBAL SALES SURVEY - 5504                                                      1
# RADFORD GLOBAL SALES SURVEY - S1512                                                     1
# RADFORD GLOBAL SALES SURVEY - S1513                                                     1
# RADFORD GLOBAL SALES SURVEY - S1514                                                     1
# RADFORD GLOBAL SALES SURVEY: L1                                                         1
# RADFORD GLOBAL SALES SURVEY: L2                                                         1
# RADFORD GLOBAL SALES SURVEY:L-1                                                         1
# RADFORD GLOBAL SALES SURVEY:L2                                                          1
# RADFORD GLOBAL TECHNICAL SURVEY                                                         1
# RADFORD GLOBAL TECHNOLOGY - CUSTOM REPORT                                               1
# RADFORD GLOBAL TECHNOLOGY -SURVEY US PREVAILING WAGE (H-1B/PERM) CUSTOM REPOR           1
# RADFORD GLOBAL TECHNOLOGY SALARY SURVEY: CUSTOM SURVEY                                  1
# RADFORD GLOBAL TECHNOLOGY SUREVEY                                                       1
# "'OFLC ONLINE DATA CENTER'                                                              1
# Name: other_wage_source_1, Length: 3105, dtype: int64

# %%
h1b["oflc_1"] = [1 if (type(a) == str and any(s in a for s in ["FLC", "LFC", "FCL", "FOREIGN LABOR"])) else 0 for a in h1b.other_wage_source_1.values.flatten().tolist()]
h1b["radford_1"] = [1 if (type(a) == str and "RADFORD" in a) else 0 for a in h1b.other_wage_source_1.values.flatten().tolist()]
h1b["owl_1"] = [1 if (type(a) == str and any(s in a for s in ["ONLINE WAGE LIBRARY", "OWL"])) else 0 for a in h1b.other_wage_source_1.values.flatten().tolist()]
h1b["cba_1"] = [1 if (type(a) == str and any(s in a for s in ["COLLECTIVE BARGAINING AGREEMENT", "CBA"])) else 0 for a in h1b.other_wage_source_1.values.flatten().tolist()]
h1b["watson_1"] = [1 if (type(a) == str and "WATSON" in a) else 0 for a in h1b.other_wage_source_1.values.flatten().tolist()]
h1b["aamc_1"] = [1 if (type(a) == str and "AAMC" in a) else 0 for a in h1b.other_wage_source_1.values.flatten().tolist()]
h1b["dietrich_1"] = [1 if (type(a) == str and "DIETRICH" in a) else 0 for a in h1b.other_wage_source_1.values.flatten().tolist()]
h1b["mercer_1"] = [1 if (type(a) == str and "MERCER" in a) else 0 for a in h1b.other_wage_source_1.values.flatten().tolist()]
h1b["bls_1"] = [1 if (type(a) == str and any(s in a for s in ["LABOR STATISTICS", "BLS"])) else 0 for a in h1b.other_wage_source_1.values.flatten().tolist()]
h1b["oes_1"] = [1 if (type(a) == str and "OES" in a) else 0 for a in h1b.other_wage_source_1.values.flatten().tolist()]

# %%
otherothers = [a for a in h1b.other_wage_source_1.values.flatten().tolist() if ((type(a) == str) and not (any(s in a for s in ["FLC", "LFC", "FCL", "FOREIGN LABOR"]) or ("RADFORD" in a) or any(s in a for s in ["ONLINE WAGE LIBRARY", "OWL"]) or any(s in a for s in ["COLLECTIVE BARGAINING AGREEMENT", "CBA"]) or ("WATSON" in a) or ("AAMC" in a) or ("DIETRICH" in a) or ("MERCER" in a) or any(s in a for s in ["LABOR STATISTICS", "BLS"]) or ("OES" in a)))]
df = pd.DataFrame({"a": otherothers})
df.groupby("a")["a"].count().sort_values(ascending=False)
# Out:
# a
# KENEXA IPAS GLOBAL HIGH TECHNOLOGY SURVEY                                                    104
# HOSPITAL AND HEALTHCARE COMPENSATION SERVICE: PHYSICIAN SALARY SURVEY                         97
# COMMITTEE OF INTERNS AND RESIDENTS SEIU                                                       89
# THE SURVEY GROUP: BENCHMARK COMPENSATION SURVEY                                               88
# HRA-NCA COMPENSATION SURVEY                                                                   84
# AMERICAN INSTITUTE OF ARCHITECTS COMPENSATION SURVEY REPORT                                   64
# MEDICAL GROUP MANAGEMENT ASSOCIATION: PHYSICIAN PLACEMENT STARTING SALARY SURVEY              39
# DCTA UNION TEACHER SALARY SCHEDULE                                                            35
# PEARL MEYER CHIPS ONE WORLD TOTAL COMPENSATION SURVEY                                         33
# 2013-2014 AAVMC COMPARATIVE DATA REPORT                                                       32
# COMPDATA SURVEYS: BENCHMARK PRO COMPENSATION SURVEY                                           31
# ONLINEWAGELIBRARY                                                                             30
# AGREEMENT BETWEEN STATE OF NY & UNITED UNIVERSITY PROFESSIONS                                 28
# THE SURVEY GROUP'S 2013 BENCHMARK COMPENSATION SURVEY                                         27
# AAUPT/COLLECTIVE BARGAINING UNIT                                                              27
# MGMA PHYSICIAN PLACEMENT STARTING SALARY SURVEY                                               26
# MEDICAL GROUP MANAGEMENT ASSOCIATION: PHYSICIAN PLACEMENT STARTING SALARY SURV                25
# ONLINE WAGE LIBRAY                                                                            23
# OFC ONLINE DATA CENTER                                                                        21
# HUMAN RESOURCE ASSOCIATION OF THE NATIONAL CAPITAL AREA 2013 COMPENSATION SURVEY REPORT       21
# UC-UAW                                                                                        20
# AMERICAN INSTITUTE OF ARCHITECTS COMPENSATION REPORT                                          19
# PEARL MEYER & PARTNERS LLC: CHIPS ONE WORLD TOTAL COMPENSATION SURVEY                         17
# PEARL MEYER & PARTNERS NATIONAL ENGINEERING & CONSTRUCTION SALARY SURVEY                      17
# AGR. BETWEEN STATE OF NY & UNITED UNIVERSITY PROF.                                            16
# ADMINISTRATIVE PROFESSIONAL ASSOCIATION UNION                                                 16
# ONLINE WAGE DATA CENTER                                                                       16
# TEMPLE ASSOCIATION OF UNIVERSITY PROFESSIONALS                                                16
# HUMAN RESOURCES ASSOCIATION FOR THE NATIONAL CAPITAL AREA COMPENSATION SURVEY REPORT 2013     15
# MGMA PHYSICIAN COMPENSATION AND PRODUCTION SURVEY                                             15
#                                                                                             ...
# EMPLOYER ASSOCIATIONS OF AMERICA NATIONAL IT AND ENGINEERING COMPENSATION SURVEY               1
# OLC ONLINE DATA CENTER                                                                         1
# ONLINE WAGE LBRARY                                                                             1
# CUSTOM SURVEY, MORTHLAND INSTITUTE OF HIGHER LEARNING                                          1
# ONLINE WAGE LIBARARY                                                                           1
# CUSTOM SURVEY - NEW JERSEY HOSPITAL ASSOCIATION WA                                             1
# PASNAP/TEMPLE UNIVERSITY HOSPITAL ALLIED HEALTH PROFESSIONALS (TAP)                            1
# CUPA PROFESSIONALS IN HIGHER EDUCATION SALARY SURVEY 2012-2013                                 1
# CUPA-HR 2012-13 PROFESSIONALS IN HIGHER EDUCATION SALARY SURVEY                                1
# OUR LADY OF MT. CARMEL ROMAN CATHOLIC CHURCH EMPLOYER'S SURVEY                                 1
# CUPA-HR NATIONAL FACULTY SALARY SURVEY (FOUR YEAR INSTITUTIONS)                                1
# CUPA-HR PROFESIONALS IN HIGHER EDUCATION SALARY SURVEY                                         1
# OPLC ONLINE DATA CENTER                                                                        1
# CUPA-HR PROFESSIONALS IN HIGHER EDUCATION SALARY SURVEY 2013                                   1
# CUPA-HR PROFESSIONALS IN HIGHER EDUCATION SURVEY 2013                                          1
# CUPA-HR SURVEY PROFESSIONALS IN HIGHER EDUCATION SALARY SURVEY                                 1
# CUPA-HR SURVEYS ONLINE                                                                         1
# CUPA-HR: NATIONAL FACULTY SALARY SURVEY 2013-2014                                              1
# ONLINE WAGEL LIBRARY                                                                           1
# CUPA.HR NATIONAL FACULTY SALARY SURVEY                                                         1
# ONLINE WAGE SURVEY                                                                             1
# ONLINE WAGE LIBRARAY                                                                           1
# ONLINE WAGE LIBRAARY                                                                           1
# CUSTOM SURVEY - EAGLE VALLY CHILDCARE ASSOCIATION                                              1
# CUSTOM SURVEY - INTEGRATED HEALTHCARE STRATEGIES P                                             1
# CUSTOM SURVEY - MGMA ANNUAL ANNUAL COMPENSATION                                                1
# ONLINE WAGE LIBARY                                                                             1
# CUSTOM SURVEY - MGMA PHYSICIAN COMPENSATION SALARY                                             1
# CUSTOM SURVEY - MGMA PHYSICIAN COMPENSATION SURVEY                                             1
# "COMPDATA SURVEYS:BENCHMARK PRO SURVEY"-2014 CROSS-INDUSTRY DATA FROM COMPDATA                 1
# Name: a, Length: 704, dtype: int64

# %%
# add the OES and CBA from the non-Other field to the newly-created fields
h1b.loc[h1b.pw_source_1 == "OES", ["oes_1"]] = 1
h1b.loc[h1b.pw_source_1 == "OES (All Industries)", ["oes_1"]] = 1
h1b.loc[h1b.pw_source_1 == "CBA", ["cba_1"]] = 1

# %%
# and the same for location 2
h1b.groupby("pw_source_2")["pw_source_2"].count().sort_values()
# Out:
# pw_source_2
# OES (All Industries)        1
# SCA                         6
# CBA                       643
# Other                   16456
# OES                     54902
# Name: pw_source_2, dtype: int64

# %%
h1b.groupby("other_wage_source_2")["other_wage_source_2"].count().sort_values(ascending=False)
# Out:
# other_wage_source_2
# OFLC ONLINE DATA CENTER                                                                       59622
# OFLC ONLINE DATACENTER                                                                         1286
# ONLINE WAGE LIBRARY                                                                            1193
# OFLC DATA CENTER                                                                                892
# FLC DATA CENTER                                                                                 588
# FLC DATA CENTER ONLINE WAGE LIBRARY                                                             477
# FLC ONLINE DATA CENTER                                                                          433
# OFLC ONLINE DATA CENTRE                                                                         369
# AAMC SURVEY OF RESIDENT/FELLOW STIPENDS AND BENEFITS                                            351
# OFLC ONLINE WAGE LIBRARY                                                                        332
# RADFORD GLOBAL TECHNOLOGY SURVEY                                                                316
# 'OFLC ONLINE DATA CENTER'                                                                       308
# COLLECTIVE BARGAINING AGREEMENT                                                                 271
# WWW.FLCDATACENTER.COM                                                                           221
# FLC DATACENTER                                                                                  159
# FLCDATACENTER                                                                                   149
# OFLC ONLINE WAGE DATA CENTER                                                                    137
# OFLC DATACENTER                                                                                 124
# OFLC ONLINE DATE CENTER                                                                         123
# DOL ONLINE WAGE LIBRARY                                                                         120
# TOWERS WATSON: PROFESSIONAL (TECHNICAL AND OPERATIONS) COMPENSATION SURVEY                      111
# OFLC ONLINE DATA WAGE CENTER                                                                    106
# AAMC SURVEY OF RESIDENT/FELLOW STIPENDS & BENEFITS                                               93
# COMMITTEE OF INTERNS AND RESIDENTS SEIU                                                          88
# FLC DATACENTER ONLINE WAGE LIBRARY                                                               85
# OFLC ONLINE DATA CENTER - FLC WAGE SEARCH WIZARD                                                 84
# FLC ONLINE WAGE LIBRARY                                                                          83
# O FLC ONLINE DATA CENTER                                                                         77
# FLC - ONLINE WAGE LIBRARY                                                                        73
# RADFORD GLOBAL TECHNOLOGY SURVEY - 5162                                                          64
#                                                                                               ...
# OFLC ONLINE DATA CENT                                                                             1
# OFLC ONLINE DATA CEBTER                                                                           1
# MRA - THE MANAGEMENT ASSOC. MANAGER. SUPERV. & PROF. SALARY SURVEY                                1
# OFLC ONLINE DATA BASE                                                                             1
# TOWERS WATSON: 2013 PROFESSIONAL (ADMINISTRATIVE AND SALES) COMPENSATION SURVEY- U.S.             1
# N/C                                                                                               1
# NATIONAL ASSOCIATION OF COMMUNITY HEALTH CENTERS: HEALTH CENTER SALARY AND BENEFITS REPORT        1
# NATIONAL IT AND ENGINEERING COMPENSATION SURVEY 2013                                              1
# TOWERS WATSON: 2013 PROFESSIONAL (ADMINISTRATIVE AND SALES) COMPENSATION SURVEY- U.S              1
# OES FLCE DATA CENTER                                                                              1
# OF C ONLINE DATA CENTER                                                                           1
# OFC ONLINE DATA CENTER                                                                            1
# OFCL DATA CENTER                                                                                  1
# OFLC - ONLINE WAGE LIBARARY                                                                       1
# TOWERS WATSON: 2013 ACCOUNTING & FINANCE COMPENSATION SURVEY - U.S.                               1
# TOWERS WATSON: (PROFESSIONAL AND OPERATIONS) COMPENSATION SURVEY                                  1
# TOWERS WATSON, CSR GENERAL INDUS SUPERVISORY & MID MGMT COMP SURVEY REPORT                        1
# OFLC DATA CENTER, ONLINE WAGE LIBRARY                                                             1
# OFLC DATA CENTRE                                                                                  1
# TOWERS WATSON SUPERVISORY AND MIDDLE MANAGEMENT COMPENSATION SURVEY                               1
# OFLC NATIONAL PROCESSING CENTER (NPC)                                                             1
# OFLC ON LINE DATA CENTER - FLC WAGE SEARCH WIZARD                                                 1
# OFLC ON LINE DATACENTER                                                                           1
# TOWERS WATSON SUPERVISORY & MIDDLE MANANSATION SURVEYGEMENT COMP                                  1
# OFLC ONILINE DATA CENTER                                                                          1
# OFLC ONILNE WAGE LIBRARY                                                                          1
# OFLC ONLIN E DATA CENTER                                                                          1
# TOWERS WATSON SCR GENERAL INDUSTRY PROFESSIONAL (TECH & OPS) COMPENSATION SURVEY REPORT           1
# TOWERS WATSON PROFESSIONAL COMP. SURVEY                                                           1
# OFLC ONLINCE DAATA CENTER                                                                         1
# Name: other_wage_source_2, Length: 740, dtype: int64

# %%
otherothers2 = [a for a in h1b.other_wage_source_2.values.flatten().tolist() if ((type(a) == str) and not (any(s in a for s in ["FLC", "LFC", "FCL", "FOREIGN LABOR"]) or ("RADFORD" in a) or any(s in a for s in ["ONLINE WAGE LIBRARY", "OWL"]) or any(s in a for s in ["COLLECTIVE BARGAINING AGREEMENT", "CBA"]) or ("WATSON" in a) or ("AAMC" in a) or ("DIETRICH" in a) or ("MERCER" in a) or any(s in a for s in ["LABOR STATISTICS", "BLS"]) or ("OES" in a)))]
df2 = pd.DataFrame({"a": otherothers})
df2.groupby("a")["a"].count().sort_values(ascending=False)
# Out:
# a
# KENEXA IPAS GLOBAL HIGH TECHNOLOGY SURVEY                                                    104
# HOSPITAL AND HEALTHCARE COMPENSATION SERVICE: PHYSICIAN SALARY SURVEY                         97
# COMMITTEE OF INTERNS AND RESIDENTS SEIU                                                       89
# THE SURVEY GROUP: BENCHMARK COMPENSATION SURVEY                                               88
# HRA-NCA COMPENSATION SURVEY                                                                   84
# AMERICAN INSTITUTE OF ARCHITECTS COMPENSATION SURVEY REPORT                                   64
# MEDICAL GROUP MANAGEMENT ASSOCIATION: PHYSICIAN PLACEMENT STARTING SALARY SURVEY              39
# DCTA UNION TEACHER SALARY SCHEDULE                                                            35
# PEARL MEYER CHIPS ONE WORLD TOTAL COMPENSATION SURVEY                                         33
# 2013-2014 AAVMC COMPARATIVE DATA REPORT                                                       32
# COMPDATA SURVEYS: BENCHMARK PRO COMPENSATION SURVEY                                           31
# ONLINEWAGELIBRARY                                                                             30
# AGREEMENT BETWEEN STATE OF NY & UNITED UNIVERSITY PROFESSIONS                                 28
# THE SURVEY GROUP'S 2013 BENCHMARK COMPENSATION SURVEY                                         27
# AAUPT/COLLECTIVE BARGAINING UNIT                                                              27
# MGMA PHYSICIAN PLACEMENT STARTING SALARY SURVEY                                               26
# MEDICAL GROUP MANAGEMENT ASSOCIATION: PHYSICIAN PLACEMENT STARTING SALARY SURV                25
# ONLINE WAGE LIBRAY                                                                            23
# OFC ONLINE DATA CENTER                                                                        21
# HUMAN RESOURCE ASSOCIATION OF THE NATIONAL CAPITAL AREA 2013 COMPENSATION SURVEY REPORT       21
# UC-UAW                                                                                        20
# AMERICAN INSTITUTE OF ARCHITECTS COMPENSATION REPORT                                          19
# PEARL MEYER & PARTNERS LLC: CHIPS ONE WORLD TOTAL COMPENSATION SURVEY                         17
# PEARL MEYER & PARTNERS NATIONAL ENGINEERING & CONSTRUCTION SALARY SURVEY                      17
# AGR. BETWEEN STATE OF NY & UNITED UNIVERSITY PROF.                                            16
# ADMINISTRATIVE PROFESSIONAL ASSOCIATION UNION                                                 16
# ONLINE WAGE DATA CENTER                                                                       16
# TEMPLE ASSOCIATION OF UNIVERSITY PROFESSIONALS                                                16
# HUMAN RESOURCES ASSOCIATION FOR THE NATIONAL CAPITAL AREA COMPENSATION SURVEY REPORT 2013     15
# MGMA PHYSICIAN COMPENSATION AND PRODUCTION SURVEY                                             15
#                                                                                             ...
# EMPLOYER ASSOCIATIONS OF AMERICA NATIONAL IT AND ENGINEERING COMPENSATION SURVEY               1
# OLC ONLINE DATA CENTER                                                                         1
# ONLINE WAGE LBRARY                                                                             1
# CUSTOM SURVEY, MORTHLAND INSTITUTE OF HIGHER LEARNING                                          1
# ONLINE WAGE LIBARARY                                                                           1
# CUSTOM SURVEY - NEW JERSEY HOSPITAL ASSOCIATION WA                                             1
# PASNAP/TEMPLE UNIVERSITY HOSPITAL ALLIED HEALTH PROFESSIONALS (TAP)                            1
# CUPA PROFESSIONALS IN HIGHER EDUCATION SALARY SURVEY 2012-2013                                 1
# CUPA-HR 2012-13 PROFESSIONALS IN HIGHER EDUCATION SALARY SURVEY                                1
# OUR LADY OF MT. CARMEL ROMAN CATHOLIC CHURCH EMPLOYER'S SURVEY                                 1
# CUPA-HR NATIONAL FACULTY SALARY SURVEY (FOUR YEAR INSTITUTIONS)                                1
# CUPA-HR PROFESIONALS IN HIGHER EDUCATION SALARY SURVEY                                         1
# OPLC ONLINE DATA CENTER                                                                        1
# CUPA-HR PROFESSIONALS IN HIGHER EDUCATION SALARY SURVEY 2013                                   1
# CUPA-HR PROFESSIONALS IN HIGHER EDUCATION SURVEY 2013                                          1
# CUPA-HR SURVEY PROFESSIONALS IN HIGHER EDUCATION SALARY SURVEY                                 1
# CUPA-HR SURVEYS ONLINE                                                                         1
# CUPA-HR: NATIONAL FACULTY SALARY SURVEY 2013-2014                                              1
# ONLINE WAGEL LIBRARY                                                                           1
# CUPA.HR NATIONAL FACULTY SALARY SURVEY                                                         1
# ONLINE WAGE SURVEY                                                                             1
# ONLINE WAGE LIBRARAY                                                                           1
# ONLINE WAGE LIBRAARY                                                                           1
# CUSTOM SURVEY - EAGLE VALLY CHILDCARE ASSOCIATION                                              1
# CUSTOM SURVEY - INTEGRATED HEALTHCARE STRATEGIES P                                             1
# CUSTOM SURVEY - MGMA ANNUAL ANNUAL COMPENSATION                                                1
# ONLINE WAGE LIBARY                                                                             1
# CUSTOM SURVEY - MGMA PHYSICIAN COMPENSATION SALARY                                             1
# CUSTOM SURVEY - MGMA PHYSICIAN COMPENSATION SURVEY                                             1
# "COMPDATA SURVEYS:BENCHMARK PRO SURVEY"-2014 CROSS-INDUSTRY DATA FROM COMPDATA                 1
# Name: a, Length: 704, dtype: int64

# %%
h1b["oflc_2"] = [1 if (type(a) == str and any(s in a for s in ["FLC", "LFC", "FCL", "FOREIGN LABOR"])) else 0 for a in h1b.other_wage_source_2.values.flatten().tolist()]
h1b["radford_2"] = [1 if (type(a) == str and "RADFORD" in a) else 0 for a in h1b.other_wage_source_2.values.flatten().tolist()]
h1b["owl_2"] = [1 if (type(a) == str and any(s in a for s in ["ONLINE WAGE LIBRARY", "OWL"])) else 0 for a in h1b.other_wage_source_2.values.flatten().tolist()]
h1b["cba_2"] = [1 if (type(a) == str and any(s in a for s in ["COLLECTIVE BARGAINING AGREEMENT", "CBA"])) else 0 for a in h1b.other_wage_source_2.values.flatten().tolist()]
h1b["watson_2"] = [1 if (type(a) == str and "WATSON" in a) else 0 for a in h1b.other_wage_source_2.values.flatten().tolist()]
h1b["aamc_2"] = [1 if (type(a) == str and "AAMC" in a) else 0 for a in h1b.other_wage_source_2.values.flatten().tolist()]
h1b["dietrich_2"] = [1 if (type(a) == str and "DIETRICH" in a) else 0 for a in h1b.other_wage_source_2.values.flatten().tolist()]
h1b["mercer_2"] = [1 if (type(a) == str and "MERCER" in a) else 0 for a in h1b.other_wage_source_2.values.flatten().tolist()]
h1b["bls_2"] = [1 if (type(a) == str and any(s in a for s in ["LABOR STATISTICS", "BLS"])) else 0 for a in h1b.other_wage_source_2.values.flatten().tolist()]
h1b["oes_2"] = [1 if (type(a) == str and "OES" in a) else 0 for a in h1b.other_wage_source_2.values.flatten().tolist()]

# %%
# and now to remove the survey columns
h1b = h1b.drop(columns=['pw_source_1', 'other_wage_source_1',
                        'pw_source_2', 'other_wage_source_2'])

# %%
# For the source years, I'll subtract 2013 from all of them, to make them close to zero
h1b["yr_source_pub_1"] = h1b.yr_source_pub_1 - 2013

# %%
# the source pub 2 values don't make much sense as years
h1b.yr_source_pub_2.unique()
# Out:
# array(['OFLC ONLINE DATA CENTER', nan, 'OFLC ONLINE WAGE LIBRARY',
#        'FLC ONLINE WAGE LIBRARY', 'ONLINE WAGE LIBRARY',
#        'FLC DATA CENTER ONLINE WAGE LIBRARY',
#        'AAMC SURVEY OF RESIDENT/FELLOW STIPENDS & BENEFITS',
#        'TOWERS WATSON: SUPERVISORY AND MIDDLE MANAGEMENT COMPENSATION SURVEY',
#        'COLLECTIVE BARGAINING AGREEMENT',
#        'TOWERS WATSON: PROFESSIONAL (TECHNICAL AND OPERATIONS) COMPENSATION SURVEY',
#        'AAMC 2013 SURVEY OF RESIDENT/FELLOW STIPENDS & BENEFITS',
#        'OFLC ONLINE DATACENTER', 'OFLC DATA CENTER',
#        'HOSPITAL AND HEALTHCARE COMPENSATION SERVICE: PHYSICIAN SALARY SURVEY',
#        'OFLC ONLINE DATA CENTE', '0FLC ONLINE DATA CENTER',
#        'MEDICAL GROUP MANAGEMENT ASSOCIATION: PHYSICIAN PLACEMENT STARTING SALARY SURVEY',
#        '2013 - MERCER BENCHMARK DATABASE INFORMATION TECHNOLOGY SURVEY',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY',
#        'MERCER BENCHMARK DATABASE INFORMATION TECHNOLOGY SURVEY REPORT',
#        'FLCDATACENTER', 'OFLC DATA CENTER ONLINE',
#        'HUMAN RESOURCE ASSOCIATION OF THE NATIONAL CAPITAL AREA 2013 COMPENSATION SURVEY REPORT',
#        'FLC ONLINE DATA CENTENR', 'FLC ONLINE DATA CENTER',
#        'OFLC ONLINE DATA CENTER/ACWIA',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY - 5504',
#        'OFLC ONLINE DATA CENTER ACWIA',
#        'RADFORD: RADFORD GLOBAL TECHNOLOGY SURVEY',
#        'FLCDATACENTER ONLINE WAGE LIBRARY', 'O FLC ONLINE DATA CENTER',
#        'AAMC - REPORT ON MEDICAL SCHOOL FACULTY SALARIES',
#        "'OFLC ONLINE DATA CENTER'",
#        'N/A - PREVAILING WAGE DETERMINED BY CBA',
#        'HRA-NCA COMPENSATION SURVEY REPORT',
#        'CULPEPPER COMPENSATION SURVEYS AND SERVICES LS80-05-300 ASSOCIATE RESEARCH POSTDOC (GENERA',
#        'RADFORD GLOBAL SALES SURVEY',
#        'HOSPITAL AND HEALTHCARE COMPENSATION SERVICE: PHYSICIAN SALARY SERVICE',
#        'US MERCER BENCHMARK DATABASE SURVEY',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY - 5062',
#        'FOREIGN LABOR CERTIFICATION DATA CENTER ONLINE WAGE LIBRARY',
#        'WWW.FLCDATACENTER.COM', 'OFLC ONLINE DATE CENTER',
#        'OFLC ONLINE DATA SURVEY', 'OFLC DATA ONLINE CENTER',
#        'PEARL MEYER & PARTNERS LLC: CHIPS ONE WORLD TOTAL COMPENSATION SURVEY',
#        'DIETRICH SPRING 2013 ENGINEERING SALARY SURVEY',
#        'US BUREAU OF LABOR STATISTICS', 'OLFC ONLINE DATA CENTER',
#        'OFLC ONLINE DATA CENTRE',
#        'FOREIGN LABOR CERTIFICATION DATA CENTRE',
#        'OFLC ON-LINE DATA CENTER',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY - 5202',
#        'TOWERS WATSON: PROFESSIONAL (ADMINISTRATIVE AND SALES) COMPENSATION SURVEY',
#        'FLC DATACENTER ONLINE WAGE LIBRARY', 'OWL', 'FLC DATACENTER',
#        'AMERICAN DENTAL EDUCATION ASSOCIATION, COMPREHENSIVE FACULTY SALARY SURVEY',
#        'FLC DATA CENTER', '2013 US MERCER BENCHMARK DATABASE',
#        'OFLC ONLINE DATA WAGE CENTER', 'FLC DATA CENTER WAGE LIBRARY',
#        'FLC - ONLINE WAGE LIBRARY',
#        'FLC DATA CENTER - ONLINE WAGE LIBRARY', 'DOL WAGE LIBRARY',
#        'OFCL ONLINE DATA CENTER',
#        '2013 US MBD: MERCER BENCHMARK DATABASE SURVEY',
#        'TOWERS WATSON CSR GEN. INDUSTRY PROFESSIONAL (TECH AND OPS) COMP. SURVEY',
#        'OFLC ONLINE WAGE DATA CENTER', 'OFLC WAGE LIBRARY',
#        'DIETRICH ASSOCIATES INC. SPRING 2013 ENGINEERING SALARY SURVEY',
#        'USMBD MERCER BENCHMARK DATABASE IT SURVEY',
#        'AGREEMENT BETWEEN STATE OF NY & UNITED UNIVERSITY PROFESSIONS',
#        'FLC-ONLINE WAGE LIBRARY', 'FLC ONLINE WAGE DATA CENTER',
#        'AAMC SURVEY OF RESIDENT/FELLOW STIPEND AND BENEFITS',
#        'FLCDATACENTER.COM',
#        'TOWERS WATSON CSR GEN. INDUSTRY PROFESSIONAL (TECH AND OPS) COMPENSATION SURVEY',
#        'FLC ONELINE WAGE LIBRARY', 'FLCDATACENTER.COM ONLINE WAGE LIBRARY',
#        "'OFLC ONLINE DATA CENTER",
#        'FOREIGN LABOR CERTIFICATION DATA CENTER', 'OFLC ONLINE CENTER',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY-5162',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY-5062',
#        'OFLC "ONLINE DATA CENTER"',
#        'TOWERS WATSON: CSR GENERAL INDUSTRY PROFESSIONAL (TECHNICAL AND OPERATIONS) COMPENSATION S',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY - US PREVAILING WAGE (H-1B/PERM) CUSTOM REPORT',
#        'US DEPARTMENT OF LABOR ONLINE WAGE LIBRARY',
#        'MERCER BENCHMARK DATABASE INFORMATION TECHNOLOGY SURVEY REPORT 2013',
#        'HOSPITAL & HEALTHCARE COMPENSATION SERVICE, PHYSICIAN SALARY & BENEFITS REPORT',
#        'OFLC ONLINE DATA CENTER1 LINCOLN HIGHWAY,',
#        'RADFORD GLOBAL SALES SURVEY: L-2',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY-5202',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY-5164', 'OFLC ONLIN E DATA CENTER',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY - 5162', 'FLC ONLINE WAGE CENTER',
#        'OFLC ONLINE DATA CENTER - FLC WAGE SEARCH WIZARD',
#        'OFLC ONLINE DATA CENTER/FLC WAGE SEARCH WIZARD',
#        'DOL ONLINE WAGE LIBRARY',
#        'US DOL BUREAU OF LABOR STATISTICS-OCCUPATIONAL EMPLOYMENT STATISTICS',
#        'OFCL ONLINE WAGE LIBRARY', 'OFLC ONLINE DATQA CENTER',
#        'OFLC ONLINE DATA CETNER',
#        'US MBD MERCER BENCHMARK DATABASE IT SURVEY',
#        'ACWIA - OFLC ONLINE DATA CENTER',
#        'TOWERSWATSON2013CSRGENERALINDUSTRYPROFESSIONAL(TECHNICAL&OPERATIONS)COMPENSATIONSURVEY',
#        'OFLC ONLINE DATA CEBTER', 'ONLINE DATA CENTER',
#        'ONLINEWAGELIBRARY', '"OFLC ONLINE DATA CENTER"',
#        'HRA-NCA COMPENSATION SURVEY',
#        'MERCER BENCHMARK DATABASE INFO TECH SURVEY REPORT',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY 5073',
#        '2013 US MDB: MERCER BENCHMARK DATABASE',
#        'DIETRICH 2013 SPRING ENGINEERING SALARY SURVEY',
#        'WWWW.FLCDATACENTER.COM', 'OFLC ON LINE DATACENTER',
#        'BLA MAY 2012 METRO & NONMETRO AREA OCUPATIONAL EMPLOYMENT & WAGE ESTIMATES, GADSDEN, AL',
#        'TOWERS WATSON 2013 CSR GENERAL INDUSTRY PROFESSIONAL SURVEY',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY 6463',
#        'TOWERS WATSON PROFESSIONAL (TECHNICAL AND OPERATIONS) COMPENSATION SURVEY',
#        'AAMC SURVEY OF RESIDENT/FELLOW STIPENDS AND BENEFITS',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY 5164',
#        'TOWERS WATSON: CSR GENERAL INDUSTRY PROFESSIONAL (TECHNICAL&OPERATIONS) COMPENSATION SURVE',
#        'TOWERS WATSON: HEALTH CARE CLINICAL AND PROFESSIONAL COMPENSATION SURVEY REPORT',
#        'MERCER BENCHMARK DATABASE INFO. TECHNO. SURVEY REPORT 2013',
#        'OFLC',
#        'TOWERS WATSON: HEALTHCARE CLINICAL & PROFESSIONAL COMPENSATION SURVEY - U.S.',
#        'ONLINE FLC DATA CENTER', 'DOL ON LINE WAGE LIBRARY',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY- 5062',
#        'TOWERS WATSON DATA SERVICES PROFESSIONAL (TECHNICAL AND OPERATIONS) COMPENSATION SURVEY',
#        'OFLC WAGE DATA CENTER', 'OFLC ONLINE LIBRARY',
#        'FLC DATACENTER WAGE LIBRARY', 'OFLC ONLINE DTATA CENTER',
#        'HOSPITAL AND HEALTHCARE COMPENSATION SERVICE: PHYSICIAN SALARY SURVEY 2013',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY 5063',
#        'OFLC ONLINE DATA CENTER - ACWIA',
#        'TOWERS WATSON 2013 HEALTH CARE CLINICAL AND PROFESSIONAL COMPENSATION SURVEY REPORT - US',
#        '107328', 'RADFORD GLOBAL TECHNOLOGY SURVEY 5064',
#        'TOWERS WATSON DATA SERVICES 2013 CSR PROFESSIONAL (ACCOUNTING AND FINANCE) COMPENSATION SU',
#        'OES', 'OFLC ONLINE DATA LIBRARY',
#        'AAMC SURVEY OF RESIDENT/FELLOW STIPENDS',
#        'MGMA: PHYSICIAN PLACEMENT STARTING SALARY SURVEY',
#        'MGMA PHYSICIAN PLACEMENT STARTING SALARY SURVEY',
#        'RADFORD: RADFORD GLOBAL TECHNLOGY SURVEY', 'FLC ONLINE DATACENTER',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY- 5202',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY - 6462',
#        'RADFORD GLOBAL LIFE SCIENCES SURVEY: CUSTOM REPORT',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY 5103',
#        'TOWERS WATSON INFORMATION TECHNOLOGY COMPENSATION SURVEY',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY- 5162',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY 5104', 'FLCDATA CENTER',
#        'OFLC ONLINE DATA CENT', 'AAMC SURVEY OF RESIDENT/FELLOW STIPEND',
#        'OFLC ONLNE DATA CENTER',
#        'MEDICAL GROUP MANAGEMENT ASSOCIATION: PHYSICIAN PLACEMENT STARTING SALARY - MGMA',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY 5144',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY 5143',
#        'AAMC SURVEY OF RESIDENT/ FELLOW STIPENDS AND BENEFITS',
#        'CUPA HR PROFESSIONALS IN HIGHER EDUCATION SALARY SURVEY FOR 2012-2013 ACADEMIC YEAR',
#        'TOWERS WATSON DATA SERVICES 2013 CSR PROFESSIONAL (ACCOUNTING AND FINANCE) COMPENSATION',
#        'AGR. BETWEEN STATE OF NY & UNITED UNIVERSITY PROF.',
#        'TOWERS WATSON:CSR GENERAL INDUSTRY PROFESSIONAL (TECHNICAL & OPERATIONS) COMPENSATION SU',
#        'HOSPITAL & HEALTHCARE COMP SERVICE, PHYSICIAN SALARY & BENEFITS REPORT',
#        'MILLIMAN: NORTHWEST TECHNOLOGY SURVEY',
#        'OES FLC DATA CENTER ONLINE WAGE LIBRARY',
#        'FLDC/ONLINE WAGE LIBRARY',
#        'TOWERS WATSON DATA SERVICES ACCOUNTING AND FINANCE COMPENSATION SURVEY',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY 5163',
#        '2013 NORTHWEST MANAGEMENT & PROFESSIONAL SALARY SURVEY SUMMARY REPORT',
#        'FLCD/ONLINE WAGE LIBRARY', "OFLC ONLINE DATA CENTER'",
#        'TOWERS WATSON CSR GENERAL INDUSTRY PROFESSIONAL (TECHNICAL & OPERATIONS) COMP SRVY RPT-U.S',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY-CUSTOM REPORT',
#        'HRA NCA CSR COMPENSATION SURVEY',
#        'TOWERS WATSON: HEALTH CARE CLINICAL & PROFESSIONAL COMPENSATION SURVEY REPORT - US',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY-US PREVAILING WAGE (H-1B/PERM) CUSTOM REPORT',
#        'NATIONAL IT AND ENGINEERING COMPENSATION SURVEY 2013',
#        'FLC WAGE DATA CENTER',
#        'TOWERS WATSON: 2013 INFORMATION TECHNOLOGY COMPENSATION SURVEY',
#        'AAMC SURVEY OF RESIDENT/FELLW STIPENDS AND BENEFITS',
#        'MEDICAL GROUP MANAGEMENT ASSOCIATION PHYSICIAN PLACEMENT STARTING SALARY SURVEY',
#        "THE SURVEY GROUP'S 2013 BENCHMARK COMPENSATION SURVEY",
#        'OES FLCE DATA CENTER', 'OFLC ONLINE WAGE SOURCE',
#        'TOWERS WATSON: 2013 ACCOUNTING AND FINANCE COMPENSATION SURVEY - U.S.',
#        'U.S. DOL BUREAU OF LABOR STATISTICS - OCCUPATIONAL EMPLOYMENT STATISTICS',
#        'OFLC ONLINE WAGE CENTER', 'OFLC - ONLINE WAGE LIBRARY',
#        'TOWERS WATSON: 2013 ACCOUNTING & FINANCE COMPENSATION SURVEY - U.S.',
#        'BLS MAY 2012 METRO & NONMETRO AREA OCCUPATIONAL EMPLOYMENT & WAGE ESTIMATES, YAKIMA, WA',
#        'OFLC - ONLINE WAGE LIBARARY', 'OFLC ONLINE DATA CEMTER',
#        'TOWERS WATSON CSR GENERAL INDUSTRY PROFESSIONAL (TECHNICAL AND OPERATIONS) COMPENSATION RE',
#        'DIETRICH ASSOCIATES INC. FALL ENGINEERING SALARY SURVEY',
#        'MERCER BENCHMARK DATABASE FINANCE, ACCOUNTING, AND LEGAL SURVEY REPORT',
#        'UNIV OF CA POST-DOC COLLECTIVE BARGAINING AGREEMENT',
#        'TOWERS WATSON PROFESSIONAL COMP. SURVEY',
#        'ROBERT HALF TECHNOLOGY, SALARY GUIDE FOR TECHNOLOGY PROFESSIONALS 2013',
#        'ONLINE WAE LIBRARY',
#        'TOWERS WATSON DATA SERVICES CSR PROFESSIONAL (TECHNICAL & OPERATIONS) COMPENSATION SURVEY',
#        'DCTA UNION TEACHER SALARY SCHEDULE', 'ICERT -ON LINE WAGE LIBRARY',
#        'ONLINE DATA WAGE CENTER',
#        'TOWERS WATSON 2013 INFORMATION TECHNOLOGY COMPENSATION SURVEY',
#        '****OFLC ONLINE DATA CENTER****',
#        'MERCER: US - MERCER BENCHMARK DATABASE INFORMATION TECHNOLOGY SURVEY REPORT 2013',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY - 5142',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY 5072',
#        'BUREAU OF LABOR STATISTICS SALARY SURVEY',
#        'TOWERS WATSON CSR GENERAL INDUSTRY PROFESSIONAL (TECHNICAL AND OPERATIONS)',
#        'DIETRICH FALL 2013 ENGINEERING SALARY SURVEY',
#        'DIETRICH FALL ENGINEERING SALARY SURVEY',
#        'KEVIN@KMWLAWOFFICES.COM',
#        'ADMINISTRATIVE PROFESSIONAL ASSOCIATION UNION',
#        'OFLC ON LINE DATA CENTER',
#        'OFLC ONLINE DATA CENTER - FLC SEARCH WIZARD',
#        'AAMC FACULTY SALARY SURVEY REPORTS', 'OFLCA ONLINE DATA CENTER',
#        'TOWERS WATSON DATA SERVICES - ACCOUNTING AND FINANCE COMPENSATION SURVEY',
#        'OFC ONLINE DATA CENTER', 'RADFORD GLOBAL TECHNOLOGY SURVEY 5214',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY 5213',
#        'TOWERS WATSON DATA SERVICES ACCOUNTING & FINANCE COMPENSATION SURVEY',
#        'COMMITTEE OF INTERNS AND RESIDENTS SEIU',
#        "PUBLISHER: BEYOND MANAGEMENT,INC./ SURVEY TITLE: EMPLOYER'S SURVEY",
#        'TEMPLE ASSOCIATION OF UNIVERSITY PROFESSORS CONTRACT',
#        'TOWERS WATSON DATA SERVICES SUPERVISORY AND MIDDLE MANAGEMENT COMPENSATION SURVEY',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY CUSTOM REPORT',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY - CUSTOM REPORT',
#        'RADFORD GLOBAL TECHNOLOGY SUREY - CUSTOM REPORT',
#        'OFLCS ONLINE DATA CENTER', 'OFLC ONLINE DATA CENETER',
#        'OFLC ONLINE DATA BASE',
#        'TOWERS WATSON DATA SERVICES 2013 CSR PROFESSIONAL (TECHNICAL AND OPERATIONS) COMPENSATION',
#        'FLC DATA ONLINE WAGE LIBRARY',
#        'TOWERS WATSON DATA SERVICES, CUSTOM SURVEY',
#        'AAMC SURVEY OF RESIDENTS/FELLOW STIPENDS AND BENEFITS',
#        'OFCL DATA CENTER',
#        'AAMC SURVEY OF RESIDENT/FELLOWS STIPENDS AND BENEFITS',
#        'TOWERS WATSON DATA SERVICES: CSR GENERAL INDUSTRY PROFESSIONAL (TECHNICAL AND OPERATIONS)',
#        'CUSTOM SURVEY MGMA ANNUAL PHYSICIAN COMPENSATION',
#        'TOWERS WATSON DATA SERVICES: CSR GEN. IND. PROF. (TECHNICAL AND OPERATIONS) COMP. SURV. RE',
#        'UAW COLLECTIVE BARGAINING AGREEMENT',
#        'TOWERS WATSON DATA SERVICES 2013 CSR PROFESSIONAL (ADMINISTRATIVE AND SALES) COMPENSATION',
#        'AAMC SURVEY OF RESIDENT/FELLOW STIPENDS AND BENEFITS REPORT',
#        'BLS OCCUPATIONAL COMPENSATION SURVEY, FORT SMITH, AR-OK',
#        'AAMC SURVEY OF RESIDENT/FELLOW STIEPNDS & BENEFITS',
#        'OFLC ONLINE DATA SOURCE', 'OFLC ONLE DATA CENTER',
#        'COMPSOURCE TOWERS WATSON DATA SERVICES INFORMATION TECHNOLOGY COMPENSATION SURVEY',
#        'TOWERS WATSON CSR ACCOUNTING & FINANCE COMPENSATION SURVEY REPORT - U.S.',
#        'TOWERSWATSON2013CSRGENERALNDUSTRYPROFESSIONAL(ADMINISTRATIVE&SALES)COMPENSATIONSURVEYREPOR',
#        'UNION OF NONTENURE-TRACK FACULTY COLLECTIVE BARGAINING AGREEMENT',
#        'TOWERS WATSON DATA SERVICES PROFESSIONAL (TECHNICAL & OPERATIONS) COMPENSATION SURVEY',
#        'US MBD MERCER BENCHMARK DATABASE FINANCE, ACCOUNTING & LEGAL SURVEY',
#        'CULPEPPER COMPENSATION SURVEYS & SERVICES LS80-05-301 INTERMEDIATE RESEARCH POSTDOC (GENER',
#        'AIA COMPENSATION REPORT 2013 A SURVEY OF U.S. ARCH',
#        'AAMC SURVEY OF RESIDENT / FELLOW STIPENDS AND BENEFITS',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY 4765',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY 4763',
#        'DIETRICH FALL 2013 ENGINEERING SASLARY SURVEY',
#        'TOWERS WATSON DATA SERVICES (TECHINCAL AND OPERATIONS) COMPENSATION SURVEY',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY 4764', 'OES ONLINE DATA CENTER',
#        'OFLE ONLINE DATA CENTER', 'OFLC ONLINE DATA CENTER-ACWIA',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY 5023',
#        'NATIONAL ASSOCIATION OF COMMUNITY HEALTH CENTERS: HEALTH CENTER SALARY AND BENEFITS REPORT',
#        'AAMC SURVEY OF RESIDENT-FELLOW STIPENDS & BENEFITS',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY 5024',
#        'ONLINE WAGE LIBRARY FLC DATA CENTER',
#        'FLC ONLINE DATA CENTER WAGE LIBRARY',
#        'COLLECTIVE BARGAINING AGREEMENT BETWEEN CUNY AND THE PROFESSIONAL STAFF CONGRESS',
#        '62442',
#        'TOWERS WATSON DATA SERVICES (TECHNICAL AND OPERATIONS) COMPENSATION SURVEY',
#        'HOSPITAL & HEALTHCARE COMPENSATION SVC: PHYSICIAN SALARY SURVEY',
#        'WARREN WOODS BOARD OF ED MASTER AGREEMENT',
#        '2014 RADFORD GLOBAL TECHNOLOGY SURVEY',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY-5063',
#        'TOWERS WATSON DATA SERVICES PROFESSIONAL (ADMINISTRATIVE AND SALES) COMPENSATION SURVEY',
#        'DOL ONINE WAGE LIBRARY',
#        'US MBD: MERCER BENCHMARK DATABASE SURVEY',
#        'FLDC ONLINE WAGE LIBRARY', 'OFL ONLINE DATA CENTER',
#        'TOWERS WATSON GENERAL INDUSTRY PROFESSIONAL (TECH & OPS) COMPENSATION SURVEY',
#        'OFLC ONLINE DATEA CENTER',
#        'AAMC 2013 SURVEY OF RESIDENT/FELLOW STIPENDS AND BENEFITS',
#        'TOWERS WATSON:SUPERVISORY AND MIDDLE MANAGEMENT COMPENSATION SURVEY',
#        'FLC ONLINE LIBRARY',
#        'MRA - THE MANAGEMENT ASSOC. MANAGER. SUPERV. & PROF. SALARY SURVEY',
#        'TOWESR WATSON CSR GEN INDUSTRY PROFESSIONAL(TECHNICAL&OPERATIONS) COMP SURVEY REPORT',
#        'TOWERS WATSON DATA SERVICES, INFORMATION TECHNOLOGY COMPENSATION SURVEY',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY - 5163',
#        'SULLIVAN, COTTER & ASSOCIATES PHYSICIAN COMPENSATION SURVEY',
#        'AAMC SURVEY OF RESIDENT / FELLOW STIPENDS & BENEFITS',
#        'FLC DATA CENTER, ONLINE WAGE LIBRARY',
#        'MERCER US - MERCER BENCHMARK DATABASE SURVEY',
#        'PEARL MEYER & PARTNERS, LLC CHIPS ONE WORLD TOTAL COMPENSATION SURVEY',
#        'TOWERS WATSON: HEALTH CARE CLINICAL & PROFESSIONAL COMP SURVEY REPORT-US',
#        'TOWERS WATSON: HEALTH CARE CLINICAL & PROFESSONAL COMP SURVEY REPORT-US',
#        'MEDICAL GROUP MANAGEMENT ASSOCIATION 2014 PHYSICIA',
#        'OFLC ONLINE DATA',
#        'US MBD MERCER BENCHMARK DATABASE FINANCE, ACCOUNTING & LEGAL',
#        'ONLINE OLFC DATA CENTER',
#        'TOWERS WATSON: 2013 PROFESSIONAL (ADMINISTRATIVE AND SALES) COMPENSATION SURVEY - U.S.',
#        '"AAMC SURVEY OF RESIDENT/FELLOW STIPENDS AND BENEFITS"',
#        "TOWERS WATSON: CSR GENERAL INDUS PROF'L (TECH & OPERATIONS) COMP SURVEY REPORT - US",
#        'TOWERS WATSON: 2013 PROFESSIONAL (TECHNICAL AND OPERATIONS) COMPENSATION SURVEY - U.S.',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY - 5063',
#        'AAMC SURVEY RESIDENT/FELLOW STIPENDS',
#        'TOWERS WATSON DATA SERVICES PROFESSIONAL (TECHNICAL AND OPERATIONS) COMPENSATION SURVEY -',
#        'TOWERS WATSON INFORMATION TECHNOLOGY COMPENSATION SURVEY - U.S.',
#        'HOSPITAL & HEALTHCARE COMPENSATION SERVICE:PHYSICIAN SALARY SURVEY',
#        'TOWERS WATSON:CSR GENERAL INDUS SUPERVISORY AND MIDD MGMT COMP SURVEY REPORT',
#        'OFLC - ONLINE DATA CENTER',
#        'RADFORD GLOBAL LIFE SCIENCE SURVEY, AON CORPORATION',
#        'TOWERS WATSON 2013 CSR GENERAL INDUSTRY PROFESSIONAL (ADMINISTRATIVE AND SALES) COMPENSATI',
#        'TOWERS WATSON DATA SERVICES PROFESSIONAL (TECHNICAL AND OPERATIONS) COMPENSATION SURVE',
#        'APWD, INC.: TOWERS WATSON: PROFESSIONAL (TECHNICAL AND OPERATIONS) COMPENSATION SURVEY',
#        'HOSPITAL AND HEALTHCARE COMPENSATION SERVICE: PHY',
#        'OFLC DATE CENTER',
#        'TOWERS WATSON 2013 CDB GENERAL INDUSTRY MIDDLE MANAGEMENT, PROFESSIONAL AND SUPPORT COMPEN',
#        'AAMC OR RESIDENTS/FELLOW STIPENDS SURVEY 2012',
#        'THE FOREIGN LABOR CERTIFICATION DATA CENTER',
#        "TOWERS WATSON: CSR GENERAL INDUS PROF'L (ADMIN & SALES) COMP SURVEY REPORT - US",
#        '2013 AAMC SURVEY OF RESIDENT/FELLOW STIPENDS',
#        'AAMC SURVEY OF RESIDENT/FELLOW STIPENDS & BENEFITS REPORT',
#        'TOWERS WATSON DATA SERVICES TECHNICAL AND OPERATIONS COMPENSATION SURVEY',
#        'OFLC ONINE DATA CENTER', 'RADFORD GLOBAL TECHNOLOGY SURVEY 5162',
#        'CUSTOM: TOWERS WATSON DATA SERVICES 2013 PROFESSIONAL (TECHNICAL AND OPERATIONS) COMPENSAT',
#        'PEARL MEYER & PARTNERS NATIONAL ENGINEERING & CONSTRUCTION SALARY SURVEY',
#        'AAMC SURVEY OF RESIDENT/FELLOW STIPENDS AND BENEFI',
#        'OFLC ONLINE DATA ONLINE', 'OFLC ONLINE DATA CNTER',
#        'TOWERS WATSON CSR GEN INDUSTRY PROFESSIONAL(TECHNICAL&OPERATIONS) COMPENSATION SURVEY',
#        'OFLC ONLIONE DATA CENTER',
#        'OFLC ONLINE DATA CENTER - FLC WAGE SEARCH CENTER',
#        'SULLIVANCOTTER AND ASSOCIATES, INC./2013 COMPENSATION SURVEY OPHTHALMOLOGY',
#        'MERCER BENCHMARK DATABASE SURVEY',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY: L-2', 'OFLCE DATA CENTER',
#        '2013 AAMC SURVEY OF RESIDENT/FELLOW STIPENDS AND BENEFITS',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY - 5164', 'BOE, ILLINOIS, 200',
#        'US-MERCER BENCHMARK DATABASE-INFORMATION TECHNOLOGY',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY: L-4',
#        'TOWERS WATSON 2013 CSR SUPERVISORY AND MIDDLE MANAGEMENT COMPENSATION SURVEY REPORT - U.S.',
#        'HTTP://WWW.FLCDATACENTER.COM/',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY: CUSTOM SURVEY',
#        'AAMC SURVEY OF RESIDENTS / FELLOW STIPENDS & BENEFITS',
#        'US MBD MECER BENCHMARK DATABASE IT SURVEY',
#        'OFLC ONLINE DATA CENER', '0FLC DATA CENTER',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY 5142', 'OFLC- ONLINE DATA CENTER',
#        'TOWERS WATSON INFORMATION TECHNOLOGY COMPENSATION SURVEY U.S.',
#        'CUSTOM SURVEY - MGMA PHYSICIAN COMPENSATION SALARY',
#        'MEDICAL GROUP MANAGEMENT ASSOCIATION: PHYSICIAN PLACEMENT STARTING',
#        'CUSTOM SURVEY: 2012 MD HEALTHCARE HR ASSOCIATION HOUSESTAFF SURVEY',
#        'CUSTOM SURVEY: NATIONAL ASSOCIATION OF INDEPENDENT SCHOOLS 2013-2014',
#        '2013 AMERICAN SOCIETY OF EMPLOYERS SUPERVISORY, MANAGERIAL AND PROFESSIONAL COMPENSATION S',
#        'COMPDATA SURVEYS: BENCHMARK PRO COMPENSATION SURVEY',
#        'HTTP://WWW.BLS.GOV/OES/CURRENT/OES_38300.HTM',
#        'CNMI DEPARTMENT OF COMMERCE-2011 CNMI PREVAILING WAGE & WORKFORCE ASSESSMENT STUDY(PWWAS)',
#        'TOWERS WATSON 2013 PROFESSIONAL (TECHNICAL AND OPERATIONS) COMPENSATION SURVEY - U.S. (GEO',
#        'TOWERS WATSON 2013 HEALTH CARE CLINICAL AND PROFESSIONAL COMPENSATION SURVEY REPORT - U.S.',
#        'ONLINE FOREIGN LABOR CERTIFICATION DATA CENTER',
#        'THE SURVEY GROUP: BENCHMARK COMPENSATION SURVEY',
#        'HRA-NCA: HRA-NCA COMPENSATION SURVEY',
#        'MERCER BENCHMARK DATABASE NORTHEAST REGION SURVEY',
#        'PEARL MEYER CHIPS ONE WORLD TOTAL COMPENSATION SURVEY',
#        'THE SURVEY GROUP 2013 BENCHMARK COMPENSATION SURVEY',
#        'OFLC DATA CENTER ONLINE WAGE LIBRARY',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY S1512',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY 4762',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY S1511', 'BLS',
#        'TOWERS WATSON DATA SERVICES: SUPERVISORY AND MIDDLE MANAGEMENT COMPENSATION SURVEY - US',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY 5022', 'OFLC ONLINE DATABASE',
#        'OFLC ONLINE DATE WAGE LIBRARY', 'OFLCONLINE DATA CENTER',
#        'TOWER WATSON: 2013 PROFESSIONAL (ADMINISTRATIVE AND SALES) COMPENSATION SURVEY - U.S.',
#        '2013-2014 AAMC SURVEY OF RESIDENT/FELLOW STIPENDS',
#        'COLLECTIVE BARGAINING AGREEMENT BETWEEN CUNY AND PROFESSIONAL STAFF CONGRESS',
#        'AAMC SURVEY OF RESIDENT STIPENDS AND BENEFITS',
#        'TOWERS WATSON DATA SERVICES INFORMATION TECHNOLOGY COMPENSATION SURVEY',
#        '2377 GOLD MEADOW WAY', 'APWD, INC.: OFLC ONLINE DATA CENTER',
#        'OFLA ONLINE DATA CENTER', 'OFLC ONLINE DATA SERVICES',
#        'OOFLC ONLINE DATA CENTER',
#        'MERCERBENCHMARKDATABASEINFORMATIONTECHNOLOGYSURVEYREPORT2013',
#        'AAMC SURVEY OF RESIDENTS/FELLOW STIPENDS & BENEFITS',
#        'US MBD MERCER BENCHMARK DATABASE NORTH CENTRAL REGION SURVEY',
#        'TOWERS WATSON PROFESSIONAL (ADMINISTRATIVE AND SALES) COMPENSATION SURVEY',
#        'MERCERBENCHMARKDATABASEINFORMATIONTECHNOLOGYSURVEYREPORT 2013',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY*-',
#        'TOWERS WATSON: PROFESSIONAL (AMINISTRATIVE AND SALES) COMPENSATION SURVEY',
#        'ONLINE WAGES LIBRARY', 'HTTP://WWW.FLCDATACENTER.COM',
#        'FLCONLINE DATA CENTER', 'FLC ON-LINE WAGE LIBRARY',
#        'U.S. DOL BUREAU OF LABOR STATISTICS-OCCUPATIONAL EMPLOYMENT STATISTICS',
#        'TOWERS WATSON DATA SERVICES (TECHNICAL & OPERATIONS) COMPENSATION SURVEY',
#        'ASSOC OF AMERICAN MEDICAL COLLEGES SURVEY OF RESIDENT/FELLOW STIPENDS & BENEFITS REPORT',
#        'TOWERS WATSON DATA SERVICES: REPORT ON CSR PROFESSIONAL TECHNICAL AND OPERATIONS',
#        'MERCER BENCHMARK DATABASE FIN., ACCT., & LEGAL SURVEY REPORT',
#        'DIETRICH ASSOCIATES INC. FALL 2013 ENGINEERING SALARY SURVEY',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY: L3', '2013',
#        'TOWERS WATSON CDB MID-MGMT, PROF & SUPPORT SURVEY',
#        'AAMC SURVEY OF RESIDENT/FELLOW STIPENT',
#        'AAMC SURVEY OF RESIDENT STIPENDS & BENEFITS',
#        'COMPDATA SURVEYS:BENCHMARK PRO COMPENSATION SURVEY',
#        'MERCER BENCHMARK DATABASE: INFO TECHNOLOGY SURVEY',
#        'FLC ON LINE WAGE DATA CENTER',
#        'MERCER BENCHMARK DFATABASE INFORMATION TECHNOLOGY SURVEY REPORT',
#        'FLCDATA ON-LINE WAGE LIBRARY',
#        'AAMC SURVEY RESIDENT/FELLOW STIPENDS AND BENEFITS REPORT',
#        'BUREAU OF LABOR STATISTICS', 'FLC DATE CENTER ONLINE WAGE LIBRARY',
#        'FLC "ONLINE DATA CENTER"',
#        'COLLECTIVE BARGAINING AGREEMENT RESEARCH SUPPORT PROFESSIONALS',
#        'OFLCDATACENTER', 'OFLC DATACENTER',
#        'AAMC SURVEY OF RESIDENTS STIPENDS & BENEFITS',
#        'HOSPITAL AND HEALTHCARE COMPENSTATION SERVICE: PHYSICIAN SALARY SURVEY',
#        "TOWERS WATSON: CSR GENERAL INDUS PROF'L (TECH & OPERATIONS) COMP SURVEY REPORT- US",
#        'RADFORD GLOBAL SALES SURVEY: L1', 'GLOBAL RADFORD SALES SURVEY',
#        'TOWERS WATSON INFORMATION TECHNOLOGY COMPENSATION SURVEY REPORT',
#        '2013- 2014 AAMC SURVEY OF RESIDENT/ FELLOW STIPENDS AND BENEFITS REPORT',
#        'OFLC ONLINE DATA CENTER WAGE LIBRARY',
#        'FLC WAGE DATA ONLINE LIBRARY', 'FLC DATA CENTER ONLINE',
#        'FLCDC ONLINE WAGE LIBRARY',
#        'TOWERS WATSON DATA SERVICES PROFESSIONAL (TECHNICAL AND OPERATIONS) CSR',
#        'HUMAN RESOURCES MANAGER',
#        'PEARL MEYER & PARTNERS LLC CHIPS ONE WORLD TOTAL COMPENSATION SURVEY',
#        'TOWERS WATSON DATA SERVICES CSR PROFESSIONAL (TECHNICAL AND OPERATIONS) COMPENSATION SURV',
#        'TOWERS WATSON 2013 PROFESSIONAL (ADMINISTRATIVE AND SALES) COMPENSATION SURVEY - AFT010',
#        'TOWERS WATSON 2013 CSR GEN. INDUSTRY PROF. (TECH & OPERATIONS) COMPENSATION SURVEY REPORT',
#        'AMERICAN ASSOCIATION OF COLLEGES OF PHARMACY (AACP)',
#        'OFLC DATA CENTER, ONLINE WAGE LIBRARY',
#        'HEALTH CENTER SALARY & BENEFITS REPORT, HOSPITAL & HEALTHCARE COMPENSATION SERVICE',
#        'OFLC ONLINE ONLINE DATA CENTER', 'OFLC: ONLINE DATA CENTER',
#        'OFLC ONLINE WAGE DATA', 'OFLC ONLINE DATA CENETR',
#        'TOWERS WATSON INFORMATION TECHNOLOGY COMPENSATION SURVEY-U.S.',
#        "MEDICAL GROUP MANAGEMENT ASS'N. 2014 PHYSICIAN SAL",
#        'MGMA:PHYSICIAN PLACEMENT STARTING SALARY SURVEY',
#        'OFLC ONLINE WAGE DATABASE',
#        'TOWERS WATSON SUPERV. AND MIDDLE MGMT. COMP. SURVEY',
#        'OFLC ONLIN DATA CENTER',
#        'MERCER BENCHMARK DATABASE FINANCE, ACCOUNTING, AND LEGAL SURVEY REPORT 2013',
#        'OFLC ONLINE DAT CENTER',
#        'MGMA PHYSICIAN COMPENSATION AND PRODUCTION REPORT',
#        'TOWERS WATSON 2013 HEALTH CARE CLINICAL & PROFESSIONAL COMPENSATION SURVEY REPORT-U.S.',
#        'TOWERS WATSON HEALTH CARE CLINICAL AND PROFESSIONAL COMPENSATION SURVEY REPORT',
#        'OF', 'OFLC ONLINE DATA CETER',
#        'TOWERS WATSON 2013 HEALTH CARE CLINICAL & PROFESSIONAL COMPENSATION SURVEY REPORT - US',
#        'OFLC ONILNE DATA CENTER',
#        'U.S BUREAU OF LABOR STATS NO OES DATA AVAILABLE',
#        'AAMC SURVEY OF RESIDENT/FELLOW STIPENDS 2013-2014',
#        'US MBD MERCER BENCHMARK DATABASE NORTHEAST REGION SURVEY',
#        'USDOL ONLINE WAGE LIBRARY', 'OFLC PNLINE DATA CENTER',
#        'OPLC ONLINE DATA CENTER',
#        'TOWERS WATSON CSR GENERAL INDUSTRY PROFESSIONAL (ADMINISTRATIVE AND SALES) COMPENSATI',
#        'SPEEA',
#        'TOWERS WATSON DATA SERVICES ACCOUNTING AND FINANCE COMPENSATION SURVEY - U.S.',
#        'OFLC ON LINE DATA CENTER - FLC WAGE SEARCH WIZARD',
#        'FLC ONLINE LIBRARY DATA CENTER', "'OFLC ONLINE DATA CENTE",
#        'MERCER BENCHMARK DATABASE NORTH CENTRAL REGION SURVEY 2013', 'N/C',
#        'FLC - ONLINE WAGE LIBRAY', 'FLC - ONLINE WAGE LI BRARY',
#        'CBA BETWEEN CPHC AND COMMITTEE OF INTERNS AND RESIDENTS-SEIU',
#        'TOWERS WATSON: 2013 PROFESSIONAL (ADMINISTRATIVE AND SALES) COMPENSATION SURVEY- U.S.',
#        'ON LINE DATA CENTER',
#        'MERCER BENCHMARK DATABASE WEST COAST REGION SURVEY 2013',
#        'HOSPITAL AND HEALTHCARE COMPENSATION SERVICE: PHYSICIAN SALARY SURVEY REPORT',
#        'CERTIFIED TEACHER CONTRACT',
#        'MEDICAL GROUP MANAGEMENT ASSOCIATION: PHYSICIAN PLACEMENT STARTING SALARY SURVEY - 2013',
#        'CULPEPPER COMPENSATION SURVEYS & SERVICES LS80-05-100 ASSOCIATE RESEARCH SCIENTIST (GENERA',
#        'FLC DATA CENTER ONLINELINE WAGE LIBRARY',
#        'TOWERS WATSON GENERAL INDUSTRY PROFESSIONAL (TECHNICAL & OPERATIONS) COMP SRVY RPT-U.S.',
#        'MGMA PHYSICIAN SALARY SURVEY',
#        'US MBD MERCER BENCHMARK DATABASE WEST COAST REGION SURVEY',
#        'MEDICAL GROUP MANAGEMENT ASSOCIATION:PHYSICIAN PLACEMENT STARTING SALARY SURVEY',
#        'ON LINE WAGE LIBRARY',
#        'DVHC 2013 COMPENSATION SURVEY, JULY EDITION',
#        'BENCHMARK DATABASE MANUFACTURING SURVEY',
#        'MERCER BENCHMARK DATABASE INFO. TECHNOLOGY SURVEY REPORT',
#        'MGMA ACADEMIC PRACTICE COMPENSATION AND PRODUCTION SURVEY FOR FACULTY AND MANAGEMENT',
#        'AAMC SURVEY OF RESIDENT FELLOW STIPENDS AND BENEFITS',
#        'ASSOCIATION OF AMERICAN VETERINARY MEDICAL COLLEGES',
#        "'OLFC ONLINE DATA CENTER'",
#        'AAMC STURVEY OF RESIDENT/FELLOW STIPENDS AND BENEFITS REPORT',
#        '2013-2014 AAVMC COMPARATIVE DATA REPORT',
#        'TOWERS WATSON DATA SERVICES:CSR GENERAL INDUSTRY PROFESSIONAL (TECHNICAL AND OPERATIONS) C',
#        'RADFORD GLOBAL TECHNOLOGY-US PREVAILING WAGE (H-1B/PERM) CUSTOM REPORT',
#        'AAMC SURVEY OF RESIDENT/FELLOW STIPENDS AND BENEFITS 2013-2014',
#        'HOSPITAL AND HEALTHCARE COMPENSATION SERVICE: PHYS',
#        'AAMC SURVEY OF RESIDENT/FELLOW STIPENDS AND AND BENEFITS 2013-2014',
#        '2013 US MBD: MERCER BENCHMARK DATABASE SURVEY (AUGUST) (US DOLLAR IN WHOLE NUMBERS)',
#        'TOWERS WATSON: HEALTH CARE CLINICAL & PROFESSIONAL COMP SURVEY REPORT - US',
#        'OFLC DATA CENTER OWL',
#        'AAMC SURVEY OF RESIDENT/FELLOW STIPENDS & BENEFITS REPORT (2013-2014)',
#        'MEDICAL GROUP MANAGEMENT ASSN: PHYSICIAN PLACEMENT STARTING SALARY SURVEY',
#        'MEDICAL GROUP MANAGEMENT ASSOCIATION: PHYSICIAN PLACEMENT STARTING SALARY SURVEY-2013 DATA',
#        'AAMC SURVEY OF REPRESENTATIVE/FELLOW STIPENDS AND BENEFITS',
#        'HHCS: PHYSICIAN SALARY SURVEY',
#        'CUSTOM SURVEY - MGMA ANNUAL ANNUAL COMPENSATION',
#        'OF C ONLINE DATA CENTER', 'WWW.FLCDATACENTER',
#        'COMPDATA SURVEYS (10/2013): PHYSICIAN & MID-LEVEL PRACTITIONER JOB REPORTS',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY-5163',
#        'TOWERS WATSON: HEALTH CARE CLINICAL AND PROFESSIONAL COMP SURVEY REPORT - US',
#        'AAMC SURVEY OF RESIDENT/ FELLOW STIPEND AND BENEFITS',
#        'OFLC ONLINE DATA SENTER',
#        'AAMC 2013-2014 SURVEY OF RESIDENT/FELLOW STIPENDS & BENEFITS',
#        'TOWERS WATSON 2013 HEALTH CARE CLINICAL & PROFESSIONAL COMP SURVEY REPORT - US',
#        'OFLC ONLIEN DATA CENTER',
#        'SULLIVAN, COTTER AND ASSOCIATES, INC. / CUSTOM SURVEY',
#        'AAMC SURVEY OF RESEDENT/FELLOW STIPENDS AND BENEFITS REPORT',
#        'MEDICAL GROUP MANAGEMENT ASSO: PHYSICIAN PLACEMENT STARTING SALARY SURVEY',
#        'FORIGN LABOR CERTIFICATION DATA CENTER ONLINE WAGE LIBRARY',
#        'CULPEPEPPER COMPENSATION REPORT TE10-40-152 SENIOR NETWORK ENGINEER (GENERAL)',
#        'TOWERS WATSON 2013 PROFESSIONAL(TECH & OPS)COMPENSATION CUSTOM SURVEY',
#        'OFLCDATACENTER.COM', 'RADFORD GLOBAL TECHNOLOGY SURVEY S1513',
#        'MERCER BENCHMARK DATABASE INFO TECHNOLOGY SURVEY REPORT',
#        'AAMC SURVEY OF RESDIENT / FELLOW STIPENDS & BENEFITS',
#        "TOWERS WATSON:CSR GENERAL INDUS. PROF'L (TECH & OPERATIONS) COMP SURV REP - US",
#        'OFLC ONLINE DATA ENTER',
#        'U.S. DOL BUREAU OF LABOR STATISTICS, OCCUPATIONAL EMPLOYMENT STATISTICS',
#        'DIETRICH FALL 2013 ENGINEERING SURVEY', 'BLS OES SURVEY',
#        'AAMC REPORT ON MEDICAL SCHOOL FACULTY SALARIES',
#        'AAMC FACULTY SALARY SURVEY',
#        'ASSOC OF AMERICAN MED COLLEGES SURVEY OF RESIDENT/FELLOW STIPENDS & BENEFITS',
#        'TOWERS WATSON PROFESSIONAL (ADMINSTRATIVE & SALES) COMP SVY: CUSTOM SURVEY',
#        'OFLC OLINE DATA CENTER',
#        'TOWERS WATSON 2013 CDB GENERAL INDUSTRY MIDDLE MANAGEMENT, PROFESSIONAL AND SU',
#        'TOWERS WATSON DATA SERVICES: CSR PROFESSIONAL (TECHNICAL/OPERATIONS) COMPENSATION SURVEY',
#        'OFLC ONLINE DATA CNETER', "'OFLC ONLINE DATA CETNER'",
#        'OFLC ONLINE DTA CENTER', 'OES ONLINE WAGE LIBRARY',
#        'TOWERS WATSON DATA SERVICES 2013 PROFESSIONAL (ACCOUNTING AND FINANCE)',
#        'TOWERS WATSON DATA SERVICES - 2013 PROFESSIONAL (ACCOUNTING AND FINANCE)',
#        'AAMC SURVEY OF RESIDENT/FELLOW STIPENDS AND BENEFITS REPOR',
#        'TOWERS WATSON:HEALTH CARE CLINICAL AND PROFESSIONAL COMPENSATION SURVEY REPORT',
#        'TOWERS WATSON, CSR GENERAL INDUS SUPERVISORY & MID MGMT COMP SURVEY REPORT',
#        'PEARL MEYER & PARTNERS CHIPS ONE WORLD TOTAL COMPENSATION SURVEY',
#        'HOSPITAL & HEALTHCARE COMPENSATION SERVICE: PHYSICIAN SALARY SURVEY',
#        'TOWERS WATSON: CSR GENERAL INDUSTRY PROFESSIONAL(TECHNICAL&OPERATIONS) COMPENS',
#        'U.S. BUREAU OF LABOR STATISTICS (NO OES DATA AVAILABLE FOR AREA)',
#        'FLCA DATA CENTER',
#        'ASSOC OF AMERICAN MEDICAL COLLEGES SURVEY OF RESIDENT/FELLOW STIPENDS & BENEFITS',
#        'SULLIVAN COTTER PHYSICIAN COMPENSATION SURVEY',
#        'OFLC WAGE LIBRARY - $90/HR DEFAULT WAGE WHEN NO LEVELED DATA AVAILABLE',
#        'HOSPITAL AND HEALTHCARE COMPENSATION SERVICE PHYSICIAN SALARY REPORT 2014',
#        'MEDICAL GROUP MANAGEMENT ASSOCIATION: PHYSICIAN PLACEMENT STARTING SALARY SUR',
#        "CBA BETWEEN CPHC AND MA LABORERS' DISTRICT COUNCIL/LOCAL 380",
#        'TOWERS WATSON:PROFESSIONAL (TECHNICAL AND OPERATIONS) COMPENSATION SURVEY',
#        'HOSPITAL AND HEALTHCARE COMPENSATION SERVICE:PHYSICIAN SALARY SURVEY',
#        'MEDICAL GROUP MANAGEMENT ASSOCATION:PHYSICIAN PLACEMENT STARTING SALARY SURVEY',
#        'OFLC ONLINCE DAATA CENTER',
#        'AAMC: SURVEY OF RESIDENT/FELLOW STIPENDS/BENEFITS',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY - 5252', '1000 S HOUSTON ST',
#        'TOWERS WATSON: SUPERVISORY AND MIDDLE MGMT. COMPENSATION SURVEY',
#        'TOWERS WATSON DATA SERVICES 2013 CSR PROFESSIONAL (INFORMATION TECHNOLOGY) COM',
#        'FLCD/ ONLINE WAGE LIBRARY',
#        'TOWERS WATSON 2013 ACCOUNTING AND FINANCE COMPENSATION SURVEY - U.S.',
#        'ONLINE FLDC DATA CENTER', 'AAUP COLLECTIVE BARGAINING AGREEMENT',
#        'TOWERS WATSON INFORMATION TECNOLOGY COMPENSATION SURVEY-U.S.',
#        'ASSOC OF AMERICAN MEDICAL COLLEGES SURVEY OF RESIDENT/FELLOW STIPENDS & BENEFI',
#        'AAMC SURVEY OF RESDIENT/FELLOW STIPENDS & BENEFITS',
#        'AAUPT/COLLECTIVE BARGAINING UNIT',
#        'MEDICAL GROUP MANAGEMENT ASSOCIATION: PHYSICIAN PLACEMENT STARTING SURVEY',
#        'MERCER BENCHMARK DATABASE NORTH CENTRAL REGION SURVEY',
#        'OFLC DATA CENTRE',
#        'MERCER BENCHMARK DATABASE MANUFACTURING SURVEY',
#        'OFLC ONLINE DATA CENTER\\',
#        '2013 AAMC SURVEY OF RESIDENT/FELLOW STIPENDS AND BENEFITS REPORT',
#        'FLCA ONLINE DATA CENTER', 'FLD DATA CENTER ONLINE WAGE LIBRARY',
#        'PEARL MEYER & PARTNERS LLC, CHIPS ONE WORLD TOTAL COMPENSATION SURVEY',
#        'OFLC NATIONAL PROCESSING CENTER (NPC)',
#        "THE SURVEY GROUP/THE SURVEY GROUP'S 2013 BENCHMARK COMPENSATION SURVEY",
#        '2013-2014 AAMC SURVEY OF RESIDENT FELLOW STIPENDS',
#        'NON-TENURE TRACK SYSTEM FACULTY COLLECTIVE BARGAINING AGREEMENT',
#        'MEDICAL GROUP MANAGEMENT ASSOCIATION: PHYSICIAN PLACEMENT STARTING SALARY SURV',
#        'TOWERS WATSON: CSR SUPERVISORY AND MIDD MGMT COMP SURVEY REPORT - U.S.',
#        'TOWERS WATSON 2013 CSR GENERAL INDUSTRY PROFESSIONAL (TECH & OPERATIONS)',
#        'TOWERS WATSON DATA SERVICES PROFESSIONAL TECHNICAL AND OPERATIONS',
#        'DIETRICH ASSOCIATES INC. SPRING ENGINEERING SALARY',
#        'FLC DATA CENTER ONLINE WAGE LIBARY',
#        'TOWERS WATSON CSR GENERAL INDUS SUPERVISORY & MIDD MGMT COMP SURVEY REPORT-U.S',
#        'AAMC SURVEY OF MEDICAL SCHOOL FACULTY SALARIES',
#        'TOWERS WATSON DATA SERVICES 2013 INFORMATION TECHNOLOGY COMPENSATION SURVEY',
#        'HTTP://WWW.BLS.GOV/OES/2013/MAY/OES_WV.HTM',
#        'HTTP://FLCDATACENTER.COM/', 'FLC CATA CENTER ONLINE WAGE LIBRARY',
#        'TSD MASTER AGREEMENT', 'DCTA UNION TEACHERS SALARY SCHEDULE',
#        'FLC DATA CENTER ONLINE LIBRARY',
#        '2013 US MERCER BENCHMARK DATABASE SURVEY',
#        "TOWERS WATSON: HEALTH CARE CLINICAL & PROF'L COMP SURVEY REPORT - US",
#        'FLC WAGE LIBRARY',
#        'TOWERS WATSON PROFESSIONAL (TECHNICAL AND OPERATIONS) COMPENSATION SURVEY REPT',
#        'MERCER BENCHMARK DATABASE SOUTH CENTRAL REGION SURVEY',
#        'HTTP://WWW.BLS.GOV/OES/2013/MAY/OES_NY.HTM',
#        'MA LEAGUE OF COMMUNITY HEALTH CENTERS, 2013 SALARY & COMPENSATION SURVEY',
#        'DIETRICH SPRING 2014 ENGINEERING SALARY SURVEY',
#        'TOWERS WATSON HEALTH CARE CLINICAL AND PROFESSIONAL COMPENSATION SURVEY REPORT-U.S.',
#        'DOL NATIONAL PREVAILING WAGE CENTER (NPWC)',
#        'U.S. BUREAU OF LABOR STATISTICS WAGE SURVEY', 'FLA DATA CENTER',
#        'CBA',
#        'TOWER WATSON DATA SERVICES ACCOUNTING AND FINANCE COMPENSATION SURVEY',
#        'TOWERS WATSON 2014 HEALTH CARE CLINICAL & PROFESSIONAL COMPENSATION SURVEY RE',
#        'HTTP://WWW.FLCDATACENTER.COM "OFLC ONLINE DATA CENTER"',
#        'OFLC ONLINE WAGE LIBARARY',
#        'HOSPITAL & HEALTHCARE COMPENSATION SERVICE: PHYSICIAN SALARY SURVEY 2014',
#        'TOWERS WATSON 2014 CSR GEN. INDUSTRY PROF. (TECH. & OPER.) COMP SURVEY REPORT',
#        'OFLC ONLINE DATA CENTER -ACWIA',
#        'MEDICAL GROUP MANAGEMENT ASSOC: PHYSICIAN PLACEMENT STARTING SALARY SURVEY',
#        'U.S. MBD: MERCER BENCHMARK DATABASE SURVEY',
#        'DCTA SALARY SCHEDULE',
#        "TOWERSWATSONCSRGENERALINDUSTRYPROF'LTECH&OPERATIONSCOMPSURVEYREPORTUS",
#        'TOWERS WATSON DATA SERVICES (ACCOUNTING AND FINANCE COMPENSATION SURVEY)',
#        'FLDC ONLINE DATA LIBRARY',
#        'EMPLOYERS ASSOCIATION OF AMERICAN (EAA) NATIONAL IT AND ENGINEERING SURVEY',
#        'DIETRICH 2014 SPRING ENGINEERING SALARY SURVEY',
#        'FLC ONLINE DATA CENTER - GUAM', 'ONLINE FLC DATACENTER',
#        'U.S. BUREAU OF LABOR STATISTICS', 'ONLINE WAGE LIBRARY FLS',
#        'TOWERS WATSON DATA SERVICES PROFESSIONAL TECHNICAL & OPERATIONS COMPENSATION SURVEY',
#        'FLC DATA CENTER WAGE LIBARY',
#        'CULPEPPER COMPENSATION SURVEYS & SERVICES LS80-05-300 ASSOCIATE RESEARCH POSTDOC (GENERA',
#        'AHABERMAN@MCCARTER.COM',
#        "TOWERS WATSON: HEALTH CARE CLINICAL AND PROF'L COMP SURVEY REPORT - US",
#        'TOWERS WATSON DATA SERVICES INFORMATION TECHNOLOGY COMPENSATION SURVEY - U.S.',
#        'TOWERS WATSON DATA SERVICES PROFESSIONAL TECHNICAL & OPERATIONS COMPENSATION',
#        'BLS OCCUPATIONAL EMPLOYMENT STATISTICS SURVEY',
#        'FLC - ONOINE WAGE LIBRARY',
#        'TOWERS WATSON SUPERVISORY & MIDDLE MANANSATION SURVEYGEMENT COMP',
#        'OFLC ONILINE DATA CENTER', 'FLCDATACENTER WAGE LIBRARY',
#        'MGMA PHYSICIAN COMPENSATION AND PRODUCTION SURVEY',
#        '2013 US MBD: MERCER BENCHMARK DATABASE INFORMATION TECHNOLOGY SURVEY',
#        'CUPA HR: NATIONAL FACULTY SALARY SURVEY 2013-2014',
#        'OFLC ONLINE DATA WAGE',
#        'HOSPITAL AND HEALTHCARE COMPENSATION SERVICE: PHYSICIAN SALARY SURVEY 2014',
#        'OFLC ONILNE WAGE LIBRARY',
#        'MGMA PHYSICIAN COMPENSATION & PRODUCTION SURVEY',
#        'TOWERS WATSON CSR GENERAL INDUS PROF (TECH OPERATIONS) COMP SURVEY REPORT - US',
#        'CULPEPPER COMPENSATION SURVEYS AND SERVICES LS90-10-100 ASSOCIATE CLINICAL DAT',
#        'CUPA PROFESSIONALS IN HIGHER EDUCATION SALARY SURVEY',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY 2014',
#        'HOSPITAL AND HEALTHCARE COMPENSATION SERVICE PHYSICIAN SALARY SURVEY',
#        'MGMA: PHYSICIAN PLACEMENT STARTING SALARY',
#        'AMERICAN MEDICAL GROUP ASSOCIATION 2013 MED. GROUP COMP. & FINANCIAL SURVEY',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY: L-3',
#        'HOSPITAL AND HEALTHCARE COMPENSATION SERVICE: PHYSYCIAN SALARY SURVEY',
#        'OFLD ONLINE DATA CENTER',
#        'TOWERS WATSON SUPERVISORY AND MIDDLE MANAGEMENT COMPENSATION SURVEY',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY-5103', 'OFLCE ONLINE DATA CENTER',
#        'US BUREAU OF STATISTICS',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY - 5073',
#        'D. DIETRICH ASSOCIATES, INC., DIETRICH SPRING ENGINEERING SALARY SURVEY',
#        'TOWERS WATSON 2014 CSR GENERAL INDUSTRY PROFESSIONAL (ADMINISTRATIVE AND SALES',
#        'TOWERS WATSON DATA SERVICES: CSR GENERAL INDUSTRY PROFESSIONAL TECHNICAL AND OPERATIONS CO',
#        'MGMA PHYSICIAN COMPENSATION & PRODUCTION SURVEY (HEMATOLOGY/ONCOLOGY)',
#        'MERCER BENCHMARK DATABASE WEST COAST REGION SURVEY',
#        'BUREAU OF LABOR STATISTICS MAY 2013 OES',
#        'TOWERS WATSON: 2013 PROFESSIONAL (ADMINISTRATIVE AND SALES) COMPENSATION SURVEY- U.S',
#        'ONLINE OFLC DATA CENTER',
#        '2013 US MERCER BENCHMARK DATABASE INFORMATION TECHNOLOGY SURVEY REPORT',
#        'TOWERS WANTSON INFORMATION TECHNOLOGY COMPENSATION SURVEY-U.S.',
#        'OFLC ONLINE WAGE LIBRARAY',
#        'TOWERS WATSON 2014 PROFESSIONAL (TECHNICAL AND OPERATIONS) COMPENSATION SURVEY',
#        'OFLC ONLNE DATA CENTRE', 'AAMC FACULTY SALARIES 2012-2013',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY - 5071',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY - 5072',
#        'TOWERS WATSON: (PROFESSIONAL AND OPERATIONS) COMPENSATION SURVEY',
#        'TOWERS WATSON DATA SERVICES CSR PROFESSIONAL (TECHNICAL & OPERATIONS) COMPENSA',
#        'AAMC SURVEY OF RESIDENT/FELLOW STIPEND AND BENEFIT REPORT',
#        'TOWERS WATSON (TECHNICAL AND OPERATIONS) COMPENSATION SURVEY',
#        '2014 TOWERS WATSON PROFESSIONAL (TECHNICAL AND OPERATIONS) COMPENSATION SURVEY',
#        'BUREAU OF LABOR STATISTICS, CENTRAL MISSOURI NONMETROPOLITAN AREA',
#        'TOWERS WATSON DATA SERVICES PROFESSIONAL (TECHNICAL AND OPERATIONS)',
#        'TOWERS WATSON DATA SERVICES PROFESSIONAL TECHNICAL AND OPERATIONS COMPENSATION',
#        'TOWERS WATSON GENERAL INDUSTRY IT COMPENSATION SURVEY REPORT - U.S.',
#        'TOWERS WATSON: SUPERVISORY AND MIDDLE MANAGEMENT COMPENSATION',
#        'TOWERSWATSON2014CSRGENINDUSTRYPROTECHNICALANDOPERATIONSCOMPENSATIONSURVEYRPTUS',
#        'TOWERS WATSON PROFESSIONAL (TECHNICAL & OPERATIONS) COMPENSATION SURVEY REPORT',
#        'CRONER DIGITAL CONTENT AND TECHNOLOGY SURVEY',
#        'OFLC ONLINE DATA SEARCH - FLC WAGE SEARCH WIZARD',
#        'MERCER BENCHMARK DATABASE IT SURVEY REPORT',
#        'MERCER US MANAGEMENT AND IT CONSULTING COMPENSATION SURVEY',
#        'OFLC (ONLINE DATA CENTER)',
#        'HOSPITAL AND HEALTHCARE COMPENSATION SERVICE: PHYSICIAN AND SALARY SURVEY',
#        'TOWERS WATSON DATA SERVICES ADMINISTRATIVE AND SALES COMPENSATION SURVEY',
#        'TOWERS WATSON 2014 CSR GEN INDUSTRY PROF (TECH & OPERATIONS) COMP SURVEY RPT',
#        'TOWERS WATSON PROFESSIONAL (TECHNICAL AND OPERATIONS) COMPENSATION',
#        'TOWERS WATSON SCR GENERAL INDUSTRY PROFESSIONAL (TECH & OPS) COMPENSATION SURVEY REPORT',
#        '2014 US MERCER BENCHMARK DATABASE INFORMATION TECHNOLOGY SURVEY',
#        'TOWERS WATSON DATA SERVICES PROFESSIONAL TECHNICAL AND OPERATIONS COMPENSATION SURVEY',
#        'UNIV. OF CA POSTDOC COLLECTIVE BARGAINING AGREEMENT',
#        'TOWERS WATSON: CSR GENERAL INDUSTRY PROFESSIONAL TECHNICAL AND OPERATIONS COMPENSATION SUR',
#        'RADFORD GLOBAL TECHNOLOGY SURVEY - 5102', 'ONLINE OFLC DATACENTER',
#        '2014 OFLC ONLINE DATA CENTER',
#        'TOWERS WATSON DATA SERVICES: 2013 ACCOUNTING AND FINANCE COMPENSATION SURVEY',
#        'QUALCOMP: MINNESOTA STATEWIDE COMPENSATION SURVEY',
#        'AAMC SUVERY OF RESIDENT / FELLOW STIPENDS & BENEFITS',
#        'FOREIGN LABOR CERTIFICATION DATA CENTER - ONLINE WAGE LIBRARY',
#        'MERCER BENCHMARK DATABASE WEST COAST REGION SURVEY 2014'], dtype=object)

# %%
# so I'll drop those
h1b = h1b.drop(columns=["yr_source_pub_2"])

# %%
# finally I'll standardise the prevailing wages so that they're nicer numbers
h1b.pw_1 = (h1b.pw_1 - h1b.pw_1.mean()) / (h1b.pw_1.max() - h1b.pw_1.min())
h1b.pw_2 = (h1b.pw_2 - h1b.pw_2.mean()) / (h1b.pw_2.max() - h1b.pw_2.min())

# %%
# this completes the design matrix, finally, I'd like to split high and low earners
# I'll make the lowest 25% be low earners, and highest 25% be high earners, getting a -1 and 1 respectively
# the rest will get zero
low = np.percentile(h1b.lca_case_wage_rate_from.values.flatten(), 25)
high = np.percentile(h1b.lca_case_wage_rate_from.values.flatten(), 75)
h1b["earners"] = np.zeros(h1b.shape[0])
h1b.loc[h1b.lca_case_wage_rate_from < low, ["earners"]] = -1
h1b.loc[h1b.lca_case_wage_rate_from > high, ["earners"]] = 1

# %%
# I won't worry about the wage_rate_to for this experiment so I can remove that information
h1b = h1b.drop(columns=["lca_case_wage_rate_to", "frac_wage_rate_to"])

# %%
# briefly save what I've got
h1b.to_csv("../dat/task2_design.csv")

# %%
dmat = h1b.drop(columns=["lca_case_wage_rate_from", "earners"])
out = h1b.earners

# %%
Xtrain, Xtest, ytrain, ytest = model_selection.train_test_split(dmat, out)

# %%
sns.heatmap(Xtrain.corr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-241-6e9a7e9996fc> in <module>()
# ----> 1 sns.heatmap(Xtrain.corr)
#
# ~/.envs/elucd/lib/python3.6/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 517                           yticklabels, mask)
#     518
#     519     # Add the pcolormesh kwargs here
#
# ~/.envs/elucd/lib/python3.6/site-packages/seaborn/matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     109         else:
#     110             plot_data = np.asarray(data)
# --> 111             data = pd.DataFrame(plot_data)
#     112
#     113         # Validate the mask and convet to DataFrame
#
# ~/.envs/elucd/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     359             else:
#     360                 mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 361                                          copy=copy)
#     362         elif isinstance(data, (list, types.GeneratorType)):
#     363             if isinstance(data, types.GeneratorType):
#
# ~/.envs/elucd/lib/python3.6/site-packages/pandas/core/frame.py in _init_ndarray(self, values, index, columns, dtype, copy)
#     511         # by definition an array here
#     512         # the dtypes will be coerced to a single dtype
# --> 513         values = _prep_ndarray(values, copy=copy)
#     514
#     515         if dtype is not None:
#
# ~/.envs/elucd/lib/python3.6/site-packages/pandas/core/frame.py in _prep_ndarray(values, copy)
#    6222         values = values.reshape((values.shape[0], 1))
#    6223     elif values.ndim != 2:
# -> 6224         raise ValueError('Must pass 2-d input')
#    6225
#    6226     return values
#
# ValueError: Must pass 2-d input

# %%
# let's try a quick random forest so
clf = RFC()
clf.fit(Xtrain, ytrain)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-243-1b8da9cf3b27> in <module>()
#       1 # let's try a quick random forest so
#       2 clf = RFC()
# ----> 3 clf.fit(Xtrain, ytrain)
#
# ~/.envs/elucd/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     245         """
#     246         # Validate or convert input data
# --> 247         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     248         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     249         if sample_weight is not None:
#
# ~/.envs/elucd/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ~/.envs/elucd/lib/python3.6/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    1149
#    1150     def __array__(self, dtype=None):
# -> 1151         return _values_from_object(self)
#    1152
#    1153     def __array_wrap__(self, result, context=None):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.values_from_object()
#
# ~/.envs/elucd/lib/python3.6/site-packages/pandas/core/generic.py in get_values(self)
#    3823     def get_values(self):
#    3824         """same as values (but handles sparseness conversions)"""
# -> 3825         return self.as_matrix()
#    3826
#    3827     def get_dtype_counts(self):
#
# ~/.envs/elucd/lib/python3.6/site-packages/pandas/core/generic.py in as_matrix(self, columns)
#    3790         self._consolidate_inplace()
#    3791         if self._AXIS_REVERSED:
# -> 3792             return self._data.as_matrix(columns).T
#    3793         return self._data.as_matrix(columns)
#    3794
#
# ~/.envs/elucd/lib/python3.6/site-packages/pandas/core/internals.py in as_matrix(self, items)
#    3671             return mgr.blocks[0].get_values()
#    3672         else:
# -> 3673             return mgr._interleave()
#    3674
#    3675     def _interleave(self):
#
# ~/.envs/elucd/lib/python3.6/site-packages/pandas/core/internals.py in _interleave(self)
#    3680         dtype = _interleaved_dtype(self.blocks)
#    3681
# -> 3682         result = np.empty(self.shape, dtype=dtype)
#    3683
#    3684         if result.shape[0] == 0:
#
# MemoryError:

# %%
n_samples = 300

# generate spherical data centered on (20, 20)
shifted_gaussian = np.random.randn(n_samples, 2) + np.array([20, 20])

# generate zero centered stretched Gaussian data
C = np.array([[0., -0.7], [3.5, .7]])
stretched_gaussian = np.dot(np.random.randn(n_samples, 2), C)

# concatenate the two datasets into the final training set
X_train = np.vstack([shifted_gaussian, stretched_gaussian])

# fit a Gaussian Mixture Model with two components
clf = mixture.GaussianMixture(n_components=2, covariance_type='full')
clf.fit(X_train)

# display predicted scores by the model as a contour plot
x = np.linspace(-20., 30.)
y = np.linspace(-20., 40.)
X, Y = np.meshgrid(x, y)
XX = np.array([X.ravel(), Y.ravel()]).T
Z = -clf.score_samples(XX)
Z = Z.reshape(X.shape)

CS = plt.contour(X, Y, Z, norm=LogNorm(vmin=1.0, vmax=1000.0),
                 levels=np.logspace(0, 3, 10))
CB = plt.colorbar(CS, shrink=0.8, extend='both')
plt.scatter(X_train[:, 0], X_train[:, 1], .8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-160ff510a6df> in <module>()
#       1 km = kmeans(h1b.lca_case_wage_rate_from.values, 2)
# ----> 2 centroids = [cent for (cent,var) in km]   # cluster centroids
#       3
#       4 D_k = [np.abs(h1b.lca_case_wage_rate_from.values - cent) for cent in centroids]
#       5
#
# <ipython-input-57-160ff510a6df> in <listcomp>(.0)
#       1 km = kmeans(h1b.lca_case_wage_rate_from.values, 2)
# ----> 2 centroids = [cent for (cent,var) in km]   # cluster centroids
#       3
#       4 D_k = [np.abs(h1b.lca_case_wage_rate_from.values - cent) for cent in centroids]
#       5
#
# TypeError: 'numpy.float64' object is not iterable
